# %% [markdown]
# # Advent of Code

# %% [markdown]
# ## 2023-012-005
# ## 2023 005

# %% [markdown]
# https://adventofcode.com/2023/day/5

# %%
def parse_input(file_path):
    """
    Parses the input file and extracts the seeds and maps.
    Returns the seeds as a list and a list of maps.
    """
    with open(file_path, 'r') as file:
        lines = file.readlines()

    seeds = []
    maps = []
    current_map = []

    for line in lines:
        line = line.strip()
        if line.startswith("seeds:"):
            seeds = list(map(int, line.replace("seeds:", "").strip().split()))
        elif "map:" in line:
            # Start of a new map
            if current_map:
                maps.append(current_map)
                current_map = []
        elif line:
            # Line contains map data
            current_map.append(list(map(int, line.split())))

    if current_map:
        maps.append(current_map)

    return seeds, maps


def process_mapping(value, mapping):
    """
    Processes a single value through a map.
    If the value falls within a source range in the map, it is mapped to the corresponding
    destination range. If not, it maps to itself.
    """
    for dest_start, source_start, length in mapping:
        if source_start <= value < source_start + length:
            offset = value - source_start
            return dest_start + offset
    return value


def process_all_mappings(seeds, maps):
    """
    Processes each seed through all maps to determine the corresponding location numbers.
    Returns a list of location numbers.
    """
    locations = []
    for seed in seeds:
        value = seed
        for mapping in maps:
            value = process_mapping(value, mapping)
        locations.append(value)
    return locations


# Parse the input
file_path = 'input.txt'
seeds, maps = parse_input(file_path)

# Process the seeds through all mappings
locations = process_all_mappings(seeds, maps)

# Find the lowest location number
lowest_location = min(locations)
lowest_location
# Out:
# 177942185

# %%
def parse_seeds_as_ranges(seed_line):
    """
    Parses the seeds line into a full list of seed numbers by interpreting ranges.
    Each pair in the seed line specifies a range: (start, length).
    """
    seeds = []
    seed_values = list(map(int, seed_line.replace("seeds:", "").strip().split()))
    for i in range(0, len(seed_values), 2):
        start, length = seed_values[i], seed_values[i + 1]
        seeds.extend(range(start, start + length))
    return seeds


# Update the parsing logic to handle ranges in the seeds line
def parse_input_with_ranges(file_path):
    """
    Parses the input file, including ranges in the seeds line.
    Returns the expanded seeds and the maps.
    """
    with open(file_path, 'r') as file:
        lines = file.readlines()

    seeds = []
    maps = []
    current_map = []

    for line in lines:
        line = line.strip()
        if line.startswith("seeds:"):
            seeds = parse_seeds_as_ranges(line)
        elif "map:" in line:
            # Start of a new map
            if current_map:
                maps.append(current_map)
                current_map = []
        elif line:
            # Line contains map data
            current_map.append(list(map(int, line.split())))

    if current_map:
        maps.append(current_map)

    return seeds, maps


# Parse the input with the updated seed ranges logic
seeds_with_ranges, maps_with_ranges = parse_input_with_ranges(file_path)

# Process the seeds through all mappings
locations_with_ranges = process_all_mappings(seeds_with_ranges, maps_with_ranges)

# Find the lowest location number
lowest_location_with_ranges = min(locations_with_ranges)
lowest_location_with_ranges

# %%
# Redefine necessary functions and reprocess the input after state reset

def parse_seeds_as_ranges(seed_line):
    """
    Parses the seeds line into a full list of seed numbers by interpreting ranges.
    Each pair in the seed line specifies a range: (start, length).
    """
    seeds = []
    seed_values = list(map(int, seed_line.replace("seeds:", "").strip().split()))
    for i in range(0, len(seed_values), 2):
        start, length = seed_values[i], seed_values[i + 1]
        seeds.extend(range(start, start + length))
    return seeds


def parse_input_with_ranges(file_path):
    """
    Parses the input file, including ranges in the seeds line.
    Returns the expanded seeds and the maps.
    """
    with open(file_path, 'r') as file:
        lines = file.readlines()

    seeds = []
    maps = []
    current_map = []

    for line in lines:
        line = line.strip()
        if line.startswith("seeds:"):
            seeds = parse_seeds_as_ranges(line)
        elif "map:" in line:
            # Start of a new map
            if current_map:
                maps.append(current_map)
                current_map = []
        elif line:
            # Line contains map data
            current_map.append(list(map(int, line.split())))

    if current_map:
        maps.append(current_map)

    return seeds, maps


def process_mapping(value, mapping):
    """
    Processes a single value through a map.
    If the value falls within a source range in the map, it is mapped to the corresponding
    destination range. If not, it maps to itself.
    """
    for dest_start, source_start, length in mapping:
        if source_start <= value < source_start + length:
            offset = value - source_start
            return dest_start + offset
    return value


def process_all_mappings(seeds, maps):
    """
    Processes each seed through all maps to determine the corresponding location numbers.
    Returns a list of location numbers.
    """
    locations = []
    for seed in seeds:
        value = seed
        for mapping in maps:
            value = process_mapping(value, mapping)
        locations.append(value)
    return locations


# File path
file_path = 'input.txt'

# Parse the input with the updated seed ranges logic
seeds_with_ranges, maps_with_ranges = parse_input_with_ranges(file_path)

# Process the seeds through all mappings
locations_with_ranges = process_all_mappings(seeds_with_ranges, maps_with_ranges)

# Find the lowest location number
lowest_location_with_ranges = min(locations_with_ranges)
lowest_location_with_ranges

# %%
def expand_seed_ranges(seed_ranges):
    """
    Expands seed ranges into a list of individual seed numbers.
    Each seed range is represented by a start number and a length.
    """
    expanded_seeds = []
    for start, length in seed_ranges:
        expanded_seeds.extend(range(start, start + length))
    return expanded_seeds

# Updated parsing function
def parse_input(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    seed_ranges = []
    maps = []
    current_map = []

    for line in lines:
        line = line.strip()
        if line.startswith("seeds:"):
            # Each pair in the seeds list describes a range
            seed_ranges = list(map(int, line.replace("seeds:", "").strip().split()))
            seed_ranges = [(seed_ranges[i], seed_ranges[i+1]) for i in range(0, len(seed_ranges), 2)]
        elif "map:" in line:
            # Start of a new map
            if current_map:
                maps.append(current_map)
                current_map = []
        elif line:
            # Line contains map data
            current_map.append(list(map(int, line.split())))

    if current_map:
        maps.append(current_map)

    return seed_ranges, maps

# Main logic to process the input and find the lowest location
seed_ranges, maps = parse_input("input.txt")

# Expand the seed ranges into a list of individual seeds
expanded_seeds = expand_seed_ranges(seed_ranges)

# Process the seeds through the mappings to get their corresponding locations
locations = process_all_mappings(expanded_seeds, maps)

# Find the lowest location number
lowest_location = min(locations)
print(lowest_location)

# %%
def process_range(value, mapping):
    """
    Processes a single range of seed values through a map.
    If the value falls within a source range in the map, it is mapped to the corresponding
    destination range. If not, it maps to itself.
    """
    # Start by assuming the value does not get changed
    new_value = value

    for dest_start, source_start, length in mapping:
        if source_start <= value < source_start + length:
            offset = value - source_start
            new_value = dest_start + offset
            break  # No need to continue once a mapping is found
    return new_value

def process_range_bulk(seed_range, maps):
    """
    Process a whole range of seed values through the mapping chain.
    This will reduce redundant calculations by processing each range instead of individual seeds.
    """
    processed_range = []
    
    for seed_value in range(seed_range[0], seed_range[0] + seed_range[1]):
        value = seed_value
        for mapping in maps:
            value = process_range(value, mapping)
        processed_range.append(value)

    return processed_range


def parse_input(file_path):
    """
    Parses the input file and extracts the seed ranges and maps.
    Returns the seed ranges as a list and a list of maps.
    """
    with open(file_path, 'r') as file:
        lines = file.readlines()

    seed_ranges = []
    maps = []
    current_map = []

    for line in lines:
        line = line.strip()
        if line.startswith("seeds:"):
            # Each pair in the seeds list describes a range
            seed_ranges = list(map(int, line.replace("seeds:", "").strip().split()))
            seed_ranges = [(seed_ranges[i], seed_ranges[i+1]) for i in range(0, len(seed_ranges), 2)]
        elif "map:" in line:
            # Start of a new map
            if current_map:
                maps.append(current_map)
                current_map = []
        elif line:
            # Line contains map data
            current_map.append(list(map(int, line.split())))

    if current_map:
        maps.append(current_map)

    return seed_ranges, maps


# Main logic to process the input and find the lowest location
seed_ranges, maps = parse_input("sample-input.txt")

# Process the seed ranges in bulk through the mappings
processed_locations = []
for seed_range in seed_ranges:
    processed_locations.extend(process_range_bulk(seed_range, maps))

# Find the lowest location number
lowest_location = min(processed_locations)
print(lowest_location)
# Out:
# 46

# %%
def process_range(value, mapping):
    """
    Processes a single range of seed values through a map.
    If the value falls within a source range in the map, it is mapped to the corresponding
    destination range. If not, it maps to itself.
    """
    # Start by assuming the value does not get changed
    new_value = value

    for dest_start, source_start, length in mapping:
        if source_start <= value < source_start + length:
            offset = value - source_start
            new_value = dest_start + offset
            break  # No need to continue once a mapping is found
    return new_value

def process_range_bulk(seed_range, maps):
    """
    Process a whole range of seed values through the mapping chain.
    This will reduce redundant calculations by processing each range instead of individual seeds.
    """
    processed_range = []
    
    for seed_value in range(seed_range[0], seed_range[0] + seed_range[1]):
        value = seed_value
        for mapping in maps:
            value = process_range(value, mapping)
        processed_range.append(value)

    return processed_range


def parse_input(file_path):
    """
    Parses the input file and extracts the seed ranges and maps.
    Returns the seed ranges as a list and a list of maps.
    """
    with open(file_path, 'r') as file:
        lines = file.readlines()

    seed_ranges = []
    maps = []
    current_map = []

    for line in lines:
        line = line.strip()
        if line.startswith("seeds:"):
            # Each pair in the seeds list describes a range
            seed_ranges = list(map(int, line.replace("seeds:", "").strip().split()))
            seed_ranges = [(seed_ranges[i], seed_ranges[i+1]) for i in range(0, len(seed_ranges), 2)]
        elif "map:" in line:
            # Start of a new map
            if current_map:
                maps.append(current_map)
                current_map = []
        elif line:
            # Line contains map data
            current_map.append(list(map(int, line.split())))

    if current_map:
        maps.append(current_map)

    return seed_ranges, maps


# Main logic to process the input and find the lowest location
seed_ranges, maps = parse_input("input.txt")

# Process the seed ranges in bulk through the mappings
processed_locations = []
print(len(seed_ranges))
for seed_range in seed_ranges:
    processed_locations.extend(process_range_bulk(seed_range, maps))

# Find the lowest location number
lowest_location = min(processed_locations)
print(lowest_location)
# Out:
# 10

# %%
import time
from tqdm import tqdm

def process_range(value, mapping):
    """
    Processes a single range of seed values through a map.
    If the value falls within a source range in the map, it is mapped to the corresponding
    destination range. If not, it maps to itself.
    """
    new_value = value
    for dest_start, source_start, length in mapping:
        if source_start <= value < source_start + length:
            offset = value - source_start
            new_value = dest_start + offset
            break  # No need to continue once a mapping is found
    return new_value

def process_range_bulk(seed_range, maps):
    """
    Process a whole range of seed values through the mapping chain.
    This will reduce redundant calculations by processing each range instead of individual seeds.
    """
    processed_range = []
    
    for seed_value in range(seed_range[0], seed_range[0] + seed_range[1]):
        value = seed_value
        for mapping in maps:
            value = process_range(value, mapping)
        processed_range.append(value)

    return processed_range


def parse_input(file_path):
    """
    Parses the input file and extracts the seed ranges and maps.
    Returns the seed ranges as a list and a list of maps.
    """
    with open(file_path, 'r') as file:
        lines = file.readlines()

    seed_ranges = []
    maps = []
    current_map = []

    for line in lines:
        line = line.strip()
        if line.startswith("seeds:"):
            seed_ranges = list(map(int, line.replace("seeds:", "").strip().split()))
            seed_ranges = [(seed_ranges[i], seed_ranges[i+1]) for i in range(0, len(seed_ranges), 2)]
        elif "map:" in line:
            if current_map:
                maps.append(current_map)
                current_map = []
        elif line:
            current_map.append(list(map(int, line.split())))

    if current_map:
        maps.append(current_map)

    return seed_ranges, maps


# Main logic to process the input and find the lowest location
start_time = time.time()  # Start the timer

seed_ranges, maps = parse_input("sample-input.txt")

# Process the seed ranges in bulk through the mappings, with a progress bar
processed_locations = []
for seed_range in tqdm(seed_ranges, desc="Processing seed ranges", unit="range"):
    processed_locations.extend(process_range_bulk(seed_range, maps))

# Find the lowest location number
lowest_location = min(processed_locations)

end_time = time.time()  # End the timer
elapsed_time = end_time - start_time

# Print the result along with the elapsed time
print(f"Lowest location number: {lowest_location}")
print(f"Time taken: {elapsed_time:.9f} s")  # Print with high precision (up to nanoseconds)
# Out:
# Processing seed ranges: 100%|█████████████████████████████████████████████████████████████████| 2/2 [00:00<?, ?range/s]
# Lowest location number: 46
# Time taken: 0.146933079 s

# %%
import time
from tqdm import tqdm

def process_range(value, mapping):
    """
    Processes a single range of seed values through a map.
    If the value falls within a source range in the map, it is mapped to the corresponding
    destination range. If not, it maps to itself.
    """
    new_value = value
    for dest_start, source_start, length in mapping:
        if source_start <= value < source_start + length:
            offset = value - source_start
            new_value = dest_start + offset
            break  # No need to continue once a mapping is found
    return new_value

def process_range_bulk(seed_range, maps):
    """
    Process a whole range of seed values through the mapping chain.
    This will reduce redundant calculations by processing each range instead of individual seeds.
    """
    processed_range = []
    
    for seed_value in range(seed_range[0], seed_range[0] + seed_range[1]):
        value = seed_value
        for mapping in maps:
            value = process_range(value, mapping)
        processed_range.append(value)

    return processed_range


def parse_input(file_path):
    """
    Parses the input file and extracts the seed ranges and maps.
    Returns the seed ranges as a list and a list of maps.
    """
    with open(file_path, 'r') as file:
        lines = file.readlines()

    seed_ranges = []
    maps = []
    current_map = []

    for line in lines:
        line = line.strip()
        if line.startswith("seeds:"):
            seed_ranges = list(map(int, line.replace("seeds:", "").strip().split()))
            seed_ranges = [(seed_ranges[i], seed_ranges[i+1]) for i in range(0, len(seed_ranges), 2)]
        elif "map:" in line:
            if current_map:
                maps.append(current_map)
                current_map = []
        elif line:
            current_map.append(list(map(int, line.split())))

    if current_map:
        maps.append(current_map)

    return seed_ranges, maps


# Main logic to process the input and find the lowest location
start_time = time.time()  # Start the timer

seed_ranges, maps = parse_input("input.txt")

# Process the seed ranges in bulk through the mappings, with a progress bar
processed_locations = []
for seed_range in tqdm(seed_ranges, desc="Processing seed ranges", unit="range"):
    processed_locations.extend(process_range_bulk(seed_range, maps))

# Find the lowest location number
lowest_location = min(processed_locations)

end_time = time.time()  # End the timer
elapsed_time = end_time - start_time

# Print the result along with the elapsed time
print(f"Lowest location number: {lowest_location}")
print(f"Time taken: {elapsed_time:.9f} s")  # Print with high precision (up to nanoseconds)
# Out:
# Processing seed ranges:   0%|                                                                | 0/10 [00:00<?, ?range/s]

# %%
def process_range(value, mapping):
    """
    Processes a single range of seed values through a map.
    If the value falls within a source range in the map, it is mapped to the corresponding
    destination range. If not, it maps to itself.
    """
    new_value = value
    for dest_start, source_start, length in mapping:
        if source_start <= value < source_start + length:
            offset = value - source_start
            new_value = dest_start + offset
            break  # No need to continue once a mapping is found
    return new_value

def process_range_bulk(seed_range, maps):
    """
    Process a whole range of seed values through the mapping chain.
    This will reduce redundant calculations by processing each range instead of individual seeds.
    """
    processed_range = []
    
    for seed_value in range(seed_range[0], seed_range[0] + seed_range[1]):
        value = seed_value
        for mapping in maps:
            value = process_range(value, mapping)
        processed_range.append(value)

    return processed_range


def parse_input(file_path):
    """
    Parses the input file and extracts the seed ranges and maps.
    Returns the seed ranges as a list and a list of maps.
    """
    with open(file_path, 'r') as file:
        lines = file.readlines()

    seed_ranges = []
    maps = []
    current_map = []

    for line in lines:
        line = line.strip()
        if line.startswith("seeds:"):
            seed_ranges = list(map(int, line.replace("seeds:", "").strip().split()))
            seed_ranges = [(seed_ranges[i], seed_ranges[i+1]) for i in range(0, len(seed_ranges), 2)]
        elif "map:" in line:
            if current_map:
                maps.append(current_map)
                current_map = []
        elif line:
            current_map.append(list(map(int, line.split())))

    if current_map:
        maps.append(current_map)

    return seed_ranges, maps


# Main logic to process the input and find the lowest location
seed_ranges, maps = parse_input("input.txt")

# Process the seed ranges in bulk through the mappings
processed_locations = []
print(f"Total seed ranges: {len(seed_ranges)}")  # Print total number of seed ranges
for idx, seed_range in enumerate(seed_ranges):
    processed_locations.extend(process_range_bulk(seed_range, maps))
    print(f"Finished processing seed range {idx + 1} / {len(seed_ranges)}")

# Find the lowest location number
lowest_location = min(processed_locations)
print(f"Lowest location number: {lowest_location}")
# Out:
# Total seed ranges: 10

# %%
import time
from tqdm import tqdm

def process_range(value, mapping):
    """
    Processes a single value through a map. 
    If the value falls within a source range, it is mapped to the corresponding destination range.
    """
    for dest_start, source_start, length in mapping:
        if source_start <= value < source_start + length:
            offset = value - source_start
            return dest_start + offset
    return value  # If no mapping, return the value as is

def process_range_bulk(seed_range, maps):
    """
    Processes all values in a range by applying the mappings to each value.
    Instead of storing all processed values, the minimum location is tracked during the process.
    """
    min_location = float('inf')  # Start with an infinitely large value
    
    # Process each value in the range and track the minimum location
    for seed_value in range(seed_range[0], seed_range[0] + seed_range[1]):
        value = seed_value
        for mapping in maps:
            value = process_range(value, mapping)
        # Track the minimum value (location)
        if value < min_location:
            min_location = value

    return min_location


def parse_input(file_path):
    """
    Parses the input file and extracts the seed ranges and maps.
    Returns the seed ranges as a list and a list of maps.
    """
    with open(file_path, 'r') as file:
        lines = file.readlines()

    seed_ranges = []
    maps = []
    current_map = []

    for line in lines:
        line = line.strip()
        if line.startswith("seeds:"):
            seed_ranges = list(map(int, line.replace("seeds:", "").strip().split()))
            seed_ranges = [(seed_ranges[i], seed_ranges[i+1]) for i in range(0, len(seed_ranges), 2)]
        elif "map:" in line:
            if current_map:
                maps.append(current_map)
                current_map = []
        elif line:
            current_map.append(list(map(int, line.split())))

    if current_map:
        maps.append(current_map)

    return seed_ranges, maps


# Main logic to process the input and find the lowest location
start_time = time.time()  # Start the timer

seed_ranges, maps = parse_input("input.txt")

# Initialize tqdm with the number of ranges
total_ranges = len(seed_ranges)

# Process seed ranges in bulk, tracking the minimum location directly
min_location = float('inf')
for idx, seed_range in enumerate(tqdm(seed_ranges, desc="Processing seed ranges", unit="range")):
    min_location = min(min_location, process_range_bulk(seed_range, maps))

end_time = time.time()  # End the timer
elapsed_time = end_time - start_time

# Print the result along with the elapsed time
print(f"Lowest location number: {min_location}")
print(f"Time taken: {elapsed_time:.9f} s")  # Print with high precision (up to nanoseconds)
# Out:
# Processing seed ranges:  10%|█████▏                                              | 1/10 [22:50<3:25:30, 1370.05s/range]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 75
#      73 min_location = float('inf')
#      74 for idx, seed_range in enumerate(tqdm(seed_ranges, desc="Processing seed ranges", unit="range")):
# ---> 75     min_location = min(min_location, process_range_bulk(seed_range, maps))
#      77 end_time = time.time()  # End the timer
#      78 elapsed_time = end_time - start_time
#
# Cell In[1], line 26, in process_range_bulk(seed_range, maps)
#      24 value = seed_value
#      25 for mapping in maps:
# ---> 26     value = process_range(value, mapping)
#      27 # Track the minimum value (location)
#      28 if value < min_location:
#
# Cell In[1], line 10, in process_range(value, mapping)
#       5 """
#       6 Processes a single value through a map.
#       7 If the value falls within a source range, it is mapped to the corresponding destination range.
#       8 """
#       9 for dest_start, source_start, length in mapping:
# ---> 10     if source_start <= value < source_start + length:
#      11         offset = value - source_start
#      12         return dest_start + offset
#
# KeyboardInterrupt:

# %% [markdown]
# # Advent of Code

# %% [markdown]
# ## 2023-012-010
# ## 2023 010

# %% [markdown]
# https://adventofcode.com/2023/day/10

# %%
# Parsing the input and implementing the logic to solve the maze problem
# Importing necessary libraries
import numpy as np
from collections import deque

# Read the uploaded input file
file_path = 'sample-input.txt'
with open(file_path, 'r') as f:
    input_data = f.read().splitlines()

# Initialize the grid
grid = np.array([list(line) for line in input_data])

# Define the directions for traversal
DIRECTIONS = {
    '|': [(0, -1), (0, 1)],  # vertical
    '-': [(-1, 0), (1, 0)],  # horizontal
    'L': [(0, -1), (-1, 0)],  # north and east
    'J': [(0, -1), (1, 0)],  # north and west
    '7': [(0, 1), (1, 0)],   # south and west
    'F': [(0, 1), (-1, 0)],  # south and east
}

# Locate the starting position
start_position = None
for r in range(grid.shape[0]):
    for c in range(grid.shape[1]):
        if grid[r, c] == 'S':
            start_position = (r, c)
            break
    if start_position:
        break

# BFS to find the loop and distances
def find_loop_and_distances(start, grid):
    queue = deque([(start, 0)])
    visited = set()
    distances = {}

    while queue:
        (x, y), dist = queue.popleft()
        if (x, y) in visited:
            continue
        visited.add((x, y))
        distances[(x, y)] = dist

        current_pipe = grid[x, y]
        if current_pipe == 'S':
            current_pipe = 'F'  # Assumption based on the problem statement

        for dx, dy in DIRECTIONS.get(current_pipe, []):
            nx, ny = x + dx, y + dy
            if 0 <= nx < grid.shape[0] and 0 <= ny < grid.shape[1] and grid[nx, ny] != '.':
                queue.append(((nx, ny), dist + 1))

    return distances

# Find the loop and distances
distances = find_loop_and_distances(start_position, grid)

# Find the farthest point in the loop
farthest_distance = max(distances.values())

farthest_distance
# Out:
# 7

# %%
import numpy as np
from collections import deque

def is_valid_position(x, y, grid):
    """Check if a position is within bounds and not ground."""
    return 0 <= x < grid.shape[0] and 0 <= y < grid.shape[1] and grid[x, y] != '.'

def mark_loop(grid, start, directions):
    """Identify the loop in the grid and return a grid with non-loop parts replaced with '.'."""
    queue = deque([start])
    visited = set()
    loop_grid = np.full(grid.shape, '.', dtype=str)

    while queue:
        x, y = queue.popleft()
        if (x, y) in visited:
            continue
        visited.add((x, y))
        loop_grid[x, y] = grid[x, y]

        current_pipe = grid[x, y]
        if current_pipe == 'S':
            current_pipe = 'F'  # Treat 'S' as a connected pipe

        for dx, dy in directions.get(current_pipe, []):
            nx, ny = x + dx, y + dy
            if is_valid_position(nx, ny, grid) and (nx, ny) not in visited:
                # Ensure connectivity matches in both directions
                reverse_dx, reverse_dy = -dx, -dy
                neighbor_pipe = grid[nx, ny]
                if neighbor_pipe == 'S':
                    neighbor_pipe = 'F'
                if (reverse_dx, reverse_dy) in directions.get(neighbor_pipe, []):
                    queue.append((nx, ny))

    return loop_grid

def loop_to_string(loop_grid):
    """Convert the loop grid to a string representation with '.' for non-loop parts."""
    return '\n'.join(''.join(row) for row in loop_grid)

def find_start(grid):
    """Locate the starting position in the grid."""
    for r in range(grid.shape[0]):
        for c in range(grid.shape[1]):
            if grid[r, c] == 'S':
                return r, c

# Define the direction mappings
DIRECTIONS = {
    '|': [(-1, 0), (1, 0)],  # vertical: north and south
    '-': [(0, -1), (0, 1)],  # horizontal: west and east
    'L': [(-1, 0), (0, 1)],  # north and east
    'J': [(-1, 0), (0, -1)],  # north and west
    '7': [(1, 0), (0, -1)],   # south and west
    'F': [(1, 0), (0, 1)],    # south and east
    'S': [(-1, 0), (1, 0), (0, -1), (0, 1)]  # Start pipe connects in all directions
}

# Parse the files and process
def parse_and_print_loops(file_path):
    with open(file_path, 'r') as file:
        data = file.read().splitlines()

    grid = np.array([list(row) for row in data])
    start = find_start(grid)
    loop_grid = mark_loop(grid, start, DIRECTIONS)
    print(loop_to_string(loop_grid))

# Example usage:
# For sample input
print("Sample Loop:")
parse_and_print_loops('sample-input.txt')

# For full input
print("\nFull Loop:")
parse_and_print_loops('input.txt')
# Out:
# Sample Loop:
# ..F7.
# .FJ|.
# SJ.L7
# |F--J
# LJ...
#
# Full Loop:
# .............................................................................................F----7.........................................
# ...............................................F7............................................L---7L7........................................
# .............................................F-J|................................................|FJ........................................
# .............................................|F7|...F7..........................................FJ|.........................................
# ...........................................F-J|LJF--J|........................................F-JFJ.........................................
# ...........................................L7FJ.FJF--J........................................L-7|..........................................
# ............................................|L--JFJF7...F7.F7.................................F-JL-7.F7.....................................
# ...........................................FJF-7FJ.||.F-JL7||......................F7..F7.....L-7F-JFJL7....................................
# .........................................F7L7|.LJ.FJL7L--7LJL7.....................|L7FJL7F-7F--JL-7L7FJ....................................
# ....................................F7..FJ|FJL7...L-7L7F7|F--J....................FJFJ|F-JL7|L----7L-J|.....................................
# ................................F7..||F7L7LJF7L-7F7.|FJ||||F7.....................L7|FJL-7FJ|F7F--JF--J.....................................
# ...............................FJ|..||||FJF-JL--J||FJL-J||||L7F7...................||L7F-JL7|||L7F-JF7......................................
# ..........................F7...L7L7FJ||||FJF--7F7||L---7||LJFJ||...F7...F7.........|L-JL---J|||FJL-7|L-7....................................
# ..........................||F--7L7|L7|||||.|F-J|||L7F7FJ||F-JFJL7F7||F-7|L7........L-------7LJ|L7F-JL7FJ....................................
# ......................F-7FJ|L-7L7|L-J||LJL-J|F7||L7|||L7|||F7|F-J|||LJFJ|FJ.....F-----7F-7.|F-J.||F7.||.F7...F7.............................
# .....................FJFJL7|F7|FJL--7|L-7F7FJ||||.||||FJLJ|||||F7|LJF-JFJL7..F7.L----7|L7|FJL-7FJLJL7||FJL-7.|L-7...........................
# .....................L7L--J|||||F7F-JL-7LJ|L-JLJL7|||||F--J||||||L7FJ..|F-J..||....F-JL-J||F--JL7F-7||||F--J.|F-J...........................
# ......................L7F-7LJ|||||L--7FJF7|F7F---J|||LJL7.FJ||LJL-J|F7FJ|.F7.|L7.F7L----7LJL-7F7LJFJ||||L7F7FJL--7..........................
# .......................LJFJF7LJLJ|F7.||FJ|||LJF-7.||L--7L7L7|L7F-7FJ||L7L7|L7|FJFJ|F7F-7L7F--J|L-7L7||||FJ|||F--7|F7........................
# .......................F-JFJL7F-7|||FJ|L7||L7FJFJFJL---JFJ.|L7||.LJFJL7L7||FJ|L7L7|||L7|.||.F7L7FJFJLJLJL-JLJL7.LJ||F---7...................
# .......................L--JF7LJ.||||L7|FJLJFJL7L7L--7F7FJF7L7LJL--7L7FJFJLJ|.L7L7||||FJL7|L7|L7||FJF-7F-7F7F7FJ..FJ||F--J...................
# ..............F7......F---7||F-7|LJ|FJ|L-7FJF7L7L7F7LJ||FJ|FJF----JFJ|.L7F-JF7|FJ||||L-7||FJ|FJ|LJFJ.LJ.LJLJLJF-7L7LJL7.....................
# ...........F7FJ|.F7...L--7|||L7|L7FJL7L--JL7||FJFJ||F7||L7||FJF7F7.L7|F7|L-7|||L-JLJ|F7|||L7||.L-7|.F---7F--7.L7|FJF-7L7....................
# ...........||L7L7||F---7FJLJ|FJL7||F7L---7FJ||L7L-J|||||.|||L7|LJL7FJ||||F-J|||F--7FJ||||L7||L7F7|L7|F--J|F-JF7||L7|.L-J....................
# .........F7||.|FJ|||F--JL7F7LJF7LJ||L7F-7|L-J|FJF--J|LJ|FJLJFJL7F7||FJ||||F7||LJF7||FJLJ|FJ||FJ|LJFJ||F-7|L--J|||FJL----7...................
# .........|LJL7|L7|||L7.F7LJL7FJL-7|L7|L7LJF--J|FJ.F7L7FJL7F7L7.||LJ|L-JLJ||||L7FJ|||L--7|L7||L7|F-JFJ|L7||F---J|||F7F---J...................
# .........L--7|L7|||L7|FJL7F7LJF7.||.||.L7FJ.F7|L7FJ|FJ|F7||L-JFJ|F7|F----J|LJFJL7|||F7FJL7||L7||L7.L7|.|LJL--7.||||LJ.F7F7..................
# .......F----J|.||||.|||F-J||.FJL-J|FJ|F7|L--JLJFJL7|L7LJ|||F7FJFJ|LJL-7F7FJF-JF7||||||L-7|||FJ|L7L7FJL7|F----JFJLJL7F-JLJ|..................
# .......L7F7F7L-JLJL7|||L-7||FJF--7|L7|||L7F--7FJ..||.|F-J||||L7L-JF--7|||L7L-7|||||||L--JLJLJFJFJFJL7FJ|L-7F7FJF7F7LJF---J....F7............
# ........LJLJL---7F-J|||F-J||L-JF-J|FJLJL-J|F7LJF7FJL-JL7FJ||L7L--7L-7LJ||.|F-J|||||||F7F-7F--J.L7|F7|L-JF-J||L7|LJ|F-JF---7F--J|............
# .........F7.F--7||F7|||L-7|L---JF7|L--7F-7LJL--J|L--7F7LJFJ|FJF-7L-7L7.||FJ|F7|||LJ|LJLJFJ|F-7F-JLJLJF--JF-J|FJL7.LJF7|F--J|F--J............
# ........FJL-JF7LJLJLJ||F-JL-----J||F7.LJFJF7F7F-JF7.LJL-7|FJL-JFJF7|FJFJ|L7|||||L-7L7F-7L7||FJL--7F--JF7.L-7||F-JF--JLJL-7.|L----7..........
# .......FJF7F-JL-7F7F7|||F7F-7F7F-JLJ|F-7L7|LJLJF-JL-7F7FJ|L---7L7||||FJFJ.|||||L-7|FJL7|FJLJL7F7.|L-7.|L7F7|LJL-7L7F-----JFJF----J..........
# .......L7|LJ.F7FJ|LJ|||||||FJ||L--7FJL7L-J|F--7L-7F-J|||FJF--7|FJ|LJ||FJF7|||||F-J|L7FJ||F---J|L7L-7|FJFJ|||F--7L-JL7.F7F7|FJF7F7...........
# ........LJ.F7||L7|F-J||||LJ|FJL7F-J|F7L--7||F-JF7||F7||||.|F-J||.|F-J||.||||||||F7L7||FJ||F7F7L7|F7|||FJ.|LJL-7L--7FJFJLJLJL-JLJ|...........
# .........F-JLJL7LJL-7LJ||F-JL7FJL-7LJL7F7|LJL7FJ|||||||||FJ|F7||FJL7FJL7|LJ||||LJ|FJ||L7|||LJ|FJ||||LJ|F-JF---J.F7LJFJF7F--7F--7|...........
# .........L----7|F7F7L-7LJ|.F-JL7F7L-7FJ|||.F-JL7||||||LJ||.LJ||||F7|L7FJ|F-J|||.FJL7|L7|||L-7||FJ||L7FJ|F-JFS.F-JL7FJFJ|L-7|L-7||...........
# ......F7.F----JLJLJL--JF7L7|F7FJ||F-JL-J||FJF7FJLJLJ|L7.|L--7|||LJ||FJL7|L7FJ||FJF7||FJLJ|F-JLJ|FJL7|L7|L7FJL7|F-7LJFJ.L--JL--JLJ...........
# .....FJL-JF7F----7F----JL7|LJ||FJ|L7F7F7|||FJ|L-7F--JFJFJF7FJLJL7FJLJF7|L7LJFJ||FJ|||L7F-JL--7FJL-7||.||.LJF7LJL7L--JF7.F-7F-7..............
# .....L---7|LJF---J|F-----J|F7||L7L-J||||LJ||FJF7||F7FJ.L7|||F---JL---J|L-JF-JFJ||FJ|L7|L7F7F7|L7F7|||FJ|F--JL-7FJ.F7.|L-JFJ|FJ.....F7.......
# .....F--7LJ.FJF7F7||F7F7F7LJLJL-JF--JLJL-7|||FJ||||||F--J|LJ|F7F7F-7F7|.F-JF7|.||L7L7||FJ||||L7||||||L7|L----7LJF-J|FJF--J.|L---7..|L7......
# .....|F7L---JFJ||LJLJLJLJL7F7F7F7L7F-7F-7|||||FJ|||LJL7F7L7.LJ|||L7|||L7|F7|LJFJL7L-J||L7|||L7|LJ||||.LJ.F---JF7L-7LJFJ.F--JF---JF7|FJ......
# .....LJ|F---7L7LJ.F------7||||||L-J|.LJ.||||LJL7||L-7FJ||FJF--J||FJ||L7|||LJF-JF7L--7LJFJ||L7|L-7LJLJF---JF--7|L-7|F-J.FJF--J.F7.|LJ|.......
# .......|L7F7|FJ.F-JF7F7F7LJ|LJLJ.F7L---7|||L--7|||F-JL7||L7|F7FJ||FJL7|||L7FJF7||F7FJF7L7|L7|L--JF7.FJF7F7|F-J|F7||L--7L7L----JL7L-7L-7.....
# ......FJFJ|LJ|F7L--JLJLJL-7|F-7F-J|F7F-JLJL-7FJLJ|L7F-J||FJ|||L7LJL7FJLJL7|L7|||LJ|L-JL7||FJ|F---JL7L-JLJLJL7FJ|LJ|F--JFJF7F--7FJ..|F-J.....
# ......L7|FJF-J|L---7F7F7F7LJL7|L-7LJLJF----7|L--7L7||F7||L7LJL7|F--JL7F-7||FJ|LJF-JF7F-J||L7|L7F--7L--------J|FJF7|L7F7|FJLJF7LJF7FJL--7....
# .......LJL-JF7L---7LJLJLJL---J|F7L----JF7F-J|F--JFJ|LJLJL7L7F7LJL-7F7|L7LJ|L7L-7|F7||L-7LJFJ|FJ|F7L7F--------JL-JLJFJ||||.F7||F7|||F---J....
# ........F---JL7F--JF-----7F7F7LJL-----7||L7FJL--7L7L---7.L7LJ|F---J|LJ.L-7L7|F-JLJ|||F7L-7L-JL-J|L-J|F-------------JFJLJL7|||||||||L7.......
# ........|F-7F7LJF--JF--7.LJLJ|F7F7F7F7LJ|FJL----J.|F7F-JF7|F-JL7F-7L----7L7||L--7FJ|||L--JF-----JF--JL-----7F7F---7FJF--7LJLJLJLJLJFJ.......
# .......FJ|.LJL-7|F--JF7L7F7.FJ|||LJLJL-7LJ.F-----7LJ||F-JLJ|.F7||FJF7F-7|FJ||F7FJL7||L---7|F7F-7FJF-7F----7|||L-7FJL7|F7L---------7L7.......
# .......L7|F--7FJ|L7F7|L7LJL-JFJLJF-----JF-7L7F---JF7LJL-7F7|FJLJ||FJ|L7|||FJ||||F7LJ|F--7|||||.LJ.L7|L-7F7|LJL--JL--JLJ|F--7F7.F-7L-J.......
# ........LJ|F7LJFJFJ|LJ.L--7F7|F7.L---7F7L7L-JL----J|F-7FJ|LJ|F--J||FJFJ||LJFJ|LJ|L--JL-7||LJLJF7.F7|L-7LJ||F--7F7F7F7F7LJF7LJL-JFJ..........
# ..........||L7FJ.L7|F-----J|LJ|L--7F7LJL-JF--------J|FJL7|.FJL-7FJ|L7L7|L-7L7L-7|F--7F-JLJF-7FJL7||L-7L--JLJF7||LJLJLJL7FJL7F7F7|F7.........
# ..........LJ.|L--7LJL-----7L-7L7F7LJL--7F7L-----7F--JL7FJL7|F-7|L7|FJFJL--JFJF-J||.FJL-7F7L7LJF7LJL-7|F-----J||L------7|L-7|||||LJL-7.......
# ..........F--JF7FJ.F7.F7F-JF-J.LJL----7LJL7F7F--J|F-7FJL-7|||.||FJ|L7|F7F--JFJF7LJFJF7FJ|L7L-7|L---7|LJF-----JL-------JL7FJLJ|||F---J.......
# ..........L-7FJLJ.FJL-J|L-7L-7F-------J.F7|||L---JL7LJF-7LJ||.|||FJFJ|||L7F7L-J|F-JFJLJ.L7L-7LJF---JL7.L-----7F-7.F7.F7.LJ.F7|||L----7......
# ............||F---JF7F7L--JF-JL------7.FJ|||L7F-7F-JF-JFJF-JL7LJ||.|FJ|L-J||F7FJL-7L7F-7.L-7L-7L7F7F7L7F7F---J|FJFJL-JL---7|||||F----J......
# ............||L----JLJL7F--JF-------7|FJFJLJ.LJ.LJF7|F-J.L-7FJF7LJ.||.|F7FJ||LJ.F7|FJL7L---JF7L7LJLJL7LJ||F--7||FJF7F7F7F7LJ||||L-7.........
# ............LJF7F-7F7F7LJF7.L7F----7LJ|FJF7..F7F7.|LJL7F7F7LJ.|L-7FJ|FJ|LJ.|L7F-JLJ|F7L---7FJL7L---7FJF7LJ|F-J|LJFJ||LJ||L7FJ||L--J.........
# ...........F7.||L7LJ||L--JL7.LJF7.FJ.FJ|.|L7FJLJL7|F--J||||.F-JF-JL-JL7L--7|FJL-7F-J||.F7FJ|F-JF--7|L7||F-JL--JF7L7||F7LJ.LJ.|L--7..........
# ...........|L-JL-JF7|L---7FJF7FJL7L-7|FJFJFJ|F---J||.F7|LJL7|F7L7F-7..L7F-J||F7FJ|F-JL-JLJFJL--JF-JL7||LJF-----JL-JLJ|L-----7|F7FJ..........
# ...........L------J|L-7F-JL7|||F7L--J|L7|FJ.||F7F7|L7|||F7FJ||L-J|FJ.F-JL7FJ||LJFJL7F7F7F7|F---7L--7LJ|F-JF------7F7.L7F----JLJLJ...........
# ............F-7F---JF7|L--7LJ|LJL----JFJ||F-JLJLJ||FJ||||LJFJL7.FJ|..L-7FJL7|L-7L7FJ|||LJLJL--7L-7.L--JL--JF----7LJL--JL---7................
# ............L7LJF7F-J||.F7L-7|F7.F7F-7L-JLJF7F7F7||L-JLJL--JF7L-JFJ....LJ..LJ..L-JL-JLJ.F7F7F7L-7|F7F------JF7F7L----------J................
# .............L7FJLJF-JL-JL--JLJL-JLJ.L-7F--JLJ||LJ|F7F7F-7F7|L--7L-7..........F7F7.F----JLJ||L--JLJLJF------JLJL---7F------7................
# ..............LJ.F7L-7F--7F---7F7F-7F-7|L----7LJF7||LJ|L7|||L--7L7FJ.......F--JLJL7L------7|L--------J.F----7F7F7F7LJF7F---J................
# .............F7F7||F-J|F-JL7F-J|||.LJFJL7F7F-JF7|LJ|F7L-JLJL-7FJ.LJ........L7F---7|F-7F---JL-7.F--7F7F7L---7LJLJLJL--JLJF7F7.F7F7...........
# ............FJLJLJLJF-JL-7FJL7FJ||F-7L-7||||F-J|L-7LJL-7F7F-7||.............||.F-J||FJL---7F7L-JF7LJLJ|.F--J.F7.F----7F7|LJL-JLJ|...........
# ............L7F7F-7FJF---J|F-JL7LJL7L--JLJLJL-7L--JF7F-J|||FJLJ.............LJ.L7FJ|L7F7F7LJL7F7|L7F-7L7L---7|L7L7F--J|LJF7F----J...........
# .............LJ||.LJ.L----JL---JF7.L---7F7F7F7|F7F7|LJF-JLJL--7...............F-JL7L7LJLJ|.F7LJLJ.||.L7|F---J|FJFJL7F-JF-J||F7F7............
# ...............LJF7F7F7.F---7F7FJ|F----J||||||||LJ|L--JF-7F7F7L7..............L-7FJ.L--7FJFJL7F7F-J|F-J|L----JL-JF7LJF7L7.LJ|LJL--7.........
# .................|||||L7L--7LJ|L7|L-----JLJLJLJL-7|F---J.||LJL-J.........F--7.F-JL7F---J|.L-7|||L--JL-7L--7F-7F-7|L7FJL7L7F7|F----J.........
# ...............F-JLJ|L7|.F7L-7|FJL------7F-7F-7F-J|L7.F-7|L--7...........L-7L7L-7FJL---7L7F7||||F-7F7.L--7LJFJL7||.LJF7L7LJLJ|.F--7.........
# ...............L---7L-JL-JL--JLJF7F7F7F7LJ.LJ.|L-7L7L-JFJL-7FJ.............L7L--JL7F7F7|FJ|LJLJ|L7LJ|F7F-JF7|F7||L---JL7L---7L-JF7L--7......
# ...............F7F7L---7F7F--7F-JLJLJLJL---7F7|F7|FJF-7L7F7LJ............F-7|F-7F7LJLJLJL7L---7|FJF7LJLJF-J|||LJ|F--7F7L--7.L--7|L---J......
# ..............FJLJL-7F7LJ||F-J|F------7F-7FJ||LJLJL7L7L7LJL--7...........L7LJ|FJ|L------7|F7F-J|L7|L----JF-JLJF7LJF-J|L--7L7F7.LJ...........
# ..............L--7F7LJL--J|L--J|F----7|L7LJ.|L-7F-7L7L7|F7F-7|............|F7|L-JF7F----JLJ|L-7|.LJF7F--7L---7|L-7L-7L-7.L7LJ|F7F7.F7.......
# ..........F7.F7F7||L--7F7FJF---J|F---JL-JF--JF7LJFJFJFJ||LJ.LJ............|||L7F-JLJF7F---7L--JL7F-JLJF7L--7FJ|F-JF7L--JF7L-7||LJL7|L7......
# .........FJL-J|||LJF7.LJLJ.L----JL-------JF7FJ|F7L7|FJ.LJF7F7.............LJL7|L--7FJLJ.F7L7F7F7LJF-7FJL--7LJ.||F7|L7F-7||F7LJL7F-J|FJF7....
# .........L---7LJL-7||F7.F7F---------7F----J|L7|||FJ|L7F-7||||...........F7...LJF-7LJF---J|.||LJ|F-J.LJ.F7FJF7FJLJ||FJ|FJ|||L7F7|L--JL-J|....
# ............FJF--7|||||FJ|L-----7F-7LJF---7|FJLJLJFJFJ|FJ|||L7F7F7......|L7....L7L-7L-7F7L7||F-JL7F7F--JLJ.|||F--J|L-JL-JLJFJ|||F---7F-J....
# ............|FJF-JLJLJ|L7L---7F-JL7L-7|F--J|L--7F7L-JFJL-J|L7||LJ|......|FJF7..FJF7L--J|L7LJ|L---J|LJF-----JLJL---JF7F7F7F7L-JLJL--7LJ......
# ............||FJF7F7F7L7|F7F7LJF--JF7LJL7F7L---J|L7.FJF--7|FJ||F-J.F7..FJL7|L7.L-JL--7FJ.L7FJ.F---JF7|F---7F7F-7F7FJLJLJ|||F-7F7F-7L--7.....
# ............LJL-JLJ||L7LJ||||F7|.F7||F-7LJL7F---JFJFJFJF7LJL7LJL7F7||F7L7FJL7|F--7F7FJ|F--J|F-JF---JLJL--7LJ|L7|||L--7F7LJLJFJ||L7L---J.....
# ............F7.F--7LJ.L--JLJ||LJFJLJLJ.L---J|F--7L7|FJFJL--7L7F7LJLJ||L-JL-7||L-7LJ||FJL7F7||F7|F---7F---JF7L7||||F--J|L---7|FJL-J.F7.......
# ............||FJF-JF7F7F7F7.LJF7L--7F7F7F7F-JL-7|FJ||FJF---J.LJL7F--JL7F---J|L-7L-7|LJF7||LJLJLJL--7|L----JL7|||||L7F7|F---JLJF7.F7|L7......
# ............||L7|F7|LJLJ||L---J|.F7LJ||LJLJF7F-J||FJ|L7L--7F-7F7||F7..|L7F-7L-7L-7||.FJ|LJF----7F--J|.F7F--7|||||L7||||L------JL7|LJFJ......
# ..........F-JL-J|||L---7|L----7|FJ|F7LJF7F-JLJF7LJL7|.L7F-J|FJ|||||L7FJFJ|FJF7|F7||L7|FJF7L--7FJL--7L7||L-7LJLJLJ.|LJLJF7F-7F---J|F-J.F7....
# ..........L7F7F7LJL7.F-J|F7.F7||L7|||F-J|L----JL7F7|L7.|L-7||FJLJ||FJL7|FJL7||LJ|||FJ|L7|L---JL--7.L7LJL--J.F----7L7F-7|LJ.LJ.F7.||.F7||....
# ...........LJLJL--7L-JF7LJL-JLJL-JLJ|L-7|F7F-7F-J||L7L7|F-J|||F-7|||F7|||F-J|L7FJLJ|FJFJL-7F--7F-JF-JF-7F--7|F---J.LJ.|L---7F7|L-JL-JLJL7...
# .........F7...F---JF7FJL7F---------7L--J|||L7||F7||.|FJ||F7||||.LJ|LJ||LJ|F7|FJL-7FJL7L7F7LJF-JL--JF-J.LJF-J||F-7.F7.FJF7F-J|||F---7F---J...
# .........||F7.L----JLJ..LJF-------7L---7|||FJLJ||||FJL7|LJ||LJL-7FJF-JL-7||LJ|F-7||F7|FJ||F7L--7F-7|.F---J.FJLJFJFJL7|FJLJF-JLJL7F7LJ.......
# .......F7||||F-----7F7.F-7L----7F7L--7FJLJLJF-7|LJLJF-JL-7|L7F--JL7L-7F-J||F-JL7||LJLJL7||||F7.LJFJL7L-----JF-7L-JF-JLJF7.L-7F--J||.F7.F7...
# ......FJ|||||L----7LJL7L7|F7F-7LJL--7|L7.F7FJFJL--7FJF--7|L7|L---7L7FJ|F7LJL7F7||L---7FJ|||||L7F7L--J.F-----J.|F-7|.F7FJ|F-7|L---JL-JL-J|...
# ......L7LJ||L7F---JF-7|FJLJ|L7L-----JL7L-J|L7|F-7.||.|F-JL7LJF---JFJ|.LJL7F7LJ|||F--7||.|||||FJ||F7.F7L--7F7F7LJ.|L-J|L7|L7||F----------J...
# .......L-7||FJL-7F-J.||L--7L-JF-7F-7..L-7FJFJ||FJFJL7|L-7.|F-JF7.FJFJF7..LJ|F-J||L-7|||FJLJLJL7|||L-JL7F-J|LJL-7FJF--JFJL-JLJL-7.F7F----7...
# .......F-JLJL---J|F--JL--7L7F-J.LJ.L7.F7LJFJFJ||FJF-J|F-JFJL-7|L7L7L-JL7F7FJ|F7||F7|LJ|L--7F--J|LJF--7|L-7|F---JL-J.F-JF7F7F7F7L-JLJF7F-J...
# ......FJF-7F-7F--JL---7F7L-J|F7.F7.FJFJL-7L7L7||L7L-7||F-JF7FJL7L7|F---J||L7||LJ||||F-JF7FJ|F7.L--JF7||F7LJL-7F7F7F-JF7||||||||F7F--JLJF7...
# ......L7|FJ|FJ|.F7F---J|L---J|L-JL-J.L7F-J.L7LJL-JF7|||L-7|LJF7L7|||F7F7|L7||L-7|||||F7||L7LJL7F---JLJLJL----J|LJLJF7|LJLJ||||LJ|L----7|L7..
# .......LJL7||FJFJLJF-7FJ.F---JF--7F7F7|L7.F7L--7F7|LJ||.FJ|F7|L-J||LJLJ|L7||L7FJLJ||LJ||L-JF--JL---7F7F7F----7|F-7FJLJF--7LJ||F-JF---7LJFJ..
# ..........LJLJ.|F7FJ.LJF7L7F--JF7LJLJLJFJFJ|F7.LJ||F7|L7L7|||L7F7LJF---J.|LJFJL--7LJF7|L--7L7.F7F7.LJLJ||F---J||.LJF7FJF7L-7|||F7L--7L7FJ...
# ...............LJLJF7F-J|.LJ.F7|L---7F7|FJFJ|L-7FJLJ|L7L-JLJL7LJ|F7L7.F-7L7FJF7F7L-7|LJF--JFJFJLJ|F---7LJL---7|L---JLJFJL--JLJ||L7F7|.LJ....
# ...............F---J|L-7L----JLJF--7LJLJL7|.L-7|L7F-J.L7F----JF7LJL7L7L7|FJ|.|||L-7||F7L--7L7L7F-JL-7FJF--7F7LJF----7FJF----7.LJFJ||L7......
# ...............L---7L7FJF--7F7F7|F7L-7F-7|L7F7||FJ|F---JL7F7F7|L-7.L7L7||L7|FJ|L-7LJLJ|F7FJFJFJ|F7F-J|.L-7LJL-7L---7|L-JF---JF-7L-JL7|......
# ..............F7.F7L7||FJF-J|||LJ|L--JL7||FJ||||L7|L----7||||||F-JF7|FJ||.||L7|F7L-7F-J||L7|.L7|||L7FJF7.L--7.L7F7FJ|F-7L7F7.L7L-7..||......
# ..............||FJL-JLJ|.L-7||L7FJF-7F7||||FJ|||FJ|F7F-7|||||LJL7FJLJL7||FJL7||||F7|L7FJL7|L7FJ||L7|L7|L7F-7|F7LJLJ.LJ.L7LJL7FJF-J..LJ......
# ..............||L7F-7F-JF-7LJL-JL7|FJ|||||||FJ|LJ.LJ||.||||||F--JL7F7.||||F-J|||LJ||FJ|F-J|FJL7LJ.|L7||FJL7|LJL------7F7|F-7||FJ............
# ............F-J|.|L7LJF7L7L------J|L7|LJLJ|||FJF----JL7||||LJ|F7F7LJL7LJ||L7FJ||F-J|L7|L7FJL7FJ.F-JFJ|||F7|L7F-----7FJ||LJ.|LJ|.............
# ..........F7|F7|FJFJ.FJL7|F7F--7F7|FJL--7FJ|||.L7F7F7FJ|||L7FJ|LJL7F7L-7||FJL7||L7FJ.|L7||F-JL-7|F7|FJ|LJ||FJL--7F7LJFJL--7|F-J.............
# ..........|LJ||LJFJF-JF7LJ|||F7||LJL-7F-J|FJLJF-J|||||FJ|L7|L7L7F-J||F7|||L-7|LJFJL-7L7|||L7F7FJ||||L7|F-J|L7F-7LJL--JF7F7||L--7............
# ..........|F-JL7FJ.L--JL-7|LJ|LJ|F---JL-7||F7.|F7||||||FJ.LJ.L-JL7FJ||LJ||F-JL-7L7F-JFJ|LJ.LJ||.LJ||FJ|L7FJFJL7|F7F-7FJLJ|||F7FJ............
# ..........LJF--J|F-------JL-7L7FJL-7F7F-J|||L-J|LJ||||||.F7F-----JL7|L7.LJ|F7F7|FJL-7L7|F7F--JL--7LJL7|.||.L7FJLJ|L7|L--7LJLJ|L7............
# ............|F-7|L7F7F7F7F7FJ.LJF7FJ||L7FJ||F7FJF-J|||||FJLJF-7F7F-J|FJF7FJ|||LJL7F7L7|||LJF-7F7FJ.F-JL7||F-J|F7.L7||F-7L-7..|FJ............
# ............||.LJFJ|||||LJ||F---JLJFJ|FJ|FJ||LJ.L7FJ||LJL--7|FJ|||F-JL-J|L7|||F--J||FJ|||F-J.|||L-7L-7FJLJL-7LJ|F7LJLJ.L-7L7.LJ.............
# ............LJ.F-JFJ||||F7LJL7F--7FJFJ|FJ|FJL-7.FJL7||.F---J||FJ||L7F-7FJFJ|||L7F7||L7LJLJF--J|L7FJF7||F-7F-JF7LJL7.F--7.|FJ................
# ...............L-7|FJ||||L---J|F-JL7L-JL7|L7F7L7L7FJLJFJF7F7|||FJ|FJL7|L7L7|||FJ|||L7L7F--JF7FJFJ|.|LJLJFJL7FJL7F7L-JF7L7LJ.................
# ................FJ|L7|LJL7F7F7|L7F7L--7.LJFJ|L7L7LJF--JFJ|||||||FJ|F7|L-J.||LJL7|||FJFJL--7||L7|FJFJF-7FJF7|L-7|||F-7|L-JF7.................
# ...............FJFJFJ|.F-J||||L7LJ|F--JF-7L7|FJFJF7L7F7|FJ|||||||.LJ|L-7F7|L7F-J|LJ|FJF7F-J||FJLJ.L7|.|L-J||F-JLJ|L7|L---JL-7...............
# ...............L-J.L7L7L7FJ|||FJF-JL7F-JFJ.||L7|FJL-J|LJ|FJLJ||LJF--JF7LJ||FJL-7|F7|L-J|L7FJ|L7F---J|FJF-7|||F7F7|FJ|F7F-7F-J...............
# ....................L7|FJL7LJ||.L--7|L-7L--J|FJ||F-7FJ.FJL--7||F-JF7FJL-7|LJF--J||LJF--J.LJFJFJL-7F7|L7|FJ||LJLJ||L7||||FJL7................
# .....................LJL7FJF-J|F---J|F-JF7F7||FJLJ.LJ.FJF-7FJLJ|F7||L7F7LJF7|F-7||F7L--7.F7L7L7F-J|||FJ|L-J|F7F-JL-J||||L7FJ................
# ........................||.L7FJL-7F7||F7||||||L----7F-JFJ.||F7.LJ||L7LJL-7|LJ|FJ|LJ|F7FJFJ|.|FJL-7|||L7L-7FJ||L----7LJLJ.|L7................
# ........................LJ.FJ|F-7||||||||||||L7F7F7|L7FJF-JLJL-7FJ|FJF7F-JL7FJ|FJF-J||L7L7L-JL7.FJ|||.|F-JL7||F----J.....L-J................
# ...........................|FJL7LJ|||||||||LJ.||||||FJ|.L-7F7F-JL7|L7||L-7FJ|FJL7L-7||FJ.L7F7FJFJFJ||FJL-7FJ||L-7F7.F-7.....................
# ...........................LJF7|F7|||||||||F--J|LJLJL7|F--J|||.F7LJ.|||F7|L7|L7FJF-J||L-7FJ|||FJFJ.||L7F-JL-J|F7LJL7L7|.....................
# ............................FJLJ|||LJLJ||LJL7F7L---7.||L--7||L-JL7.FJ||||L7||FJ|.|F-J|F7||FJLJ|FJF-J|.||F7F--J||F-7L-JL--7..................
# ............................L--7|||F---JL7F7LJ|F---JFJL7F-J|L7F-7|FJFJ||L7|||L7|FJL-7||LJ|L7F-JL7|F7|FJLJ|L--7|||.|F--7F7L7.................
# ...............................|||||F-7F7||L-7|L-7F7L7FJL7FJFJ|FJ|L7|FJL7LJLJ.||L7F7||L-7|FJL7F-JLJLJ|F-7|F--J||L7LJ..||L-J.................
# ..............................FJ|LJLJFJ||||F7LJF7LJL7LJ.FJ|FJFJL-J.LJ|F7L----7LJ.|||||F7|||F-JL--7F--JL7LJ|F7FJL7L-7..LJ....................
# ..............................L-J....|FJLJLJL7FJL7F-JF-7L-JL7|.....F-J|L-----J...LJ||||||||L-7F--JL-7F7L7.LJ||.FJF7L7.......................
# .....................................||..F---JL-7|L--JFJ....LJ.....|F7L----7.......||LJLJLJF-JL-7.F-J|L7|F--JL7L-JL-J.......................
# .....................................LJ.FJF7F7F-JL7F7FJ............LJL7F7F-J.......||......L7F-7|.L-7|.LJL7F-7L--7..........................
# ........................................L7|LJ|L7F7||LJ...............FJ||L-7.......LJ......FJL7LJ.F-JL---7||FJF--J..........................
# .........................................LJF-JFJ|LJL7................L7|L7FJ...............|F-J...L-7F7F7|LJL7L-7...........................
# ...........................................L-7L7L7F7L-7...............LJ.LJ................LJ.......LJLJ||...L7FJ...........................
# ............................................FJFJFJ|L7FJ.................................................LJ...FJL-7..........................
# ............................................L7L7|FJ.||F-7....................................................L-7FJ..........................
# ...........................................F-JFJ|L7.|LJFJ......................................................LJ...........................
# ...........................................L--J.L-J.|F7|....................................................................................
# ....................................................LJLJ....................................................................................

# %%
import numpy as np
from collections import deque

def is_valid_position(x, y, grid):
    """Check if a position is within bounds and not ground."""
    return 0 <= x < grid.shape[0] and 0 <= y < grid.shape[1] and grid[x, y] != '.'

def compute_distances(loop_grid, start, directions):
    """Perform BFS to compute distances along the loop from the starting point."""
    queue = deque([(start, 0)])
    visited = set()
    distances = {}

    while queue:
        (x, y), dist = queue.popleft()
        if (x, y) in visited:
            continue
        visited.add((x, y))
        distances[(x, y)] = dist

        current_pipe = loop_grid[x, y]
        if current_pipe == '.':
            continue  # Ignore non-loop tiles

        for dx, dy in directions.get(current_pipe, []):
            nx, ny = x + dx, y + dy
            if (nx, ny) not in visited and 0 <= nx < loop_grid.shape[0] and 0 <= ny < loop_grid.shape[1]:
                if loop_grid[nx, ny] != '.':
                    queue.append(((nx, ny), dist + 1))

    return distances

def mark_loop_and_number(grid, start, directions):
    """Identify the loop and replace loop parts with the last digit of the distance."""
    loop_grid = mark_loop(grid, start, directions)  # Identify loop parts
    distances = compute_distances(loop_grid, start, directions)  # Compute distances

    numbered_grid = np.full(grid.shape, '.', dtype=str)
    for (x, y), dist in distances.items():
        numbered_grid[x, y] = str(dist % 10)  # Replace with the last digit of the distance

    return numbered_grid

def loop_to_string(loop_grid):
    """Convert the loop grid to a string representation."""
    return '\n'.join(''.join(row) for row in loop_grid)

def find_start(grid):
    """Locate the starting position in the grid."""
    for r in range(grid.shape[0]):
        for c in range(grid.shape[1]):
            if grid[r, c] == 'S':
                return r, c

# Define the direction mappings
DIRECTIONS = {
    '|': [(-1, 0), (1, 0)],  # vertical: north and south
    '-': [(0, -1), (0, 1)],  # horizontal: west and east
    'L': [(-1, 0), (0, 1)],  # north and east
    'J': [(-1, 0), (0, -1)],  # north and west
    '7': [(1, 0), (0, -1)],   # south and west
    'F': [(1, 0), (0, 1)],    # south and east
    'S': [(-1, 0), (1, 0), (0, -1), (0, 1)]  # Start pipe connects in all directions
}

# Parse the files and process
def parse_and_number_loops(file_path):
    with open(file_path, 'r') as file:
        data = file.read().splitlines()

    grid = np.array([list(row) for row in data])
    start = find_start(grid)
    numbered_grid = mark_loop_and_number(grid, start, DIRECTIONS)
    print(loop_to_string(numbered_grid))

# Example usage:
# For sample input
print("Sample Loop with Numbers:")
parse_and_number_loops('sample-input.txt')

# For full input
print("\nFull Loop with Numbers:")
parse_and_number_loops('input.txt')
# Out:
# Sample Loop with Numbers:
# ..45.
# .236.
# 01.78
# 14567
# 23...
#
# Full Loop with Numbers:
# .............................................................................................321098.........................................
# ...............................................43............................................4567876........................................
# .............................................7652................................................945........................................
# .............................................8781...32..........................................103.........................................
# ...........................................10969076541........................................43212.........................................
# ...........................................2345.987890........................................5670..........................................
# ............................................432105676...21.54.................................098987.32.....................................
# ...........................................6589034.85.5430963......................09..21.....1234565410....................................
# .........................................54787.12.094367898721.....................187430987676543216789....................................
# ....................................10..7630965...123214307890....................325656789058901230987.....................................
# ................................65..290989216743298.490521610.....................454765432147676543456.....................................
# ...............................874..3818103458901076587612529854...................6389012343858901232......................................
# ..........................43...903254727212543232167890103436763...54...09.........721098765294109874109....................................
# ..........................5232101216763630.69014125454329434587212163098187........890123456103234565678....................................
# ......................87676145698309854549878105034363458525498903072167256.....0987654765.7012.4309.76.43...76.............................
# .....................0945890547674567456701672969.5272767616307214983454343..21.1234563894989876521878565210.8543...........................
# .....................123210963850909832189254387876181878907216305612..5012..30....9872103034567812369476789.9012...........................
# ......................34789872941812349010389234567090965.981254987010769.10.498.090123452121010905450385476109876..........................
# .......................5610121032709.583294701876.890123430103434589298987298567218985436767892987674129238529012565........................
# .......................43290347896187674585650945098765412.29852.67438701636765434707672.85.1034569832101094387.347498765...................
# .......................56783256.05278967676341232123478905434761098565632545.7832561698109432985410789234781256..98301234...................
# ..............54......321094121014361058901210341032569876365234567874.45234989016525012901236763256.01.569034987012109.....................
# ...........54763.76...45678503492345234321092965894165078927010965.903436109070987434983810945.7894.210989876.0163212387....................
# ...........638921850987698769658743874567878387876507416.01898187432125276781614567230747238543430323456703458725450.456....................
# .........1072.09094123450145872365296543296547096789832521096723892301618587252321812165654761252101438761210963476987654...................
# .........2981018703210.87236701456101456103456145.329034349054.4701498709496343430903456567670967896529052123454385690123...................
# .........34569236123490965658921.70.23.7812.652325412129858123656985890123054125690987874385898765.781.1430987.529478.6521..................
# .......2109878.4521.58123474.430989432769098743016703410767438745076765432189054781896901294107894309092123456761032987430..................
# .......34781276543096721098365012385618501234589..89.545676529032189014523476563872705432103256101212783098109834781056789....89............
# ........56903456767876367892789654787094321876721098763298561012347652361.52347296361458901234.230763654567290125692349876545670............
# .........98.4321852185454301098789690125670965430123478103478943256743.707610981054523672105436549854123454383210.01430123434321............
# ........10765670943094501212345670521.3498903478943.5690129876501438129898901890123432103496127890789054.67874789876521098.2567890..........
# .......329034589090343690943298321430765018125676521032321012349852901078.0927098741234965870987.1654.6325496565490123456701654321..........
# .......45812.21218125278185010745678989432721098907894149054325676109256761836145650965874567896523438701630789032109.12569872367...........
# ........67.7630347876187276921650987430123636789816985058.690165.767834.85274523096787678343090145452989.721654123478903478901458...........
# .........098549856901096367834341236521434545410725076967878547498545432943654321898785492521832363610709832123.90567898987676549...........
# .........12345674309234545.765218745690525.123236341678769.76383034367010345634.67016903016787412727856165410.6781256107012589030...........
# ......76.2109876521876567438129096987876169054545432589.50123292125298981218725456525212101096509810943276321250983432.6543432121...........
# .....985438923456701234589290381050123890787636781234103410541010761034723090163874343478923458901290.23.54103412765478.234123..............
# .....0123470121098965432101874723432147098781232909832.2129656789890125654789872923432565652167610381014543298743.90.690165054.....23.......
# .....321056.43894587014589096565478905612369054109074789038741054321876.456329.1010561634743078529472985678901656781450987.967890..145......
# .....478987656703678923670189450165876321450969018165656545.32963450967838741090129870721834989438563.76.65432905432321.56785432167076......
# .....569234565412.210987652703692349.54.054187872723434747656787276905492965678983456989092567012765410987678981232543.349876.67.5898.......
# .......01010723.5430145894361278.650123496323456367652183894989818781230101456507438723870107654387.32781252107874167892101234589432901.....
# ......218929812167892367012565498741076587210765458989092103070109654321092327416529014561898321096545690343456965032109010765410..1432.....
# ......3474389030987632985434783012329890123498901430743012321652123456345830183290121876527694523454321098765410569452383298783212905678....
# .......565678745678541076321092983456787676585432121652109458943098107216749890185430901434507612167456789012323478761474.01694503832109....
# ........321096521096789012569010765432185896767890923456.8767034567298.09856743276349092343218903098321098765432109890565692503694745.......
# ........4345894323456543.347814501458909410543210.85498723632121432345678767656781258187650987654901234567894545678787654783412785676.......
# .......652.6701210987672187.32369236701232.23456787630901454.670501874329458565090967234561672347876587654303632109658123210987654389.......
# .......781098743012125890965412789876543456103210901218769854589690965610309474101876543272581.56.8949014521278901234903678923.789210.......
# ........90167658943034.012367010.012347832789456789256745076309878145870121238329234567818349010.430321236187654309652145650145610..........
# ..........258967.56909876545892987632569012109876543498321.121236723290923410901832101090987632985212309870945452187430987438709256.........
# ..........34.054327812345674323478541098543456789012301012303214543012187658943274.89234769054787610947890123636789012389012961834789.......
# ..........43216701.54.09098901.569012347632543210987632987494.05234983674567650165670965854123690123856321098721098765476321052743210.......
# ..........5674589.763218123876321098765.901634567890545676585.9616567458329878923452187.90321458765476.4567890567.78.23.54.23436567890......
# ............83210989034765434545678901.781072187632123498567678707.565490107874321034109.123098903478541054321498569014567814345654321......
# ............92345678125690123210987652563298.09.54781210.432989098.47.365216965.569652387654347612569032961234303410329832905254789.........
# ............018709854107854.458901234345412..9034.69034905610.812323812743.50123478709456781256543212123870765212329410741076163210.........
# ...........43.96127632987632.6765.54.236.034781256587658147.56765410909890143210909818.4309098745670341478989010945854565.98.07890..........
# ...........52105434523456701438743678187896561098749.907238943278345..874323434781432765218901230989850567654321876763678901296521..........
# ...........67890123610909898529232109090787.525690301816541034109276.45656125256325634903474321012347690985678901256.218765438743...........
# ............654109872381234761014567892169234347812327256321256.018..32187096109458725812565678987.5678123410987634789090123................
# ............78325690147.32567076.2187634501652165214563478905478909....09..87..87690167.107676901632987654327812543210987654................
# .............90347876565410989854309.5430987430743010769872163210123..........4309.76543298585432541090123456903456701234567................
# ..............12.878901234789010189034521234569856929850163078909854.......876521878901234549012345678.876543096521896521098................
# .............763296321076565432927.12761054987454783674325498721.76........9056789632109876321.76541076901232187430987432367.1256...........
# ............985410547898903456783676589096301236321458907834563.............14.210549012345890989032985.7654.67.90123478145890347...........
# ............014501256543212987654589432187210987890763216927654.............23.34345874309670145812345438901258987876569098321098...........
# .............2369.34.6789010123432.0123490561272187854345018901...............765216765218.652367.32.672765434105690345210745690............
# ...............78983232.2109854541098765814703630969012987218723..............89090.8901678743656541098189012323454127634.654781234.........
# .................074141034567636701234567238945456543210.6309654.........6543.32187654325.90127478901230987432765632985456903098765.........
# ...............321650569.5478929898765432987432987456.01254567...........7892145656789014365218343298.456765018947.10343278121.5678.........
# ...............456789878763210107812569010.65.1012327894343298.............01098743096521274309256107430985694303890125610987234989012......
# ...............5410901236723454569034781234567076301432569010............76527896721874309890121874565212347852129876107890.6543076543......
# ..............763298743458187636543210921076589854985610781234...........89436105890123458545430903678901098769010345298761256.21...........
# ..............89016765210909012701234583498.490145676789430985............0565234541098767636789.12107654123458123210345.543472367.90.......
# ..........54.0943258901458921098909876765012343238745098521.76............147438763278123452109874329834321076765456987656321814589812......
# .........763218523432.2367.345678123456789436527690321.767676.............2389290125690.656767016567812567898.67014785674723090921074389....
# .........89012761094165.3232109876543098765278185212347658585...........54...0143234109874.85892345.90.430989458923094983814523834565670....
# ............432345850745414567890789216789010909430165834949436521......632....561092349032945432121876521.70365432123012907614709876321....
# ............501876769836709876321650125432101234349870921030127430......70165..8723876581210367890309012345612789014309650989056123454......
# ............690945894521834905412345434569098765256.21678923218789.76..9898743.901456767.3412.87654569654329854321652187418543436545678.....
# ............78123670367092581670.096309878127890187434587014509652185650167892109854985876501090123478789010767230789090327612527832109.....
# ............65.543212.8901672589218721.7654361098905230965436701430947432543012347630349056925694321054321236581494321812345076109.12.......
# ............747690165218743.34763456905690345234721612189012.8923012389890121098567212761478347856789678901454905856127098769890.67034......
# ............83898327430965210985.54781478121076563870347654543094909..07654323476581.9852309876521098.21210963096767036123456781258965......
# ..........1092107418901256789014763872343432981254909.56123612185818721456121058949090341012343434567630345872187.5894565210765434987.90....
# ..........2367016509.543410.65238929676525678903432187.7098703276725634387092967030781212987652109.78549876.45678943098743.98.89.30.4581....
# ...........4589234587634329874321010589014343276541236585678941236341052967838721216329034589016781096781234343210.21.7890121270121236723...
# .........76...0987678125690123456789432105256181050.43494109850.45432961058745634545458765674325432345.9076525890.89.56985430365432187654...
# .........8543.12345690..7876543210901234961870929696521032907698765678789496549876309656745456781232.21098.01672167014107678945678909.......
# .......549452765432187.54389012367876565870909838787890123812345678543210301230167218743836365.90541034567890983454323278.654109870.45.90...
# ......7630361890123096567298109458901478.232167456767098747632109890123672109652589012129272743656789.7654321.74325.905696783234561236781...
# ......8921270987654345498107238765432329014345432.85.1456565434567210.45892387434109830.01818127498.438901236765.167814305492321098765432...
# .......0121878901012.630123654567012..1096565450109432321.701298.438943..0141234323474921090909830765214321458909054321212301456.01456789...
# .......543096543290987210945234.89.34.01878723692101238909898707656765218765098525456583456567892145670567054321876.890549810987892365210...
# ......7634545656781234545876165.10.65892349010783498747210125612547678909678907616365676587410.012321896589678781256709630729074309874301...
# ......892763874.43098763678907432987.76765.12987652365634503498343852187054981230727410749032987654309874321096903454187216381652123456923..
# .......01892923652167812.2109812347812589.5434569014565.7694307652943096123076549818329832145678901256905678905210763256785472901654327854..
# ..........0101.70145.9098347890545690341076321.7810767438985212561012345.32145678909458901232.6521.3478145432143.989034769016383278901076...
# ...............8923652107.56.0963210965298123098329858921076103470109.109452387090123676543018743032109236789034567812985432547410321.98....
# ...............1098743456543218767898743010.456745234.0145678987892387238761.961876329878909890789456785432981298765410567890.65894123......
# ...............234563276789012125870123212983276761654323254549654.45654789010523454107432167216989876.6781076501234323454321234765094......
# ..............87.32781856321030349654345036741858907890121636301230963456.092343256745652345.34507014565.9012.43096529876701.10567..85......
# ..............9654109094.456949810109216945650941096543230727210921872165218743418783276105436541652327436543672187.10.65892389098..76......
# ..............05676781234327856723278307854789032.8745.14981856783478.074345652509690187896127832.434181278345890123452341094721............
# ............3214.854903256109876543654987638721890123670589094329856909834327616345098965870909.12365090769216543210761432.8563.............
# ..........8747830923.5410723890187434567812963.7610549896701234107610123250189072121.701496781230547890985090789034989056787654.............
# ..........9656921018763498147652965210109010543452963078765210563452987416987098903456523054105496387612341874321256789854967890............
# ..........03450189.90125670567430567892349278.27638721698.43.98721438965074561238787634321.3296.87294521032565618787610763052121............
# ..........1254327654321098987892143210765836901854781250.01456789056701.9830987456901214125678789010323.94.438709690523452143034............
# ............61236781256569056.01670129896745430945690341892365454987632781218965436523050343210921.9014585012923.5414109678..965............
# ............70.45090347478141234589438105654521.32109432765472363034545690927090127454969654.0183458767676987014783232.87690.87.............
# ............89.32189438323230921096567234723678.012385.901238187212109810783618765836787876789276761258123456765690.4567.521................
# ...............45676529214567836787854321810109098547678547690901290127236545256749218923456543458.034905432985498123438943.................
# ................87678101098709454109012.098929812763456763850909438543654.4543438309010109874563098909876121012307432521012.................
# ...............0945090.678961856329654367876367436721218129418185.7634569036701292183278567838721.761.78903054321656167890345...............
# ...............123.12985410527876787834509.5454545890309010327276901298781298987034745694309290123452563214969034587032543876...............
# ....................34723234369.5432921012345236309854.892345636789810765210345612563210.21012109876343490587812549094161290................
# .....................56105434507890107896543618721.76.6787676545210723674389298721874567.12983456785412587674387632185070921................
# ........................96.212165410167674527090123434509.5812.4301654589070105630965498903.7654329450967856529012347698.834................
# ........................87.90389032925858361898761052121234903458923454321652145434563018745678.01036.81094361098765.....765................
# ...........................854761238349492709.785296903.10943876763216345634323672107232.65650989212767234127012367.567.....................
# ...........................76125434743030183456943878745678529.3454.072767214109878981456347416743.18547650989874589438.....................
# ............................903452565212109218701234.6543216101256.8981858905890.61090107298325658909.38125678963210129012..................
# ............................8765616789012389096987654567890709654767090943096761452349298101234787430129034321054.076549834.................
# ...............................4707632109470125012563298769878723854189012187.52327658345032101096521098747890145698..30765.................
# ..............................2389854901856323432347810.4505698109.3276523456743.18567216947892345678901656323232789..21....................
# ..............................109....8327654105410109678321430.....45674321098...094763078565498765430923.5414.016501.......................
# .....................................74..567896789234509....21.....309890123.......38549876123012.0121874789056987432.......................
# .....................................65.347632109876521............218787654.......29......098763.9872.65650987890..........................
# ........................................21854123236743...............5696789.......10......789054.4563456741674321..........................
# .........................................098905414589................4305410...............6321...321874383254567...........................
# ...........................................765670965012...............21.32................54.......096529...3298...........................
# ............................................34987874343.................................................10...01012..........................
# ............................................2101698.25890....................................................98743..........................
# ...........................................89032501.16721......................................................65...........................
# ...........................................7654.432.0763....................................................................................
# ....................................................9854....................................................................................

# %%
import numpy as np
from collections import deque

def is_valid_position(x, y, grid):
    """Check if a position is within bounds and not ground."""
    return 0 <= x < grid.shape[0] and 0 <= y < grid.shape[1] and grid[x, y] != '.'

def mark_loop(grid, start, directions):
    """Identify the loop in the grid and return a grid with non-loop parts replaced with '.'."""
    queue = deque([start])
    visited = set()
    loop_grid = np.full(grid.shape, '.', dtype=str)

    while queue:
        x, y = queue.popleft()
        if (x, y) in visited:
            continue
        visited.add((x, y))
        loop_grid[x, y] = grid[x, y]

        current_pipe = grid[x, y]
        if current_pipe == 'S':
            current_pipe = 'F'  # Treat 'S' as a connected pipe

        for dx, dy in directions.get(current_pipe, []):
            nx, ny = x + dx, y + dy
            if is_valid_position(nx, ny, grid) and (nx, ny) not in visited:
                # Ensure connectivity matches in both directions
                reverse_dx, reverse_dy = -dx, -dy
                neighbor_pipe = grid[nx, ny]
                if neighbor_pipe == 'S':
                    neighbor_pipe = 'F'
                if (reverse_dx, reverse_dy) in directions.get(neighbor_pipe, []):
                    queue.append((nx, ny))

    return loop_grid

def count_loop_tiles(loop_grid):
    """Count the number of loop tiles in the grid."""
    return np.sum(loop_grid != '.')  # Count all tiles that are not '.'

def find_start(grid):
    """Locate the starting position in the grid."""
    for r in range(grid.shape[0]):
        for c in range(grid.shape[1]):
            if grid[r, c] == 'S':
                return r, c

# Define the direction mappings
DIRECTIONS = {
    '|': [(-1, 0), (1, 0)],  # vertical: north and south
    '-': [(0, -1), (0, 1)],  # horizontal: west and east
    'L': [(-1, 0), (0, 1)],  # north and east
    'J': [(-1, 0), (0, -1)],  # north and west
    '7': [(1, 0), (0, -1)],   # south and west
    'F': [(1, 0), (0, 1)],    # south and east
    'S': [(-1, 0), (1, 0), (0, -1), (0, 1)]  # Start pipe connects in all directions
}

# Parse the file and compute the maximum distance
def parse_and_compute_max_distance(file_path):
    with open(file_path, 'r') as file:
        data = file.read().splitlines()

    grid = np.array([list(row) for row in data])
    start = find_start(grid)
    loop_grid = mark_loop(grid, start, DIRECTIONS)
    loop_tile_count = count_loop_tiles(loop_grid)
    max_distance = loop_tile_count // 2  # Maximum distance is half the loop size
    return max_distance

# Example usage:
# For sample input
print("Sample Maximum Distance:")
sample_max_distance = parse_and_compute_max_distance('sample-input.txt')
print(sample_max_distance)

# For full input
print("\nFull Maximum Distance:")
full_max_distance = parse_and_compute_max_distance('input.txt')
print(full_max_distance)
# Out:
# Sample Maximum Distance:
# 8
#
# Full Maximum Distance:
# 6768

# %%
import numpy as np
from collections import deque

def is_valid_position(x, y, grid):
    """Check if a position is within bounds."""
    return 0 <= x < grid.shape[0] and 0 <= y < grid.shape[1]

def mark_loop(grid, start, directions):
    """Identify the loop in the grid and return a grid with non-loop parts replaced with '.'."""
    queue = deque([start])
    visited = set()
    loop_grid = np.full(grid.shape, '.', dtype=str)

    while queue:
        x, y = queue.popleft()
        if (x, y) in visited:
            continue
        visited.add((x, y))
        loop_grid[x, y] = grid[x, y]

        current_pipe = grid[x, y]
        if current_pipe == 'S':
            current_pipe = 'F'  # Treat 'S' as a connected pipe

        for dx, dy in directions.get(current_pipe, []):
            nx, ny = x + dx, y + dy
            if is_valid_position(nx, ny, grid) and (nx, ny) not in visited:
                # Ensure connectivity matches in both directions
                reverse_dx, reverse_dy = -dx, -dy
                neighbor_pipe = grid[nx, ny]
                if neighbor_pipe == 'S':
                    neighbor_pipe = 'F'
                if (reverse_dx, reverse_dy) in directions.get(neighbor_pipe, []):
                    queue.append((nx, ny))

    return loop_grid

def flood_fill(grid, start, fill_char):
    """Flood fill from the starting position to mark areas as inside or outside."""
    queue = deque([start])
    visited = set()

    while queue:
        x, y = queue.popleft()
        if (x, y) in visited or not is_valid_position(x, y, grid) or grid[x, y] != '.':
            continue
        visited.add((x, y))
        grid[x, y] = fill_char  # Mark the tile

        # Explore all neighbors
        for dx, dy in [(-1, 0), (1, 0), (0, -1), (0, 1)]:
            queue.append((x + dx, y + dy))

def count_tiles(grid, char):
    """Count the number of tiles with the specified character."""
    return np.sum(grid == char)

def identify_inside_outside(grid, loop_grid):
    """Mark inside (I) and outside (O) regions and count inside tiles."""
    marked_grid = loop_grid.copy()

    # Flood fill from edges to mark outside ('O') tiles
    for row in range(grid.shape[0]):
        if marked_grid[row, 0] == '.':
            flood_fill(marked_grid, (row, 0), 'O')
        if marked_grid[row, grid.shape[1] - 1] == '.':
            flood_fill(marked_grid, (row, grid.shape[1] - 1), 'O')
    for col in range(grid.shape[1]):
        if marked_grid[0, col] == '.':
            flood_fill(marked_grid, (0, col), 'O')
        if marked_grid[grid.shape[0] - 1, col] == '.':
            flood_fill(marked_grid, (grid.shape[0] - 1, col), 'O')

    # Flood fill remaining '.' tiles to mark inside ('I') tiles
    for row in range(grid.shape[0]):
        for col in range(grid.shape[1]):
            if marked_grid[row, col] == '.':
                flood_fill(marked_grid, (row, col), 'I')

    # Count the number of inside tiles
    inside_tile_count = count_tiles(marked_grid, 'I')

    return marked_grid, inside_tile_count

def find_start(grid):
    """Locate the starting position in the grid."""
    for r in range(grid.shape[0]):
        for c in range(grid.shape[1]):
            if grid[r, c] == 'S':
                return r, c

# Define the direction mappings
DIRECTIONS = {
    '|': [(-1, 0), (1, 0)],  # vertical: north and south
    '-': [(0, -1), (0, 1)],  # horizontal: west and east
    'L': [(-1, 0), (0, 1)],  # north and east
    'J': [(-1, 0), (0, -1)],  # north and west
    '7': [(1, 0), (0, -1)],   # south and west
    'F': [(1, 0), (0, 1)],    # south and east
    'S': [(-1, 0), (1, 0), (0, -1), (0, 1)]  # Start pipe connects in all directions
}

# Parse the file and compute inside tiles
def parse_and_compute_inside_tiles(file_path):
    with open(file_path, 'r') as file:
        data = file.read().splitlines()

    grid = np.array([list(row) for row in data])
    start = find_start(grid)
    loop_grid = mark_loop(grid, start, DIRECTIONS)
    marked_grid, inside_tile_count = identify_inside_outside(grid, loop_grid)
    return marked_grid, inside_tile_count

# Example usage:
# For sample input
print("Sample Input:")
sample_marked_grid, sample_inside_count = parse_and_compute_inside_tiles('sample-input.txt')
print('\n'.join(''.join(row) for row in sample_marked_grid))
print(f"Inside tiles: {sample_inside_count}")

# For full input
print("\nFull Input:")
full_marked_grid, full_inside_count = parse_and_compute_inside_tiles('input.txt')
print('\n'.join(''.join(row) for row in full_marked_grid))  # Limit rows for readability
print(f"Inside tiles: {full_inside_count}")
# Out:
# Sample Input:
# OOF7O
# OFJ|O
# SJIL7
# |F--J
# LJOOO
# Inside tiles: 1
#
# Full Input:
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF----7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOL---7L7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF-J|OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO|FJOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO|F7|OOOF7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOFJ|OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF-J|LJF--J|OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF-JFJOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOL7FJIFJF--JOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOL-7|OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO|L--JFJF7OOOF7OF7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF-JL-7OF7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOFJF-7FJI||OF-JL7||OOOOOOOOOOOOOOOOOOOOOOF7OOF7OOOOOL-7F-JFJL7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF7L7|ILJIFJL7L--7LJL7OOOOOOOOOOOOOOOOOOOOO|L7FJL7F-7F--JL-7L7FJOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF7OOFJ|FJL7IIIL-7L7F7|F--JOOOOOOOOOOOOOOOOOOOOFJFJ|F-JL7|L----7L-J|OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF7OO||F7L7LJF7L-7F7I|FJ||||F7OOOOOOOOOOOOOOOOOOOOOL7|FJL-7FJ|F7F--JF--JOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOFJ|OO||||FJF-JL--J||FJL-J||||L7F7OOOOOOOOOOOOOOOOOOO||L7F-JL7|||L7F-JF7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOF7OOOL7L7FJ||||FJF--7F7||L---7||LJFJ||OOOF7OOOF7OOOOOOOOO|L-JL---J|||FJL-7|L-7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOO||F--7L7|L7|||||I|F-J|||L7F7FJ||F-JFJL7F7||F-7|L7OOOOOOOOL-------7LJ|L7F-JL7FJOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOF-7FJ|L-7L7|L-J||LJL-J|F7||L7|||L7|||F7|F-J|||LJFJ|FJOOOOOF-----7F-7I|F-JI||F7I||IF7OOOF7OOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOFJFJL7|F7|FJL--7|L-7F7FJ||||I||||FJLJ|||||F7|LJF-JFJL7OOF7OL----7|L7|FJL-7FJLJL7||FJL-7O|L-7OOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOL7L--J|||||F7F-JL-7LJ|L-JLJL7|||||F--J||||||L7FJII|F-JOO||OOOOF-JL-J||F--JL7F-7||||F--JO|F-JOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOL7F-7LJ|||||L--7FJF7|F7F---J|||LJL7IFJ||LJL-J|F7FJ|IF7O|L7OF7L----7LJL-7F7LJFJ||||L7F7FJL--7OOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOLJFJF7LJLJ|F7I||FJ|||LJF-7I||L--7L7L7|L7F-7FJ||L7L7|L7|FJFJ|F7F-7L7F--J|L-7L7||||FJ|||F--7|F7OOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOF-JFJL7F-7|||FJ|L7||L7FJFJFJL---JFJI|L7||ILJFJL7L7||FJ|L7L7|||L7|I||IF7L7FJFJLJLJL-JLJL7ILJ||F---7OOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOL--JF7LJI||||L7|FJLJFJL7L7L--7F7FJF7L7LJL--7L7FJFJLJ|IL7L7||||FJL7|L7|L7||FJF-7F-7F7F7FJIIFJ||F--JOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOF7OOOOOOF---7||F-7|LJ|FJ|L-7FJF7L7L7F7LJ||FJ|FJF----JFJ|IL7F-JF7|FJ||||L-7||FJ|FJ|LJFJILJILJLJLJF-7L7LJL7OOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOF7FJ|OF7OOOL--7|||L7|L7FJL7L--JL7||FJFJ||F7||L7||FJF7F7IL7|F7|L-7|||L-JLJ|F7|||L7||IL-7|IF---7F--7IL7|FJF-7L7OOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOO||L7L7||F---7FJLJ|FJL7||F7L---7FJ||L7L-J|||||I|||L7|LJL7FJ||||F-J|||F--7FJ||||L7||L7F7|L7|F--J|F-JF7||L7|IL-JOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOF7||I|FJ|||F--JL7F7LJF7LJ||L7F-7|L-J|FJF--J|LJ|FJLJFJL7F7||FJ||||F7||LJF7||FJLJ|FJ||FJ|LJFJ||F-7|L--J|||FJL----7OOOOOOOOOOOOOOOOOOO
# OOOOOOOOO|LJL7|L7|||L7IF7LJL7FJL-7|L7|L7LJF--J|FJIF7L7FJL7F7L7I||LJ|L-JLJ||||L7FJ|||L--7|L7||L7|F-JFJ|L7||F---J|||F7F---JOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOL--7|L7|||L7|FJL7F7LJF7I||I||IL7FJIF7|L7FJ|FJ|F7||L-JFJ|F7|F----J|LJFJL7|||F7FJL7||L7||L7IL7|I|LJL--7I||||LJIF7F7OOOOOOOOOOOOOOOOOO
# OOOOOOOF----J|I||||I|||F-J||IFJL-J|FJ|F7|L--JLJFJL7|L7LJ|||F7FJFJ|LJL-7F7FJF-JF7||||||L-7|||FJ|L7L7FJL7|F----JFJLJL7F-JLJ|OOOOOOOOOOOOOOOOOO
# OOOOOOOL7F7F7L-JLJL7|||L-7||FJF--7|L7|||L7F--7FJII||I|F-J||||L7L-JF--7|||L7L-7|||||||L--JLJLJFJFJFJL7FJ|L-7F7FJF7F7LJF---JOOOOF7OOOOOOOOOOOO
# OOOOOOOOLJLJL---7F-J|||F-J||L-JF-J|FJLJL-J|F7LJF7FJL-JL7FJ||L7L--7L-7LJ||I|F-J|||||||F7F-7F--JIL7|F7|L-JF-J||L7|LJ|F-JF---7F--J|OOOOOOOOOOOO
# OOOOOOOOOF7IF--7||F7|||L-7|L---JF7|L--7F-7LJL--J|L--7F7LJFJ|FJF-7L-7L7I||FJ|F7|||LJ|LJLJFJ|F-7F-JLJLJF--JF-J|FJL7ILJF7|F--J|F--JOOOOOOOOOOOO
# OOOOOOOOFJL-JF7LJLJLJ||F-JL-----J||F7ILJFJF7F7F-JF7ILJL-7|FJL-JFJF7|FJFJ|L7|||||L-7L7F-7L7||FJL--7F--JF7IL-7||F-JF--JLJL-7I|L----7OOOOOOOOOO
# OOOOOOOFJF7F-JL-7F7F7|||F7F-7F7F-JLJ|F-7L7|LJLJF-JL-7F7FJ|L---7L7||||FJFJI|||||L-7|FJL7|FJLJL7F7I|L-7I|L7F7|LJL-7L7F-----JFJF----JOOOOOOOOOO
# OOOOOOOL7|LJIF7FJ|LJ|||||||FJ||L--7FJL7L-J|F--7L-7F-J|||FJF--7|FJ|LJ||FJF7|||||F-J|L7FJ||F---J|L7L-7|FJFJ|||F--7L-JL7IF7F7|FJF7F7OOOOOOOOOOO
# OOOOOOOOLJIF7||L7|F-J||||LJ|FJL7F-J|F7L--7||F-JF7||F7||||I|F-J||I|F-J||I||||||||F7L7||FJ||F7F7L7|F7|||FJI|LJL-7L--7FJFJLJLJL-JLJ|OOOOOOOOOOO
# OOOOOOOOOF-JLJL7LJL-7LJ||F-JL7FJL-7LJL7F7|LJL7FJ|||||||||FJ|F7||FJL7FJL7|LJ||||LJ|FJ||L7|||LJ|FJ||||LJ|F-JF---JIF7LJFJF7F--7F--7|OOOOOOOOOOO
# OOOOOOOOOL----7|F7F7L-7LJ|IF-JL7F7L-7FJ|||IF-JL7||||||LJ||ILJ||||F7|L7FJ|F-J|||IFJL7|L7|||L-7||FJ||L7FJ|F-JFSIF-JL7FJFJ|L-7|L-7||OOOOOOOOOOO
# OOOOOOF7OF----JLJLJL--JF7L7|F7FJ||F-JL-J||FJF7FJLJLJ|L7I|L--7|||LJ||FJL7|L7FJ||FJF7||FJLJ|F-JLJ|FJL7|L7|L7FJL7|F-7LJFJIL--JL--JLJOOOOOOOOOOO
# OOOOOFJL-JF7F----7F----JL7|LJ||FJ|L7F7F7|||FJ|L-7F--JFJFJF7FJLJL7FJLJF7|L7LJFJ||FJ|||L7F-JL--7FJL-7||I||ILJF7LJL7L--JF7IF-7F-7OOOOOOOOOOOOOO
# OOOOOL---7|LJF---J|F-----J|F7||L7L-J||||LJ||FJF7||F7FJIL7|||F---JL---J|L-JF-JFJ||FJ|L7|L7F7F7|L7F7|||FJ|F--JL-7FJIF7I|L-JFJ|FJOOOOOF7OOOOOOO
# OOOOOF--7LJIFJF7F7||F7F7F7LJLJL-JF--JLJL-7|||FJ||||||F--J|LJ|F7F7F-7F7|IF-JF7|I||L7L7||FJ||||L7||||||L7|L----7LJF-J|FJF--JI|L---7OO|L7OOOOOO
# OOOOO|F7L---JFJ||LJLJLJLJL7F7F7F7L7F-7F-7|||||FJ|||LJL7F7L7ILJ|||L7|||L7|F7|LJFJL7L-J||L7|||L7|LJ||||ILJIF---JF7L-7LJFJIF--JF---JF7|FJOOOOOO
# OOOOOLJ|F---7L7LJIF------7||||||L-J|ILJI||||LJL7||L-7FJ||FJF--J||FJ||L7|||LJF-JF7L--7LJFJ||L7|L-7LJLJF---JF--7|L-7|F-JIFJF--JIF7I|LJ|OOOOOOO
# OOOOOOO|L7F7|FJIF-JF7F7F7LJ|LJLJIF7L---7|||L--7|||F-JL7||L7|F7FJ||FJL7|||L7FJF7||F7FJF7L7|L7|L--JF7IFJF7F7|F-J|F7||L--7L7L----JL7L-7L-7OOOOO
# OOOOOOFJFJ|LJ|F7L--JLJLJL-7|F-7F-J|F7F-JLJL-7FJLJ|L7F-J||FJ|||L7LJL7FJLJL7|L7|||LJ|L-JL7||FJ|F---JL7L-JLJLJL7FJ|LJ|F--JFJF7F--7FJII|F-JOOOOO
# OOOOOOL7|FJF-J|L---7F7F7F7LJL7|L-7LJLJF----7|L--7L7||F7||L7LJL7|F--JL7F-7||FJ|LJF-JF7F-J||L7|L7F--7L--------J|FJF7|L7F7|FJLJF7LJF7FJL--7OOOO
# OOOOOOOLJL-JF7L---7LJLJLJL---J|F7L----JF7F-J|F--JFJ|LJLJL7L7F7LJL-7F7|L7LJ|L7L-7|F7||L-7LJFJ|FJ|F7L7F--------JL-JLJFJ||||IF7||F7|||F---JOOOO
# OOOOOOOOF---JL7F--JF-----7F7F7LJL-----7||L7FJL--7L7L---7IL7LJ|F---J|LJIL-7L7|F-JLJ|||F7L-7L-JL-J|L-J|F-------------JFJLJL7|||||||||L7OOOOOOO
# OOOOOOOO|F-7F7LJF--JF--7ILJLJ|F7F7F7F7LJ|FJL----JI|F7F-JF7|F-JL7F-7L----7L7||L--7FJ|||L--JF-----JF--JL-----7F7F---7FJF--7LJLJLJLJLJFJOOOOOOO
# OOOOOOOFJ|ILJL-7|F--JF7L7F7IFJ|||LJLJL-7LJIF-----7LJ||F-JLJ|IF7||FJF7F-7|FJ||F7FJL7||L---7|F7F-7FJF-7F----7|||L-7FJL7|F7L---------7L7OOOOOOO
# OOOOOOOL7|F--7FJ|L7F7|L7LJL-JFJLJF-----JF-7L7F---JF7LJL-7F7|FJLJ||FJ|L7|||FJ||||F7LJ|F--7|||||ILJIL7|L-7F7|LJL--JL--JLJ|F--7F7IF-7L-JOOOOOOO
# OOOOOOOOLJ|F7LJFJFJ|LJIL--7F7|F7IL---7F7L7L-JL----J|F-7FJ|LJ|F--J||FJFJ||LJFJ|LJ|L--JL-7||LJLJF7IF7|L-7LJ||F--7F7F7F7F7LJF7LJL-JFJOOOOOOOOOO
# OOOOOOOOOO||L7FJIL7|F-----J|LJ|L--7F7LJL-JF--------J|FJL7|IFJL-7FJ|L7L7|L-7L7L-7|F--7F-JLJF-7FJL7||L-7L--JLJF7||LJLJLJL7FJL7F7F7|F7OOOOOOOOO
# OOOOOOOOOOLJI|L--7LJL-----7L-7L7F7LJL--7F7L-----7F--JL7FJL7|F-7|L7|FJFJL--JFJF-J||IFJL-7F7L7LJF7LJL-7|F-----J||L------7|L-7|||||LJL-7OOOOOOO
# OOOOOOOOOOF--JF7FJIF7IF7F-JF-JILJL----7LJL7F7F--J|F-7FJL-7|||I||FJ|L7|F7F--JFJF7LJFJF7FJ|L7L-7|L---7|LJF-----JL-------JL7FJLJ|||F---JOOOOOOO
# OOOOOOOOOOL-7FJLJIFJL-J|L-7L-7F-------JIF7|||L---JL7LJF-7LJ||I|||FJFJ|||L7F7L-J|F-JFJLJIL7L-7LJF---JL7IL-----7F-7IF7IF7ILJIF7|||L----7OOOOOO
# OOOOOOOOOOOO||F---JF7F7L--JF-JL------7IFJ|||L7F-7F-JF-JFJF-JL7LJ||I|FJ|L-J||F7FJL-7L7F-7IL-7L-7L7F7F7L7F7F---J|FJFJL-JL---7|||||F----JOOOOOO
# OOOOOOOOOOOO||L----JLJL7F--JF-------7|FJFJLJILJILJF7|F-JIL-7FJF7LJI||I|F7FJ||LJIF7|FJL7L---JF7L7LJLJL7LJ||F--7||FJF7F7F7F7LJ||||L-7OOOOOOOOO
# OOOOOOOOOOOOLJF7F-7F7F7LJF7IL7F----7LJ|FJF7IIF7F7I|LJL7F7F7LJI|L-7FJ|FJ|LJI|L7F-JLJ|F7L---7FJL7L---7FJF7LJ|F-J|LJFJ||LJ||L7FJ||L--JOOOOOOOOO
# OOOOOOOOOOOF7I||L7LJ||L--JL7ILJF7IFJIFJ|I|L7FJLJL7|F--J||||IF-JF-JL-JL7L--7|FJL-7F-J||IF7FJ|F-JF--7|L7||F-JL--JF7L7||F7LJILJI|L--7OOOOOOOOOO
# OOOOOOOOOOO|L-JL-JF7|L---7FJF7FJL7L-7|FJFJFJ|F---J||IF7|LJL7|F7L7F-7IIL7F-J||F7FJ|F-JL-JLJFJL--JF-JL7||LJF-----JL-JLJ|L-----7|F7FJOOOOOOOOOO
# OOOOOOOOOOOL------J|L-7F-JL7|||F7L--J|L7|FJI||F7F7|L7|||F7FJ||L-J|FJIF-JL7FJ||LJFJL7F7F7F7|F---7L--7LJ|F-JF------7F7IL7F----JLJLJOOOOOOOOOOO
# OOOOOOOOOOOOF-7F---JF7|L--7LJ|LJL----JFJ||F-JLJLJ||FJ||||LJFJL7IFJ|IIL-7FJL7|L-7L7FJ|||LJLJL--7L-7IL--JL--JF----7LJL--JL---7OOOOOOOOOOOOOOOO
# OOOOOOOOOOOOL7LJF7F-J||IF7L-7|F7IF7F-7L-JLJF7F7F7||L-JLJL--JF7L-JFJIIIILJIILJIIL-JL-JLJIF7F7F7L-7|F7F------JF7F7L----------JOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOL7FJLJF-JL-JL--JLJL-JLJIL-7F--JLJ||LJ|F7F7F-7F7|L--7L-7IIIIIIIIIIF7F7IF----JLJ||L--JLJLJF------JLJL---7F------7OOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOLJIF7L-7F--7F---7F7F-7F-7|L----7LJF7||LJ|L7|||L--7L7FJIIIIIIIF--JLJL7L------7|L--------JIF----7F7F7F7LJF7F---JOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOF7F7||F-J|F-JL7F-J|||ILJFJL7F7F-JF7|LJ|F7L-JLJL-7FJILJIIIIIIIIL7F---7|F-7F---JL-7IF--7F7F7L---7LJLJLJL--JLJF7F7OF7F7OOOOOOOOOOO
# OOOOOOOOOOOOFJLJLJLJF-JL-7FJL7FJ||F-7L-7||||F-J|L-7LJL-7F7F-7||IIIIIIIIIIIII||IF-J||FJL---7F7L-JF7LJLJ|IF--JIF7IF----7F7|LJL-JLJ|OOOOOOOOOOO
# OOOOOOOOOOOOL7F7F-7FJF---J|F-JL7LJL7L--JLJLJL-7L--JF7F-J|||FJLJIIIIIIIIIIIIILJIL7FJ|L7F7F7LJL7F7|L7F-7L7L---7|L7L7F--J|LJF7F----JOOOOOOOOOOO
# OOOOOOOOOOOOOLJ||ILJIL----JL---JF7IL---7F7F7F7|F7F7|LJF-JLJL--7IIIIIIIIIIIIIIIF-JL7L7LJLJ|IF7LJLJI||IL7|F---J|FJFJL7F-JF-J||F7F7OOOOOOOOOOOO
# OOOOOOOOOOOOOOOLJF7F7F7IF---7F7FJ|F----J||||||||LJ|L--JF-7F7F7L7IIIIIIIIIIIIIIL-7FJIL--7FJFJL7F7F-J|F-J|L----JL-JF7LJF7L7ILJ|LJL--7OOOOOOOOO
# OOOOOOOOOOOOOOOOO|||||L7L--7LJ|L7|L-----JLJLJLJL-7|F---JI||LJL-JIIIIIIIIIF--7IF-JL7F---J|IL-7|||L--JL-7L--7F-7F-7|L7FJL7L7F7|F----JOOOOOOOOO
# OOOOOOOOOOOOOOOF-JLJ|L7|IF7L-7|FJL------7F-7F-7F-J|L7IF-7|L--7IIIIIIIIIIIL-7L7L-7FJL---7L7F7||||F-7F7IL--7LJFJL7||ILJF7L7LJLJ|IF--7OOOOOOOOO
# OOOOOOOOOOOOOOOL---7L-JL-JL--JLJF7F7F7F7LJILJI|L-7L7L-JFJL-7FJIIIIIIIIIIIIIL7L--JL7F7F7|FJ|LJLJ|L7LJ|F7F-JF7|F7||L---JL7L---7L-JF7L--7OOOOOO
# OOOOOOOOOOOOOOOF7F7L---7F7F--7F-JLJLJLJL---7F7|F7|FJF-7L7F7LJIIIIIIIIIIIIF-7|F-7F7LJLJLJL7L---7|FJF7LJLJF-J|||LJ|F--7F7L--7IL--7|L---JOOOOOO
# OOOOOOOOOOOOOOFJLJL-7F7LJ||F-J|F------7F-7FJ||LJLJL7L7L7LJL--7IIIIIIIIIIIL7LJ|FJ|L------7|F7F-J|L7|L----JF-JLJF7LJF-J|L--7L7F7ILJOOOOOOOOOOO
# OOOOOOOOOOOOOOL--7F7LJL--J|L--J|F----7|L7LJI|L-7F-7L7L7|F7F-7|IIIIIIIIIIII|F7|L-JF7F----JLJ|L-7|ILJF7F--7L---7|L-7L-7L-7IL7LJ|F7F7OF7OOOOOOO
# OOOOOOOOOOF7OF7F7||L--7F7FJF---J|F---JL-JF--JF7LJFJFJFJ||LJILJIIIIIIIIIIII|||L7F-JLJF7F---7L--JL7F-JLJF7L--7FJ|F-JF7L--JF7L-7||LJL7|L7OOOOOO
# OOOOOOOOOFJL-J|||LJF7ILJLJIL----JL-------JF7FJ|F7L7|FJILJF7F7IIIIIIIIIIIIILJL7|L--7FJLJIF7L7F7F7LJF-7FJL--7LJI||F7|L7F-7||F7LJL7F-J|FJF7OOOO
# OOOOOOOOOL---7LJL-7||F7IF7F---------7F----J|L7|||FJ|L7F-7||||IIIIIIIIIIIF7IIILJF-7LJF---J|I||LJ|F-JILJIF7FJF7FJLJ||FJ|FJ|||L7F7|L--JL-J|OOOO
# OOOOOOOOOOOOFJF--7|||||FJ|L-----7F-7LJF---7|FJLJLJFJFJ|FJ|||L7F7F7IIIIII|L7IIIIL7L-7L-7F7L7||F-JL7F7F--JLJI|||F--J|L-JL-JLJFJ|||F---7F-JOOOO
# OOOOOOOOOOOO|FJF-JLJLJ|L7L---7F-JL7L-7|F--J|L--7F7L-JFJL-J|L7||LJ|IIIIII|FJF7IIFJF7L--J|L7LJ|L---J|LJF-----JLJL---JF7F7F7F7L-JLJL--7LJOOOOOO
# OOOOOOOOOOOO||FJF7F7F7L7|F7F7LJF--JF7LJL7F7L---J|L7IFJF--7|FJ||F-JIF7IIFJL7|L7IL-JL--7FJIL7FJIF---JF7|F---7F7F-7F7FJLJLJ|||F-7F7F-7L--7OOOOO
# OOOOOOOOOOOOLJL-JLJ||L7LJ||||F7|IF7||F-7LJL7F---JFJFJFJF7LJL7LJL7F7||F7L7FJL7|F--7F7FJ|F--J|F-JF---JLJL--7LJ|L7|||L--7F7LJLJFJ||L7L---JOOOOO
# OOOOOOOOOOOOF7IF--7LJIL--JLJ||LJFJLJLJIL---J|F--7L7|FJFJL--7L7F7LJLJ||L-JL-7||L-7LJ||FJL7F7||F7|F---7F---JF7L7||||F--J|L---7|FJL-JIF7OOOOOOO
# OOOOOOOOOOOO||FJF-JF7F7F7F7ILJF7L--7F7F7F7F-JL-7|FJ||FJF---JILJL7F--JL7F---J|L-7L-7|LJF7||LJLJLJL--7|L----JL7|||||L7F7|F---JLJF7IF7|L7OOOOOO
# OOOOOOOOOOOO||L7|F7|LJLJ||L---J|IF7LJ||LJLJF7F-J||FJ|L7L--7F-7F7||F7II|L7F-7L-7L-7||IFJ|LJF----7F--J|IF7F--7|||||L7||||L------JL7|LJFJOOOOOO
# OOOOOOOOOOF-JL-J|||L---7|L----7|FJ|F7LJF7F-JLJF7LJL7|IL7F-J|FJ|||||L7FJFJ|FJF7|F7||L7|FJF7L--7FJL--7L7||L-7LJLJLJI|LJLJF7F-7F---J|F-JIF7OOOO
# OOOOOOOOOOL7F7F7LJL7IF-J|F7IF7||L7|||F-J|L----JL7F7|L7I|L-7||FJLJ||FJL7|FJL7||LJ|||FJ|L7|L---JL--7IL7LJL--JIF----7L7F-7|LJILJIF7I||IF7||OOOO
# OOOOOOOOOOOLJLJL--7L-JF7LJL-JLJL-JLJ|L-7|F7F-7F-J||L7L7|F-J|||F-7|||F7|||F-J|L7FJLJ|FJFJL-7F--7F-JF-JF-7F--7|F---JILJI|L---7F7|L-JL-JLJL7OOO
# OOOOOOOOOF7IIIF---JF7FJL7F---------7L--J|||L7||F7||I|FJ||F7||||ILJ|LJ||LJ|F7|FJL-7FJL7L7F7LJF-JL--JF-JILJF-J||F-7IF7IFJF7F-J|||F---7F---JOOO
# OOOOOOOOO||F7IL----JLJIILJF-------7L---7|||FJLJ||||FJL7|LJ||LJL-7FJF-JL-7||LJ|F-7||F7|FJ||F7L--7F-7|IF---JIFJLJFJFJL7|FJLJF-JLJL7F7LJOOOOOOO
# OOOOOOOF7||||F-----7F7IF-7L----7F7L--7FJLJLJF-7|LJLJF-JL-7|L7F--JL7L-7F-J||F-JL7||LJLJL7||||F7ILJFJL7L-----JF-7L-JF-JLJF7IL-7F--J||IF7OF7OOO
# OOOOOOFJ|||||L----7LJL7L7|F7F-7LJL--7|L7IF7FJFJL--7FJF--7|L7|L---7L7FJ|F7LJL7F7||L---7FJ|||||L7F7L--JIF-----JI|F-7|IF7FJ|F-7|L---JL-JL-J|OOO
# OOOOOOL7LJ||L7F---JF-7|FJLJ|L7L-----JL7L-J|L7|F-7I||I|F-JL7LJF---JFJ|ILJL7F7LJ|||F--7||I|||||FJ||F7IF7L--7F7F7LJI|L-J|L7|L7||F----------JOOO
# OOOOOOOL-7||FJL-7F-JI||L--7L-JF-7F-7IIL-7FJFJ||FJFJL7|L-7I|F-JF7IFJFJF7IILJ|F-J||L-7|||FJLJLJL7|||L-JL7F-J|LJL-7FJF--JFJL-JLJL-7IF7F----7OOO
# OOOOOOOF-JLJL---J|F--JL--7L7F-JILJIL7IF7LJFJFJ||FJF-J|F-JFJL-7|L7L7L-JL7F7FJ|F7||F7|LJ|L--7F--J|LJF--7|L-7|F---JL-JIF-JF7F7F7F7L-JLJF7F-JOOO
# OOOOOOFJF-7F-7F--JL---7F7L-J|F7IF7IFJFJL-7L7L7||L7L-7||F-JF7FJL7L7|F---J||L7||LJ||||F-JF7FJ|F7IL--JF7||F7LJL-7F7F7F-JF7||||||||F7F--JLJF7OOO
# OOOOOOL7|FJ|FJ|IF7F---J|L---J|L-JL-JIL7F-JIL7LJL-JF7|||L-7|LJF7L7|||F7F7|L7||L-7|||||F7||L7LJL7F---JLJLJL----J|LJLJF7|LJLJ||||LJ|L----7|L7OO
# OOOOOOOLJL7||FJFJLJF-7FJIF---JF--7F7F7|L7IF7L--7F7|LJ||IFJ|F7|L-J||LJLJ|L7||L7FJLJ||LJ||L-JF--JL---7F7F7F----7|F-7FJLJF--7LJ||F-JF---7LJFJOO
# OOOOOOOOOOLJLJO|F7FJILJF7L7F--JF7LJLJLJFJFJ|F7ILJ||F7|L7L7|||L7F7LJF---JI|LJFJL--7LJF7|L--7L7IF7F7ILJLJ||F---J||ILJF7FJF7L-7|||F7L--7L7FJOOO
# OOOOOOOOOOOOOOOLJLJF7F-J|ILJIF7|L---7F7|FJFJ|L-7FJLJ|L7L-JLJL7LJ|F7L7IF-7L7FJF7F7L-7|LJF--JFJFJLJ|F---7LJL---7|L---JLJFJL--JLJ||L7F7|ILJOOOO
# OOOOOOOOOOOOOOOF---J|L-7L----JLJF--7LJLJL7|IL-7|L7F-JIL7F----JF7LJL7L7L7|FJ|I|||L-7||F7L--7L7L7F-JL-7FJF--7F7LJF----7FJF----7ILJFJ||L7OOOOOO
# OOOOOOOOOOOOOOOL---7L7FJF--7F7F7|F7L-7F-7|L7F7||FJ|F---JL7F7F7|L-7IL7L7||L7|FJ|L-7LJLJ|F7FJFJFJ|F7F-J|IL-7LJL-7L---7|L-JF---JF-7L-JL7|OOOOOO
# OOOOOOOOOOOOOOF7IF7L7||FJF-J|||LJ|L--JL7||FJ||||L7|L----7||||||F-JF7|FJ||I||L7|F7L-7F-J||L7|IL7|||L7FJF7IL--7IL7F7FJ|F-7L7F7IL7L-7OO||OOOOOO
# OOOOOOOOOOOOOO||FJL-JLJ|IL-7||L7FJF-7F7||||FJ|||FJ|F7F-7|||||LJL7FJLJL7||FJL7||||F7|L7FJL7|L7FJ||L7|L7|L7F-7|F7LJLJILJIL7LJL7FJF-JOOLJOOOOOO
# OOOOOOOOOOOOOO||L7F-7F-JF-7LJL-JL7|FJ|||||||FJ|LJILJ||I||||||F--JL7F7I||||F-J|||LJ||FJ|F-J|FJL7LJI|L7||FJL7|LJL------7F7|F-7||FJOOOOOOOOOOOO
# OOOOOOOOOOOOF-J|I|L7LJF7L7L------J|L7|LJLJ|||FJF----JL7||||LJ|F7F7LJL7LJ||L7FJ||F-J|L7|L7FJL7FJIF-JFJ|||F7|L7F-----7FJ||LJI|LJ|OOOOOOOOOOOOO
# OOOOOOOOOOF7|F7|FJFJIFJL7|F7F--7F7|FJL--7FJ|||IL7F7F7FJ|||L7FJ|LJL7F7L-7||FJL7||L7FJI|L7||F-JL-7|F7|FJ|LJ||FJL--7F7LJFJL--7|F-JOOOOOOOOOOOOO
# OOOOOOOOOO|LJ||LJFJF-JF7LJ|||F7||LJL-7F-J|FJLJF-J|||||FJ|L7|L7L7F-J||F7|||L-7|LJFJL-7L7|||L7F7FJ||||L7|F-J|L7F-7LJL--JF7F7||L--7OOOOOOOOOOOO
# OOOOOOOOOO|F-JL7FJIL--JL-7|LJ|LJ|F---JL-7||F7I|F7||||||FJILJIL-JL7FJ||LJ||F-JL-7L7F-JFJ|LJILJ||ILJ||FJ|L7FJFJL7|F7F-7FJLJ|||F7FJOOOOOOOOOOOO
# OOOOOOOOOOLJF--J|F-------JL-7L7FJL-7F7F-J|||L-J|LJ||||||IF7F-----JL7|L7ILJ|F7F7|FJL-7L7|F7F--JL--7LJL7|I||IL7FJLJ|L7|L--7LJLJ|L7OOOOOOOOOOOO
# OOOOOOOOOOOO|F-7|L7F7F7F7F7FJILJF7FJ||L7FJ||F7FJF-J|||||FJLJF-7F7F-J|FJF7FJ|||LJL7F7L7|||LJF-7F7FJIF-JL7||F-J|F7IL7||F-7L-7OO|FJOOOOOOOOOOOO
# OOOOOOOOOOOO||OLJFJ|||||LJ||F---JLJFJ|FJ|FJ||LJIL7FJ||LJL--7|FJ|||F-JL-J|L7|||F--J||FJ|||F-JI|||L-7L-7FJLJL-7LJ|F7LJLJIL-7L7OLJOOOOOOOOOOOOO
# OOOOOOOOOOOOLJOF-JFJ||||F7LJL7F--7FJFJ|FJ|FJL-7IFJL7||IF---J||FJ||L7F-7FJFJ|||L7F7||L7LJLJF--J|L7FJF7||F-7F-JF7LJL7IF--7I|FJOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOL-7|FJ||||L---J|F-JL7L-JL7|L7F7L7L7FJLJFJF7F7|||FJ|FJL7|L7L7|||FJ|||L7L7F--JF7FJFJ|I|LJLJFJL7FJL7F7L-JF7L7LJOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOFJ|L7|LJL7F7F7|L7F7L--7ILJFJ|L7L7LJF--JFJ|||||||FJ|F7|L-JI||LJL7|||FJFJL--7||L7|FJFJF-7FJF7|L-7|||F-7|L-JF7OOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOFJFJFJ|IF-J||||L7LJ|F--JF-7L7|FJFJF7L7F7|FJ|||||||ILJ|L-7F7|L7F-J|LJ|FJF7F-J||FJLJIL7|I|L-J||F-JLJ|L7|L---JL-7OOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOL-JOL7L7L7FJ|||FJF-JL7F-JFJI||L7|FJL-J|LJ|FJLJ||LJF--JF7LJ||FJL-7|F7|L-J|L7FJ|L7F---J|FJF-7|||F7F7|FJ|F7F-7F-JOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOL7|FJL7LJ||IL--7|L-7L--J|FJ||F-7FJIFJL--7||F-JF7FJL-7|LJF--J||LJF--JILJFJFJL-7F7|L7|FJ||LJLJ||L7||||FJL7OOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOLJL7FJF-J|F---J|F-JF7F7||FJLJILJIFJF-7FJLJ|F7||L7F7LJF7|F-7||F7L--7IF7L7L7F-J|||FJ|L-J|F7F-JL-J||||L7FJOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOO||OL7FJL-7F7||F7||||||L----7F-JFJI||F7ILJ||L7LJL-7|LJ|FJ|LJ|F7FJFJ|I|FJL-7|||L7L-7FJ||L----7LJLJO|L7OOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOLJOFJ|F-7||||||||||||L7F7F7|L7FJF-JLJL-7FJ|FJF7F-JL7FJ|FJF-J||L7L7L-JL7IFJ|||I|F-JL7||F----JOOOOOL-JOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOO|FJL7LJ|||||||||LJI||||||FJ|IL-7F7F-JL7|L7||L-7FJ|FJL7L-7||FJIL7F7FJFJFJ||FJL-7FJ||L-7F7IF-7OOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOLJF7|F7|||||||||F--J|LJLJL7|F--J|||IF7LJI|||F7|L7|L7FJF-J||L-7FJ|||FJFJI||L7F-JL-J|F7LJL7L7|OOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOFJLJ|||LJLJ||LJL7F7L---7I||L--7||L-JL7IFJ||||L7||FJ|I|F-J|F7||FJLJ|FJF-J|I||F7F--J||F-7L-JL--7OOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOL--7|||F---JL7F7LJ|F---JFJL7F-J|L7F-7|FJFJ||L7|||L7|FJL-7||LJ|L7F-JL7|F7|FJLJ|L--7|||I|F--7F7L7OOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO|||||F-7F7||L-7|L-7F7L7FJL7FJFJ|FJ|L7|FJL7LJLJI||L7F7||L-7|FJL7F-JLJLJ|F-7|F--J||L7LJOO||L-JOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOFJ|LJLJFJ||||F7LJF7LJL7LJIFJ|FJFJL-JOLJ|F7L----7LJO|||||F7|||F-JL--7F--JL7LJ|F7FJL7L-7OOLJOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOL-JOOOO|FJLJLJL7FJL7F-JF-7L-JL7|OOOOOF-J|L-----JOOOLJ||||||||L-7F--JL-7F7L7ILJ||IFJF7L7OOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO||OOF---JL-7|L--JFJOOOOLJOOOOO|F7L----7OOOOOOO||LJLJLJF-JL-7OF-J|L7|F--JL7L-JL-JOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOLJOFJF7F7F-JL7F7FJOOOOOOOOOOOOLJL7F7F-JOOOOOOO||OOOOOOL7F-7|OL-7|ILJL7F-7L--7OOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOL7|LJ|L7F7||LJOOOOOOOOOOOOOOOFJ||L-7OOOOOOOLJOOOOOOFJL7LJOF-JL---7||FJF--JOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOLJF-JFJ|LJL7OOOOOOOOOOOOOOOOL7|L7FJOOOOOOOOOOOOOOO|F-JOOOL-7F7F7|LJL7L-7OOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOL-7L7L7F7L-7OOOOOOOOOOOOOOOLJOLJOOOOOOOOOOOOOOOOLJOOOOOOOLJLJ||OOOL7FJOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOFJFJFJ|L7FJOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOLJOOOFJL-7OOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOL7L7|FJO||F-7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOL-7FJOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF-JFJ|L7O|LJFJOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOLJOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOL--JOL-JO|F7|OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOLJLJOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Inside tiles: 610

# %% [markdown]
# 610 That's not the right answer; your answer is too high. If you're stuck, make sure you're using the full input data; there are also some general tips on the about page, or you can ask for hints on the subreddit. Please wait one minute before trying again. [Return to Day 10]

# %%
import numpy as np
from collections import deque

def is_valid_position(x, y, grid):
    """Check if a position is within bounds."""
    return 0 <= x < grid.shape[0] and 0 <= y < grid.shape[1]

def mark_loop(grid, start, directions):
    """Identify the loop in the grid and return a grid with non-loop parts replaced with '.'."""
    queue = deque([start])
    visited = set()
    loop_grid = np.full(grid.shape, '.', dtype=str)

    while queue:
        x, y = queue.popleft()
        if (x, y) in visited:
            continue
        visited.add((x, y))
        loop_grid[x, y] = grid[x, y]

        current_pipe = grid[x, y]
        if current_pipe == 'S':
            current_pipe = 'F'  # Treat 'S' as a connected pipe

        for dx, dy in directions.get(current_pipe, []):
            nx, ny = x + dx, y + dy
            if is_valid_position(nx, ny, grid) and (nx, ny) not in visited:
                # Ensure connectivity matches in both directions
                reverse_dx, reverse_dy = -dx, -dy
                neighbor_pipe = grid[nx, ny]
                if neighbor_pipe == 'S':
                    neighbor_pipe = 'F'
                if (reverse_dx, reverse_dy) in directions.get(neighbor_pipe, []):
                    queue.append((nx, ny))

    return loop_grid

def flood_fill(grid, start, fill_char):
    """Flood fill from the starting position to mark areas as inside or outside."""
    queue = deque([start])
    visited = set()

    while queue:
        x, y = queue.popleft()
        if (x, y) in visited or not is_valid_position(x, y, grid) or grid[x, y] != '.':
            continue
        visited.add((x, y))
        grid[x, y] = fill_char  # Mark the tile

        # Explore all neighbors
        for dx, dy in [(-1, 0), (1, 0), (0, -1), (0, 1)]:
            queue.append((x + dx, y + dy))

def count_tiles(grid, char):
    """Count the number of tiles with the specified character."""
    return np.sum(grid == char)

def identify_inside_outside(grid, loop_grid):
    """Mark inside (I) and outside (O) regions and count inside tiles."""
    marked_grid = loop_grid.copy()

    # Flood fill from edges to mark outside ('O') tiles
    for row in range(grid.shape[0]):
        if marked_grid[row, 0] == '.':
            flood_fill(marked_grid, (row, 0), 'O')
        if marked_grid[row, grid.shape[1] - 1] == '.':
            flood_fill(marked_grid, (row, grid.shape[1] - 1), 'O')
    for col in range(grid.shape[1]):
        if marked_grid[0, col] == '.':
            flood_fill(marked_grid, (0, col), 'O')
        if marked_grid[grid.shape[0] - 1, col] == '.':
            flood_fill(marked_grid, (grid.shape[0] - 1, col), 'O')

    # Flood fill remaining '.' tiles to mark inside ('I') tiles
    for row in range(grid.shape[0]):
        for col in range(grid.shape[1]):
            if marked_grid[row, col] == '.':
                flood_fill(marked_grid, (row, col), 'I')

    # Count the number of inside tiles
    inside_tile_count = count_tiles(marked_grid, 'I')

    return marked_grid, inside_tile_count

def loop_to_string(loop_grid):
    """Convert the loop grid to a string representation."""
    return '\n'.join(''.join(row) for row in loop_grid)

def find_start(grid):
    """Locate the starting position in the grid."""
    for r in range(grid.shape[0]):
        for c in range(grid.shape[1]):
            if grid[r, c] == 'S':
                return r, c

# Define the direction mappings
DIRECTIONS = {
    '|': [(-1, 0), (1, 0)],  # vertical: north and south
    '-': [(0, -1), (0, 1)],  # horizontal: west and east
    'L': [(-1, 0), (0, 1)],  # north and east
    'J': [(-1, 0), (0, -1)],  # north and west
    '7': [(1, 0), (0, -1)],   # south and west
    'F': [(1, 0), (0, 1)],    # south and east
    'S': [(-1, 0), (1, 0), (0, -1), (0, 1)]  # Start pipe connects in all directions
}

# Parse the file and compute inside tiles
def parse_and_compute_inside_tiles(file_path):
    with open(file_path, 'r') as file:
        data = file.read().splitlines()

    grid = np.array([list(row) for row in data])
    start = find_start(grid)
    loop_grid = mark_loop(grid, start, DIRECTIONS)
    marked_grid, inside_tile_count = identify_inside_outside(grid, loop_grid)
    return loop_to_string(marked_grid), inside_tile_count

# For full input
print("Full Input:")
full_marked_grid, full_inside_count = parse_and_compute_inside_tiles('input.txt')
print(full_marked_grid)  # Print the entire grid for the full input
print(f"Inside tiles: {full_inside_count}")
# Out:
# Full Input:
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF----7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOL---7L7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF-J|OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO|FJOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO|F7|OOOF7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOFJ|OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF-J|LJF--J|OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF-JFJOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOL7FJIFJF--JOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOL-7|OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO|L--JFJF7OOOF7OF7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF-JL-7OF7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOFJF-7FJI||OF-JL7||OOOOOOOOOOOOOOOOOOOOOOF7OOF7OOOOOL-7F-JFJL7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF7L7|ILJIFJL7L--7LJL7OOOOOOOOOOOOOOOOOOOOO|L7FJL7F-7F--JL-7L7FJOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF7OOFJ|FJL7IIIL-7L7F7|F--JOOOOOOOOOOOOOOOOOOOOFJFJ|F-JL7|L----7L-J|OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF7OO||F7L7LJF7L-7F7I|FJ||||F7OOOOOOOOOOOOOOOOOOOOOL7|FJL-7FJ|F7F--JF--JOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOFJ|OO||||FJF-JL--J||FJL-J||||L7F7OOOOOOOOOOOOOOOOOOO||L7F-JL7|||L7F-JF7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOF7OOOL7L7FJ||||FJF--7F7||L---7||LJFJ||OOOF7OOOF7OOOOOOOOO|L-JL---J|||FJL-7|L-7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOO||F--7L7|L7|||||I|F-J|||L7F7FJ||F-JFJL7F7||F-7|L7OOOOOOOOL-------7LJ|L7F-JL7FJOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOF-7FJ|L-7L7|L-J||LJL-J|F7||L7|||L7|||F7|F-J|||LJFJ|FJOOOOOF-----7F-7I|F-JI||F7I||IF7OOOF7OOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOFJFJL7|F7|FJL--7|L-7F7FJ||||I||||FJLJ|||||F7|LJF-JFJL7OOF7OL----7|L7|FJL-7FJLJL7||FJL-7O|L-7OOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOL7L--J|||||F7F-JL-7LJ|L-JLJL7|||||F--J||||||L7FJII|F-JOO||OOOOF-JL-J||F--JL7F-7||||F--JO|F-JOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOL7F-7LJ|||||L--7FJF7|F7F---J|||LJL7IFJ||LJL-J|F7FJ|IF7O|L7OF7L----7LJL-7F7LJFJ||||L7F7FJL--7OOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOLJFJF7LJLJ|F7I||FJ|||LJF-7I||L--7L7L7|L7F-7FJ||L7L7|L7|FJFJ|F7F-7L7F--J|L-7L7||||FJ|||F--7|F7OOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOF-JFJL7F-7|||FJ|L7||L7FJFJFJL---JFJI|L7||ILJFJL7L7||FJ|L7L7|||L7|I||IF7L7FJFJLJLJL-JLJL7ILJ||F---7OOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOL--JF7LJI||||L7|FJLJFJL7L7L--7F7FJF7L7LJL--7L7FJFJLJ|IL7L7||||FJL7|L7|L7||FJF-7F-7F7F7FJIIFJ||F--JOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOF7OOOOOOF---7||F-7|LJ|FJ|L-7FJF7L7L7F7LJ||FJ|FJF----JFJ|IL7F-JF7|FJ||||L-7||FJ|FJ|LJFJILJILJLJLJF-7L7LJL7OOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOF7FJ|OF7OOOL--7|||L7|L7FJL7L--JL7||FJFJ||F7||L7||FJF7F7IL7|F7|L-7|||L-JLJ|F7|||L7||IL-7|IF---7F--7IL7|FJF-7L7OOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOO||L7L7||F---7FJLJ|FJL7||F7L---7FJ||L7L-J|||||I|||L7|LJL7FJ||||F-J|||F--7FJ||||L7||L7F7|L7|F--J|F-JF7||L7|IL-JOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOF7||I|FJ|||F--JL7F7LJF7LJ||L7F-7|L-J|FJF--J|LJ|FJLJFJL7F7||FJ||||F7||LJF7||FJLJ|FJ||FJ|LJFJ||F-7|L--J|||FJL----7OOOOOOOOOOOOOOOOOOO
# OOOOOOOOO|LJL7|L7|||L7IF7LJL7FJL-7|L7|L7LJF--J|FJIF7L7FJL7F7L7I||LJ|L-JLJ||||L7FJ|||L--7|L7||L7|F-JFJ|L7||F---J|||F7F---JOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOL--7|L7|||L7|FJL7F7LJF7I||I||IL7FJIF7|L7FJ|FJ|F7||L-JFJ|F7|F----J|LJFJL7|||F7FJL7||L7||L7IL7|I|LJL--7I||||LJIF7F7OOOOOOOOOOOOOOOOOO
# OOOOOOOF----J|I||||I|||F-J||IFJL-J|FJ|F7|L--JLJFJL7|L7LJ|||F7FJFJ|LJL-7F7FJF-JF7||||||L-7|||FJ|L7L7FJL7|F----JFJLJL7F-JLJ|OOOOOOOOOOOOOOOOOO
# OOOOOOOL7F7F7L-JLJL7|||L-7||FJF--7|L7|||L7F--7FJII||I|F-J||||L7L-JF--7|||L7L-7|||||||L--JLJLJFJFJFJL7FJ|L-7F7FJF7F7LJF---JOOOOF7OOOOOOOOOOOO
# OOOOOOOOLJLJL---7F-J|||F-J||L-JF-J|FJLJL-J|F7LJF7FJL-JL7FJ||L7L--7L-7LJ||I|F-J|||||||F7F-7F--JIL7|F7|L-JF-J||L7|LJ|F-JF---7F--J|OOOOOOOOOOOO
# OOOOOOOOOF7IF--7||F7|||L-7|L---JF7|L--7F-7LJL--J|L--7F7LJFJ|FJF-7L-7L7I||FJ|F7|||LJ|LJLJFJ|F-7F-JLJLJF--JF-J|FJL7ILJF7|F--J|F--JOOOOOOOOOOOO
# OOOOOOOOFJL-JF7LJLJLJ||F-JL-----J||F7ILJFJF7F7F-JF7ILJL-7|FJL-JFJF7|FJFJ|L7|||||L-7L7F-7L7||FJL--7F--JF7IL-7||F-JF--JLJL-7I|L----7OOOOOOOOOO
# OOOOOOOFJF7F-JL-7F7F7|||F7F-7F7F-JLJ|F-7L7|LJLJF-JL-7F7FJ|L---7L7||||FJFJI|||||L-7|FJL7|FJLJL7F7I|L-7I|L7F7|LJL-7L7F-----JFJF----JOOOOOOOOOO
# OOOOOOOL7|LJIF7FJ|LJ|||||||FJ||L--7FJL7L-J|F--7L-7F-J|||FJF--7|FJ|LJ||FJF7|||||F-J|L7FJ||F---J|L7L-7|FJFJ|||F--7L-JL7IF7F7|FJF7F7OOOOOOOOOOO
# OOOOOOOOLJIF7||L7|F-J||||LJ|FJL7F-J|F7L--7||F-JF7||F7||||I|F-J||I|F-J||I||||||||F7L7||FJ||F7F7L7|F7|||FJI|LJL-7L--7FJFJLJLJL-JLJ|OOOOOOOOOOO
# OOOOOOOOOF-JLJL7LJL-7LJ||F-JL7FJL-7LJL7F7|LJL7FJ|||||||||FJ|F7||FJL7FJL7|LJ||||LJ|FJ||L7|||LJ|FJ||||LJ|F-JF---JIF7LJFJF7F--7F--7|OOOOOOOOOOO
# OOOOOOOOOL----7|F7F7L-7LJ|IF-JL7F7L-7FJ|||IF-JL7||||||LJ||ILJ||||F7|L7FJ|F-J|||IFJL7|L7|||L-7||FJ||L7FJ|F-JFSIF-JL7FJFJ|L-7|L-7||OOOOOOOOOOO
# OOOOOOF7OF----JLJLJL--JF7L7|F7FJ||F-JL-J||FJF7FJLJLJ|L7I|L--7|||LJ||FJL7|L7FJ||FJF7||FJLJ|F-JLJ|FJL7|L7|L7FJL7|F-7LJFJIL--JL--JLJOOOOOOOOOOO
# OOOOOFJL-JF7F----7F----JL7|LJ||FJ|L7F7F7|||FJ|L-7F--JFJFJF7FJLJL7FJLJF7|L7LJFJ||FJ|||L7F-JL--7FJL-7||I||ILJF7LJL7L--JF7IF-7F-7OOOOOOOOOOOOOO
# OOOOOL---7|LJF---J|F-----J|F7||L7L-J||||LJ||FJF7||F7FJIL7|||F---JL---J|L-JF-JFJ||FJ|L7|L7F7F7|L7F7|||FJ|F--JL-7FJIF7I|L-JFJ|FJOOOOOF7OOOOOOO
# OOOOOF--7LJIFJF7F7||F7F7F7LJLJL-JF--JLJL-7|||FJ||||||F--J|LJ|F7F7F-7F7|IF-JF7|I||L7L7||FJ||||L7||||||L7|L----7LJF-J|FJF--JI|L---7OO|L7OOOOOO
# OOOOO|F7L---JFJ||LJLJLJLJL7F7F7F7L7F-7F-7|||||FJ|||LJL7F7L7ILJ|||L7|||L7|F7|LJFJL7L-J||L7|||L7|LJ||||ILJIF---JF7L-7LJFJIF--JF---JF7|FJOOOOOO
# OOOOOLJ|F---7L7LJIF------7||||||L-J|ILJI||||LJL7||L-7FJ||FJF--J||FJ||L7|||LJF-JF7L--7LJFJ||L7|L-7LJLJF---JF--7|L-7|F-JIFJF--JIF7I|LJ|OOOOOOO
# OOOOOOO|L7F7|FJIF-JF7F7F7LJ|LJLJIF7L---7|||L--7|||F-JL7||L7|F7FJ||FJL7|||L7FJF7||F7FJF7L7|L7|L--JF7IFJF7F7|F-J|F7||L--7L7L----JL7L-7L-7OOOOO
# OOOOOOFJFJ|LJ|F7L--JLJLJL-7|F-7F-J|F7F-JLJL-7FJLJ|L7F-J||FJ|||L7LJL7FJLJL7|L7|||LJ|L-JL7||FJ|F---JL7L-JLJLJL7FJ|LJ|F--JFJF7F--7FJII|F-JOOOOO
# OOOOOOL7|FJF-J|L---7F7F7F7LJL7|L-7LJLJF----7|L--7L7||F7||L7LJL7|F--JL7F-7||FJ|LJF-JF7F-J||L7|L7F--7L--------J|FJF7|L7F7|FJLJF7LJF7FJL--7OOOO
# OOOOOOOLJL-JF7L---7LJLJLJL---J|F7L----JF7F-J|F--JFJ|LJLJL7L7F7LJL-7F7|L7LJ|L7L-7|F7||L-7LJFJ|FJ|F7L7F--------JL-JLJFJ||||IF7||F7|||F---JOOOO
# OOOOOOOOF---JL7F--JF-----7F7F7LJL-----7||L7FJL--7L7L---7IL7LJ|F---J|LJIL-7L7|F-JLJ|||F7L-7L-JL-J|L-J|F-------------JFJLJL7|||||||||L7OOOOOOO
# OOOOOOOO|F-7F7LJF--JF--7ILJLJ|F7F7F7F7LJ|FJL----JI|F7F-JF7|F-JL7F-7L----7L7||L--7FJ|||L--JF-----JF--JL-----7F7F---7FJF--7LJLJLJLJLJFJOOOOOOO
# OOOOOOOFJ|ILJL-7|F--JF7L7F7IFJ|||LJLJL-7LJIF-----7LJ||F-JLJ|IF7||FJF7F-7|FJ||F7FJL7||L---7|F7F-7FJF-7F----7|||L-7FJL7|F7L---------7L7OOOOOOO
# OOOOOOOL7|F--7FJ|L7F7|L7LJL-JFJLJF-----JF-7L7F---JF7LJL-7F7|FJLJ||FJ|L7|||FJ||||F7LJ|F--7|||||ILJIL7|L-7F7|LJL--JL--JLJ|F--7F7IF-7L-JOOOOOOO
# OOOOOOOOLJ|F7LJFJFJ|LJIL--7F7|F7IL---7F7L7L-JL----J|F-7FJ|LJ|F--J||FJFJ||LJFJ|LJ|L--JL-7||LJLJF7IF7|L-7LJ||F--7F7F7F7F7LJF7LJL-JFJOOOOOOOOOO
# OOOOOOOOOO||L7FJIL7|F-----J|LJ|L--7F7LJL-JF--------J|FJL7|IFJL-7FJ|L7L7|L-7L7L-7|F--7F-JLJF-7FJL7||L-7L--JLJF7||LJLJLJL7FJL7F7F7|F7OOOOOOOOO
# OOOOOOOOOOLJI|L--7LJL-----7L-7L7F7LJL--7F7L-----7F--JL7FJL7|F-7|L7|FJFJL--JFJF-J||IFJL-7F7L7LJF7LJL-7|F-----J||L------7|L-7|||||LJL-7OOOOOOO
# OOOOOOOOOOF--JF7FJIF7IF7F-JF-JILJL----7LJL7F7F--J|F-7FJL-7|||I||FJ|L7|F7F--JFJF7LJFJF7FJ|L7L-7|L---7|LJF-----JL-------JL7FJLJ|||F---JOOOOOOO
# OOOOOOOOOOL-7FJLJIFJL-J|L-7L-7F-------JIF7|||L---JL7LJF-7LJ||I|||FJFJ|||L7F7L-J|F-JFJLJIL7L-7LJF---JL7IL-----7F-7IF7IF7ILJIF7|||L----7OOOOOO
# OOOOOOOOOOOO||F---JF7F7L--JF-JL------7IFJ|||L7F-7F-JF-JFJF-JL7LJ||I|FJ|L-J||F7FJL-7L7F-7IL-7L-7L7F7F7L7F7F---J|FJFJL-JL---7|||||F----JOOOOOO
# OOOOOOOOOOOO||L----JLJL7F--JF-------7|FJFJLJILJILJF7|F-JIL-7FJF7LJI||I|F7FJ||LJIF7|FJL7L---JF7L7LJLJL7LJ||F--7||FJF7F7F7F7LJ||||L-7OOOOOOOOO
# OOOOOOOOOOOOLJF7F-7F7F7LJF7IL7F----7LJ|FJF7IIF7F7I|LJL7F7F7LJI|L-7FJ|FJ|LJI|L7F-JLJ|F7L---7FJL7L---7FJF7LJ|F-J|LJFJ||LJ||L7FJ||L--JOOOOOOOOO
# OOOOOOOOOOOF7I||L7LJ||L--JL7ILJF7IFJIFJ|I|L7FJLJL7|F--J||||IF-JF-JL-JL7L--7|FJL-7F-J||IF7FJ|F-JF--7|L7||F-JL--JF7L7||F7LJILJI|L--7OOOOOOOOOO
# OOOOOOOOOOO|L-JL-JF7|L---7FJF7FJL7L-7|FJFJFJ|F---J||IF7|LJL7|F7L7F-7IIL7F-J||F7FJ|F-JL-JLJFJL--JF-JL7||LJF-----JL-JLJ|L-----7|F7FJOOOOOOOOOO
# OOOOOOOOOOOL------J|L-7F-JL7|||F7L--J|L7|FJI||F7F7|L7|||F7FJ||L-J|FJIF-JL7FJ||LJFJL7F7F7F7|F---7L--7LJ|F-JF------7F7IL7F----JLJLJOOOOOOOOOOO
# OOOOOOOOOOOOF-7F---JF7|L--7LJ|LJL----JFJ||F-JLJLJ||FJ||||LJFJL7IFJ|IIL-7FJL7|L-7L7FJ|||LJLJL--7L-7IL--JL--JF----7LJL--JL---7OOOOOOOOOOOOOOOO
# OOOOOOOOOOOOL7LJF7F-J||IF7L-7|F7IF7F-7L-JLJF7F7F7||L-JLJL--JF7L-JFJIIIILJIILJIIL-JL-JLJIF7F7F7L-7|F7F------JF7F7L----------JOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOL7FJLJF-JL-JL--JLJL-JLJIL-7F--JLJ||LJ|F7F7F-7F7|L--7L-7IIIIIIIIIIF7F7IF----JLJ||L--JLJLJF------JLJL---7F------7OOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOLJIF7L-7F--7F---7F7F-7F-7|L----7LJF7||LJ|L7|||L--7L7FJIIIIIIIF--JLJL7L------7|L--------JIF----7F7F7F7LJF7F---JOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOF7F7||F-J|F-JL7F-J|||ILJFJL7F7F-JF7|LJ|F7L-JLJL-7FJILJIIIIIIIIL7F---7|F-7F---JL-7IF--7F7F7L---7LJLJLJL--JLJF7F7OF7F7OOOOOOOOOOO
# OOOOOOOOOOOOFJLJLJLJF-JL-7FJL7FJ||F-7L-7||||F-J|L-7LJL-7F7F-7||IIIIIIIIIIIII||IF-J||FJL---7F7L-JF7LJLJ|IF--JIF7IF----7F7|LJL-JLJ|OOOOOOOOOOO
# OOOOOOOOOOOOL7F7F-7FJF---J|F-JL7LJL7L--JLJLJL-7L--JF7F-J|||FJLJIIIIIIIIIIIIILJIL7FJ|L7F7F7LJL7F7|L7F-7L7L---7|L7L7F--J|LJF7F----JOOOOOOOOOOO
# OOOOOOOOOOOOOLJ||ILJIL----JL---JF7IL---7F7F7F7|F7F7|LJF-JLJL--7IIIIIIIIIIIIIIIF-JL7L7LJLJ|IF7LJLJI||IL7|F---J|FJFJL7F-JF-J||F7F7OOOOOOOOOOOO
# OOOOOOOOOOOOOOOLJF7F7F7IF---7F7FJ|F----J||||||||LJ|L--JF-7F7F7L7IIIIIIIIIIIIIIL-7FJIL--7FJFJL7F7F-J|F-J|L----JL-JF7LJF7L7ILJ|LJL--7OOOOOOOOO
# OOOOOOOOOOOOOOOOO|||||L7L--7LJ|L7|L-----JLJLJLJL-7|F---JI||LJL-JIIIIIIIIIF--7IF-JL7F---J|IL-7|||L--JL-7L--7F-7F-7|L7FJL7L7F7|F----JOOOOOOOOO
# OOOOOOOOOOOOOOOF-JLJ|L7|IF7L-7|FJL------7F-7F-7F-J|L7IF-7|L--7IIIIIIIIIIIL-7L7L-7FJL---7L7F7||||F-7F7IL--7LJFJL7||ILJF7L7LJLJ|IF--7OOOOOOOOO
# OOOOOOOOOOOOOOOL---7L-JL-JL--JLJF7F7F7F7LJILJI|L-7L7L-JFJL-7FJIIIIIIIIIIIIIL7L--JL7F7F7|FJ|LJLJ|L7LJ|F7F-JF7|F7||L---JL7L---7L-JF7L--7OOOOOO
# OOOOOOOOOOOOOOOF7F7L---7F7F--7F-JLJLJLJL---7F7|F7|FJF-7L7F7LJIIIIIIIIIIIIF-7|F-7F7LJLJLJL7L---7|FJF7LJLJF-J|||LJ|F--7F7L--7IL--7|L---JOOOOOO
# OOOOOOOOOOOOOOFJLJL-7F7LJ||F-J|F------7F-7FJ||LJLJL7L7L7LJL--7IIIIIIIIIIIL7LJ|FJ|L------7|F7F-J|L7|L----JF-JLJF7LJF-J|L--7L7F7ILJOOOOOOOOOOO
# OOOOOOOOOOOOOOL--7F7LJL--J|L--J|F----7|L7LJI|L-7F-7L7L7|F7F-7|IIIIIIIIIIII|F7|L-JF7F----JLJ|L-7|ILJF7F--7L---7|L-7L-7L-7IL7LJ|F7F7OF7OOOOOOO
# OOOOOOOOOOF7OF7F7||L--7F7FJF---J|F---JL-JF--JF7LJFJFJFJ||LJILJIIIIIIIIIIII|||L7F-JLJF7F---7L--JL7F-JLJF7L--7FJ|F-JF7L--JF7L-7||LJL7|L7OOOOOO
# OOOOOOOOOFJL-J|||LJF7ILJLJIL----JL-------JF7FJ|F7L7|FJILJF7F7IIIIIIIIIIIIILJL7|L--7FJLJIF7L7F7F7LJF-7FJL--7LJI||F7|L7F-7||F7LJL7F-J|FJF7OOOO
# OOOOOOOOOL---7LJL-7||F7IF7F---------7F----J|L7|||FJ|L7F-7||||IIIIIIIIIIIF7IIILJF-7LJF---J|I||LJ|F-JILJIF7FJF7FJLJ||FJ|FJ|||L7F7|L--JL-J|OOOO
# OOOOOOOOOOOOFJF--7|||||FJ|L-----7F-7LJF---7|FJLJLJFJFJ|FJ|||L7F7F7IIIIII|L7IIIIL7L-7L-7F7L7||F-JL7F7F--JLJI|||F--J|L-JL-JLJFJ|||F---7F-JOOOO
# OOOOOOOOOOOO|FJF-JLJLJ|L7L---7F-JL7L-7|F--J|L--7F7L-JFJL-J|L7||LJ|IIIIII|FJF7IIFJF7L--J|L7LJ|L---J|LJF-----JLJL---JF7F7F7F7L-JLJL--7LJOOOOOO
# OOOOOOOOOOOO||FJF7F7F7L7|F7F7LJF--JF7LJL7F7L---J|L7IFJF--7|FJ||F-JIF7IIFJL7|L7IL-JL--7FJIL7FJIF---JF7|F---7F7F-7F7FJLJLJ|||F-7F7F-7L--7OOOOO
# OOOOOOOOOOOOLJL-JLJ||L7LJ||||F7|IF7||F-7LJL7F---JFJFJFJF7LJL7LJL7F7||F7L7FJL7|F--7F7FJ|F--J|F-JF---JLJL--7LJ|L7|||L--7F7LJLJFJ||L7L---JOOOOO
# OOOOOOOOOOOOF7IF--7LJIL--JLJ||LJFJLJLJIL---J|F--7L7|FJFJL--7L7F7LJLJ||L-JL-7||L-7LJ||FJL7F7||F7|F---7F---JF7L7||||F--J|L---7|FJL-JIF7OOOOOOO
# OOOOOOOOOOOO||FJF-JF7F7F7F7ILJF7L--7F7F7F7F-JL-7|FJ||FJF---JILJL7F--JL7F---J|L-7L-7|LJF7||LJLJLJL--7|L----JL7|||||L7F7|F---JLJF7IF7|L7OOOOOO
# OOOOOOOOOOOO||L7|F7|LJLJ||L---J|IF7LJ||LJLJF7F-J||FJ|L7L--7F-7F7||F7II|L7F-7L-7L-7||IFJ|LJF----7F--J|IF7F--7|||||L7||||L------JL7|LJFJOOOOOO
# OOOOOOOOOOF-JL-J|||L---7|L----7|FJ|F7LJF7F-JLJF7LJL7|IL7F-J|FJ|||||L7FJFJ|FJF7|F7||L7|FJF7L--7FJL--7L7||L-7LJLJLJI|LJLJF7F-7F---J|F-JIF7OOOO
# OOOOOOOOOOL7F7F7LJL7IF-J|F7IF7||L7|||F-J|L----JL7F7|L7I|L-7||FJLJ||FJL7|FJL7||LJ|||FJ|L7|L---JL--7IL7LJL--JIF----7L7F-7|LJILJIF7I||IF7||OOOO
# OOOOOOOOOOOLJLJL--7L-JF7LJL-JLJL-JLJ|L-7|F7F-7F-J||L7L7|F-J|||F-7|||F7|||F-J|L7FJLJ|FJFJL-7F--7F-JF-JF-7F--7|F---JILJI|L---7F7|L-JL-JLJL7OOO
# OOOOOOOOOF7IIIF---JF7FJL7F---------7L--J|||L7||F7||I|FJ||F7||||ILJ|LJ||LJ|F7|FJL-7FJL7L7F7LJF-JL--JF-JILJF-J||F-7IF7IFJF7F-J|||F---7F---JOOO
# OOOOOOOOO||F7IL----JLJIILJF-------7L---7|||FJLJ||||FJL7|LJ||LJL-7FJF-JL-7||LJ|F-7||F7|FJ||F7L--7F-7|IF---JIFJLJFJFJL7|FJLJF-JLJL7F7LJOOOOOOO
# OOOOOOOF7||||F-----7F7IF-7L----7F7L--7FJLJLJF-7|LJLJF-JL-7|L7F--JL7L-7F-J||F-JL7||LJLJL7||||F7ILJFJL7L-----JF-7L-JF-JLJF7IL-7F--J||IF7OF7OOO
# OOOOOOFJ|||||L----7LJL7L7|F7F-7LJL--7|L7IF7FJFJL--7FJF--7|L7|L---7L7FJ|F7LJL7F7||L---7FJ|||||L7F7L--JIF-----JI|F-7|IF7FJ|F-7|L---JL-JL-J|OOO
# OOOOOOL7LJ||L7F---JF-7|FJLJ|L7L-----JL7L-J|L7|F-7I||I|F-JL7LJF---JFJ|ILJL7F7LJ|||F--7||I|||||FJ||F7IF7L--7F7F7LJI|L-J|L7|L7||F----------JOOO
# OOOOOOOL-7||FJL-7F-JI||L--7L-JF-7F-7IIL-7FJFJ||FJFJL7|L-7I|F-JF7IFJFJF7IILJ|F-J||L-7|||FJLJLJL7|||L-JL7F-J|LJL-7FJF--JFJL-JLJL-7IF7F----7OOO
# OOOOOOOF-JLJL---J|F--JL--7L7F-JILJIL7IF7LJFJFJ||FJF-J|F-JFJL-7|L7L7L-JL7F7FJ|F7||F7|LJ|L--7F--J|LJF--7|L-7|F---JL-JIF-JF7F7F7F7L-JLJF7F-JOOO
# OOOOOOFJF-7F-7F--JL---7F7L-J|F7IF7IFJFJL-7L7L7||L7L-7||F-JF7FJL7L7|F---J||L7||LJ||||F-JF7FJ|F7IL--JF7||F7LJL-7F7F7F-JF7||||||||F7F--JLJF7OOO
# OOOOOOL7|FJ|FJ|IF7F---J|L---J|L-JL-JIL7F-JIL7LJL-JF7|||L-7|LJF7L7|||F7F7|L7||L-7|||||F7||L7LJL7F---JLJLJL----J|LJLJF7|LJLJ||||LJ|L----7|L7OO
# OOOOOOOLJL7||FJFJLJF-7FJIF---JF--7F7F7|L7IF7L--7F7|LJ||IFJ|F7|L-J||LJLJ|L7||L7FJLJ||LJ||L-JF--JL---7F7F7F----7|F-7FJLJF--7LJ||F-JF---7LJFJOO
# OOOOOOOOOOLJLJO|F7FJILJF7L7F--JF7LJLJLJFJFJ|F7ILJ||F7|L7L7|||L7F7LJF---JI|LJFJL--7LJF7|L--7L7IF7F7ILJLJ||F---J||ILJF7FJF7L-7|||F7L--7L7FJOOO
# OOOOOOOOOOOOOOOLJLJF7F-J|ILJIF7|L---7F7|FJFJ|L-7FJLJ|L7L-JLJL7LJ|F7L7IF-7L7FJF7F7L-7|LJF--JFJFJLJ|F---7LJL---7|L---JLJFJL--JLJ||L7F7|ILJOOOO
# OOOOOOOOOOOOOOOF---J|L-7L----JLJF--7LJLJL7|IL-7|L7F-JIL7F----JF7LJL7L7L7|FJ|I|||L-7||F7L--7L7L7F-JL-7FJF--7F7LJF----7FJF----7ILJFJ||L7OOOOOO
# OOOOOOOOOOOOOOOL---7L7FJF--7F7F7|F7L-7F-7|L7F7||FJ|F---JL7F7F7|L-7IL7L7||L7|FJ|L-7LJLJ|F7FJFJFJ|F7F-J|IL-7LJL-7L---7|L-JF---JF-7L-JL7|OOOOOO
# OOOOOOOOOOOOOOF7IF7L7||FJF-J|||LJ|L--JL7||FJ||||L7|L----7||||||F-JF7|FJ||I||L7|F7L-7F-J||L7|IL7|||L7FJF7IL--7IL7F7FJ|F-7L7F7IL7L-7OO||OOOOOO
# OOOOOOOOOOOOOO||FJL-JLJ|IL-7||L7FJF-7F7||||FJ|||FJ|F7F-7|||||LJL7FJLJL7||FJL7||||F7|L7FJL7|L7FJ||L7|L7|L7F-7|F7LJLJILJIL7LJL7FJF-JOOLJOOOOOO
# OOOOOOOOOOOOOO||L7F-7F-JF-7LJL-JL7|FJ|||||||FJ|LJILJ||I||||||F--JL7F7I||||F-J|||LJ||FJ|F-J|FJL7LJI|L7||FJL7|LJL------7F7|F-7||FJOOOOOOOOOOOO
# OOOOOOOOOOOOF-J|I|L7LJF7L7L------J|L7|LJLJ|||FJF----JL7||||LJ|F7F7LJL7LJ||L7FJ||F-J|L7|L7FJL7FJIF-JFJ|||F7|L7F-----7FJ||LJI|LJ|OOOOOOOOOOOOO
# OOOOOOOOOOF7|F7|FJFJIFJL7|F7F--7F7|FJL--7FJ|||IL7F7F7FJ|||L7FJ|LJL7F7L-7||FJL7||L7FJI|L7||F-JL-7|F7|FJ|LJ||FJL--7F7LJFJL--7|F-JOOOOOOOOOOOOO
# OOOOOOOOOO|LJ||LJFJF-JF7LJ|||F7||LJL-7F-J|FJLJF-J|||||FJ|L7|L7L7F-J||F7|||L-7|LJFJL-7L7|||L7F7FJ||||L7|F-J|L7F-7LJL--JF7F7||L--7OOOOOOOOOOOO
# OOOOOOOOOO|F-JL7FJIL--JL-7|LJ|LJ|F---JL-7||F7I|F7||||||FJILJIL-JL7FJ||LJ||F-JL-7L7F-JFJ|LJILJ||ILJ||FJ|L7FJFJL7|F7F-7FJLJ|||F7FJOOOOOOOOOOOO
# OOOOOOOOOOLJF--J|F-------JL-7L7FJL-7F7F-J|||L-J|LJ||||||IF7F-----JL7|L7ILJ|F7F7|FJL-7L7|F7F--JL--7LJL7|I||IL7FJLJ|L7|L--7LJLJ|L7OOOOOOOOOOOO
# OOOOOOOOOOOO|F-7|L7F7F7F7F7FJILJF7FJ||L7FJ||F7FJF-J|||||FJLJF-7F7F-J|FJF7FJ|||LJL7F7L7|||LJF-7F7FJIF-JL7||F-J|F7IL7||F-7L-7OO|FJOOOOOOOOOOOO
# OOOOOOOOOOOO||OLJFJ|||||LJ||F---JLJFJ|FJ|FJ||LJIL7FJ||LJL--7|FJ|||F-JL-J|L7|||F--J||FJ|||F-JI|||L-7L-7FJLJL-7LJ|F7LJLJIL-7L7OLJOOOOOOOOOOOOO
# OOOOOOOOOOOOLJOF-JFJ||||F7LJL7F--7FJFJ|FJ|FJL-7IFJL7||IF---J||FJ||L7F-7FJFJ|||L7F7||L7LJLJF--J|L7FJF7||F-7F-JF7LJL7IF--7I|FJOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOL-7|FJ||||L---J|F-JL7L-JL7|L7F7L7L7FJLJFJF7F7|||FJ|FJL7|L7L7|||FJ|||L7L7F--JF7FJFJ|I|LJLJFJL7FJL7F7L-JF7L7LJOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOFJ|L7|LJL7F7F7|L7F7L--7ILJFJ|L7L7LJF--JFJ|||||||FJ|F7|L-JI||LJL7|||FJFJL--7||L7|FJFJF-7FJF7|L-7|||F-7|L-JF7OOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOFJFJFJ|IF-J||||L7LJ|F--JF-7L7|FJFJF7L7F7|FJ|||||||ILJ|L-7F7|L7F-J|LJ|FJF7F-J||FJLJIL7|I|L-J||F-JLJ|L7|L---JL-7OOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOL-JOL7L7L7FJ|||FJF-JL7F-JFJI||L7|FJL-J|LJ|FJLJ||LJF--JF7LJ||FJL-7|F7|L-J|L7FJ|L7F---J|FJF-7|||F7F7|FJ|F7F-7F-JOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOL7|FJL7LJ||IL--7|L-7L--J|FJ||F-7FJIFJL--7||F-JF7FJL-7|LJF--J||LJF--JILJFJFJL-7F7|L7|FJ||LJLJ||L7||||FJL7OOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOLJL7FJF-J|F---J|F-JF7F7||FJLJILJIFJF-7FJLJ|F7||L7F7LJF7|F-7||F7L--7IF7L7L7F-J|||FJ|L-J|F7F-JL-J||||L7FJOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOO||OL7FJL-7F7||F7||||||L----7F-JFJI||F7ILJ||L7LJL-7|LJ|FJ|LJ|F7FJFJ|I|FJL-7|||L7L-7FJ||L----7LJLJO|L7OOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOLJOFJ|F-7||||||||||||L7F7F7|L7FJF-JLJL-7FJ|FJF7F-JL7FJ|FJF-J||L7L7L-JL7IFJ|||I|F-JL7||F----JOOOOOL-JOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOO|FJL7LJ|||||||||LJI||||||FJ|IL-7F7F-JL7|L7||L-7FJ|FJL7L-7||FJIL7F7FJFJFJ||FJL-7FJ||L-7F7IF-7OOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOLJF7|F7|||||||||F--J|LJLJL7|F--J|||IF7LJI|||F7|L7|L7FJF-J||L-7FJ|||FJFJI||L7F-JL-J|F7LJL7L7|OOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOFJLJ|||LJLJ||LJL7F7L---7I||L--7||L-JL7IFJ||||L7||FJ|I|F-J|F7||FJLJ|FJF-J|I||F7F--J||F-7L-JL--7OOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOL--7|||F---JL7F7LJ|F---JFJL7F-J|L7F-7|FJFJ||L7|||L7|FJL-7||LJ|L7F-JL7|F7|FJLJ|L--7|||I|F--7F7L7OOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO|||||F-7F7||L-7|L-7F7L7FJL7FJFJ|FJ|L7|FJL7LJLJI||L7F7||L-7|FJL7F-JLJLJ|F-7|F--J||L7LJOO||L-JOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOFJ|LJLJFJ||||F7LJF7LJL7LJIFJ|FJFJL-JOLJ|F7L----7LJO|||||F7|||F-JL--7F--JL7LJ|F7FJL7L-7OOLJOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOL-JOOOO|FJLJLJL7FJL7F-JF-7L-JL7|OOOOOF-J|L-----JOOOLJ||||||||L-7F--JL-7F7L7ILJ||IFJF7L7OOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO||OOF---JL-7|L--JFJOOOOLJOOOOO|F7L----7OOOOOOO||LJLJLJF-JL-7OF-J|L7|F--JL7L-JL-JOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOLJOFJF7F7F-JL7F7FJOOOOOOOOOOOOLJL7F7F-JOOOOOOO||OOOOOOL7F-7|OL-7|ILJL7F-7L--7OOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOL7|LJ|L7F7||LJOOOOOOOOOOOOOOOFJ||L-7OOOOOOOLJOOOOOOFJL7LJOF-JL---7||FJF--JOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOLJF-JFJ|LJL7OOOOOOOOOOOOOOOOL7|L7FJOOOOOOOOOOOOOOO|F-JOOOL-7F7F7|LJL7L-7OOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOL-7L7L7F7L-7OOOOOOOOOOOOOOOLJOLJOOOOOOOOOOOOOOOOLJOOOOOOOLJLJ||OOOL7FJOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOFJFJFJ|L7FJOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOLJOOOFJL-7OOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOL7L7|FJO||F-7OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOL-7FJOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOF-JFJ|L7O|LJFJOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOLJOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOL--JOL-JO|F7|OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOLJLJOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Inside tiles: 610

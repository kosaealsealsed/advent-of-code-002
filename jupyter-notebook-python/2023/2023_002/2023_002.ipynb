# %% [markdown]
# # Advent of Code

# %% [markdown]
# ## 2023-012-002
# ## 2023 002

# %% [markdown]
# https://adventofcode.com/2023/day/2

# %%
import re

# Bag configuration limits
limits = {'red': 12, 'green': 13, 'blue': 14}

# Parse the games and check if they are possible with the given bag configuration
def parse_and_check_games(lines, limits):
    possible_game_ids = []
    for line in lines:
        # Extract the game ID and sets of cubes revealed
        match = re.match(r"Game (\d+): (.+)", line.strip())
        if not match:
            continue
        game_id, sets = match.groups()
        game_id = int(game_id)

        # Check each set of cubes in the game
        is_possible = True
        for cube_set in sets.split(";"):
            # Parse the cubes in the current set
            cubes = re.findall(r"(\d+) (\w+)", cube_set.strip())
            for count, color in cubes:
                count = int(count)
                if count > limits.get(color, 0):
                    is_possible = False
                    break
            if not is_possible:
                break

        # If the game is possible, record its ID
        if is_possible:
            possible_game_ids.append(game_id)
    
    return possible_game_ids

# Read the input file and check games
with open('input.txt', 'r') as file:
    input_lines = file.readlines()

possible_games = parse_and_check_games(input_lines, limits)
sum_of_possible_games = sum(possible_games)

possible_games, sum_of_possible_games
# Out:
# ([1,
#   3,
#   4,
#   5,
#   7,
#   8,
#   12,
#   13,
#   14,
#   16,
#   20,
#   24,
#   25,
#   28,
#   32,
#   35,
#   36,
#   37,
#   38,
#   41,
#   44,
#   48,
#   49,
#   51,
#   52,
#   55,
#   58,
#   59,
#   60,
#   61,
#   62,
#   63,
#   64,
#   66,
#   67,
#   68,
#   69,
#   70,
#   72,
#   74,
#   77,
#   79,
#   82,
#   85,
#   86,
#   87,
#   88,
#   93,
#   94,
#   97,
#   98,
#   99,
#   100],
#  2776)

# %%
# Calculate the minimum number of cubes required for each game to be possible
def calculate_minimum_cubes_and_power(lines):
    game_powers = {}
    for line in lines:
        # Extract the game ID and sets of cubes revealed
        match = re.match(r"Game (\d+): (.+)", line.strip())
        if not match:
            continue
        game_id, sets = match.groups()
        game_id = int(game_id)

        # Track the minimum number of each color required
        min_cubes = {'red': 0, 'green': 0, 'blue': 0}
        for cube_set in sets.split(";"):
            # Parse the cubes in the current set
            cubes = re.findall(r"(\d+) (\w+)", cube_set.strip())
            for count, color in cubes:
                count = int(count)
                min_cubes[color] = max(min_cubes[color], count)

        # Calculate the power of the minimum set
        power = min_cubes['red'] * min_cubes['green'] * min_cubes['blue']
        game_powers[game_id] = power

    # Calculate the total power sum
    total_power_sum = sum(game_powers.values())
    return game_powers, total_power_sum

# Calculate for the given input
game_powers, total_power_sum = calculate_minimum_cubes_and_power(input_lines)

game_powers, total_power_sum
# Out:
# ({1: 63,
#   2: 1008,
#   3: 60,
#   4: 900,
#   5: 560,
#   6: 360,
#   7: 810,
#   8: 30,
#   9: 1155,
#   10: 364,
#   11: 624,
#   12: 616,
#   13: 12,
#   14: 840,
#   15: 2112,
#   16: 1080,
#   17: 480,
#   18: 1440,
#   19: 351,
#   20: 784,
#   21: 312,
#   22: 3150,
#   23: 288,
#   24: 80,
#   25: 45,
#   26: 3000,
#   27: 510,
#   28: 130,
#   29: 765,
#   30: 1672,
#   31: 190,
#   32: 240,
#   33: 1235,
#   34: 1456,
#   35: 144,
#   36: 55,
#   37: 96,
#   38: 182,
#   39: 1575,
#   40: 900,
#   41: 297,
#   42: 990,
#   43: 285,
#   44: 512,
#   45: 3060,
#   46: 210,
#   47: 770,
#   48: 308,
#   49: 1188,
#   50: 975,
#   51: 21,
#   52: 20,
#   53: 3825,
#   54: 672,
#   55: 48,
#   56: 546,
#   57: 3042,
#   58: 616,
#   59: 168,
#   60: 162,
#   61: 144,
#   62: 840,
#   63: 5,
#   64: 416,
#   65: 1500,
#   66: 1183,
#   67: 35,
#   68: 168,
#   69: 720,
#   70: 336,
#   71: 209,
#   72: 40,
#   73: 294,
#   74: 360,
#   75: 2197,
#   76: 1792,
#   77: 27,
# ...

# %%
import re

def parse_input(file_path):
    """Parse the input file into a list of games and their subsets."""
    games = []
    with open(file_path, 'r') as f:
        for line in f:
            match = re.match(r'Game (\d+): (.+)', line.strip())
            if match:
                game_id = int(match.group(1))
                subsets = match.group(2).split(';')
                games.append((game_id, subsets))
    return games

def parse_subset(subset):
    """Parse a subset string into a dictionary of cube counts."""
    counts = {'red': 0, 'green': 0, 'blue': 0}
    matches = re.findall(r'(\d+) (red|green|blue)', subset)
    for count, color in matches:
        counts[color] += int(count)
    return counts

def is_game_possible(subsets, max_counts):
    """Determine if a game is possible given the maximum counts for each color."""
    for subset in subsets:
        subset_counts = parse_subset(subset)
        for color, count in subset_counts.items():
            if count > max_counts[color]:
                return False
    return True

def calculate_sum(file_path, max_counts):
    """Calculate the sum of game IDs for possible games."""
    games = parse_input(file_path)
    total = 0
    for game_id, subsets in games:
        if is_game_possible(subsets, max_counts):
            total += game_id
    return total

# Main Execution
file_path = 'input.txt'
max_counts = {'red': 12, 'green': 13, 'blue': 14}
result = calculate_sum(file_path, max_counts)
print(f"The sum of game IDs that are possible is: {result}"
# Out:
#   Cell In[1], line 45
#     print(f"The sum of game IDs that are possible is: {result}"
#                                                                ^
# SyntaxError: incomplete input

# %%
import re

# Load the input data from the uploaded file
file_path = 'input.txt'
with open(file_path, 'r') as file:
    input_data = file.readlines()

# Define the maximum cubes for each color
max_cubes = {'red': 12, 'green': 13, 'blue': 14}

# Parse the input data
game_ids = []
possible_games = []

for line in input_data:
    match = re.match(r'Game (\d+): (.+)', line.strip())
    if match:
        game_id, rounds = match.groups()
        game_ids.append(int(game_id))
        
        # Check if all subsets are valid for this game
        is_possible = True
        subsets = rounds.split('; ')
        for subset in subsets:
            cubes = re.findall(r'(\d+) (\w+)', subset)
            for count, color in cubes:
                if int(count) > max_cubes[color]:
                    is_possible = False
                    break
            if not is_possible:
                break

        if is_possible:
            possible_games.append(int(game_id))

# Calculate the sum of possible game IDs
sum_of_possible_games = sum(possible_games)
sum_of_possible_games
# Out:
# 2776

# %%
# Function to calculate the minimum number of cubes required for each game and their power
def calculate_minimum_cubes_power(data):
    min_cubes_power_sum = 0
    for line in data:
        match = re.match(r'Game (\d+): (.+)', line.strip())
        if match:
            rounds = match.group(2)
            
            # Initialize minimum required cubes for this game
            required_cubes = {'red': 0, 'green': 0, 'blue': 0}
            
            # Parse each subset and update the required cubes
            subsets = rounds.split('; ')
            for subset in subsets:
                cubes = re.findall(r'(\d+) (\w+)', subset)
                for count, color in cubes:
                    required_cubes[color] = max(required_cubes[color], int(count))
            
            # Calculate the power for this game
            power = required_cubes['red'] * required_cubes['green'] * required_cubes['blue']
            min_cubes_power_sum += power

    return min_cubes_power_sum

# Calculate the result
minimum_cubes_power_sum = calculate_minimum_cubes_power(input_data)
minimum_cubes_power_sum
# Out:
# 68638

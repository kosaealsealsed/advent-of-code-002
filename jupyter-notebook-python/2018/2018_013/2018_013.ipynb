# %% [markdown]
# # Advent of Code

# %% [markdown]
# ## 2018-012-013
# ## 2018 013

# %% [markdown]
# https://adventofcode.com/2018/day/13

# %%
def parse_input(file_path):
    """
    Parse the input file to extract the track layout and carts.
    """
    with open(file_path, 'r') as file:
        lines = file.readlines()

    tracks = []
    carts = []

    # Process each line to separate tracks and carts
    for y, line in enumerate(lines):
        track_row = []
        for x, char in enumerate(line.rstrip('\n')):
            if char in '^v<>':  # Cart found
                # Store the cart with its direction and initial position
                carts.append({'x': x, 'y': y, 'dir': char, 'turn': 0})  # turn: 0=left, 1=straight, 2=right
                # Replace cart with the underlying track
                track_row.append('|' if char in '^v' else '-')
            else:
                track_row.append(char)
        tracks.append(track_row)

    return tracks, carts


def move_cart(cart, tracks):
    """
    Move the cart based on its current direction and update its state based on the track.
    """
    # Move the cart
    if cart['dir'] == '^':
        cart['y'] -= 1
    elif cart['dir'] == 'v':
        cart['y'] += 1
    elif cart['dir'] == '<':
        cart['x'] -= 1
    elif cart['dir'] == '>':
        cart['x'] += 1

    # Determine the new direction based on the track piece
    current_track = tracks[cart['y']][cart['x']]
    if current_track == '/':
        cart['dir'] = {'^': '>', 'v': '<', '<': 'v', '>': '^'}[cart['dir']]
    elif current_track == '\\':
        cart['dir'] = {'^': '<', 'v': '>', '<': '^', '>': 'v'}[cart['dir']]
    elif current_track == '+':
        # Intersection: decide turn based on the turn counter
        if cart['turn'] == 0:  # Turn left
            cart['dir'] = {'^': '<', 'v': '>', '<': 'v', '>': '^'}[cart['dir']]
        elif cart['turn'] == 2:  # Turn right
            cart['dir'] = {'^': '>', 'v': '<', '<': '^', '>': 'v'}[cart['dir']]
        # Update turn counter
        cart['turn'] = (cart['turn'] + 1) % 3


def detect_collision(carts):
    """
    Check if any two carts have collided.
    """
    positions = {}
    for cart in carts:
        pos = (cart['x'], cart['y'])
        if pos in positions:
            return pos  # Collision detected
        positions[pos] = True
    return None


def simulate_tracks(tracks, carts):
    """
    Simulate the carts on the track until the first collision.
    """
    while True:
        # Sort carts by position for turn order
        carts.sort(key=lambda c: (c['y'], c['x']))
        for cart in carts:
            move_cart(cart, tracks)
            collision = detect_collision(carts)
            if collision:
                return collision


# Read the input file and parse the track and carts
input_file_path = 'input.txt'
tracks, carts = parse_input(input_file_path)

# Simulate the track system and find the first collision
first_collision = simulate_tracks(tracks, carts)
first_collision
# Out:
# (118, 66)

# %%
def simulate_tracks_with_debug(tracks, carts):
    """
    Simulate the carts on the track until only one cart remains, with debugging.
    """
    tick = 0  # Track the number of ticks
    while len(carts) > 1:
        tick += 1

        # Sort carts by position for turn order
        carts.sort(key=lambda c: (c['y'], c['x']))
        carts_to_remove = set()

        for cart in carts:
            # Skip carts already involved in crashes this tick
            if (cart['x'], cart['y']) in carts_to_remove:
                continue

            move_cart(cart, tracks)
            collision = detect_collision(carts)

            if collision:
                # Mark carts involved in the collision for removal
                carts_to_remove.update(
                    [(c['x'], c['y']) for c in carts if (c['x'], c['y']) == collision]
                )
                print(f"Collision detected at {collision} on tick {tick}.")

        # Remove carts involved in crashes
        carts = [c for c in carts if (c['x'], c['y']) not in carts_to_remove]

        # Debugging output for each tick
        print(f"Tick {tick}: {len(carts)} carts remaining.")

    # Only one cart remains; return its position
    last_cart = carts[0]
    return last_cart['x'], last_cart['y']


# Simulate the track system with debugging until only one cart remains
last_cart_position_debug = simulate_tracks_with_debug(tracks, carts)
last_cart_position_debug
# Out:
# Collision detected at (101, 18) on tick 1.
# Collision detected at (101, 18) on tick 1.
# Collision detected at (101, 18) on tick 1.
# Collision detected at (101, 18) on tick 1.
# Collision detected at (101, 18) on tick 1.
# Collision detected at (101, 18) on tick 1.
# Collision detected at (101, 18) on tick 1.
# Collision detected at (101, 18) on tick 1.
# Collision detected at (101, 18) on tick 1.
# Collision detected at (101, 18) on tick 1.
# Collision detected at (101, 18) on tick 1.
# Collision detected at (101, 18) on tick 1.
# Collision detected at (101, 18) on tick 1.
# Collision detected at (101, 18) on tick 1.
# Collision detected at (101, 18) on tick 1.
# Tick 1: 15 carts remaining.
# Tick 2: 15 carts remaining.
# Tick 3: 15 carts remaining.
# Tick 4: 15 carts remaining.
# Tick 5: 15 carts remaining.
# Tick 6: 15 carts remaining.
# Tick 7: 15 carts remaining.
# Tick 8: 15 carts remaining.
# Tick 9: 15 carts remaining.
# Tick 10: 15 carts remaining.
# Tick 11: 15 carts remaining.
# Tick 12: 15 carts remaining.
# Tick 13: 15 carts remaining.
# Tick 14: 15 carts remaining.
# Tick 15: 15 carts remaining.
# Tick 16: 15 carts remaining.
# Tick 17: 15 carts remaining.
# Tick 18: 15 carts remaining.
# Tick 19: 15 carts remaining.
# Tick 20: 15 carts remaining.
# Tick 21: 15 carts remaining.
# Tick 22: 15 carts remaining.
# Tick 23: 15 carts remaining.
# Tick 24: 15 carts remaining.
# Tick 25: 15 carts remaining.
# Tick 26: 15 carts remaining.
# Tick 27: 15 carts remaining.
# Tick 28: 15 carts remaining.
# Tick 29: 15 carts remaining.
# Tick 30: 15 carts remaining.
# Tick 31: 15 carts remaining.
# Tick 32: 15 carts remaining.
# Tick 33: 15 carts remaining.
# Tick 34: 15 carts remaining.
# Tick 35: 15 carts remaining.
# Tick 36: 15 carts remaining.
# Tick 37: 15 carts remaining.
# Tick 38: 15 carts remaining.
# Tick 39: 15 carts remaining.
# Tick 40: 15 carts remaining.
# Tick 41: 15 carts remaining.
# Tick 42: 15 carts remaining.
# Tick 43: 15 carts remaining.
# Tick 44: 15 carts remaining.
# Tick 45: 15 carts remaining.
# Tick 46: 15 carts remaining.
# Tick 47: 15 carts remaining.
# Tick 48: 15 carts remaining.
# Tick 49: 15 carts remaining.
# Tick 50: 15 carts remaining.
# Tick 51: 15 carts remaining.
# Tick 52: 15 carts remaining.
# Tick 53: 15 carts remaining.
# Tick 54: 15 carts remaining.
# Tick 55: 15 carts remaining.
# Tick 56: 15 carts remaining.
# Tick 57: 15 carts remaining.
# Tick 58: 15 carts remaining.
# Tick 59: 15 carts remaining.
# Tick 60: 15 carts remaining.
# Tick 61: 15 carts remaining.
# Tick 62: 15 carts remaining.
# Tick 63: 15 carts remaining.
# Tick 64: 15 carts remaining.
# Tick 65: 15 carts remaining.
# Tick 66: 15 carts remaining.
# Tick 67: 15 carts remaining.
# Tick 68: 15 carts remaining.
# Tick 69: 15 carts remaining.
# Tick 70: 15 carts remaining.
# Tick 71: 15 carts remaining.
# Tick 72: 15 carts remaining.
# Tick 73: 15 carts remaining.
# Tick 74: 15 carts remaining.
# Tick 75: 15 carts remaining.
# Tick 76: 15 carts remaining.
# Tick 77: 15 carts remaining.
# Tick 78: 15 carts remaining.
# Tick 79: 15 carts remaining.
# Tick 80: 15 carts remaining.
# Tick 81: 15 carts remaining.
# Tick 82: 15 carts remaining.
# Tick 83: 15 carts remaining.
# Tick 84: 15 carts remaining.
# Tick 85: 15 carts remaining.
# Collision detected at (108, 107) on tick 86.
# Tick 86: 13 carts remaining.
# Tick 87: 13 carts remaining.
# Tick 88: 13 carts remaining.
# Tick 89: 13 carts remaining.
# Tick 90: 13 carts remaining.
# Tick 91: 13 carts remaining.
# Tick 92: 13 carts remaining.
# Tick 93: 13 carts remaining.
# Tick 94: 13 carts remaining.
# Tick 95: 13 carts remaining.
# Tick 96: 13 carts remaining.
# Tick 97: 13 carts remaining.
# Tick 98: 13 carts remaining.
# Tick 99: 13 carts remaining.
# Tick 100: 13 carts remaining.
# Tick 101: 13 carts remaining.
# Tick 102: 13 carts remaining.
# Tick 103: 13 carts remaining.
# Tick 104: 13 carts remaining.
# Tick 105: 13 carts remaining.
# Tick 106: 13 carts remaining.
# Tick 107: 13 carts remaining.
# Tick 108: 13 carts remaining.
# Tick 109: 13 carts remaining.
# Tick 110: 13 carts remaining.
# Tick 111: 13 carts remaining.
# Tick 112: 13 carts remaining.
# Tick 113: 13 carts remaining.
# Tick 114: 13 carts remaining.
# Tick 115: 13 carts remaining.
# Tick 116: 13 carts remaining.
# Tick 117: 13 carts remaining.
# Tick 118: 13 carts remaining.
# Tick 119: 13 carts remaining.
# Tick 120: 13 carts remaining.
# Tick 121: 13 carts remaining.
# Tick 122: 13 carts remaining.
# Tick 123: 13 carts remaining.
# Tick 124: 13 carts remaining.
# Tick 125: 13 carts remaining.
# Tick 126: 13 carts remaining.
# Tick 127: 13 carts remaining.
# Tick 128: 13 carts remaining.
# Tick 129: 13 carts remaining.
# Tick 130: 13 carts remaining.
# Tick 131: 13 carts remaining.
# Tick 132: 13 carts remaining.
# Tick 133: 13 carts remaining.
# Tick 134: 13 carts remaining.
# Tick 135: 13 carts remaining.
# Tick 136: 13 carts remaining.
# Tick 137: 13 carts remaining.
# Tick 138: 13 carts remaining.
# Tick 139: 13 carts remaining.
# Tick 140: 13 carts remaining.
# Tick 141: 13 carts remaining.
# Tick 142: 13 carts remaining.
# Tick 143: 13 carts remaining.
# Tick 144: 13 carts remaining.
# Tick 145: 13 carts remaining.
# Tick 146: 13 carts remaining.
# Tick 147: 13 carts remaining.
# Tick 148: 13 carts remaining.
# Tick 149: 13 carts remaining.
# Tick 150: 13 carts remaining.
# Tick 151: 13 carts remaining.
# Tick 152: 13 carts remaining.
# Tick 153: 13 carts remaining.
# Tick 154: 13 carts remaining.
# Tick 155: 13 carts remaining.
# Tick 156: 13 carts remaining.
# Tick 157: 13 carts remaining.
# Tick 158: 13 carts remaining.
# Tick 159: 13 carts remaining.
# Tick 160: 13 carts remaining.
# Tick 161: 13 carts remaining.
# Tick 162: 13 carts remaining.
# Tick 163: 13 carts remaining.
# Tick 164: 13 carts remaining.
# Collision detected at (73, 43) on tick 165.
# Collision detected at (73, 43) on tick 165.
# Collision detected at (73, 43) on tick 165.
# Collision detected at (73, 43) on tick 165.
# Collision detected at (73, 43) on tick 165.
# Collision detected at (73, 43) on tick 165.
# Collision detected at (73, 43) on tick 165.
# Tick 165: 11 carts remaining.
# Tick 166: 11 carts remaining.
# Tick 167: 11 carts remaining.
# Tick 168: 11 carts remaining.
# Tick 169: 11 carts remaining.
# Tick 170: 11 carts remaining.
# Tick 171: 11 carts remaining.
# Tick 172: 11 carts remaining.
# Tick 173: 11 carts remaining.
# Tick 174: 11 carts remaining.
# Tick 175: 11 carts remaining.
# Tick 176: 11 carts remaining.
# Tick 177: 11 carts remaining.
# Tick 178: 11 carts remaining.
# Tick 179: 11 carts remaining.
# Tick 180: 11 carts remaining.
# Tick 181: 11 carts remaining.
# Tick 182: 11 carts remaining.
# Tick 183: 11 carts remaining.
# Tick 184: 11 carts remaining.
# Tick 185: 11 carts remaining.
# Tick 186: 11 carts remaining.
# Tick 187: 11 carts remaining.
# Tick 188: 11 carts remaining.
# Tick 189: 11 carts remaining.
# Tick 190: 11 carts remaining.
# Tick 191: 11 carts remaining.
# Tick 192: 11 carts remaining.
# Tick 193: 11 carts remaining.
# Tick 194: 11 carts remaining.
# Tick 195: 11 carts remaining.
# Tick 196: 11 carts remaining.
# Tick 197: 11 carts remaining.
# Tick 198: 11 carts remaining.
# Tick 199: 11 carts remaining.
# Tick 200: 11 carts remaining.
# Tick 201: 11 carts remaining.
# Tick 202: 11 carts remaining.
# Tick 203: 11 carts remaining.
# Tick 204: 11 carts remaining.
# Tick 205: 11 carts remaining.
# Tick 206: 11 carts remaining.
# Tick 207: 11 carts remaining.
# Tick 208: 11 carts remaining.
# Tick 209: 11 carts remaining.
# Tick 210: 11 carts remaining.
# Tick 211: 11 carts remaining.
# Tick 212: 11 carts remaining.
# Tick 213: 11 carts remaining.
# Tick 214: 11 carts remaining.
# Tick 215: 11 carts remaining.
# Tick 216: 11 carts remaining.
# Tick 217: 11 carts remaining.
# Tick 218: 11 carts remaining.
# Tick 219: 11 carts remaining.
# Tick 220: 11 carts remaining.
# Tick 221: 11 carts remaining.
# Tick 222: 11 carts remaining.
# Tick 223: 11 carts remaining.
# Tick 224: 11 carts remaining.
# Tick 225: 11 carts remaining.
# Tick 226: 11 carts remaining.
# Tick 227: 11 carts remaining.
# Tick 228: 11 carts remaining.
# Tick 229: 11 carts remaining.
# Tick 230: 11 carts remaining.
# Tick 231: 11 carts remaining.
# Tick 232: 11 carts remaining.
# Tick 233: 11 carts remaining.
# Tick 234: 11 carts remaining.
# Tick 235: 11 carts remaining.
# Tick 236: 11 carts remaining.
# Tick 237: 11 carts remaining.
# Tick 238: 11 carts remaining.
# Tick 239: 11 carts remaining.
# Tick 240: 11 carts remaining.
# Tick 241: 11 carts remaining.
# Tick 242: 11 carts remaining.
# Tick 243: 11 carts remaining.
# Tick 244: 11 carts remaining.
# Tick 245: 11 carts remaining.
# Tick 246: 11 carts remaining.
# Tick 247: 11 carts remaining.
# Tick 248: 11 carts remaining.
# Tick 249: 11 carts remaining.
# Tick 250: 11 carts remaining.
# Tick 251: 11 carts remaining.
# Tick 252: 11 carts remaining.
# Tick 253: 11 carts remaining.
# Tick 254: 11 carts remaining.
# Tick 255: 11 carts remaining.
# Tick 256: 11 carts remaining.
# Tick 257: 11 carts remaining.
# Tick 258: 11 carts remaining.
# Tick 259: 11 carts remaining.
# Tick 260: 11 carts remaining.
# Tick 261: 11 carts remaining.
# Tick 262: 11 carts remaining.
# Tick 263: 11 carts remaining.
# Tick 264: 11 carts remaining.
# Tick 265: 11 carts remaining.
# Tick 266: 11 carts remaining.
# Tick 267: 11 carts remaining.
# Tick 268: 11 carts remaining.
# Tick 269: 11 carts remaining.
# Tick 270: 11 carts remaining.
# Tick 271: 11 carts remaining.
# Tick 272: 11 carts remaining.
# Tick 273: 11 carts remaining.
# Tick 274: 11 carts remaining.
# Tick 275: 11 carts remaining.
# Tick 276: 11 carts remaining.
# Tick 277: 11 carts remaining.
# Tick 278: 11 carts remaining.
# Tick 279: 11 carts remaining.
# Tick 280: 11 carts remaining.
# Tick 281: 11 carts remaining.
# Tick 282: 11 carts remaining.
# Tick 283: 11 carts remaining.
# Tick 284: 11 carts remaining.
# Tick 285: 11 carts remaining.
# Tick 286: 11 carts remaining.
# Tick 287: 11 carts remaining.
# Tick 288: 11 carts remaining.
# Tick 289: 11 carts remaining.
# Tick 290: 11 carts remaining.
# Tick 291: 11 carts remaining.
# Tick 292: 11 carts remaining.
# Tick 293: 11 carts remaining.
# Tick 294: 11 carts remaining.
# Tick 295: 11 carts remaining.
# Tick 296: 11 carts remaining.
# Tick 297: 11 carts remaining.
# Tick 298: 11 carts remaining.
# Tick 299: 11 carts remaining.
# Tick 300: 11 carts remaining.
# Tick 301: 11 carts remaining.
# Tick 302: 11 carts remaining.
# Tick 303: 11 carts remaining.
# Tick 304: 11 carts remaining.
# Tick 305: 11 carts remaining.
# Tick 306: 11 carts remaining.
# Tick 307: 11 carts remaining.
# Tick 308: 11 carts remaining.
# Tick 309: 11 carts remaining.
# Tick 310: 11 carts remaining.
# Tick 311: 11 carts remaining.
# Tick 312: 11 carts remaining.
# Tick 313: 11 carts remaining.
# Tick 314: 11 carts remaining.
# Tick 315: 11 carts remaining.
# Tick 316: 11 carts remaining.
# Tick 317: 11 carts remaining.
# Tick 318: 11 carts remaining.
# Tick 319: 11 carts remaining.
# Tick 320: 11 carts remaining.
# Tick 321: 11 carts remaining.
# Tick 322: 11 carts remaining.
# Tick 323: 11 carts remaining.
# Tick 324: 11 carts remaining.
# Tick 325: 11 carts remaining.
# Tick 326: 11 carts remaining.
# Tick 327: 11 carts remaining.
# Tick 328: 11 carts remaining.
# Tick 329: 11 carts remaining.
# Tick 330: 11 carts remaining.
# Tick 331: 11 carts remaining.
# Tick 332: 11 carts remaining.
# Tick 333: 11 carts remaining.
# Tick 334: 11 carts remaining.
# Tick 335: 11 carts remaining.
# Tick 336: 11 carts remaining.
# Tick 337: 11 carts remaining.
# Tick 338: 11 carts remaining.
# Tick 339: 11 carts remaining.
# Tick 340: 11 carts remaining.
# Tick 341: 11 carts remaining.
# Tick 342: 11 carts remaining.
# Tick 343: 11 carts remaining.
# Tick 344: 11 carts remaining.
# Tick 345: 11 carts remaining.
# Tick 346: 11 carts remaining.
# Tick 347: 11 carts remaining.
# Tick 348: 11 carts remaining.
# Tick 349: 11 carts remaining.
# Collision detected at (88, 61) on tick 350.
# Collision detected at (88, 61) on tick 350.
# Collision detected at (88, 61) on tick 350.
# Collision detected at (88, 61) on tick 350.
# Collision detected at (88, 61) on tick 350.
# Collision detected at (88, 61) on tick 350.
# Tick 350: 9 carts remaining.
# Tick 351: 9 carts remaining.
# Tick 352: 9 carts remaining.
# Tick 353: 9 carts remaining.
# Tick 354: 9 carts remaining.
# Tick 355: 9 carts remaining.
# Tick 356: 9 carts remaining.
# Tick 357: 9 carts remaining.
# Tick 358: 9 carts remaining.
# Tick 359: 9 carts remaining.
# Tick 360: 9 carts remaining.
# Tick 361: 9 carts remaining.
# Tick 362: 9 carts remaining.
# Tick 363: 9 carts remaining.
# Tick 364: 9 carts remaining.
# Tick 365: 9 carts remaining.
# Tick 366: 9 carts remaining.
# Tick 367: 9 carts remaining.
# Tick 368: 9 carts remaining.
# Tick 369: 9 carts remaining.
# Tick 370: 9 carts remaining.
# Tick 371: 9 carts remaining.
# Tick 372: 9 carts remaining.
# Tick 373: 9 carts remaining.
# Tick 374: 9 carts remaining.
# Tick 375: 9 carts remaining.
# Tick 376: 9 carts remaining.
# Tick 377: 9 carts remaining.
# Tick 378: 9 carts remaining.
# Tick 379: 9 carts remaining.
# Tick 380: 9 carts remaining.
# Tick 381: 9 carts remaining.
# Tick 382: 9 carts remaining.
# Tick 383: 9 carts remaining.
# Tick 384: 9 carts remaining.
# Tick 385: 9 carts remaining.
# Tick 386: 9 carts remaining.
# Tick 387: 9 carts remaining.
# Tick 388: 9 carts remaining.
# Tick 389: 9 carts remaining.
# Tick 390: 9 carts remaining.
# Tick 391: 9 carts remaining.
# Tick 392: 9 carts remaining.
# Tick 393: 9 carts remaining.
# Tick 394: 9 carts remaining.
# Tick 395: 9 carts remaining.
# Tick 396: 9 carts remaining.
# Tick 397: 9 carts remaining.
# Tick 398: 9 carts remaining.
# Tick 399: 9 carts remaining.
# Tick 400: 9 carts remaining.
# Tick 401: 9 carts remaining.
# Tick 402: 9 carts remaining.
# Tick 403: 9 carts remaining.
# Tick 404: 9 carts remaining.
# Tick 405: 9 carts remaining.
# Tick 406: 9 carts remaining.
# Tick 407: 9 carts remaining.
# Tick 408: 9 carts remaining.
# Tick 409: 9 carts remaining.
# Tick 410: 9 carts remaining.
# Tick 411: 9 carts remaining.
# Tick 412: 9 carts remaining.
# Tick 413: 9 carts remaining.
# Tick 414: 9 carts remaining.
# Tick 415: 9 carts remaining.
# Tick 416: 9 carts remaining.
# Tick 417: 9 carts remaining.
# Tick 418: 9 carts remaining.
# Tick 419: 9 carts remaining.
# Tick 420: 9 carts remaining.
# Tick 421: 9 carts remaining.
# Tick 422: 9 carts remaining.
# Tick 423: 9 carts remaining.
# Tick 424: 9 carts remaining.
# Tick 425: 9 carts remaining.
# Tick 426: 9 carts remaining.
# Tick 427: 9 carts remaining.
# Tick 428: 9 carts remaining.
# Tick 429: 9 carts remaining.
# Tick 430: 9 carts remaining.
# Tick 431: 9 carts remaining.
# Tick 432: 9 carts remaining.
# Tick 433: 9 carts remaining.
# Tick 434: 9 carts remaining.
# Tick 435: 9 carts remaining.
# Tick 436: 9 carts remaining.
# Tick 437: 9 carts remaining.
# Tick 438: 9 carts remaining.
# Tick 439: 9 carts remaining.
# Tick 440: 9 carts remaining.
# Tick 441: 9 carts remaining.
# Tick 442: 9 carts remaining.
# Tick 443: 9 carts remaining.
# Tick 444: 9 carts remaining.
# Tick 445: 9 carts remaining.
# Tick 446: 9 carts remaining.
# Tick 447: 9 carts remaining.
# Tick 448: 9 carts remaining.
# Tick 449: 9 carts remaining.
# Tick 450: 9 carts remaining.
# Tick 451: 9 carts remaining.
# Tick 452: 9 carts remaining.
# Tick 453: 9 carts remaining.
# Tick 454: 9 carts remaining.
# Tick 455: 9 carts remaining.
# Tick 456: 9 carts remaining.
# Tick 457: 9 carts remaining.
# Tick 458: 9 carts remaining.
# Tick 459: 9 carts remaining.
# Tick 460: 9 carts remaining.
# Tick 461: 9 carts remaining.
# Tick 462: 9 carts remaining.
# Tick 463: 9 carts remaining.
# Tick 464: 9 carts remaining.
# Tick 465: 9 carts remaining.
# Tick 466: 9 carts remaining.
# Tick 467: 9 carts remaining.
# Tick 468: 9 carts remaining.
# Tick 469: 9 carts remaining.
# Tick 470: 9 carts remaining.
# Tick 471: 9 carts remaining.
# Tick 472: 9 carts remaining.
# Tick 473: 9 carts remaining.
# Tick 474: 9 carts remaining.
# Tick 475: 9 carts remaining.
# Tick 476: 9 carts remaining.
# Tick 477: 9 carts remaining.
# Tick 478: 9 carts remaining.
# Tick 479: 9 carts remaining.
# Tick 480: 9 carts remaining.
# Tick 481: 9 carts remaining.
# Tick 482: 9 carts remaining.
# Tick 483: 9 carts remaining.
# Tick 484: 9 carts remaining.
# Tick 485: 9 carts remaining.
# Tick 486: 9 carts remaining.
# Tick 487: 9 carts remaining.
# Tick 488: 9 carts remaining.
# Tick 489: 9 carts remaining.
# Tick 490: 9 carts remaining.
# Tick 491: 9 carts remaining.
# Tick 492: 9 carts remaining.
# Tick 493: 9 carts remaining.
# Tick 494: 9 carts remaining.
# Tick 495: 9 carts remaining.
# Tick 496: 9 carts remaining.
# Tick 497: 9 carts remaining.
# Tick 498: 9 carts remaining.
# Tick 499: 9 carts remaining.
# Tick 500: 9 carts remaining.
# Tick 501: 9 carts remaining.
# Tick 502: 9 carts remaining.
# Tick 503: 9 carts remaining.
# Tick 504: 9 carts remaining.
# Tick 505: 9 carts remaining.
# Tick 506: 9 carts remaining.
# Tick 507: 9 carts remaining.
# Tick 508: 9 carts remaining.
# Tick 509: 9 carts remaining.
# Tick 510: 9 carts remaining.
# Tick 511: 9 carts remaining.
# Tick 512: 9 carts remaining.
# Tick 513: 9 carts remaining.
# Tick 514: 9 carts remaining.
# Tick 515: 9 carts remaining.
# Tick 516: 9 carts remaining.
# Tick 517: 9 carts remaining.
# Tick 518: 9 carts remaining.
# Tick 519: 9 carts remaining.
# Tick 520: 9 carts remaining.
# Tick 521: 9 carts remaining.
# Tick 522: 9 carts remaining.
# Tick 523: 9 carts remaining.
# Tick 524: 9 carts remaining.
# Tick 525: 9 carts remaining.
# Tick 526: 9 carts remaining.
# Tick 527: 9 carts remaining.
# Tick 528: 9 carts remaining.
# Tick 529: 9 carts remaining.
# Tick 530: 9 carts remaining.
# Tick 531: 9 carts remaining.
# Tick 532: 9 carts remaining.
# Tick 533: 9 carts remaining.
# Tick 534: 9 carts remaining.
# Tick 535: 9 carts remaining.
# Tick 536: 9 carts remaining.
# Tick 537: 9 carts remaining.
# Tick 538: 9 carts remaining.
# Tick 539: 9 carts remaining.
# Tick 540: 9 carts remaining.
# Tick 541: 9 carts remaining.
# Tick 542: 9 carts remaining.
# Tick 543: 9 carts remaining.
# Tick 544: 9 carts remaining.
# Tick 545: 9 carts remaining.
# Tick 546: 9 carts remaining.
# Tick 547: 9 carts remaining.
# Tick 548: 9 carts remaining.
# Tick 549: 9 carts remaining.
# Tick 550: 9 carts remaining.
# Tick 551: 9 carts remaining.
# Tick 552: 9 carts remaining.
# Tick 553: 9 carts remaining.
# Tick 554: 9 carts remaining.
# Tick 555: 9 carts remaining.
# Tick 556: 9 carts remaining.
# Tick 557: 9 carts remaining.
# Tick 558: 9 carts remaining.
# Tick 559: 9 carts remaining.
# Tick 560: 9 carts remaining.
# Tick 561: 9 carts remaining.
# Tick 562: 9 carts remaining.
# Tick 563: 9 carts remaining.
# Tick 564: 9 carts remaining.
# Tick 565: 9 carts remaining.
# Tick 566: 9 carts remaining.
# Tick 567: 9 carts remaining.
# Tick 568: 9 carts remaining.
# Tick 569: 9 carts remaining.
# Tick 570: 9 carts remaining.
# Tick 571: 9 carts remaining.
# Tick 572: 9 carts remaining.
# Tick 573: 9 carts remaining.
# Tick 574: 9 carts remaining.
# Tick 575: 9 carts remaining.
# Tick 576: 9 carts remaining.
# Tick 577: 9 carts remaining.
# Tick 578: 9 carts remaining.
# Tick 579: 9 carts remaining.
# Tick 580: 9 carts remaining.
# Tick 581: 9 carts remaining.
# Tick 582: 9 carts remaining.
# Tick 583: 9 carts remaining.
# Tick 584: 9 carts remaining.
# Tick 585: 9 carts remaining.
# Tick 586: 9 carts remaining.
# Tick 587: 9 carts remaining.
# Tick 588: 9 carts remaining.
# Tick 589: 9 carts remaining.
# Tick 590: 9 carts remaining.
# Tick 591: 9 carts remaining.
# Tick 592: 9 carts remaining.
# Tick 593: 9 carts remaining.
# Tick 594: 9 carts remaining.
# Tick 595: 9 carts remaining.
# Tick 596: 9 carts remaining.
# Tick 597: 9 carts remaining.
# Tick 598: 9 carts remaining.
# Tick 599: 9 carts remaining.
# Tick 600: 9 carts remaining.
# Tick 601: 9 carts remaining.
# Tick 602: 9 carts remaining.
# Tick 603: 9 carts remaining.
# Tick 604: 9 carts remaining.
# Tick 605: 9 carts remaining.
# Tick 606: 9 carts remaining.
# Tick 607: 9 carts remaining.
# Tick 608: 9 carts remaining.
# Tick 609: 9 carts remaining.
# Tick 610: 9 carts remaining.
# Tick 611: 9 carts remaining.
# Tick 612: 9 carts remaining.
# Tick 613: 9 carts remaining.
# Tick 614: 9 carts remaining.
# Tick 615: 9 carts remaining.
# Tick 616: 9 carts remaining.
# Tick 617: 9 carts remaining.
# Tick 618: 9 carts remaining.
# Tick 619: 9 carts remaining.
# Tick 620: 9 carts remaining.
# Tick 621: 9 carts remaining.
# Tick 622: 9 carts remaining.
# Tick 623: 9 carts remaining.
# Tick 624: 9 carts remaining.
# Tick 625: 9 carts remaining.
# Tick 626: 9 carts remaining.
# Tick 627: 9 carts remaining.
# Tick 628: 9 carts remaining.
# Tick 629: 9 carts remaining.
# Tick 630: 9 carts remaining.
# Tick 631: 9 carts remaining.
# Tick 632: 9 carts remaining.
# Tick 633: 9 carts remaining.
# Tick 634: 9 carts remaining.
# Tick 635: 9 carts remaining.
# Tick 636: 9 carts remaining.
# Tick 637: 9 carts remaining.
# Tick 638: 9 carts remaining.
# Tick 639: 9 carts remaining.
# Tick 640: 9 carts remaining.
# Tick 641: 9 carts remaining.
# Tick 642: 9 carts remaining.
# Tick 643: 9 carts remaining.
# Tick 644: 9 carts remaining.
# Tick 645: 9 carts remaining.
# Tick 646: 9 carts remaining.
# Tick 647: 9 carts remaining.
# Tick 648: 9 carts remaining.
# Tick 649: 9 carts remaining.
# Tick 650: 9 carts remaining.
# Tick 651: 9 carts remaining.
# Tick 652: 9 carts remaining.
# Tick 653: 9 carts remaining.
# Tick 654: 9 carts remaining.
# Tick 655: 9 carts remaining.
# Tick 656: 9 carts remaining.
# Tick 657: 9 carts remaining.
# Tick 658: 9 carts remaining.
# Tick 659: 9 carts remaining.
# Tick 660: 9 carts remaining.
# Tick 661: 9 carts remaining.
# Tick 662: 9 carts remaining.
# Tick 663: 9 carts remaining.
# Tick 664: 9 carts remaining.
# Tick 665: 9 carts remaining.
# Tick 666: 9 carts remaining.
# Tick 667: 9 carts remaining.
# Tick 668: 9 carts remaining.
# Tick 669: 9 carts remaining.
# Tick 670: 9 carts remaining.
# Tick 671: 9 carts remaining.
# Tick 672: 9 carts remaining.
# Tick 673: 9 carts remaining.
# Tick 674: 9 carts remaining.
# Tick 675: 9 carts remaining.
# Tick 676: 9 carts remaining.
# Tick 677: 9 carts remaining.
# Tick 678: 9 carts remaining.
# Tick 679: 9 carts remaining.
# Tick 680: 9 carts remaining.
# Tick 681: 9 carts remaining.
# Tick 682: 9 carts remaining.
# Tick 683: 9 carts remaining.
# Tick 684: 9 carts remaining.
# Tick 685: 9 carts remaining.
# Tick 686: 9 carts remaining.
# Tick 687: 9 carts remaining.
# Tick 688: 9 carts remaining.
# Tick 689: 9 carts remaining.
# Tick 690: 9 carts remaining.
# Tick 691: 9 carts remaining.
# Tick 692: 9 carts remaining.
# Tick 693: 9 carts remaining.
# Tick 694: 9 carts remaining.
# Tick 695: 9 carts remaining.
# Tick 696: 9 carts remaining.
# Tick 697: 9 carts remaining.
# Tick 698: 9 carts remaining.
# Collision detected at (94, 117) on tick 699.
# Collision detected at (94, 117) on tick 699.
# Collision detected at (94, 117) on tick 699.
# Tick 699: 7 carts remaining.
# Tick 700: 7 carts remaining.
# Tick 701: 7 carts remaining.
# Tick 702: 7 carts remaining.
# Tick 703: 7 carts remaining.
# Tick 704: 7 carts remaining.
# Tick 705: 7 carts remaining.
# Tick 706: 7 carts remaining.
# Tick 707: 7 carts remaining.
# Tick 708: 7 carts remaining.
# Tick 709: 7 carts remaining.
# Tick 710: 7 carts remaining.
# Tick 711: 7 carts remaining.
# Tick 712: 7 carts remaining.
# Tick 713: 7 carts remaining.
# Tick 714: 7 carts remaining.
# Tick 715: 7 carts remaining.
# Tick 716: 7 carts remaining.
# Tick 717: 7 carts remaining.
# Tick 718: 7 carts remaining.
# Tick 719: 7 carts remaining.
# Tick 720: 7 carts remaining.
# Tick 721: 7 carts remaining.
# Tick 722: 7 carts remaining.
# Tick 723: 7 carts remaining.
# Tick 724: 7 carts remaining.
# Tick 725: 7 carts remaining.
# Tick 726: 7 carts remaining.
# Tick 727: 7 carts remaining.
# Tick 728: 7 carts remaining.
# Tick 729: 7 carts remaining.
# Tick 730: 7 carts remaining.
# Tick 731: 7 carts remaining.
# Tick 732: 7 carts remaining.
# Tick 733: 7 carts remaining.
# Tick 734: 7 carts remaining.
# Tick 735: 7 carts remaining.
# Tick 736: 7 carts remaining.
# Tick 737: 7 carts remaining.
# Tick 738: 7 carts remaining.
# Tick 739: 7 carts remaining.
# Tick 740: 7 carts remaining.
# Tick 741: 7 carts remaining.
# Tick 742: 7 carts remaining.
# Tick 743: 7 carts remaining.
# Tick 744: 7 carts remaining.
# Tick 745: 7 carts remaining.
# Tick 746: 7 carts remaining.
# Tick 747: 7 carts remaining.
# Tick 748: 7 carts remaining.
# Tick 749: 7 carts remaining.
# Tick 750: 7 carts remaining.
# Tick 751: 7 carts remaining.
# Tick 752: 7 carts remaining.
# Tick 753: 7 carts remaining.
# Tick 754: 7 carts remaining.
# Collision detected at (140, 124) on tick 755.
# Collision detected at (140, 124) on tick 755.
# Collision detected at (140, 124) on tick 755.
# Tick 755: 5 carts remaining.
# Tick 756: 5 carts remaining.
# Tick 757: 5 carts remaining.
# Tick 758: 5 carts remaining.
# Tick 759: 5 carts remaining.
# Tick 760: 5 carts remaining.
# Tick 761: 5 carts remaining.
# Tick 762: 5 carts remaining.
# Tick 763: 5 carts remaining.
# Tick 764: 5 carts remaining.
# Tick 765: 5 carts remaining.
# Tick 766: 5 carts remaining.
# Tick 767: 5 carts remaining.
# Tick 768: 5 carts remaining.
# Tick 769: 5 carts remaining.
# Tick 770: 5 carts remaining.
# Tick 771: 5 carts remaining.
# Tick 772: 5 carts remaining.
# Tick 773: 5 carts remaining.
# Tick 774: 5 carts remaining.
# Tick 775: 5 carts remaining.
# Tick 776: 5 carts remaining.
# Tick 777: 5 carts remaining.
# Tick 778: 5 carts remaining.
# Tick 779: 5 carts remaining.
# Tick 780: 5 carts remaining.
# Tick 781: 5 carts remaining.
# Tick 782: 5 carts remaining.
# Tick 783: 5 carts remaining.
# Tick 784: 5 carts remaining.
# Tick 785: 5 carts remaining.
# Tick 786: 5 carts remaining.
# Tick 787: 5 carts remaining.
# Tick 788: 5 carts remaining.
# Tick 789: 5 carts remaining.
# Tick 790: 5 carts remaining.
# Tick 791: 5 carts remaining.
# Tick 792: 5 carts remaining.
# Tick 793: 5 carts remaining.
# Tick 794: 5 carts remaining.
# Tick 795: 5 carts remaining.
# Tick 796: 5 carts remaining.
# Tick 797: 5 carts remaining.
# Tick 798: 5 carts remaining.
# Tick 799: 5 carts remaining.
# Tick 800: 5 carts remaining.
# Tick 801: 5 carts remaining.
# Tick 802: 5 carts remaining.
# Tick 803: 5 carts remaining.
# Tick 804: 5 carts remaining.
# Tick 805: 5 carts remaining.
# Tick 806: 5 carts remaining.
# Tick 807: 5 carts remaining.
# Tick 808: 5 carts remaining.
# Tick 809: 5 carts remaining.
# Tick 810: 5 carts remaining.
# Tick 811: 5 carts remaining.
# Tick 812: 5 carts remaining.
# Tick 813: 5 carts remaining.
# Tick 814: 5 carts remaining.
# Tick 815: 5 carts remaining.
# Tick 816: 5 carts remaining.
# Tick 817: 5 carts remaining.
# Tick 818: 5 carts remaining.
# Tick 819: 5 carts remaining.
# Collision detected at (74, 102) on tick 820.
# Collision detected at (74, 102) on tick 820.
# Tick 820: 3 carts remaining.
# Tick 821: 3 carts remaining.
# Tick 822: 3 carts remaining.
# Tick 823: 3 carts remaining.
# Tick 824: 3 carts remaining.
# Tick 825: 3 carts remaining.
# Tick 826: 3 carts remaining.
# Tick 827: 3 carts remaining.
# Tick 828: 3 carts remaining.
# Tick 829: 3 carts remaining.
# Tick 830: 3 carts remaining.
# Tick 831: 3 carts remaining.
# Tick 832: 3 carts remaining.
# Tick 833: 3 carts remaining.
# Tick 834: 3 carts remaining.
# Tick 835: 3 carts remaining.
# Tick 836: 3 carts remaining.
# Tick 837: 3 carts remaining.
# Tick 838: 3 carts remaining.
# Tick 839: 3 carts remaining.
# Tick 840: 3 carts remaining.
# Tick 841: 3 carts remaining.
# Tick 842: 3 carts remaining.
# Tick 843: 3 carts remaining.
# Tick 844: 3 carts remaining.
# Tick 845: 3 carts remaining.
# Tick 846: 3 carts remaining.
# Tick 847: 3 carts remaining.
# Tick 848: 3 carts remaining.
# Tick 849: 3 carts remaining.
# Tick 850: 3 carts remaining.
# Tick 851: 3 carts remaining.
# Tick 852: 3 carts remaining.
# Tick 853: 3 carts remaining.
# Tick 854: 3 carts remaining.
# Tick 855: 3 carts remaining.
# Tick 856: 3 carts remaining.
# Tick 857: 3 carts remaining.
# Tick 858: 3 carts remaining.
# Tick 859: 3 carts remaining.
# Tick 860: 3 carts remaining.
# Tick 861: 3 carts remaining.
# Tick 862: 3 carts remaining.
# Tick 863: 3 carts remaining.
# Tick 864: 3 carts remaining.
# Tick 865: 3 carts remaining.
# Tick 866: 3 carts remaining.
# Tick 867: 3 carts remaining.
# Tick 868: 3 carts remaining.
# Tick 869: 3 carts remaining.
# Tick 870: 3 carts remaining.
# Tick 871: 3 carts remaining.
# Tick 872: 3 carts remaining.
# Tick 873: 3 carts remaining.
# Tick 874: 3 carts remaining.
# Tick 875: 3 carts remaining.
# Tick 876: 3 carts remaining.
# Tick 877: 3 carts remaining.
# Tick 878: 3 carts remaining.
# Tick 879: 3 carts remaining.
# Tick 880: 3 carts remaining.
# Tick 881: 3 carts remaining.
# Tick 882: 3 carts remaining.
# Tick 883: 3 carts remaining.
# Tick 884: 3 carts remaining.
# Tick 885: 3 carts remaining.
# Tick 886: 3 carts remaining.
# Tick 887: 3 carts remaining.
# Tick 888: 3 carts remaining.
# Tick 889: 3 carts remaining.
# Tick 890: 3 carts remaining.
# Tick 891: 3 carts remaining.
# Tick 892: 3 carts remaining.
# Tick 893: 3 carts remaining.
# Tick 894: 3 carts remaining.
# Tick 895: 3 carts remaining.
# Tick 896: 3 carts remaining.
# Tick 897: 3 carts remaining.
# Tick 898: 3 carts remaining.
# Tick 899: 3 carts remaining.
# Tick 900: 3 carts remaining.
# Tick 901: 3 carts remaining.
# Tick 902: 3 carts remaining.
# Tick 903: 3 carts remaining.
# Tick 904: 3 carts remaining.
# Tick 905: 3 carts remaining.
# Tick 906: 3 carts remaining.
# Tick 907: 3 carts remaining.
# Tick 908: 3 carts remaining.
# Tick 909: 3 carts remaining.
# Tick 910: 3 carts remaining.
# Tick 911: 3 carts remaining.
# Tick 912: 3 carts remaining.
# Tick 913: 3 carts remaining.
# Tick 914: 3 carts remaining.
# Tick 915: 3 carts remaining.
# Tick 916: 3 carts remaining.
# Tick 917: 3 carts remaining.
# Tick 918: 3 carts remaining.
# Tick 919: 3 carts remaining.
# Tick 920: 3 carts remaining.
# Tick 921: 3 carts remaining.
# Tick 922: 3 carts remaining.
# Tick 923: 3 carts remaining.
# Tick 924: 3 carts remaining.
# Tick 925: 3 carts remaining.
# Tick 926: 3 carts remaining.
# Tick 927: 3 carts remaining.
# Tick 928: 3 carts remaining.
# Tick 929: 3 carts remaining.
# Tick 930: 3 carts remaining.
# Tick 931: 3 carts remaining.
# Tick 932: 3 carts remaining.
# Tick 933: 3 carts remaining.
# Tick 934: 3 carts remaining.
# Tick 935: 3 carts remaining.
# Tick 936: 3 carts remaining.
# Tick 937: 3 carts remaining.
# Tick 938: 3 carts remaining.
# Tick 939: 3 carts remaining.
# Tick 940: 3 carts remaining.
# Tick 941: 3 carts remaining.
# Tick 942: 3 carts remaining.
# Tick 943: 3 carts remaining.
# Tick 944: 3 carts remaining.
# Tick 945: 3 carts remaining.
# Tick 946: 3 carts remaining.
# Tick 947: 3 carts remaining.
# Tick 948: 3 carts remaining.
# Tick 949: 3 carts remaining.
# Tick 950: 3 carts remaining.
# Tick 951: 3 carts remaining.
# Tick 952: 3 carts remaining.
# Tick 953: 3 carts remaining.
# Tick 954: 3 carts remaining.
# Tick 955: 3 carts remaining.
# Tick 956: 3 carts remaining.
# Tick 957: 3 carts remaining.
# Tick 958: 3 carts remaining.
# Tick 959: 3 carts remaining.
# Tick 960: 3 carts remaining.
# Tick 961: 3 carts remaining.
# Tick 962: 3 carts remaining.
# Tick 963: 3 carts remaining.
# Tick 964: 3 carts remaining.
# Tick 965: 3 carts remaining.
# Tick 966: 3 carts remaining.
# Tick 967: 3 carts remaining.
# Tick 968: 3 carts remaining.
# Tick 969: 3 carts remaining.
# Tick 970: 3 carts remaining.
# Tick 971: 3 carts remaining.
# Tick 972: 3 carts remaining.
# Tick 973: 3 carts remaining.
# Tick 974: 3 carts remaining.
# Tick 975: 3 carts remaining.
# Tick 976: 3 carts remaining.
# Tick 977: 3 carts remaining.
# Tick 978: 3 carts remaining.
# Tick 979: 3 carts remaining.
# Tick 980: 3 carts remaining.
# Tick 981: 3 carts remaining.
# Tick 982: 3 carts remaining.
# Tick 983: 3 carts remaining.
# Tick 984: 3 carts remaining.
# Tick 985: 3 carts remaining.
# Tick 986: 3 carts remaining.
# Tick 987: 3 carts remaining.
# Tick 988: 3 carts remaining.
# Tick 989: 3 carts remaining.
# Tick 990: 3 carts remaining.
# Tick 991: 3 carts remaining.
# Tick 992: 3 carts remaining.
# Tick 993: 3 carts remaining.
# Tick 994: 3 carts remaining.
# Tick 995: 3 carts remaining.
# Tick 996: 3 carts remaining.
# Tick 997: 3 carts remaining.
# Tick 998: 3 carts remaining.
# Tick 999: 3 carts remaining.
# Tick 1000: 3 carts remaining.
# Tick 1001: 3 carts remaining.
# Tick 1002: 3 carts remaining.
# Tick 1003: 3 carts remaining.
# Tick 1004: 3 carts remaining.
# Tick 1005: 3 carts remaining.
# Tick 1006: 3 carts remaining.
# Tick 1007: 3 carts remaining.
# Tick 1008: 3 carts remaining.
# Tick 1009: 3 carts remaining.
# Tick 1010: 3 carts remaining.
# Tick 1011: 3 carts remaining.
# Tick 1012: 3 carts remaining.
# Tick 1013: 3 carts remaining.
# Tick 1014: 3 carts remaining.
# Tick 1015: 3 carts remaining.
# Tick 1016: 3 carts remaining.
# Tick 1017: 3 carts remaining.
# Tick 1018: 3 carts remaining.
# Tick 1019: 3 carts remaining.
# Tick 1020: 3 carts remaining.
# Tick 1021: 3 carts remaining.
# Tick 1022: 3 carts remaining.
# Tick 1023: 3 carts remaining.
# Tick 1024: 3 carts remaining.
# Tick 1025: 3 carts remaining.
# Tick 1026: 3 carts remaining.
# Tick 1027: 3 carts remaining.
# Tick 1028: 3 carts remaining.
# Tick 1029: 3 carts remaining.
# Tick 1030: 3 carts remaining.
# Tick 1031: 3 carts remaining.
# Tick 1032: 3 carts remaining.
# Tick 1033: 3 carts remaining.
# Tick 1034: 3 carts remaining.
# Tick 1035: 3 carts remaining.
# Tick 1036: 3 carts remaining.
# Tick 1037: 3 carts remaining.
# Tick 1038: 3 carts remaining.
# Tick 1039: 3 carts remaining.
# Tick 1040: 3 carts remaining.
# Tick 1041: 3 carts remaining.
# Tick 1042: 3 carts remaining.
# Tick 1043: 3 carts remaining.
# Tick 1044: 3 carts remaining.
# Tick 1045: 3 carts remaining.
# Tick 1046: 3 carts remaining.
# Tick 1047: 3 carts remaining.
# Tick 1048: 3 carts remaining.
# Tick 1049: 3 carts remaining.
# Tick 1050: 3 carts remaining.
# Tick 1051: 3 carts remaining.
# Tick 1052: 3 carts remaining.
# Tick 1053: 3 carts remaining.
# Tick 1054: 3 carts remaining.
# Tick 1055: 3 carts remaining.
# Tick 1056: 3 carts remaining.
# Tick 1057: 3 carts remaining.
# Tick 1058: 3 carts remaining.
# Tick 1059: 3 carts remaining.
# Tick 1060: 3 carts remaining.
# Tick 1061: 3 carts remaining.
# Tick 1062: 3 carts remaining.
# Tick 1063: 3 carts remaining.
# Tick 1064: 3 carts remaining.
# Tick 1065: 3 carts remaining.
# Tick 1066: 3 carts remaining.
# Tick 1067: 3 carts remaining.
# Tick 1068: 3 carts remaining.
# Tick 1069: 3 carts remaining.
# Tick 1070: 3 carts remaining.
# Tick 1071: 3 carts remaining.
# Tick 1072: 3 carts remaining.
# Tick 1073: 3 carts remaining.
# Tick 1074: 3 carts remaining.
# Tick 1075: 3 carts remaining.
# Tick 1076: 3 carts remaining.
# Tick 1077: 3 carts remaining.
# Tick 1078: 3 carts remaining.
# Tick 1079: 3 carts remaining.
# Tick 1080: 3 carts remaining.
# Tick 1081: 3 carts remaining.
# Tick 1082: 3 carts remaining.
# Tick 1083: 3 carts remaining.
# Tick 1084: 3 carts remaining.
# Tick 1085: 3 carts remaining.
# Tick 1086: 3 carts remaining.
# Tick 1087: 3 carts remaining.
# Tick 1088: 3 carts remaining.
# Tick 1089: 3 carts remaining.
# Tick 1090: 3 carts remaining.
# Tick 1091: 3 carts remaining.
# Tick 1092: 3 carts remaining.
# Tick 1093: 3 carts remaining.
# Tick 1094: 3 carts remaining.
# Tick 1095: 3 carts remaining.
# Tick 1096: 3 carts remaining.
# Tick 1097: 3 carts remaining.
# Tick 1098: 3 carts remaining.
# Tick 1099: 3 carts remaining.
# Tick 1100: 3 carts remaining.
# Tick 1101: 3 carts remaining.
# Tick 1102: 3 carts remaining.
# Tick 1103: 3 carts remaining.
# Tick 1104: 3 carts remaining.
# Tick 1105: 3 carts remaining.
# Tick 1106: 3 carts remaining.
# Tick 1107: 3 carts remaining.
# Tick 1108: 3 carts remaining.
# Tick 1109: 3 carts remaining.
# Tick 1110: 3 carts remaining.
# Tick 1111: 3 carts remaining.
# Tick 1112: 3 carts remaining.
# Tick 1113: 3 carts remaining.
# Tick 1114: 3 carts remaining.
# Tick 1115: 3 carts remaining.
# Tick 1116: 3 carts remaining.
# Tick 1117: 3 carts remaining.
# Tick 1118: 3 carts remaining.
# Tick 1119: 3 carts remaining.
# Tick 1120: 3 carts remaining.
# Tick 1121: 3 carts remaining.
# Tick 1122: 3 carts remaining.
# Tick 1123: 3 carts remaining.
# Tick 1124: 3 carts remaining.
# Tick 1125: 3 carts remaining.
# Tick 1126: 3 carts remaining.
# Tick 1127: 3 carts remaining.
# Tick 1128: 3 carts remaining.
# Tick 1129: 3 carts remaining.
# Tick 1130: 3 carts remaining.
# Tick 1131: 3 carts remaining.
# Tick 1132: 3 carts remaining.
# Tick 1133: 3 carts remaining.
# Tick 1134: 3 carts remaining.
# Tick 1135: 3 carts remaining.
# Tick 1136: 3 carts remaining.
# Tick 1137: 3 carts remaining.
# Tick 1138: 3 carts remaining.
# Tick 1139: 3 carts remaining.
# Tick 1140: 3 carts remaining.
# Tick 1141: 3 carts remaining.
# Tick 1142: 3 carts remaining.
# Tick 1143: 3 carts remaining.
# Tick 1144: 3 carts remaining.
# Tick 1145: 3 carts remaining.
# Tick 1146: 3 carts remaining.
# Tick 1147: 3 carts remaining.
# Tick 1148: 3 carts remaining.
# Tick 1149: 3 carts remaining.
# Tick 1150: 3 carts remaining.
# Tick 1151: 3 carts remaining.
# Tick 1152: 3 carts remaining.
# Tick 1153: 3 carts remaining.
# Tick 1154: 3 carts remaining.
# Tick 1155: 3 carts remaining.
# Tick 1156: 3 carts remaining.
# Tick 1157: 3 carts remaining.
# Tick 1158: 3 carts remaining.
# Tick 1159: 3 carts remaining.
# Tick 1160: 3 carts remaining.
# Tick 1161: 3 carts remaining.
# Tick 1162: 3 carts remaining.
# Tick 1163: 3 carts remaining.
# Tick 1164: 3 carts remaining.
# Tick 1165: 3 carts remaining.
# Tick 1166: 3 carts remaining.
# Tick 1167: 3 carts remaining.
# Tick 1168: 3 carts remaining.
# Tick 1169: 3 carts remaining.
# Tick 1170: 3 carts remaining.
# Tick 1171: 3 carts remaining.
# Tick 1172: 3 carts remaining.
# Tick 1173: 3 carts remaining.
# Tick 1174: 3 carts remaining.
# Tick 1175: 3 carts remaining.
# Tick 1176: 3 carts remaining.
# Tick 1177: 3 carts remaining.
# Tick 1178: 3 carts remaining.
# Tick 1179: 3 carts remaining.
# Tick 1180: 3 carts remaining.
# Tick 1181: 3 carts remaining.
# Tick 1182: 3 carts remaining.
# Tick 1183: 3 carts remaining.
# Tick 1184: 3 carts remaining.
# Tick 1185: 3 carts remaining.
# Tick 1186: 3 carts remaining.
# Tick 1187: 3 carts remaining.
# Tick 1188: 3 carts remaining.
# Tick 1189: 3 carts remaining.
# Tick 1190: 3 carts remaining.
# Tick 1191: 3 carts remaining.
# Tick 1192: 3 carts remaining.
# Tick 1193: 3 carts remaining.
# Tick 1194: 3 carts remaining.
# Tick 1195: 3 carts remaining.
# Tick 1196: 3 carts remaining.
# Tick 1197: 3 carts remaining.
# Tick 1198: 3 carts remaining.
# Tick 1199: 3 carts remaining.
# Tick 1200: 3 carts remaining.
# Tick 1201: 3 carts remaining.
# Tick 1202: 3 carts remaining.
# Tick 1203: 3 carts remaining.
# Tick 1204: 3 carts remaining.
# Tick 1205: 3 carts remaining.
# Tick 1206: 3 carts remaining.
# Tick 1207: 3 carts remaining.
# Tick 1208: 3 carts remaining.
# Tick 1209: 3 carts remaining.
# Tick 1210: 3 carts remaining.
# Tick 1211: 3 carts remaining.
# Tick 1212: 3 carts remaining.
# Tick 1213: 3 carts remaining.
# Tick 1214: 3 carts remaining.
# Tick 1215: 3 carts remaining.
# Tick 1216: 3 carts remaining.
# Tick 1217: 3 carts remaining.
# Tick 1218: 3 carts remaining.
# Tick 1219: 3 carts remaining.
# Tick 1220: 3 carts remaining.
# Tick 1221: 3 carts remaining.
# Tick 1222: 3 carts remaining.
# Tick 1223: 3 carts remaining.
# Tick 1224: 3 carts remaining.
# Tick 1225: 3 carts remaining.
# Tick 1226: 3 carts remaining.
# Tick 1227: 3 carts remaining.
# Tick 1228: 3 carts remaining.
# Tick 1229: 3 carts remaining.
# Tick 1230: 3 carts remaining.
# Tick 1231: 3 carts remaining.
# Tick 1232: 3 carts remaining.
# Tick 1233: 3 carts remaining.
# Tick 1234: 3 carts remaining.
# Tick 1235: 3 carts remaining.
# Tick 1236: 3 carts remaining.
# Tick 1237: 3 carts remaining.
# Tick 1238: 3 carts remaining.
# Tick 1239: 3 carts remaining.
# Tick 1240: 3 carts remaining.
# Tick 1241: 3 carts remaining.
# Tick 1242: 3 carts remaining.
# Tick 1243: 3 carts remaining.
# Tick 1244: 3 carts remaining.
# Tick 1245: 3 carts remaining.
# Tick 1246: 3 carts remaining.
# Tick 1247: 3 carts remaining.
# Tick 1248: 3 carts remaining.
# Tick 1249: 3 carts remaining.
# Tick 1250: 3 carts remaining.
# Tick 1251: 3 carts remaining.
# Tick 1252: 3 carts remaining.
# Tick 1253: 3 carts remaining.
# Tick 1254: 3 carts remaining.
# Tick 1255: 3 carts remaining.
# Tick 1256: 3 carts remaining.
# Tick 1257: 3 carts remaining.
# Tick 1258: 3 carts remaining.
# Tick 1259: 3 carts remaining.
# Tick 1260: 3 carts remaining.
# Tick 1261: 3 carts remaining.
# Tick 1262: 3 carts remaining.
# Tick 1263: 3 carts remaining.
# Tick 1264: 3 carts remaining.
# Tick 1265: 3 carts remaining.
# Tick 1266: 3 carts remaining.
# Tick 1267: 3 carts remaining.
# Tick 1268: 3 carts remaining.
# Tick 1269: 3 carts remaining.
# Tick 1270: 3 carts remaining.
# Tick 1271: 3 carts remaining.
# Tick 1272: 3 carts remaining.
# Tick 1273: 3 carts remaining.
# Tick 1274: 3 carts remaining.
# Tick 1275: 3 carts remaining.
# Tick 1276: 3 carts remaining.
# Tick 1277: 3 carts remaining.
# Tick 1278: 3 carts remaining.
# Tick 1279: 3 carts remaining.
# Tick 1280: 3 carts remaining.
# Tick 1281: 3 carts remaining.
# Tick 1282: 3 carts remaining.
# Tick 1283: 3 carts remaining.
# Tick 1284: 3 carts remaining.
# Tick 1285: 3 carts remaining.
# Tick 1286: 3 carts remaining.
# Tick 1287: 3 carts remaining.
# Tick 1288: 3 carts remaining.
# Tick 1289: 3 carts remaining.
# Tick 1290: 3 carts remaining.
# Tick 1291: 3 carts remaining.
# Tick 1292: 3 carts remaining.
# Tick 1293: 3 carts remaining.
# Tick 1294: 3 carts remaining.
# Tick 1295: 3 carts remaining.
# Tick 1296: 3 carts remaining.
# Tick 1297: 3 carts remaining.
# Tick 1298: 3 carts remaining.
# Tick 1299: 3 carts remaining.
# Tick 1300: 3 carts remaining.
# Tick 1301: 3 carts remaining.
# Tick 1302: 3 carts remaining.
# Tick 1303: 3 carts remaining.
# Tick 1304: 3 carts remaining.
# Tick 1305: 3 carts remaining.
# Tick 1306: 3 carts remaining.
# Tick 1307: 3 carts remaining.
# Tick 1308: 3 carts remaining.
# Tick 1309: 3 carts remaining.
# Tick 1310: 3 carts remaining.
# Tick 1311: 3 carts remaining.
# Tick 1312: 3 carts remaining.
# Tick 1313: 3 carts remaining.
# Tick 1314: 3 carts remaining.
# Tick 1315: 3 carts remaining.
# Tick 1316: 3 carts remaining.
# Tick 1317: 3 carts remaining.
# Tick 1318: 3 carts remaining.
# Tick 1319: 3 carts remaining.
# Tick 1320: 3 carts remaining.
# Tick 1321: 3 carts remaining.
# Tick 1322: 3 carts remaining.
# Tick 1323: 3 carts remaining.
# Tick 1324: 3 carts remaining.
# Tick 1325: 3 carts remaining.
# Tick 1326: 3 carts remaining.
# Tick 1327: 3 carts remaining.
# Tick 1328: 3 carts remaining.
# Tick 1329: 3 carts remaining.
# Tick 1330: 3 carts remaining.
# Tick 1331: 3 carts remaining.
# Tick 1332: 3 carts remaining.
# Tick 1333: 3 carts remaining.
# Tick 1334: 3 carts remaining.
# Tick 1335: 3 carts remaining.
# Tick 1336: 3 carts remaining.
# Tick 1337: 3 carts remaining.
# Tick 1338: 3 carts remaining.
# Tick 1339: 3 carts remaining.
# Tick 1340: 3 carts remaining.
# Tick 1341: 3 carts remaining.
# Tick 1342: 3 carts remaining.
# Tick 1343: 3 carts remaining.
# Tick 1344: 3 carts remaining.
# Tick 1345: 3 carts remaining.
# Tick 1346: 3 carts remaining.
# Tick 1347: 3 carts remaining.
# Tick 1348: 3 carts remaining.
# Tick 1349: 3 carts remaining.
# Tick 1350: 3 carts remaining.
# Tick 1351: 3 carts remaining.
# Tick 1352: 3 carts remaining.
# Tick 1353: 3 carts remaining.
# Tick 1354: 3 carts remaining.
# Tick 1355: 3 carts remaining.
# Tick 1356: 3 carts remaining.
# Tick 1357: 3 carts remaining.
# Tick 1358: 3 carts remaining.
# Tick 1359: 3 carts remaining.
# Tick 1360: 3 carts remaining.
# Tick 1361: 3 carts remaining.
# Tick 1362: 3 carts remaining.
# Tick 1363: 3 carts remaining.
# Tick 1364: 3 carts remaining.
# Tick 1365: 3 carts remaining.
# Tick 1366: 3 carts remaining.
# Tick 1367: 3 carts remaining.
# Tick 1368: 3 carts remaining.
# Tick 1369: 3 carts remaining.
# Tick 1370: 3 carts remaining.
# Tick 1371: 3 carts remaining.
# Tick 1372: 3 carts remaining.
# Tick 1373: 3 carts remaining.
# Tick 1374: 3 carts remaining.
# Tick 1375: 3 carts remaining.
# Tick 1376: 3 carts remaining.
# Tick 1377: 3 carts remaining.
# Tick 1378: 3 carts remaining.
# Tick 1379: 3 carts remaining.
# Tick 1380: 3 carts remaining.
# Tick 1381: 3 carts remaining.
# Tick 1382: 3 carts remaining.
# Tick 1383: 3 carts remaining.
# Tick 1384: 3 carts remaining.
# Tick 1385: 3 carts remaining.
# Tick 1386: 3 carts remaining.
# Tick 1387: 3 carts remaining.
# Tick 1388: 3 carts remaining.
# Tick 1389: 3 carts remaining.
# Tick 1390: 3 carts remaining.
# Tick 1391: 3 carts remaining.
# Tick 1392: 3 carts remaining.
# Tick 1393: 3 carts remaining.
# Tick 1394: 3 carts remaining.
# Tick 1395: 3 carts remaining.
# Tick 1396: 3 carts remaining.
# Tick 1397: 3 carts remaining.
# Tick 1398: 3 carts remaining.
# Tick 1399: 3 carts remaining.
# Tick 1400: 3 carts remaining.
# Tick 1401: 3 carts remaining.
# Tick 1402: 3 carts remaining.
# Tick 1403: 3 carts remaining.
# Tick 1404: 3 carts remaining.
# Tick 1405: 3 carts remaining.
# Tick 1406: 3 carts remaining.
# Tick 1407: 3 carts remaining.
# Tick 1408: 3 carts remaining.
# Tick 1409: 3 carts remaining.
# Tick 1410: 3 carts remaining.
# Tick 1411: 3 carts remaining.
# Tick 1412: 3 carts remaining.
# Tick 1413: 3 carts remaining.
# Tick 1414: 3 carts remaining.
# Tick 1415: 3 carts remaining.
# Tick 1416: 3 carts remaining.
# Tick 1417: 3 carts remaining.
# Tick 1418: 3 carts remaining.
# Tick 1419: 3 carts remaining.
# Tick 1420: 3 carts remaining.
# Tick 1421: 3 carts remaining.
# Tick 1422: 3 carts remaining.
# Tick 1423: 3 carts remaining.
# Tick 1424: 3 carts remaining.
# Tick 1425: 3 carts remaining.
# Tick 1426: 3 carts remaining.
# Tick 1427: 3 carts remaining.
# Tick 1428: 3 carts remaining.
# Tick 1429: 3 carts remaining.
# Tick 1430: 3 carts remaining.
# Tick 1431: 3 carts remaining.
# Tick 1432: 3 carts remaining.
# Tick 1433: 3 carts remaining.
# Tick 1434: 3 carts remaining.
# Tick 1435: 3 carts remaining.
# Tick 1436: 3 carts remaining.
# Tick 1437: 3 carts remaining.
# Tick 1438: 3 carts remaining.
# Tick 1439: 3 carts remaining.
# Tick 1440: 3 carts remaining.
# Tick 1441: 3 carts remaining.
# Tick 1442: 3 carts remaining.
# Tick 1443: 3 carts remaining.
# Tick 1444: 3 carts remaining.
# Tick 1445: 3 carts remaining.
# Tick 1446: 3 carts remaining.
# Tick 1447: 3 carts remaining.
# Tick 1448: 3 carts remaining.
# Tick 1449: 3 carts remaining.
# Tick 1450: 3 carts remaining.
# Tick 1451: 3 carts remaining.
# Tick 1452: 3 carts remaining.
# Tick 1453: 3 carts remaining.
# Tick 1454: 3 carts remaining.
# Tick 1455: 3 carts remaining.
# Tick 1456: 3 carts remaining.
# Tick 1457: 3 carts remaining.
# Tick 1458: 3 carts remaining.
# Tick 1459: 3 carts remaining.
# Tick 1460: 3 carts remaining.
# Tick 1461: 3 carts remaining.
# Tick 1462: 3 carts remaining.
# Tick 1463: 3 carts remaining.
# Tick 1464: 3 carts remaining.
# Tick 1465: 3 carts remaining.
# Tick 1466: 3 carts remaining.
# Tick 1467: 3 carts remaining.
# Tick 1468: 3 carts remaining.
# Tick 1469: 3 carts remaining.
# Tick 1470: 3 carts remaining.
# Tick 1471: 3 carts remaining.
# Tick 1472: 3 carts remaining.
# Tick 1473: 3 carts remaining.
# Tick 1474: 3 carts remaining.
# Tick 1475: 3 carts remaining.
# Tick 1476: 3 carts remaining.
# Tick 1477: 3 carts remaining.
# Tick 1478: 3 carts remaining.
# Tick 1479: 3 carts remaining.
# Tick 1480: 3 carts remaining.
# Tick 1481: 3 carts remaining.
# Tick 1482: 3 carts remaining.
# Tick 1483: 3 carts remaining.
# Tick 1484: 3 carts remaining.
# Tick 1485: 3 carts remaining.
# Tick 1486: 3 carts remaining.
# Tick 1487: 3 carts remaining.
# Tick 1488: 3 carts remaining.
# Tick 1489: 3 carts remaining.
# Tick 1490: 3 carts remaining.
# Tick 1491: 3 carts remaining.
# Tick 1492: 3 carts remaining.
# Tick 1493: 3 carts remaining.
# Tick 1494: 3 carts remaining.
# Tick 1495: 3 carts remaining.
# Tick 1496: 3 carts remaining.
# Tick 1497: 3 carts remaining.
# Tick 1498: 3 carts remaining.
# Tick 1499: 3 carts remaining.
# Tick 1500: 3 carts remaining.
# Tick 1501: 3 carts remaining.
# Tick 1502: 3 carts remaining.
# Tick 1503: 3 carts remaining.
# Tick 1504: 3 carts remaining.
# Tick 1505: 3 carts remaining.
# Tick 1506: 3 carts remaining.
# Tick 1507: 3 carts remaining.
# Tick 1508: 3 carts remaining.
# Tick 1509: 3 carts remaining.
# Tick 1510: 3 carts remaining.
# Tick 1511: 3 carts remaining.
# Tick 1512: 3 carts remaining.
# Tick 1513: 3 carts remaining.
# Tick 1514: 3 carts remaining.
# Tick 1515: 3 carts remaining.
# Tick 1516: 3 carts remaining.
# Tick 1517: 3 carts remaining.
# Tick 1518: 3 carts remaining.
# Tick 1519: 3 carts remaining.
# Tick 1520: 3 carts remaining.
# Tick 1521: 3 carts remaining.
# Tick 1522: 3 carts remaining.
# Tick 1523: 3 carts remaining.
# Tick 1524: 3 carts remaining.
# Tick 1525: 3 carts remaining.
# Tick 1526: 3 carts remaining.
# Tick 1527: 3 carts remaining.
# Tick 1528: 3 carts remaining.
# Tick 1529: 3 carts remaining.
# Tick 1530: 3 carts remaining.
# Tick 1531: 3 carts remaining.
# Tick 1532: 3 carts remaining.
# Tick 1533: 3 carts remaining.
# Tick 1534: 3 carts remaining.
# Tick 1535: 3 carts remaining.
# Tick 1536: 3 carts remaining.
# Tick 1537: 3 carts remaining.
# Tick 1538: 3 carts remaining.
# Tick 1539: 3 carts remaining.
# Tick 1540: 3 carts remaining.
# Tick 1541: 3 carts remaining.
# Tick 1542: 3 carts remaining.
# Tick 1543: 3 carts remaining.
# Tick 1544: 3 carts remaining.
# Tick 1545: 3 carts remaining.
# Tick 1546: 3 carts remaining.
# Tick 1547: 3 carts remaining.
# Tick 1548: 3 carts remaining.
# Tick 1549: 3 carts remaining.
# Tick 1550: 3 carts remaining.
# Tick 1551: 3 carts remaining.
# Tick 1552: 3 carts remaining.
# Tick 1553: 3 carts remaining.
# Tick 1554: 3 carts remaining.
# Tick 1555: 3 carts remaining.
# Tick 1556: 3 carts remaining.
# Tick 1557: 3 carts remaining.
# Tick 1558: 3 carts remaining.
# Tick 1559: 3 carts remaining.
# Tick 1560: 3 carts remaining.
# Tick 1561: 3 carts remaining.
# Tick 1562: 3 carts remaining.
# Tick 1563: 3 carts remaining.
# Tick 1564: 3 carts remaining.
# Tick 1565: 3 carts remaining.
# Tick 1566: 3 carts remaining.
# Tick 1567: 3 carts remaining.
# Tick 1568: 3 carts remaining.
# Tick 1569: 3 carts remaining.
# Tick 1570: 3 carts remaining.
# Tick 1571: 3 carts remaining.
# ...
# Tick 1670: 3 carts remaining.
# Tick 1671: 3 carts remaining.
# Tick 1672: 3 carts remaining.
# Tick 1673: 3 carts remaining.
# Tick 1674: 3 carts remaining.
# Tick 1675: 3 carts remaining.
# Tick 1676: 3 carts remaining.
# Tick 1677: 3 carts remaining.
# Tick 1678: 3 carts remaining.
# Tick 1679: 3 carts remaining.
# Tick 1680: 3 carts remaining.
# Tick 1681: 3 carts remaining.
# Tick 1682: 3 carts remaining.
# Tick 1683: 3 carts remaining.
# Tick 1684: 3 carts remaining.
# Tick 1685: 3 carts remaining.
# Tick 1686: 3 carts remaining.
# Tick 1687: 3 carts remaining.
# Tick 1688: 3 carts remaining.
# Tick 1689: 3 carts remaining.
# Tick 1690: 3 carts remaining.
# Tick 1691: 3 carts remaining.
# Tick 1692: 3 carts remaining.
# Tick 1693: 3 carts remaining.
# Tick 1694: 3 carts remaining.
# Tick 1695: 3 carts remaining.
# Tick 1696: 3 carts remaining.
# Tick 1697: 3 carts remaining.
# Tick 1698: 3 carts remaining.
# Tick 1699: 3 carts remaining.
# Tick 1700: 3 carts remaining.
# Tick 1701: 3 carts remaining.
# Tick 1702: 3 carts remaining.
# Tick 1703: 3 carts remaining.
# Tick 1704: 3 carts remaining.
# Tick 1705: 3 carts remaining.
# Tick 1706: 3 carts remaining.
# Tick 1707: 3 carts remaining.
# Tick 1708: 3 carts remaining.
# Tick 1709: 3 carts remaining.
# Tick 1710: 3 carts remaining.
# Tick 1711: 3 carts remaining.
# Tick 1712: 3 carts remaining.
# Tick 1713: 3 carts remaining.
# Tick 1714: 3 carts remaining.
# Tick 1715: 3 carts remaining.
# Tick 1716: 3 carts remaining.
# Tick 1717: 3 carts remaining.
# Tick 1718: 3 carts remaining.
# Tick 1719: 3 carts remaining.
# Tick 1720: 3 carts remaining.
# Tick 1721: 3 carts remaining.
# Tick 1722: 3 carts remaining.
# Tick 1723: 3 carts remaining.
# Tick 1724: 3 carts remaining.
# Tick 1725: 3 carts remaining.
# Tick 1726: 3 carts remaining.
# Tick 1727: 3 carts remaining.
# Tick 1728: 3 carts remaining.
# Tick 1729: 3 carts remaining.
# Tick 1730: 3 carts remaining.
# Tick 1731: 3 carts remaining.
# Tick 1732: 3 carts remaining.
# Tick 1733: 3 carts remaining.
# Tick 1734: 3 carts remaining.
# Tick 1735: 3 carts remaining.
# Tick 1736: 3 carts remaining.
# Tick 1737: 3 carts remaining.
# Tick 1738: 3 carts remaining.
# Tick 1739: 3 carts remaining.
# Tick 1740: 3 carts remaining.
# Tick 1741: 3 carts remaining.
# Tick 1742: 3 carts remaining.
# Tick 1743: 3 carts remaining.
# Tick 1744: 3 carts remaining.
# Tick 1745: 3 carts remaining.
# Tick 1746: 3 carts remaining.
# Tick 1747: 3 carts remaining.
# Tick 1748: 3 carts remaining.
# Tick 1749: 3 carts remaining.
# Tick 1750: 3 carts remaining.
# Tick 1751: 3 carts remaining.
# Tick 1752: 3 carts remaining.
# Tick 1753: 3 carts remaining.
# Tick 1754: 3 carts remaining.
# Tick 1755: 3 carts remaining.
# Tick 1756: 3 carts remaining.
# Tick 1757: 3 carts remaining.
# Tick 1758: 3 carts remaining.
# Tick 1759: 3 carts remaining.
# Tick 1760: 3 carts remaining.
# Tick 1761: 3 carts remaining.
# Tick 1762: 3 carts remaining.
# Tick 1763: 3 carts remaining.
# Tick 1764: 3 carts remaining.
# Tick 1765: 3 carts remaining.
# Tick 1766: 3 carts remaining.
# Tick 1767: 3 carts remaining.
# Tick 1768: 3 carts remaining.
# Tick 1769: 3 carts remaining.
# Tick 1770: 3 carts remaining.
# Tick 1771: 3 carts remaining.
# Tick 1772: 3 carts remaining.
# Tick 1773: 3 carts remaining.
# Tick 1774: 3 carts remaining.
# Tick 1775: 3 carts remaining.
# Tick 1776: 3 carts remaining.
# Tick 1777: 3 carts remaining.
# Tick 1778: 3 carts remaining.
# Tick 1779: 3 carts remaining.
# Tick 1780: 3 carts remaining.
# Tick 1781: 3 carts remaining.
# Tick 1782: 3 carts remaining.
# Tick 1783: 3 carts remaining.
# Tick 1784: 3 carts remaining.
# Tick 1785: 3 carts remaining.
# Tick 1786: 3 carts remaining.
# Tick 1787: 3 carts remaining.
# Tick 1788: 3 carts remaining.
# Tick 1789: 3 carts remaining.
# Tick 1790: 3 carts remaining.
# Tick 1791: 3 carts remaining.
# Tick 1792: 3 carts remaining.
# Tick 1793: 3 carts remaining.
# Tick 1794: 3 carts remaining.
# Tick 1795: 3 carts remaining.
# Tick 1796: 3 carts remaining.
# Tick 1797: 3 carts remaining.
# Tick 1798: 3 carts remaining.
# Tick 1799: 3 carts remaining.
# Tick 1800: 3 carts remaining.
# Tick 1801: 3 carts remaining.
# Tick 1802: 3 carts remaining.
# Tick 1803: 3 carts remaining.
# Tick 1804: 3 carts remaining.
# Tick 1805: 3 carts remaining.
# Tick 1806: 3 carts remaining.
# Tick 1807: 3 carts remaining.
# Tick 1808: 3 carts remaining.
# Tick 1809: 3 carts remaining.
# Tick 1810: 3 carts remaining.
# Tick 1811: 3 carts remaining.
# Tick 1812: 3 carts remaining.
# Tick 1813: 3 carts remaining.
# Tick 1814: 3 carts remaining.
# Tick 1815: 3 carts remaining.
# Tick 1816: 3 carts remaining.
# Tick 1817: 3 carts remaining.
# Tick 1818: 3 carts remaining.
# Tick 1819: 3 carts remaining.
# Tick 1820: 3 carts remaining.
# Tick 1821: 3 carts remaining.
# Tick 1822: 3 carts remaining.
# Tick 1823: 3 carts remaining.
# Tick 1824: 3 carts remaining.
# Tick 1825: 3 carts remaining.
# Tick 1826: 3 carts remaining.
# Tick 1827: 3 carts remaining.
# Tick 1828: 3 carts remaining.
# Tick 1829: 3 carts remaining.
# Tick 1830: 3 carts remaining.
# Tick 1831: 3 carts remaining.
# Tick 1832: 3 carts remaining.
# Tick 1833: 3 carts remaining.
# Tick 1834: 3 carts remaining.
# Tick 1835: 3 carts remaining.
# Tick 1836: 3 carts remaining.
# Tick 1837: 3 carts remaining.
# Tick 1838: 3 carts remaining.
# Tick 1839: 3 carts remaining.
# Tick 1840: 3 carts remaining.
# Tick 1841: 3 carts remaining.
# Tick 1842: 3 carts remaining.
# Tick 1843: 3 carts remaining.
# Tick 1844: 3 carts remaining.
# Tick 1845: 3 carts remaining.
# Tick 1846: 3 carts remaining.
# Tick 1847: 3 carts remaining.
# Tick 1848: 3 carts remaining.
# Tick 1849: 3 carts remaining.
# Tick 1850: 3 carts remaining.
# Tick 1851: 3 carts remaining.
# Tick 1852: 3 carts remaining.
# Tick 1853: 3 carts remaining.
# Tick 1854: 3 carts remaining.
# Tick 1855: 3 carts remaining.
# Tick 1856: 3 carts remaining.
# Tick 1857: 3 carts remaining.
# Tick 1858: 3 carts remaining.
# Tick 1859: 3 carts remaining.
# Tick 1860: 3 carts remaining.
# Tick 1861: 3 carts remaining.
# Tick 1862: 3 carts remaining.
# Tick 1863: 3 carts remaining.
# Tick 1864: 3 carts remaining.
# Tick 1865: 3 carts remaining.
# Tick 1866: 3 carts remaining.
# Tick 1867: 3 carts remaining.
# Tick 1868: 3 carts remaining.
# Tick 1869: 3 carts remaining.
# Tick 1870: 3 carts remaining.
# Tick 1871: 3 carts remaining.
# Tick 1872: 3 carts remaining.
# Tick 1873: 3 carts remaining.
# Tick 1874: 3 carts remaining.
# Tick 1875: 3 carts remaining.
# Tick 1876: 3 carts remaining.
# Tick 1877: 3 carts remaining.
# Tick 1878: 3 carts remaining.
# Tick 1879: 3 carts remaining.
# Tick 1880: 3 carts remaining.
# Tick 1881: 3 carts remaining.
# Tick 1882: 3 carts remaining.
# Tick 1883: 3 carts remaining.
# Tick 1884: 3 carts remaining.
# Tick 1885: 3 carts remaining.
# Tick 1886: 3 carts remaining.
# Tick 1887: 3 carts remaining.
# Tick 1888: 3 carts remaining.
# Tick 1889: 3 carts remaining.
# Tick 1890: 3 carts remaining.
# Tick 1891: 3 carts remaining.
# Tick 1892: 3 carts remaining.
# Tick 1893: 3 carts remaining.
# Tick 1894: 3 carts remaining.
# Tick 1895: 3 carts remaining.
# Tick 1896: 3 carts remaining.
# Tick 1897: 3 carts remaining.
# Tick 1898: 3 carts remaining.
# Tick 1899: 3 carts remaining.
# Tick 1900: 3 carts remaining.
# Tick 1901: 3 carts remaining.
# Tick 1902: 3 carts remaining.
# Tick 1903: 3 carts remaining.
# Tick 1904: 3 carts remaining.
# Tick 1905: 3 carts remaining.
# Tick 1906: 3 carts remaining.
# Tick 1907: 3 carts remaining.
# Tick 1908: 3 carts remaining.
# Tick 1909: 3 carts remaining.
# Tick 1910: 3 carts remaining.
# Tick 1911: 3 carts remaining.
# Tick 1912: 3 carts remaining.
# Tick 1913: 3 carts remaining.
# Tick 1914: 3 carts remaining.
# Tick 1915: 3 carts remaining.
# Tick 1916: 3 carts remaining.
# Tick 1917: 3 carts remaining.
# Tick 1918: 3 carts remaining.
# Tick 1919: 3 carts remaining.
# Tick 1920: 3 carts remaining.
# Tick 1921: 3 carts remaining.
# Tick 1922: 3 carts remaining.
# Tick 1923: 3 carts remaining.
# Tick 1924: 3 carts remaining.
# Tick 1925: 3 carts remaining.
# Tick 1926: 3 carts remaining.
# Tick 1927: 3 carts remaining.
# Tick 1928: 3 carts remaining.
# Tick 1929: 3 carts remaining.
# Tick 1930: 3 carts remaining.
# Tick 1931: 3 carts remaining.
# Tick 1932: 3 carts remaining.
# Tick 1933: 3 carts remaining.
# Tick 1934: 3 carts remaining.
# Tick 1935: 3 carts remaining.
# Tick 1936: 3 carts remaining.
# Tick 1937: 3 carts remaining.
# Tick 1938: 3 carts remaining.
# Tick 1939: 3 carts remaining.
# Tick 1940: 3 carts remaining.
# Tick 1941: 3 carts remaining.
# Tick 1942: 3 carts remaining.
# Tick 1943: 3 carts remaining.
# Tick 1944: 3 carts remaining.
# Tick 1945: 3 carts remaining.
# Tick 1946: 3 carts remaining.
# Tick 1947: 3 carts remaining.
# Tick 1948: 3 carts remaining.
# Tick 1949: 3 carts remaining.
# Tick 1950: 3 carts remaining.
# Tick 1951: 3 carts remaining.
# Tick 1952: 3 carts remaining.
# Tick 1953: 3 carts remaining.
# Tick 1954: 3 carts remaining.
# Tick 1955: 3 carts remaining.
# Tick 1956: 3 carts remaining.
# Tick 1957: 3 carts remaining.
# Tick 1958: 3 carts remaining.
# Tick 1959: 3 carts remaining.
# Tick 1960: 3 carts remaining.
# Tick 1961: 3 carts remaining.
# Tick 1962: 3 carts remaining.
# Tick 1963: 3 carts remaining.
# Tick 1964: 3 carts remaining.
# Tick 1965: 3 carts remaining.
# Tick 1966: 3 carts remaining.
# Tick 1967: 3 carts remaining.
# Tick 1968: 3 carts remaining.
# Tick 1969: 3 carts remaining.
# Tick 1970: 3 carts remaining.
# Tick 1971: 3 carts remaining.
# Tick 1972: 3 carts remaining.
# Tick 1973: 3 carts remaining.
# Tick 1974: 3 carts remaining.
# Tick 1975: 3 carts remaining.
# Tick 1976: 3 carts remaining.
# Tick 1977: 3 carts remaining.
# Tick 1978: 3 carts remaining.
# Tick 1979: 3 carts remaining.
# Tick 1980: 3 carts remaining.
# Tick 1981: 3 carts remaining.
# Tick 1982: 3 carts remaining.
# Tick 1983: 3 carts remaining.
# Tick 1984: 3 carts remaining.
# Tick 1985: 3 carts remaining.
# Tick 1986: 3 carts remaining.
# Tick 1987: 3 carts remaining.
# Tick 1988: 3 carts remaining.
# Tick 1989: 3 carts remaining.
# Tick 1990: 3 carts remaining.
# Tick 1991: 3 carts remaining.
# Tick 1992: 3 carts remaining.
# Tick 1993: 3 carts remaining.
# Tick 1994: 3 carts remaining.
# Tick 1995: 3 carts remaining.
# Tick 1996: 3 carts remaining.
# Tick 1997: 3 carts remaining.
# Tick 1998: 3 carts remaining.
# Tick 1999: 3 carts remaining.
# Tick 2000: 3 carts remaining.
# Tick 2001: 3 carts remaining.
# Tick 2002: 3 carts remaining.
# Tick 2003: 3 carts remaining.
# Tick 2004: 3 carts remaining.
# Tick 2005: 3 carts remaining.
# Tick 2006: 3 carts remaining.
# Tick 2007: 3 carts remaining.
# Tick 2008: 3 carts remaining.
# Tick 2009: 3 carts remaining.
# Tick 2010: 3 carts remaining.
# Tick 2011: 3 carts remaining.
# Tick 2012: 3 carts remaining.
# Tick 2013: 3 carts remaining.
# Tick 2014: 3 carts remaining.
# Tick 2015: 3 carts remaining.
# Tick 2016: 3 carts remaining.
# Tick 2017: 3 carts remaining.
# Tick 2018: 3 carts remaining.
# Tick 2019: 3 carts remaining.
# Tick 2020: 3 carts remaining.
# Tick 2021: 3 carts remaining.
# Tick 2022: 3 carts remaining.
# Tick 2023: 3 carts remaining.
# Tick 2024: 3 carts remaining.
# Tick 2025: 3 carts remaining.
# Tick 2026: 3 carts remaining.
# Tick 2027: 3 carts remaining.
# Tick 2028: 3 carts remaining.
# Tick 2029: 3 carts remaining.
# Tick 2030: 3 carts remaining.
# Tick 2031: 3 carts remaining.
# Tick 2032: 3 carts remaining.
# Tick 2033: 3 carts remaining.
# Tick 2034: 3 carts remaining.
# Tick 2035: 3 carts remaining.
# Tick 2036: 3 carts remaining.
# Tick 2037: 3 carts remaining.
# Tick 2038: 3 carts remaining.
# Tick 2039: 3 carts remaining.
# Tick 2040: 3 carts remaining.
# Tick 2041: 3 carts remaining.
# Tick 2042: 3 carts remaining.
# Tick 2043: 3 carts remaining.
# Tick 2044: 3 carts remaining.
# Tick 2045: 3 carts remaining.
# Tick 2046: 3 carts remaining.
# Tick 2047: 3 carts remaining.
# Tick 2048: 3 carts remaining.
# Tick 2049: 3 carts remaining.
# Tick 2050: 3 carts remaining.
# Tick 2051: 3 carts remaining.
# Tick 2052: 3 carts remaining.
# Tick 2053: 3 carts remaining.
# Tick 2054: 3 carts remaining.
# Tick 2055: 3 carts remaining.
# Tick 2056: 3 carts remaining.
# Tick 2057: 3 carts remaining.
# Tick 2058: 3 carts remaining.
# Tick 2059: 3 carts remaining.
# Tick 2060: 3 carts remaining.
# Tick 2061: 3 carts remaining.
# Tick 2062: 3 carts remaining.
# Tick 2063: 3 carts remaining.
# Tick 2064: 3 carts remaining.
# Tick 2065: 3 carts remaining.
# Tick 2066: 3 carts remaining.
# Tick 2067: 3 carts remaining.
# Tick 2068: 3 carts remaining.
# Tick 2069: 3 carts remaining.
# Tick 2070: 3 carts remaining.
# Tick 2071: 3 carts remaining.
# Tick 2072: 3 carts remaining.
# Tick 2073: 3 carts remaining.
# Tick 2074: 3 carts remaining.
# Tick 2075: 3 carts remaining.
# Tick 2076: 3 carts remaining.
# Tick 2077: 3 carts remaining.
# Tick 2078: 3 carts remaining.
# Tick 2079: 3 carts remaining.
# Tick 2080: 3 carts remaining.
# Tick 2081: 3 carts remaining.
# Tick 2082: 3 carts remaining.
# Tick 2083: 3 carts remaining.
# Tick 2084: 3 carts remaining.
# Tick 2085: 3 carts remaining.
# Tick 2086: 3 carts remaining.
# Tick 2087: 3 carts remaining.
# Tick 2088: 3 carts remaining.
# Tick 2089: 3 carts remaining.
# Tick 2090: 3 carts remaining.
# Tick 2091: 3 carts remaining.
# Tick 2092: 3 carts remaining.
# Tick 2093: 3 carts remaining.
# Tick 2094: 3 carts remaining.
# Tick 2095: 3 carts remaining.
# Tick 2096: 3 carts remaining.
# Tick 2097: 3 carts remaining.
# Tick 2098: 3 carts remaining.
# Tick 2099: 3 carts remaining.
# Tick 2100: 3 carts remaining.
# Tick 2101: 3 carts remaining.
# Tick 2102: 3 carts remaining.
# Tick 2103: 3 carts remaining.
# Tick 2104: 3 carts remaining.
# Tick 2105: 3 carts remaining.
# Tick 2106: 3 carts remaining.
# Tick 2107: 3 carts remaining.
# Tick 2108: 3 carts remaining.
# Tick 2109: 3 carts remaining.
# Tick 2110: 3 carts remaining.
# Tick 2111: 3 carts remaining.
# Tick 2112: 3 carts remaining.
# Tick 2113: 3 carts remaining.
# Tick 2114: 3 carts remaining.
# Tick 2115: 3 carts remaining.
# Tick 2116: 3 carts remaining.
# Tick 2117: 3 carts remaining.
# Tick 2118: 3 carts remaining.
# Tick 2119: 3 carts remaining.
# Tick 2120: 3 carts remaining.
# Tick 2121: 3 carts remaining.
# Tick 2122: 3 carts remaining.
# Tick 2123: 3 carts remaining.
# Tick 2124: 3 carts remaining.
# Tick 2125: 3 carts remaining.
# Tick 2126: 3 carts remaining.
# Tick 2127: 3 carts remaining.
# Tick 2128: 3 carts remaining.
# Tick 2129: 3 carts remaining.
# Tick 2130: 3 carts remaining.
# Tick 2131: 3 carts remaining.
# Tick 2132: 3 carts remaining.
# Tick 2133: 3 carts remaining.
# Tick 2134: 3 carts remaining.
# Tick 2135: 3 carts remaining.
# Tick 2136: 3 carts remaining.
# Tick 2137: 3 carts remaining.
# Tick 2138: 3 carts remaining.
# Tick 2139: 3 carts remaining.
# Tick 2140: 3 carts remaining.
# Tick 2141: 3 carts remaining.
# Tick 2142: 3 carts remaining.
# Tick 2143: 3 carts remaining.
# Tick 2144: 3 carts remaining.
# Tick 2145: 3 carts remaining.
# Tick 2146: 3 carts remaining.
# Tick 2147: 3 carts remaining.
# Tick 2148: 3 carts remaining.
# Tick 2149: 3 carts remaining.
# Tick 2150: 3 carts remaining.
# Tick 2151: 3 carts remaining.
# Tick 2152: 3 carts remaining.
# Tick 2153: 3 carts remaining.
# Tick 2154: 3 carts remaining.
# Tick 2155: 3 carts remaining.
# Tick 2156: 3 carts remaining.
# Tick 2157: 3 carts remaining.
# Tick 2158: 3 carts remaining.
# Tick 2159: 3 carts remaining.
# Tick 2160: 3 carts remaining.
# Tick 2161: 3 carts remaining.
# Tick 2162: 3 carts remaining.
# Tick 2163: 3 carts remaining.
# Tick 2164: 3 carts remaining.
# Tick 2165: 3 carts remaining.
# Tick 2166: 3 carts remaining.
# Tick 2167: 3 carts remaining.
# Tick 2168: 3 carts remaining.
# Tick 2169: 3 carts remaining.
# Tick 2170: 3 carts remaining.
# Tick 2171: 3 carts remaining.
# Tick 2172: 3 carts remaining.
# Tick 2173: 3 carts remaining.
# Tick 2174: 3 carts remaining.
# Tick 2175: 3 carts remaining.
# Tick 2176: 3 carts remaining.
# Tick 2177: 3 carts remaining.
# Tick 2178: 3 carts remaining.
# Tick 2179: 3 carts remaining.
# Tick 2180: 3 carts remaining.
# Tick 2181: 3 carts remaining.
# Tick 2182: 3 carts remaining.
# Tick 2183: 3 carts remaining.
# Tick 2184: 3 carts remaining.
# Tick 2185: 3 carts remaining.
# Tick 2186: 3 carts remaining.
# Tick 2187: 3 carts remaining.
# Tick 2188: 3 carts remaining.
# Tick 2189: 3 carts remaining.
# Tick 2190: 3 carts remaining.
# Tick 2191: 3 carts remaining.
# Tick 2192: 3 carts remaining.
# Tick 2193: 3 carts remaining.
# Tick 2194: 3 carts remaining.
# Tick 2195: 3 carts remaining.
# Tick 2196: 3 carts remaining.
# Tick 2197: 3 carts remaining.
# Tick 2198: 3 carts remaining.
# Tick 2199: 3 carts remaining.
# Collision detected at (66, 66) on tick 2200.
# Tick 2200: 1 carts remaining.
# (148, 38)

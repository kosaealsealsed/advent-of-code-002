# %% [markdown]
# # Advent of Code

# %% [markdown]
# ## 2016-012-004
# ## 2016 004

# %% [markdown]
# https://adventofcode.com/2016/day/4

# %%
import re
from collections import Counter

def is_real_room(name, checksum):
    # Remove the dashes and count the frequency of each letter
    name = name.replace('-', '')
    letter_count = Counter(name)

    # Sort the letters by frequency and alphabetically for ties
    sorted_letters = sorted(letter_count.items(), key=lambda x: (-x[1], x[0]))

    # Extract the first five letters
    calculated_checksum = ''.join([letter[0] for letter in sorted_letters[:5]])

    # Check if the checksum matches
    return calculated_checksum == checksum

def process_room(line):
    # Use regular expression to extract the name, sector ID, and checksum
    match = re.match(r'([a-z\-]+)-(\d+)\[([a-z]+)\]', line)
    if match:
        encrypted_name = match.group(1)
        sector_id = int(match.group(2))
        checksum = match.group(3)
        return encrypted_name, sector_id, checksum
    return None

def sum_real_rooms(input_lines):
    total_sum = 0

    for line in input_lines:
        result = process_room(line)
        if result:
            encrypted_name, sector_id, checksum = result
            if is_real_room(encrypted_name, checksum):
                total_sum += sector_id

    return total_sum

# Read input data from a file
with open('input.txt', 'r') as file:
    input_lines = file.readlines()

# Calculate the sum of sector IDs of real rooms
result = sum_real_rooms(input_lines)
print(f"The sum of the sector IDs of the real rooms is: {result}")
# Out:
# The sum of the sector IDs of the real rooms is: 137896

# %%
from collections import defaultdict

def decrypt_name(encrypted_name, sector_id):
    decrypted_name = []
    
    for char in encrypted_name:
        if char == '-':
            decrypted_name.append(' ')
        else:
            # Rotate character
            new_char = chr(((ord(char) - ord('a') + sector_id) % 26) + ord('a'))
            decrypted_name.append(new_char)
    
    return ''.join(decrypted_name)

def process_room(line):
    # Use regular expression to extract the name, sector ID, and checksum
    match = re.match(r'([a-z\-]+)-(\d+)\[([a-z]+)\]', line)
    if match:
        encrypted_name = match.group(1)
        sector_id = int(match.group(2))
        checksum = match.group(3)
        return encrypted_name, sector_id, checksum
    return None

def store_rooms(input_lines):
    rooms = []
    for line in input_lines:
        result = process_room(line)
        if result:
            encrypted_name, sector_id, checksum = result
            decrypted_name = decrypt_name(encrypted_name, sector_id)
            rooms.append((decrypted_name, sector_id))
    return rooms

# Read input data from a file
with open('input.txt', 'r') as file:
    input_lines = file.readlines()

# Store all rooms and their decrypted names and sector IDs
rooms = store_rooms(input_lines)

# Group by real name
grouped_rooms = defaultdict(list)

for decrypted_name, sector_id in rooms:
    grouped_rooms[decrypted_name].append(sector_id)

# Sort the groups first by the number of sector IDs (ascending) and then alphabetically by the real name
sorted_rooms = {k: sorted(v) for k, v in sorted(grouped_rooms.items(), key=lambda item: (len(item[1]), item[0]))}

# Print the grouped and sorted result
for decrypted_name, sector_ids in sorted_rooms.items():
    print(f"{decrypted_name}: {sector_ids}")
# Out:
# biohazardous basket customer service: [511]
# biohazardous basket department: [874]
# biohazardous basket deployment: [938]
# biohazardous basket design: [172]
# biohazardous basket engineering: [748]
# biohazardous basket laboratory: [173]
# biohazardous basket services: [916]
# biohazardous basket storage: [799]
# biohazardous basket workshop: [282]
# biohazardous bunny department: [708]
# biohazardous bunny reacquisition: [872]
# biohazardous bunny storage: [371]
# biohazardous bunny technology: [386]
# biohazardous candy coating laboratory: [726]
# biohazardous candy coating workshop: [765]
# biohazardous candy customer service: [544]
# biohazardous candy financing: [351]
# biohazardous candy training: [242]
# biohazardous chocolate development: [245]
# biohazardous chocolate reacquisition: [814]
# biohazardous corrosive rabbit development: [466]
# biohazardous cryogenic rabbit user testing: [367]
# biohazardous dye containment: [851]
# biohazardous dye engineering: [463]
# biohazardous dye shipping: [867]
# biohazardous dye storage: [476]
# biohazardous egg design: [740]
# biohazardous egg development: [897]
# biohazardous egg logistics: [794]
# biohazardous egg sales: [972]
# biohazardous egg storage: [248]
# biohazardous flower acquisition: [622]
# biohazardous flower marketing: [616]
# biohazardous flower receiving: [476]
# biohazardous flower training: [918]
# biohazardous fuzzy bunny research: [857]
# biohazardous international bunny deployment: [493]
# biohazardous jellybean analysis: [694]
# biohazardous jellybean deployment: [930]
# biohazardous jellybean development: [600]
# biohazardous jellybean marketing: [183]
# biohazardous jellybean reacquisition: [838]
# biohazardous jellybean research: [743]
# biohazardous jellybean shipping: [740]
# biohazardous jellybean storage: [488]
# biohazardous jellybean training: [971]
# biohazardous jellybean user testing: [122]
# biohazardous plastic grass development: [323]
# biohazardous plastic grass marketing: [124]
# biohazardous plastic grass technology: [318]
# biohazardous rabbit analysis: [831]
# biohazardous rabbit customer service: [889]
# biohazardous rabbit development: [694]
# biohazardous rabbit engineering: [170]
# biohazardous rabbit user testing: [502]
# biohazardous scavenger hunt department: [477]
# biohazardous scavenger hunt purchasing: [671]
# biohazardous scavenger hunt storage: [639]
# biohazardous scavenger hunt technology: [122]
# biohazardous unstable egg services: [890]
# biohazardous weaponized scavenger hunt analysis: [244]
# chocolate analysis: [629]
# classified basket laboratory: [691]
# classified basket logistics: [632]
# classified basket sales: [251]
# classified basket user testing: [417]
# classified bunny analysis: [953]
# classified bunny logistics: [991]
# classified bunny shipping: [658]
# classified candy coating analysis: [684]
# classified candy coating containment: [511]
# classified candy coating engineering: [522]
# classified candy coating financing: [113]
# classified candy coating shipping: [534]
# classified candy containment: [974]
# classified candy receiving: [110]
# classified chocolate logistics: [464]
# classified chocolate reacquisition: [774]
# classified chocolate receiving: [801]
# classified chocolate training: [595]
# classified corrosive candy coating logistics: [265]
# classified corrosive chocolate logistics: [246]
# classified cryogenic basket logistics: [212]
# classified cryogenic plastic grass logistics: [226]
# classified dye development: [658]
# classified dye operations: [894]
# classified dye receiving: [324]
# classified dye sales: [666]
# classified egg financing: [414]
# classified egg laboratory: [201]
# classified egg management: [446]
# classified egg operations: [316]
# classified egg purchasing: [395]
# classified egg services: [258]
# classified egg technology: [129]
# classified flower acquisition: [316]
# classified flower logistics: [441]
# classified flower research: [649]
# classified flower services: [655]
# classified international dye sales: [810]
# classified jellybean shipping: [685]
# classified jellybean user testing: [773]
# classified plastic grass storage: [643]
# classified projectile basket receiving: [594]
# classified rabbit training: [238]
# classified rabbit user testing: [279]
# classified radioactive scavenger hunt storage: [346]
# classified rampaging candy coating department: [531]
# classified scavenger hunt acquisition: [530]
# classified scavenger hunt customer service: [768]
# classified scavenger hunt technology: [475]
# classified scavenger hunt training: [892]
# classified scavenger hunt user testing: [729]
# colorful basket customer service: [314]
# colorful basket design: [770]
# colorful basket receiving: [930]
# colorful basket research: [119]
# colorful bunny acquisition: [324]
# colorful bunny analysis: [993]
# colorful bunny deployment: [311]
# colorful bunny shipping: [498]
# colorful candy coating customer service: [831]
# colorful candy coating engineering: [986]
# colorful candy coating management: [596]
# colorful candy coating storage: [238]
# colorful candy coating user testing: [992]
# colorful candy department: [186]
# colorful candy deployment: [303]
# colorful candy laboratory: [989]
# colorful candy operations: [784]
# colorful candy services: [409]
# colorful chocolate deployment: [271]
# colorful chocolate research: [908]
# colorful corrosive bunny storage: [864]
# colorful corrosive scavenger hunt development: [745]
# colorful dye department: [684]
# colorful dye design: [149]
# colorful dye logistics: [665]
# colorful dye operations: [872]
# colorful dye shipping: [422]
# colorful egg development: [953]
# colorful egg storage: [819]
# colorful flower management: [826]
# colorful flower marketing: [587]
# colorful flower storage: [259]
# colorful jellybean customer service: [933]
# colorful jellybean design: [895]
# colorful jellybean operations: [179]
# colorful military grade candy coating management: [743]
# colorful plastic grass acquisition: [741]
# colorful plastic grass analysis: [948]
# colorful plastic grass customer service: [518]
# colorful plastic grass design: [595]
# colorful plastic grass training: [444]
# colorful projectile dye technology: [356]
# colorful projectile jellybean logistics: [139]
# colorful rabbit management: [987]
# colorful rabbit sales: [939]
# colorful rabbit services: [771]
# colorful rabbit technology: [978]
# colorful rabbit user testing: [973]
# colorful rampaging egg research: [903]
# colorful scavenger hunt department: [967]
# colorful scavenger hunt deployment: [508]
# colorful scavenger hunt design: [564]
# colorful scavenger hunt logistics: [481]
# colorful scavenger hunt marketing: [306]
# colorful scavenger hunt sales: [409]
# colorful scavenger hunt shipping: [732]
# colorful weaponized chocolate shipping: [805]
# consumer grade basket containment: [205]
# consumer grade basket development: [872]
# consumer grade basket engineering: [403]
# consumer grade basket laboratory: [391]
# consumer grade basket logistics: [996]
# consumer grade basket receiving: [956]
# consumer grade basket technology: [472]
# consumer grade bunny customer service: [176]
# consumer grade bunny engineering: [484]
# consumer grade bunny technology: [776]
# consumer grade bunny training: [586]
# consumer grade candy coating department: [578]
# consumer grade candy coating deployment: [730]
# consumer grade candy coating financing: [453]
# consumer grade candy coating management: [765]
# consumer grade candy coating marketing: [299]
# consumer grade candy coating operations: [765]
# consumer grade candy coating storage: [173]
# consumer grade candy engineering: [302]
# consumer grade candy financing: [578]
# consumer grade candy logistics: [483]
# consumer grade candy purchasing: [490]
# consumer grade candy storage: [921]
# consumer grade candy technology: [321]
# consumer grade candy user testing: [934]
# consumer grade chocolate engineering: [232]
# consumer grade chocolate receiving: [261]
# consumer grade chocolate technology: [307]
# consumer grade chocolate workshop: [440]
# consumer grade classified plastic grass containment: [971]
# consumer grade colorful flower deployment: [305]
# consumer grade colorful plastic grass engineering: [765]
# consumer grade dye acquisition: [566]
# consumer grade dye deployment: [345]
# consumer grade dye financing: [834]
# consumer grade dye management: [550]
# consumer grade dye operations: [960]
# consumer grade dye receiving: [990]
# consumer grade dye services: [907]
# consumer grade dye shipping: [250]
# consumer grade egg acquisition: [128]
# consumer grade egg storage: [795]
# consumer grade egg workshop: [438]
# consumer grade flower acquisition: [882]
# consumer grade flower analysis: [606]
# consumer grade flower purchasing: [617]
# consumer grade flower storage: [885]
# consumer grade flower technology: [801]
# consumer grade fuzzy jellybean containment: [815]
# consumer grade jellybean analysis: [384]
# consumer grade jellybean design: [137]
# consumer grade jellybean sales: [831]
# consumer grade jellybean technology: [542]
# consumer grade magnetic scavenger hunt management: [589]
# consumer grade plastic grass acquisition: [809]
# consumer grade plastic grass customer service: [722]
# consumer grade plastic grass deployment: [121]
# consumer grade plastic grass laboratory: [591]
# consumer grade rabbit management: [188]
# consumer grade rabbit marketing: [527]
# consumer grade rabbit purchasing: [725]
# consumer grade rabbit training: [755]
# consumer grade rabbit user testing: [595]
# consumer grade rampaging basket laboratory: [535]
# consumer grade scavenger hunt deployment: [899]
# consumer grade scavenger hunt design: [301]
# consumer grade scavenger hunt marketing: [590]
# consumer grade scavenger hunt purchasing: [557]
# consumer grade scavenger hunt sales: [170]
# corrosive basket customer service: [299]
# corrosive bunny laboratory: [608]
# corrosive bunny receiving: [238]
# corrosive bunny sales: [613]
# corrosive bunny services: [487]
# corrosive candy coating financing: [516]
# corrosive candy coating reacquisition: [314]
# corrosive candy coating research: [586]
# corrosive candy containment: [555]
# corrosive candy development: [942]
# corrosive candy engineering: [136]
# corrosive candy receiving: [247]
# corrosive chocolate deployment: [849]
# corrosive chocolate management: [166]
# corrosive colorful chocolate management: [184]
# corrosive cryogenic rabbit acquisition: [492]
# corrosive cryogenic scavenger hunt training: [929]
# corrosive dye design: [350]
# corrosive dye financing: [432]
# corrosive dye purchasing: [769]
# corrosive egg acquisition: [282]
# corrosive egg analysis: [362]
# corrosive egg laboratory: [833]
# corrosive egg services: [864]
# corrosive flower laboratory: [516]
# corrosive flower management: [394]
# corrosive flower receiving: [116]
# corrosive flower storage: [197]
# corrosive flower user testing: [401]
# corrosive fuzzy bunny receiving: [751]
# corrosive international dye shipping: [803]
# corrosive jellybean deployment: [556]
# corrosive jellybean marketing: [640]
# corrosive jellybean services: [795]
# corrosive military grade flower reacquisition: [695]
# corrosive plastic grass acquisition: [566]
# corrosive plastic grass department: [963]
# corrosive plastic grass receiving: [971]
# corrosive plastic grass research: [522]
# corrosive plastic grass storage: [716]
# corrosive projectile candy management: [214]
# corrosive rabbit reacquisition: [972]
# corrosive rabbit research: [386]
# corrosive rabbit shipping: [663]
# corrosive rabbit user testing: [110]
# corrosive radioactive basket training: [501]
# corrosive scavenger hunt operations: [894]
# corrosive scavenger hunt research: [163]
# corrosive scavenger hunt sales: [514]
# corrosive scavenger hunt storage: [211]
# cryogenic basket training: [616]
# cryogenic biohazardous bunny shipping: [316]
# cryogenic bunny customer service: [530]
# cryogenic bunny development: [719]
# cryogenic bunny engineering: [932]
# cryogenic bunny management: [759]
# cryogenic candy analysis: [191]
# cryogenic candy coating acquisition: [185]
# cryogenic candy coating department: [321]
# cryogenic candy coating marketing: [746]
# cryogenic candy coating sales: [816]
# cryogenic candy coating shipping: [224]
# cryogenic candy coating user testing: [931]
# cryogenic candy development: [187]
# cryogenic candy reacquisition: [855]
# cryogenic candy storage: [308]
# cryogenic candy workshop: [587]
# cryogenic chocolate sales: [975]
# cryogenic colorful dye reacquisition: [603]
# cryogenic colorful dye research: [604]
# cryogenic corrosive candy deployment: [450]
# cryogenic dye analysis: [740]
# cryogenic dye customer service: [732]
# cryogenic dye deployment: [614]
# cryogenic dye management: [173]
# cryogenic dye marketing: [379]
# cryogenic dye reacquisition: [303]
# cryogenic dye shipping: [478]
# cryogenic dye technology: [685]
# cryogenic dye user testing: [591]
# cryogenic dye workshop: [215]
# cryogenic egg customer service: [371]
# cryogenic egg deployment: [764]
# cryogenic egg laboratory: [493]
# cryogenic egg logistics: [642]
# cryogenic egg operations: [845]
# cryogenic egg receiving: [897]
# cryogenic egg services: [392]
# cryogenic egg shipping: [952]
# cryogenic egg workshop: [999]
# cryogenic flower department: [705]
# cryogenic flower design: [900]
# cryogenic flower management: [332]
# cryogenic flower operations: [811]
# cryogenic fuzzy basket deployment: [428]
# cryogenic fuzzy flower research: [309]
# cryogenic international scavenger hunt technology: [508]
# cryogenic jellybean financing: [215]
# cryogenic jellybean reacquisition: [646]
# cryogenic jellybean workshop: [709]
# cryogenic plastic grass engineering: [531]
# cryogenic plastic grass operations: [621]
# cryogenic plastic grass reacquisition: [189]
# cryogenic plastic grass technology: [947]
# cryogenic rabbit development: [662]
# cryogenic rabbit management: [195]
# cryogenic rabbit technology: [559]
# cryogenic rampaging chocolate customer service: [735]
# cryogenic scavenger hunt analysis: [461]
# cryogenic scavenger hunt department: [396]
# cryogenic scavenger hunt design: [257]
# cryogenic scavenger hunt storage: [697]
# cryogenic scavenger hunt user testing: [436]
# cryogenic top secret flower operations: [129]
# cryogenic unstable flower research: [640]
# dye design: [185]
# fuzzy basket department: [649]
# fuzzy basket laboratory: [103]
# fuzzy basket marketing: [968]
# fuzzy basket purchasing: [925]
# fuzzy basket receiving: [838]
# fuzzy basket sales: [268]
# fuzzy basket storage: [344]
# fuzzy bunny financing: [566]
# fuzzy bunny receiving: [555]
# fuzzy bunny sales: [794]
# fuzzy bunny storage: [301]
# fuzzy bunny training: [360]
# fuzzy candy analysis: [124]
# fuzzy candy coating analysis: [308]
# fuzzy candy coating customer service: [403]
# fuzzy candy coating design: [815]
# fuzzy candy coating storage: [940]
# fuzzy candy customer service: [179]
# fuzzy candy marketing: [587]
# fuzzy candy technology: [810]
# fuzzy candy workshop: [350]
# fuzzy chocolate deployment: [273]
# fuzzy chocolate logistics: [933]
# fuzzy chocolate receiving: [614]
# fuzzy chocolate research: [463]
# fuzzy chocolate training: [272]
# fuzzy chocolate user testing: [109]
# fuzzy colorful chocolate research: [577]
# fuzzy consumer grade bunny operations: [879]
# fuzzy dye acquisition: [459]
# fuzzy dye development: [620]
# fuzzy dye research: [197]
# fuzzy egg analysis: [697]
# fuzzy egg engineering: [839]
# fuzzy egg logistics: [138]
# fuzzy egg shipping: [427]
# fuzzy egg training: [675]
# fuzzy flower acquisition: [439]
# fuzzy flower analysis: [194]
# fuzzy flower development: [581]
# fuzzy jellybean acquisition: [207]
# fuzzy jellybean analysis: [807]
# fuzzy jellybean laboratory: [842]
# fuzzy jellybean purchasing: [103]
# fuzzy jellybean receiving: [558]
# fuzzy jellybean user testing: [661]
# fuzzy plastic grass financing: [175]
# fuzzy plastic grass operations: [124]
# fuzzy plastic grass storage: [771]
# fuzzy plastic grass user testing: [273]
# fuzzy rabbit acquisition: [775]
# fuzzy rabbit analysis: [815]
# fuzzy rabbit design: [639]
# fuzzy rabbit management: [206]
# fuzzy rabbit user testing: [659]
# fuzzy radioactive basket department: [679]
# fuzzy rampaging plastic grass analysis: [142]
# fuzzy scavenger hunt deployment: [752]
# fuzzy scavenger hunt engineering: [892]
# fuzzy scavenger hunt operations: [339]
# fuzzy scavenger hunt sales: [601]
# fuzzy scavenger hunt storage: [353]
# fuzzy top secret plastic grass containment: [997]
# fuzzy unstable candy coating technology: [300]
# international basket department: [457]
# international basket reacquisition: [903]
# international basket receiving: [964]
# international basket technology: [989]
# international basket user testing: [596]
# international biohazardous egg reacquisition: [516]
# international bunny deployment: [365]
# international bunny purchasing: [508]
# international bunny research: [606]
# international bunny shipping: [867]
# international bunny training: [477]
# international bunny workshop: [528]
# international candy coating technology: [879]
# international candy design: [263]
# international candy financing: [845]
# international candy logistics: [298]
# international candy receiving: [876]
# international candy shipping: [222]
# international candy workshop: [957]
# international chocolate containment: [513]
# international chocolate customer service: [588]
# international chocolate department: [256]
# international chocolate design: [181]
# international chocolate management: [265]
# international chocolate receiving: [779]
# international chocolate research: [162]
# international chocolate storage: [694]
# international chocolate technology: [849]
# international classified flower marketing: [136]
# international dye reacquisition: [352]
# international dye research: [262]
# international dye services: [986]
# international egg marketing: [574]
# international egg operations: [859]
# international egg reacquisition: [999]
# international egg shipping: [674]
# international flower analysis: [203]
# international flower deployment: [764]
# international flower design: [894]
# international flower engineering: [469]
# international flower laboratory: [991]
# international flower operations: [593]
# international flower sales: [202]
# international flower workshop: [594]
# international jellybean engineering: [996]
# international jellybean marketing: [449]
# international jellybean technology: [433]
# international magnetic basket department: [108]
# international plastic grass containment: [167]
# international plastic grass reacquisition: [610]
# international plastic grass receiving: [158]
# international plastic grass sales: [401]
# international plastic grass services: [756]
# international rabbit development: [957]
# international rabbit management: [903]
# international rabbit training: [252]
# international scavenger hunt acquisition: [299]
# international scavenger hunt laboratory: [937]
# international scavenger hunt research: [902]
# international scavenger hunt sales: [164]
# international unstable basket workshop: [863]
# international unstable egg user testing: [290]
# magnetic basket analysis: [457]
# magnetic basket containment: [171]
# magnetic basket development: [641]
# magnetic basket financing: [643]
# magnetic basket laboratory: [755]
# magnetic basket purchasing: [420]
# magnetic basket sales: [241]
# magnetic biohazardous egg workshop: [968]
# magnetic bunny deployment: [945]
# magnetic bunny design: [817]
# magnetic bunny reacquisition: [662]
# magnetic bunny storage: [106]
# magnetic candy coating containment: [490]
# magnetic candy coating deployment: [197]
# magnetic candy coating receiving: [576]
# magnetic candy coating services: [493]
# magnetic candy coating technology: [994]
# magnetic candy coating user testing: [730]
# magnetic candy engineering: [310]
# magnetic candy storage: [116]
# magnetic chocolate acquisition: [253]
# magnetic chocolate deployment: [407]
# magnetic chocolate development: [124]
# magnetic chocolate marketing: [407]
# magnetic chocolate research: [513]
# magnetic colorful flower services: [985]
# magnetic corrosive basket services: [102]
# magnetic dye acquisition: [485]
# magnetic dye containment: [692]
# magnetic dye engineering: [643]
# magnetic dye user testing: [490]
# magnetic egg financing: [343]
# magnetic flower laboratory: [646]
# magnetic flower reacquisition: [196]
# magnetic flower services: [292]
# magnetic fuzzy dye storage: [547]
# magnetic jellybean financing: [566]
# magnetic plastic grass laboratory: [603]
# magnetic plastic grass marketing: [249]
# magnetic plastic grass shipping: [374]
# magnetic plastic grass storage: [384]
# magnetic plastic grass workshop: [852]
# magnetic projectile scavenger hunt customer service: [833]
# magnetic rabbit engineering: [558]
# magnetic rabbit reacquisition: [595]
# magnetic rabbit storage: [382]
# magnetic rabbit workshop: [320]
# magnetic scavenger hunt reacquisition: [153]
# magnetic scavenger hunt receiving: [376]
# magnetic scavenger hunt research: [693]
# magnetic scavenger hunt services: [922]
# magnetic scavenger hunt technology: [843]
# magnetic scavenger hunt training: [251]
# magnetic unstable basket research: [488]
# magnetic unstable bunny technology: [326]
# magnetic unstable candy coating research: [313]
# magnetic unstable candy coating workshop: [706]
# military grade basket acquisition: [788]
# military grade basket department: [294]
# military grade basket engineering: [604]
# military grade basket management: [282]
# military grade basket operations: [288]
# military grade basket training: [395]
# military grade biohazardous bunny laboratory: [905]
# military grade bunny deployment: [526]
# military grade candy acquisition: [481]
# military grade candy coating department: [418]
# military grade candy coating reacquisition: [526]
# military grade candy coating shipping: [114]
# military grade candy coating training: [788]
# military grade candy containment: [557]
# military grade candy department: [588]
# military grade candy design: [219]
# military grade candy management: [373]
# military grade chocolate customer service: [805]
# military grade chocolate logistics: [953]
# military grade colorful scavenger hunt customer service: [241]
# military grade consumer grade dye purchasing: [680]
# military grade cryogenic chocolate technology: [488]
# military grade dye containment: [251]
# military grade dye department: [294]
# military grade dye management: [563]
# military grade dye purchasing: [986]
# military grade dye research: [582]
# military grade dye user testing: [816]
# military grade egg design: [953]
# military grade egg receiving: [299]
# military grade egg services: [418]
# military grade egg user testing: [292]
# military grade egg workshop: [977]
# military grade flower analysis: [641]
# military grade flower development: [680]
# military grade flower operations: [876]
# military grade international plastic grass development: [529]
# military grade jellybean customer service: [544]
# military grade jellybean deployment: [842]
# military grade jellybean engineering: [927]
# military grade jellybean management: [709]
# military grade jellybean marketing: [818]
# military grade jellybean purchasing: [272]
# military grade jellybean receiving: [671]
# military grade jellybean training: [863]
# military grade plastic grass department: [113]
# military grade projectile bunny department: [306]
# military grade rabbit department: [200]
# military grade rabbit design: [700]
# military grade rabbit research: [742]
# military grade rabbit sales: [930]
# military grade scavenger hunt acquisition: [820]
# military grade scavenger hunt purchasing: [368]
# military grade scavenger hunt technology: [438]
# military grade scavenger hunt workshop: [571]
# northpole object storage: [501]
# projectile basket logistics: [701]
# projectile basket management: [603]
# projectile basket workshop: [888]
# projectile candy coating deployment: [748]
# projectile candy coating logistics: [230]
# projectile candy coating reacquisition: [229]
# projectile candy deployment: [288]
# projectile candy design: [183]
# projectile candy operations: [384]
# projectile candy services: [345]
# projectile candy shipping: [244]
# projectile chocolate department: [342]
# projectile chocolate engineering: [621]
# projectile chocolate sales: [840]
# projectile classified chocolate reacquisition: [714]
# projectile corrosive flower department: [944]
# projectile cryogenic candy coating training: [535]
# projectile dye customer service: [608]
# projectile dye department: [916]
# projectile dye design: [967]
# projectile dye storage: [923]
# projectile dye workshop: [568]
# projectile flower containment: [809]
# projectile flower development: [959]
# projectile flower management: [378]
# projectile flower reacquisition: [232]
# projectile flower storage: [115]
# projectile international dye training: [368]
# projectile jellybean design: [675]
# projectile jellybean sales: [147]
# projectile jellybean shipping: [986]
# projectile jellybean technology: [376]
# projectile jellybean workshop: [422]
# projectile magnetic jellybean training: [644]
# projectile military grade flower acquisition: [696]
# projectile military grade scavenger hunt shipping: [899]
# projectile plastic grass analysis: [826]
# projectile plastic grass logistics: [237]
# projectile rabbit analysis: [924]
# projectile rabbit purchasing: [454]
# projectile radioactive dye purchasing: [381]
# projectile rampaging bunny technology: [687]
# projectile scavenger hunt engineering: [732]
# projectile scavenger hunt logistics: [444]
# projectile scavenger hunt research: [990]
# projectile scavenger hunt shipping: [214]
# projectile scavenger hunt technology: [834]
# projectile scavenger hunt training: [135]
# radioactive basket financing: [507]
# radioactive basket management: [995]
# radioactive basket reacquisition: [862]
# radioactive basket user testing: [856]
# radioactive bunny marketing: [946]
# radioactive bunny research: [530]
# radioactive bunny services: [292]
# radioactive bunny user testing: [986]
# radioactive candy coating containment: [359]
# radioactive candy coating customer service: [134]
# radioactive candy coating development: [597]
# radioactive candy coating laboratory: [946]
# radioactive candy coating research: [533]
# radioactive candy coating services: [723]
# radioactive candy reacquisition: [154]
# radioactive chocolate development: [614]
# radioactive chocolate operations: [187]
# radioactive chocolate services: [903]
# radioactive chocolate technology: [254]
# radioactive classified egg development: [698]
# radioactive dye deployment: [592]
# radioactive dye storage: [431]
# radioactive dye technology: [127]
# radioactive dye workshop: [167]
# radioactive egg acquisition: [946]
# radioactive egg analysis: [344]
# radioactive egg deployment: [920]
# radioactive egg engineering: [918]
# radioactive egg storage: [266]
# radioactive flower containment: [115]
# radioactive flower department: [369]
# radioactive flower design: [616]
# radioactive flower laboratory: [411]
# radioactive flower operations: [498]
# radioactive flower reacquisition: [154]
# radioactive flower shipping: [751]
# radioactive flower storage: [521]
# radioactive fuzzy flower shipping: [841]
# radioactive jellybean containment: [388]
# radioactive jellybean sales: [682]
# radioactive jellybean services: [610]
# radioactive plastic grass analysis: [112]
# radioactive plastic grass deployment: [341]
# radioactive plastic grass engineering: [495]
# radioactive plastic grass purchasing: [782]
# radioactive plastic grass workshop: [407]
# radioactive rabbit acquisition: [451]
# radioactive rabbit financing: [783]
# radioactive rabbit management: [678]
# radioactive rabbit research: [986]
# radioactive rabbit storage: [594]
# radioactive rampaging bunny development: [931]
# radioactive scavenger hunt analysis: [604]
# radioactive scavenger hunt containment: [209]
# radioactive scavenger hunt logistics: [733]
# radioactive scavenger hunt receiving: [837]
# radioactive scavenger hunt services: [545]
# radioactive weaponized candy containment: [335]
# rampaging basket containment: [353]
# rampaging basket engineering: [183]
# rampaging basket logistics: [190]
# rampaging basket sales: [768]
# rampaging basket workshop: [781]
# rampaging bunny deployment: [515]
# rampaging bunny services: [421]
# rampaging candy coating operations: [470]
# rampaging candy coating reacquisition: [735]
# rampaging candy reacquisition: [443]
# rampaging chocolate analysis: [251]
# rampaging chocolate containment: [396]
# rampaging chocolate purchasing: [860]
# rampaging chocolate shipping: [454]
# rampaging chocolate storage: [965]
# rampaging chocolate user testing: [336]
# rampaging chocolate workshop: [283]
# rampaging consumer grade candy department: [864]
# rampaging corrosive egg financing: [935]
# rampaging dye department: [522]
# rampaging dye financing: [524]
# rampaging dye storage: [562]
# rampaging egg acquisition: [651]
# rampaging egg deployment: [334]
# rampaging egg engineering: [436]
# rampaging egg purchasing: [893]
# rampaging egg reacquisition: [819]
# rampaging egg user testing: [395]
# rampaging flower deployment: [428]
# rampaging flower management: [514]
# rampaging flower marketing: [959]
# rampaging jellybean receiving: [529]
# rampaging jellybean shipping: [329]
# rampaging magnetic chocolate department: [640]
# rampaging plastic grass containment: [785]
# rampaging plastic grass deployment: [782]
# rampaging plastic grass design: [406]
# rampaging plastic grass services: [345]
# rampaging projectile flower research: [135]
# rampaging rabbit acquisition: [714]
# rampaging rabbit containment: [359]
# rampaging rabbit development: [160]
# rampaging rabbit financing: [384]
# rampaging rabbit management: [667]
# rampaging rabbit research: [586]
# rampaging rabbit storage: [608]
# rampaging rabbit user testing: [139]
# rampaging rabbit workshop: [608]
# rampaging radioactive jellybean technology: [673]
# rampaging scavenger hunt engineering: [467]
# rampaging scavenger hunt financing: [761]
# rampaging scavenger hunt marketing: [965]
# rampaging scavenger hunt workshop: [139]
# rampaging unstable rabbit storage: [191]
# rampaging weaponized egg storage: [871]
# top secret basket analysis: [253]
# top secret basket containment: [196]
# top secret basket design: [623]
# top secret basket development: [258]
# top secret basket sales: [464]
# top secret basket services: [455]
# top secret bunny deployment: [251]
# top secret bunny reacquisition: [717]
# top secret bunny research: [163]
# top secret bunny training: [150]
# top secret candy coating analysis: [199]
# top secret candy coating containment: [635]
# top secret candy coating design: [798]
# top secret candy coating operations: [373]
# top secret candy coating storage: [249]
# top secret candy coating training: [265]
# top secret candy management: [841]
# top secret candy research: [617]
# top secret candy shipping: [354]
# top secret chocolate logistics: [466]
# top secret chocolate management: [200]
# top secret chocolate marketing: [616]
# top secret chocolate shipping: [129]
# top secret consumer grade candy purchasing: [350]
# top secret dye containment: [168]
# top secret dye logistics: [544]
# top secret dye marketing: [420]
# top secret dye services: [904]
# top secret egg acquisition: [143]
# top secret egg design: [856]
# top secret egg sales: [870]
# top secret egg technology: [385]
# top secret egg training: [214]
# top secret egg user testing: [446]
# top secret flower receiving: [435]
# top secret flower sales: [919]
# top secret flower shipping: [515]
# top secret flower technology: [351]
# top secret flower user testing: [756]
# top secret fuzzy rabbit purchasing: [838]
# top secret international bunny marketing: [532]
# top secret jellybean containment: [748]
# top secret jellybean department: [513]
# top secret jellybean engineering: [437]
# top secret military grade candy coating marketing: [287]
# top secret military grade plastic grass research: [870]
# top secret plastic grass analysis: [429]
# top secret plastic grass logistics: [316]
# top secret plastic grass services: [525]
# top secret plastic grass training: [320]
# top secret rabbit acquisition: [609]
# top secret rabbit engineering: [854]
# top secret rabbit sales: [825]
# top secret rabbit user testing: [898]
# top secret scavenger hunt analysis: [263]
# top secret scavenger hunt laboratory: [531]
# top secret scavenger hunt management: [583]
# top secret scavenger hunt receiving: [540]
# top secret scavenger hunt services: [950]
# top secret weaponized candy logistics: [217]
# unstable basket customer service: [471]
# unstable basket design: [627]
# unstable basket laboratory: [291]
# unstable basket receiving: [978]
# unstable basket shipping: [487]
# unstable biohazardous plastic grass management: [129]
# unstable bunny department: [220]
# unstable bunny reacquisition: [613]
# unstable bunny shipping: [118]
# unstable candy coating acquisition: [227]
# unstable candy coating analysis: [687]
# unstable candy containment: [980]
# unstable candy deployment: [238]
# unstable candy logistics: [378]
# unstable chocolate containment: [747]
# unstable chocolate financing: [343]
# unstable chocolate receiving: [741]
# unstable chocolate technology: [320]
# unstable classified flower user testing: [887]
# unstable cryogenic basket receiving: [741]
# unstable dye containment: [655]
# unstable dye design: [173]
# unstable dye research: [954]
# unstable dye sales: [121]
# unstable dye technology: [438]
# unstable egg analysis: [214]
# unstable egg management: [481]
# unstable egg research: [985]
# unstable egg sales: [343]
# unstable flower analysis: [300]
# unstable flower department: [320]
# unstable flower financing: [451]
# unstable flower purchasing: [870]
# unstable flower services: [227]
# unstable flower shipping: [485]
# unstable flower workshop: [643]
# unstable jellybean purchasing: [720]
# unstable jellybean sales: [873]
# unstable jellybean user testing: [472]
# unstable plastic grass analysis: [418]
# unstable plastic grass deployment: [790]
# unstable plastic grass laboratory: [287]
# unstable plastic grass management: [691]
# unstable plastic grass operations: [215]
# unstable plastic grass reacquisition: [891]
# unstable projectile rabbit deployment: [303]
# unstable rabbit acquisition: [351]
# unstable rabbit containment: [436]
# unstable rabbit customer service: [429]
# unstable rabbit design: [445]
# unstable rabbit engineering: [395]
# unstable rabbit reacquisition: [309]
# unstable rabbit research: [315]
# unstable rabbit sales: [944]
# unstable rampaging basket training: [480]
# unstable rampaging dye receiving: [397]
# unstable scavenger hunt development: [129]
# unstable weaponized scavenger hunt services: [498]
# weaponized basket acquisition: [131]
# weaponized basket customer service: [116]
# weaponized basket financing: [654]
# weaponized basket logistics: [730]
# weaponized basket operations: [420]
# weaponized basket storage: [809]
# weaponized biohazardous candy coating design: [552]
# weaponized bunny deployment: [197]
# weaponized bunny laboratory: [227]
# weaponized bunny reacquisition: [373]
# weaponized bunny research: [213]
# weaponized candy coating laboratory: [655]
# weaponized candy coating research: [950]
# weaponized candy coating services: [604]
# weaponized candy purchasing: [218]
# weaponized candy research: [649]
# weaponized chocolate logistics: [626]
# weaponized chocolate management: [604]
# weaponized chocolate purchasing: [388]
# weaponized chocolate technology: [631]
# weaponized chocolate user testing: [181]
# weaponized dye acquisition: [436]
# weaponized dye containment: [993]
# weaponized dye customer service: [336]
# weaponized dye development: [472]
# weaponized dye financing: [133]
# weaponized dye purchasing: [582]
# weaponized dye reacquisition: [316]
# weaponized egg analysis: [391]
# weaponized egg department: [456]
# weaponized egg deployment: [100]
# weaponized egg development: [254]
# weaponized egg logistics: [319]
# weaponized egg shipping: [853]
# weaponized egg training: [625]
# weaponized flower customer service: [366]
# weaponized flower shipping: [802]
# weaponized flower storage: [653]
# weaponized flower training: [512]
# weaponized flower user testing: [493]
# weaponized international basket laboratory: [585]
# weaponized international flower development: [712]
# weaponized international scavenger hunt development: [803]
# weaponized jellybean deployment: [534]
# weaponized jellybean engineering: [695]
# weaponized jellybean purchasing: [695]
# weaponized jellybean research: [738]
# weaponized jellybean sales: [696]
# weaponized jellybean shipping: [149]
# weaponized jellybean user testing: [857]
# weaponized magnetic plastic grass workshop: [634]
# weaponized magnetic rabbit analysis: [649]
# weaponized plastic grass engineering: [643]
# weaponized plastic grass laboratory: [870]
# weaponized plastic grass operations: [461]
# weaponized plastic grass shipping: [838]
# weaponized plastic grass workshop: [400]
# weaponized rabbit shipping: [864]
# weaponized rabbit technology: [170]
# weaponized rabbit training: [537]
# weaponized radioactive candy development: [455]
# weaponized scavenger hunt research: [941]

# %%
import re
from collections import defaultdict

def decrypt_name(encrypted_name, sector_id):
    decrypted_name = []
    
    for char in encrypted_name:
        if char == '-':
            decrypted_name.append(' ')
        else:
            # Rotate character
            new_char = chr(((ord(char) - ord('a') + sector_id) % 26) + ord('a'))
            decrypted_name.append(new_char)
    
    return ''.join(decrypted_name)

def process_room(line):
    # Use regular expression to extract the name, sector ID, and checksum
    match = re.match(r'([a-z\-]+)-(\d+)\[([a-z]+)\]', line)
    if match:
        encrypted_name = match.group(1)
        sector_id = int(match.group(2))
        checksum = match.group(3)
        return encrypted_name, sector_id, checksum
    return None

def store_rooms(input_lines):
    rooms = []
    for line in input_lines:
        result = process_room(line)
        if result:
            encrypted_name, sector_id, checksum = result
            decrypted_name = decrypt_name(encrypted_name, sector_id)
            rooms.append((decrypted_name, sector_id))
    return rooms

# Read input data from a file
with open('input.txt', 'r') as file:
    input_lines = file.readlines()

# Store all rooms and their decrypted names and sector IDs
rooms = store_rooms(input_lines)

# Regex to find sector IDs with 'north' in the decrypted name (case insensitive)
north_regex = re.compile(r'north', re.IGNORECASE)

# Find and print the sector IDs that contain 'north' in the decrypted name
sector_ids_with_north = [sector_id for decrypted_name, sector_id in rooms if north_regex.search(decrypted_name)]

# Print the sector IDs that contain 'north'
print("Sector IDs that contain 'north':", sector_ids_with_north)
# Out:
# Sector IDs that contain 'north': [501]

# %%
import re

def decrypt_name(encrypted_name, sector_id):
    decrypted_name = []
    
    for char in encrypted_name:
        if char == '-':
            decrypted_name.append(' ')
        else:
            # Rotate character
            new_char = chr(((ord(char) - ord('a') + sector_id) % 26) + ord('a'))
            decrypted_name.append(new_char)
    
    return ''.join(decrypted_name)

def process_room(line):
    # Use regular expression to extract the name, sector ID, and checksum
    match = re.match(r'([a-z\-]+)-(\d+)\[([a-z]+)\]', line)
    if match:
        encrypted_name = match.group(1)
        sector_id = int(match.group(2))
        checksum = match.group(3)
        return encrypted_name, sector_id, checksum
    return None

def store_rooms(input_lines):
    rooms = []
    for line in input_lines:
        result = process_room(line)
        if result:
            encrypted_name, sector_id, checksum = result
            decrypted_name = decrypt_name(encrypted_name, sector_id)
            rooms.append((decrypted_name, sector_id))
    return rooms

# Read input data from a file
with open('input.txt', 'r') as file:
    input_lines = file.readlines()

# Store all rooms and their decrypted names and sector IDs
rooms = store_rooms(input_lines)

# Regex to find sector IDs with 'north' in the decrypted name (case insensitive)
north_regex = re.compile(r'north', re.IGNORECASE)

# Find the sector ID that contains 'north' in the decrypted name
north_sector_id = None
for decrypted_name, sector_id in rooms:
    if north_regex.search(decrypted_name):
        north_sector_id = sector_id
        break

# Print the sector ID that contains 'north'
if north_sector_id:
    print(f"The sector ID of the room where North Pole objects are stored is: {north_sector_id}.")
else:
    print("No room with 'north' found.")
# Out:
# The sector ID of the room where North Pole objects are stored is: 501.

# %% [markdown]
# This was a tricky one because it wasn't compute x, it was you don't know what you're searching for or looking for or aiming for or what the solution or goal is. You can use regex.

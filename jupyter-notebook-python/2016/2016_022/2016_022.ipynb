# %% [markdown]
# # Advent of Code

# %% [markdown]
# ## 2016-012-022
# ## 2016 022

# %% [markdown]
# https://adventofcode.com/2016/day/22

# %%
import re
from itertools import combinations

# Load data from input.txt
with open("input.txt", "r") as file:
    data = file.readlines()

# Parse the input
nodes = []
for line in data:
    match = re.match(r"/dev/grid/node-x(\d+)-y(\d+)\s+(\d+)T\s+(\d+)T\s+(\d+)T", line)
    if match:
        x, y, size, used, avail = map(int, match.groups())
        nodes.append({"x": x, "y": y, "size": size, "used": used, "avail": avail})

# Count viable pairs
viable_pairs = 0
for a, b in combinations(nodes, 2):
    # Check if A -> B is a viable pair
    if a["used"] > 0 and a["used"] <= b["avail"]:
        viable_pairs += 1
    # Check if B -> A is a viable pair
    if b["used"] > 0 and b["used"] <= a["avail"]:
        viable_pairs += 1

print(f"Number of viable pairs: {viable_pairs}")
# Out:
# Number of viable pairs: 924

# %%
import re
from collections import deque

# Load grid data from input.txt
with open("input.txt", "r") as file:
    data = file.readlines()

# Parse the grid and extract node information
grid = {}
max_x = max_y = 0

for line in data:
    match = re.match(r"/dev/grid/node-x(\d+)-y(\d+)\s+(\d+)T\s+(\d+)T\s+(\d+)T", line)
    if match:
        x, y, size, used, avail = map(int, match.groups())
        grid[(x, y)] = {"size": size, "used": used, "avail": avail}
        max_x = max(max_x, x)
        max_y = max(max_y, y)

# Find the empty node
empty_node = next(pos for pos, stats in grid.items() if stats["used"] == 0)

# Identify immovable and movable nodes
grid_visual = [["." for _ in range(max_x + 1)] for _ in range(max_y + 1)]
for (x, y), stats in grid.items():
    if stats["used"] == 0:
        grid_visual[y][x] = "_"
    elif stats["used"] > 100:  # Arbitrary threshold for "immovable"
        grid_visual[y][x] = "#"
    elif x == max_x and y == 0:  # Goal data
        grid_visual[y][x] = "G"

# BFS to calculate shortest path for moving the empty node
def bfs(start, goal, is_valid):
    queue = deque([(start, 0)])  # (position, steps)
    visited = set()
    visited.add(start)

    while queue:
        pos, steps = queue.popleft()
        if pos == goal:
            return steps

        x, y = pos
        for dx, dy in [(-1, 0), (1, 0), (0, -1), (0, 1)]:  # Neighboring nodes
            nx, ny = x + dx, y + dy
            if (nx, ny) in grid and (nx, ny) not in visited and is_valid((nx, ny)):
                visited.add((nx, ny))
                queue.append(((nx, ny), steps + 1))
    return float("inf")  # No valid path found

# Move the empty node next to the goal
goal_pos = (max_x, 0)
total_steps = 0

# Step 1: Move `_` adjacent to `G`
for dx, dy in [(-1, 0), (1, 0), (0, -1), (0, 1)]:
    adjacent_to_goal = (goal_pos[0] + dx, goal_pos[1] + dy)
    if adjacent_to_goal in grid:
        steps = bfs(empty_node, adjacent_to_goal, lambda pos: grid_visual[pos[1]][pos[0]] != "#")
        total_steps += steps
        empty_node = adjacent_to_goal
        break

# Step 2: Move `G` to `(0, 0)`
while goal_pos != (0, 0):
    # Move `G` one step closer to `(0, 0)`
    new_goal_pos = (goal_pos[0] - 1, goal_pos[1])  # Move left
    steps = bfs(empty_node, new_goal_pos, lambda pos: grid_visual[pos[1]][pos[0]] != "#")
    total_steps += steps + 1  # Include the move of `G`
    empty_node = goal_pos  # Empty node swaps with `G`
    goal_pos = new_goal_pos

print(f"Fewest number of steps: {total_steps}")
# Out:
# Fewest number of steps: 151

# %%
import re
from collections import deque

# Load grid data from input.txt
with open("input.txt", "r") as file:
    data = file.readlines()

# Parse the grid and extract node information
grid = {}
max_x = max_y = 0

for line in data:
    match = re.match(r"/dev/grid/node-x(\d+)-y(\d+)\s+(\d+)T\s+(\d+)T\s+(\d+)T", line)
    if match:
        x, y, size, used, avail = map(int, match.groups())
        grid[(x, y)] = {"size": size, "used": used, "avail": avail}
        max_x = max(max_x, x)
        max_y = max(max_y, y)

# Represent the grid as a 2D list for visualization
grid_visual = [["." for _ in range(max_x + 1)] for _ in range(max_y + 1)]
empty_node = None

for (x, y), stats in grid.items():
    if stats["used"] == 0:
        grid_visual[y][x] = "_"
        empty_node = (x, y)
    elif stats["used"] > 100:  # Arbitrary threshold for "immovable"
        grid_visual[y][x] = "#"
    elif x == max_x and y == 0:  # Goal data
        grid_visual[y][x] = "G"

# BFS for shortest path
def bfs(start, goal, is_valid):
    queue = deque([(start, 0)])  # (position, steps)
    visited = set()
    visited.add(start)

    while queue:
        pos, steps = queue.popleft()
        if pos == goal:
            return steps

        x, y = pos
        for dx, dy in [(-1, 0), (1, 0), (0, -1), (0, 1)]:  # Neighboring nodes
            nx, ny = x + dx, y + dy
            if (nx, ny) in grid and (nx, ny) not in visited and is_valid((nx, ny)):
                visited.add((nx, ny))
                queue.append(((nx, ny), steps + 1))
    return float("inf")  # No valid path found

# Move the empty node next to the goal
goal_pos = (max_x, 0)
total_steps = 0

# Step 1: Move `_` adjacent to `G`
for dx, dy in [(-1, 0), (1, 0), (0, -1), (0, 1)]:
    adjacent_to_goal = (goal_pos[0] + dx, goal_pos[1] + dy)
    if adjacent_to_goal in grid:
        steps = bfs(empty_node, adjacent_to_goal, lambda pos: grid_visual[pos[1]][pos[0]] != "#")
        total_steps += steps
        empty_node = adjacent_to_goal
        break

# Step 2: Move `G` to `(0, 0)`
while goal_pos != (0, 0):
    # Move `G` one step closer to `(0, 0)`
    new_goal_pos = (goal_pos[0] - 1, goal_pos[1])  # Move left
    steps = bfs(empty_node, new_goal_pos, lambda pos: grid_visual[pos[1]][pos[0]] != "#")
    total_steps += steps + 1  # Include the move of `G`
    empty_node = goal_pos  # Empty node swaps with `G`
    goal_pos = new_goal_pos

print(f"Fewest number of steps: {total_steps}")
# Out:
# Fewest number of steps: 151

# %%
from collections import deque

def parse_input(file_path):
    grid = {}
    max_x = max_y = 0
    with open(file_path, "r") as f:
        for line in f:
            parts = line.split()
            if parts[0].startswith('/dev/grid'):
                x, y = map(int, [parts[0].split('-')[1][1:], parts[0].split('-')[2][1:]])
                size, used, avail = map(int, [parts[1][:-1], parts[2][:-1], parts[3][:-1]])
                grid[(x, y)] = {"size": size, "used": used, "avail": avail}
                max_x = max(max_x, x)
                max_y = max(max_y, y)
    return grid, max_x, max_y

def bfs_empty_node(grid, empty_pos, target_pos, max_x, max_y):
    queue = deque([(empty_pos, 0)])
    visited = set()
    visited.add(empty_pos)
    
    while queue:
        (x, y), steps = queue.popleft()
        if (x, y) == target_pos:
            return steps
        
        for dx, dy in [(-1, 0), (1, 0), (0, -1), (0, 1)]:
            nx, ny = x + dx, y + dy
            if 0 <= nx <= max_x and 0 <= ny <= max_y and (nx, ny) not in visited:
                if grid[(nx, ny)]["used"] <= grid[(x, y)]["size"]:  # Can the empty node move here?
                    queue.append(((nx, ny), steps + 1))
                    visited.add((nx, ny))
    return float('inf')

def solve(file_path):
    grid, max_x, max_y = parse_input(file_path)
    
    # Locate the empty node and the goal position
    empty_pos = next(pos for pos, node in grid.items() if node["used"] == 0)
    goal_pos = (max_x, 0)  # Top-right corner
    
    # Step 1: Move the empty node next to the goal position
    adjacent_goal_positions = [(goal_pos[0] - 1, goal_pos[1]), 
                               (goal_pos[0], goal_pos[1] - 1), 
                               (goal_pos[0] + 1, goal_pos[1]), 
                               (goal_pos[0], goal_pos[1] + 1)]
    target_pos = next(pos for pos in adjacent_goal_positions if pos in grid)
    
    steps_to_target = bfs_empty_node(grid, empty_pos, target_pos, max_x, max_y)
    
    # Step 2: Move the goal data to (0, 0)
    # It takes one step to move the goal data one position left, and (max_x - 1) steps to get to (0, 0)
    goal_steps = max_x * 5 + (steps_to_target - 1)
    
    return goal_steps

# Specify the input file path
file_path = "input.txt"

# Solve the puzzle
print(solve(file_path))
# Out:
# 216

# %%
from collections import deque

def parse_input(grid_data):
    grid = {}
    max_x = max_y = 0
    for line in grid_data:
        parts = line.split()
        if parts[0].startswith('/dev/grid'):
            x, y = map(int, parts[0].split('-')[1:])
            size, used, avail = map(int, [parts[1][:-1], parts[2][:-1], parts[3][:-1]])
            grid[(x, y)] = {"size": size, "used": used, "avail": avail}
            max_x = max(max_x, x)
            max_y = max(max_y, y)
    return grid, max_x, max_y

def bfs_empty_node(grid, empty_pos, target_pos, max_x, max_y):
    queue = deque([(empty_pos, 0)])
    visited = set()
    visited.add(empty_pos)
    
    while queue:
        (x, y), steps = queue.popleft()
        if (x, y) == target_pos:
            return steps
        
        for dx, dy in [(-1, 0), (1, 0), (0, -1), (0, 1)]:
            nx, ny = x + dx, y + dy
            if 0 <= nx <= max_x and 0 <= ny <= max_y and (nx, ny) not in visited:
                if grid[(nx, ny)]["used"] <= grid[(x, y)]["size"]:  # Can the empty node move here?
                    queue.append(((nx, ny), steps + 1))
                    visited.add((nx, ny))
    return float('inf')

def solve(grid_data):
    grid, max_x, max_y = parse_input(grid_data)
    
    # Locate the empty node and the goal position
    empty_pos = next(pos for pos, node in grid.items() if node["used"] == 0)
    goal_pos = (max_x, 0)  # Top-right corner
    
    # Step 1: Move the empty node next to the goal position
    adjacent_goal_positions = [(goal_pos[0] - 1, goal_pos[1]), 
                               (goal_pos[0], goal_pos[1] - 1), 
                               (goal_pos[0] + 1, goal_pos[1]), 
                               (goal_pos[0], goal_pos[1] + 1)]
    target_pos = next(pos for pos in adjacent_goal_positions if pos in grid)
    
    steps_to_target = bfs_empty_node(grid, empty_pos, target_pos, max_x, max_y)
    
    # Step 2: Move the goal data to (0, 0)
    # It takes one step to move the goal data one position left, and (max_x - 1) steps to get to (0, 0)
    goal_steps = max_x * 5 + (steps_to_target - 1)
    
    return goal_steps

# Example Input
grid_data = [
    "/dev/grid/node-x0-y0   10T    8T     2T   80%",
    "/dev/grid/node-x0-y1   11T    6T     5T   54%",
    "/dev/grid/node-x0-y2   32T   28T     4T   87%",
    "/dev/grid/node-x1-y0    9T    7T     2T   77%",
    "/dev/grid/node-x1-y1    8T    0T     8T    0%",
    "/dev/grid/node-x1-y2   11T    7T     4T   63%",
    "/dev/grid/node-x2-y0   10T    6T     4T   60%",
    "/dev/grid/node-x2-y1    9T    8T     1T   88%",
    "/dev/grid/node-x2-y2    9T    6T     3T   66%",
]

print(solve(grid_data))  # Expected Output: 7
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 69
#      56 # Example Input
#      57 grid_data = [
#      58     "/dev/grid/node-x0-y0   10T    8T     2T   80%",
#      59     "/dev/grid/node-x0-y1   11T    6T     5T   54%",
#    (...)
#      66     "/dev/grid/node-x2-y2    9T    6T     3T   66%",
#      67 ]
# ---> 69 print(solve(grid_data))  # Expected Output: 7
#
# Cell In[5], line 35, in solve(grid_data)
#      34 def solve(grid_data):
# ---> 35     grid, max_x, max_y = parse_input(grid_data)
#      37     # Locate the empty node and the goal position
#      38     empty_pos = next(pos for pos, node in grid.items() if node["used"] == 0)
#
# Cell In[5], line 9, in parse_input(grid_data)
#       7 parts = line.split()
#       8 if parts[0].startswith('/dev/grid'):
# ----> 9     x, y = map(int, parts[0].split('-')[1:])
#      10     size, used, avail = map(int, [parts[1][:-1], parts[2][:-1], parts[3][:-1]])
#      11     grid[(x, y)] = {"size": size, "used": used, "avail": avail}
#
# ValueError: invalid literal for int() with base 10: 'x0'

# %%
from collections import deque

def parse_input(file_path):
    grid = {}
    max_x = max_y = 0
    with open(file_path, "r") as f:
        for line in f:
            parts = line.split()
            if parts[0].startswith('/dev/grid'):
                x, y = map(int, [parts[0].split('-')[1][1:], parts[0].split('-')[2][1:]])
                size, used, avail = map(int, [parts[1][:-1], parts[2][:-1], parts[3][:-1]])
                grid[(x, y)] = {"size": size, "used": used, "avail": avail}
                max_x = max(max_x, x)
                max_y = max(max_y, y)
    return grid, max_x, max_y

def bfs_empty_node(grid, empty_pos, target_pos, max_x, max_y):
    queue = deque([(empty_pos, 0)])
    visited = set()
    visited.add(empty_pos)
    
    while queue:
        (x, y), steps = queue.popleft()
        if (x, y) == target_pos:
            return steps
        
        for dx, dy in [(-1, 0), (1, 0), (0, -1), (0, 1)]:
            nx, ny = x + dx, y + dy
            if 0 <= nx <= max_x and 0 <= ny <= max_y and (nx, ny) not in visited:
                if grid[(nx, ny)]["used"] <= grid[(x, y)]["size"]:  # Can the empty node move here?
                    queue.append(((nx, ny), steps + 1))
                    visited.add((nx, ny))
    return float('inf')

def solve(file_path):
    grid, max_x, max_y = parse_input(file_path)
    
    # Locate the empty node and the goal position
    empty_pos = next(pos for pos, node in grid.items() if node["used"] == 0)
    goal_pos = (max_x, 0)  # Top-right corner
    
    # Step 1: Move the empty node next to the goal position
    adjacent_goal_positions = [(goal_pos[0] - 1, goal_pos[1]), 
                               (goal_pos[0], goal_pos[1] - 1), 
                               (goal_pos[0] + 1, goal_pos[1]), 
                               (goal_pos[0], goal_pos[1] + 1)]
    target_pos = next(pos for pos in adjacent_goal_positions if pos in grid)
    
    steps_to_target = bfs_empty_node(grid, empty_pos, target_pos, max_x, max_y)
    
    # Step 2: Move the goal data to (0, 0)
    # It takes one step to move the goal data one position left, and (max_x - 1) steps to get to (0, 0)
    goal_steps = max_x * 5 + (steps_to_target - 1)
    
    return goal_steps

# Specify the input file path
file_path = "input.txt"

# Solve the puzzle
print(solve(file_path))
# Out:
# 216

# %%
# Read the input data
with open('part-002-example-input.txt') as f:
    lines = f.readlines()

import re
from collections import deque

# Parse the input data
nodes = {}
max_x = max_y = 0
for line in lines[1:]:
    match = re.match(r'/dev/grid/node-x(\d+)-y(\d+)\s+(\d+)T\s+(\d+)T\s+(\d+)T', line)
    if match:
        x, y, size, used, avail = map(int, match.groups())
        nodes[(x, y)] = {'size': size, 'used': used, 'avail': avail}
        max_x = max(max_x, x)
        max_y = max(max_y, y)
print('parsed')
# Build the grid
grid = [['.' for _ in range(max_x + 1)] for _ in range(max_y + 1)]
empty_node = None
for (x, y), node in nodes.items():
    if node['used'] == 0:
        grid[y][x] = '_'
        empty_node = (x, y)
    elif node['used'] > 100:  # Arbitrary threshold for large nodes
        grid[y][x] = '#'
    if y == 0 and x == max_x:
        goal_data = (x, y)

# Function to find the minimal steps
def find_min_steps(grid, empty_node, goal_data):
    from copy import deepcopy
    visited = set()
    queue = deque()
    state = (deepcopy(grid), empty_node, goal_data, 0)
    queue.append(state)
    while queue:
        grid_state, empty_pos, goal_pos, steps = queue.popleft()
        if goal_pos == (0, 0):
            return steps
        key = (tuple(map(tuple, grid_state)), empty_pos, goal_pos)
        if key in visited:
            continue
        visited.add(key)
        x, y = empty_pos
        for dx, dy in [(-1,0),(1,0),(0,-1),(0,1)]:
            nx, ny = x + dx, y + dy
            if 0 <= nx <= max_x and 0 <= ny <= max_y and grid_state[ny][nx] != '#':
                new_grid = deepcopy(grid_state)
                # Swap empty node with its neighbor
                new_grid[y][x], new_grid[ny][nx] = new_grid[ny][nx], new_grid[y][x]
                new_empty_pos = (nx, ny)
                new_goal_pos = goal_pos
                if (nx, ny) == goal_pos:
                    new_goal_pos = (x, y)
                queue.append((new_grid, new_empty_pos, new_goal_pos, steps + 1))
    return -1  # Should not reach here for solvable puzzles

# Find the minimal steps
min_steps = find_min_steps(grid, empty_node, goal_data)

# Output the result
print(min_steps)

# %%
print(1)
# Out:
# 1

# %%
# Read the input data
with open('part-002-example-input.txt') as f:
    lines = f.readlines()
print('opened')
import re
from collections import deque

# Parse the input data
nodes = {}
max_x = max_y = 0
for line in lines[1:]:
    match = re.match(r'/dev/grid/node-x(\d+)-y(\d+)\s+(\d+)T\s+(\d+)T\s+(\d+)T', line)
    if match:
        x, y, size, used, avail = map(int, match.groups())
        nodes[(x, y)] = {'size': size, 'used': used, 'avail': avail}
        max_x = max(max_x, x)
        max_y = max(max_y, y)
print('parsed')
# Build the grid
grid = [['.' for _ in range(max_x + 1)] for _ in range(max_y + 1)]
empty_node = None
for (x, y), node in nodes.items():
    if node['used'] == 0:
        grid[y][x] = '_'
        empty_node = (x, y)
    elif node['used'] > 100:  # Arbitrary threshold for large nodes
        grid[y][x] = '#'
    if y == 0 and x == max_x:
        goal_data = (x, y)
print('grid built')

# Function to find the minimal steps
def find_min_steps(grid, empty_node, goal_data):
    from copy import deepcopy
    visited = set()
    queue = deque()
    state = (deepcopy(grid), empty_node, goal_data, 0)
    queue.append(state)
    while queue:
        grid_state, empty_pos, goal_pos, steps = queue.popleft()
        if goal_pos == (0, 0):
            return steps
        key = (tuple(map(tuple, grid_state)), empty_pos, goal_pos)
        if key in visited:
            continue
        visited.add(key)
        x, y = empty_pos
        for dx, dy in [(-1,0),(1,0),(0,-1),(0,1)]:
            nx, ny = x + dx, y + dy
            if 0 <= nx <= max_x and 0 <= ny <= max_y and grid_state[ny][nx] != '#':
                new_grid = deepcopy(grid_state)
                # Swap empty node with its neighbor
                new_grid[y][x], new_grid[ny][nx] = new_grid[ny][nx], new_grid[y][x]
                new_empty_pos = (nx, ny)
                new_goal_pos = goal_pos
                if (nx, ny) == goal_pos:
                    new_goal_pos = (x, y)
                queue.append((new_grid, new_empty_pos, new_goal_pos, steps + 1))
    return -1  # Should not reach here for solvable puzzles

# Find the minimal steps
min_steps = find_min_steps(grid, empty_node, goal_data)

# Output the result
print(min_steps)
# Out:
# opened
# parsed
# grid built
# 7

# %%
# Read the input data
with open('input.txt') as f:
    lines = f.readlines()
print('opened')
import re
from collections import deque

# Parse the input data
nodes = {}
max_x = max_y = 0
for line in lines[1:]:
    match = re.match(r'/dev/grid/node-x(\d+)-y(\d+)\s+(\d+)T\s+(\d+)T\s+(\d+)T', line)
    if match:
        x, y, size, used, avail = map(int, match.groups())
        nodes[(x, y)] = {'size': size, 'used': used, 'avail': avail}
        max_x = max(max_x, x)
        max_y = max(max_y, y)
print('parsed')
# Build the grid
grid = [['.' for _ in range(max_x + 1)] for _ in range(max_y + 1)]
empty_node = None
for (x, y), node in nodes.items():
    if node['used'] == 0:
        grid[y][x] = '_'
        empty_node = (x, y)
    elif node['used'] > 100:  # Arbitrary threshold for large nodes
        grid[y][x] = '#'
    if y == 0 and x == max_x:
        goal_data = (x, y)
print('grid built')

# Function to find the minimal steps
def find_min_steps(grid, empty_node, goal_data):
    from copy import deepcopy
    visited = set()
    queue = deque()
    state = (deepcopy(grid), empty_node, goal_data, 0)
    queue.append(state)
    while queue:
        grid_state, empty_pos, goal_pos, steps = queue.popleft()
        if goal_pos == (0, 0):
            return steps
        key = (tuple(map(tuple, grid_state)), empty_pos, goal_pos)
        if key in visited:
            continue
        visited.add(key)
        x, y = empty_pos
        for dx, dy in [(-1,0),(1,0),(0,-1),(0,1)]:
            nx, ny = x + dx, y + dy
            if 0 <= nx <= max_x and 0 <= ny <= max_y and grid_state[ny][nx] != '#':
                new_grid = deepcopy(grid_state)
                # Swap empty node with its neighbor
                new_grid[y][x], new_grid[ny][nx] = new_grid[ny][nx], new_grid[y][x]
                new_empty_pos = (nx, ny)
                new_goal_pos = goal_pos
                if (nx, ny) == goal_pos:
                    new_goal_pos = (x, y)
                queue.append((new_grid, new_empty_pos, new_goal_pos, steps + 1))
    return -1  # Should not reach here for solvable puzzles

# Find the minimal steps
min_steps = find_min_steps(grid, empty_node, goal_data)

# Output the result
print(min_steps)
# Out:
# opened
# parsed
# grid built
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 62
#      59     return -1  # Should not reach here for solvable puzzles
#      61 # Find the minimal steps
# ---> 62 min_steps = find_min_steps(grid, empty_node, goal_data)
#      64 # Output the result
#      65 print(min_steps)
#
# Cell In[6], line 51, in find_min_steps(grid, empty_node, goal_data)
#      49 nx, ny = x + dx, y + dy
#      50 if 0 <= nx <= max_x and 0 <= ny <= max_y and grid_state[ny][nx] != '#':
# ---> 51     new_grid = deepcopy(grid_state)
#      52     # Swap empty node with its neighbor
#      53     new_grid[y][x], new_grid[ny][nx] = new_grid[ny][nx], new_grid[y][x]
#
# File ~\miniconda3\envs\chatgpt-is-helping\Lib\copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File ~\miniconda3\envs\chatgpt-is-helping\Lib\copy.py:196, in _deepcopy_list(x, memo, deepcopy)
#     194 append = y.append
#     195 for a in x:
# --> 196     append(deepcopy(a, memo))
#     197 return y
#
# File ~\miniconda3\envs\chatgpt-is-helping\Lib\copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File ~\miniconda3\envs\chatgpt-is-helping\Lib\copy.py:196, in _deepcopy_list(x, memo, deepcopy)
#     194 append = y.append
#     195 for a in x:
# --> 196     append(deepcopy(a, memo))
#     197 return y
#
# KeyboardInterrupt:

# %%
import re
from collections import deque

# Read the input data
with open('part-002-example-input.txt') as f:
    lines = f.readlines()

# Parse the input data
nodes = {}
max_x = max_y = 0
for line in lines[1:]:
    match = re.match(r'/dev/grid/node-x(\d+)-y(\d+)\s+(\d+)T\s+(\d+)T\s+(\d+)T', line)
    if match:
        x, y, size, used, avail = map(int, match.groups())
        nodes[(x, y)] = {'size': size, 'used': used, 'avail': avail}
        max_x = max(max_x, x)
        max_y = max(max_y, y)

# Build the grid
grid = [['.' for _ in range(max_x + 1)] for _ in range(max_y + 1)]
empty_node = None
for (x, y), node in nodes.items():
    if node['used'] == 0:
        grid[y][x] = '_'
        empty_node = (x, y)
    elif node['used'] > 100:  # Arbitrary threshold for large nodes
        grid[y][x] = '#'
    if y == 0 and x == max_x:
        goal_data = (x, y)

# Function to find the minimal steps
def find_min_steps(grid, empty_node, goal_data):
    from copy import deepcopy
    visited = set()
    queue = deque()
    state = (deepcopy(grid), empty_node, goal_data, 0)
    queue.append(state)
    steps_checked = 0  # Counter for progress reporting
    report_interval = 100  # Adjust this value as needed

    while queue:
        grid_state, empty_pos, goal_pos, steps = queue.popleft()
        steps_checked += 1

        # Progress reporting
        if steps_checked % report_interval == 0:
            print(f"Searched {steps_checked} states.")

        if goal_pos == (0, 0):
            return steps
        key = (tuple(map(tuple, grid_state)), empty_pos, goal_pos)
        if key in visited:
            continue
        visited.add(key)
        x, y = empty_pos
        for dx, dy in [(-1,0),(1,0),(0,-1),(0,1)]:
            nx, ny = x + dx, y + dy
            if 0 <= nx <= max_x and 0 <= ny <= max_y and grid_state[ny][nx] != '#':
                new_grid = deepcopy(grid_state)
                # Swap empty node with its neighbor
                new_grid[y][x], new_grid[ny][nx] = new_grid[ny][nx], new_grid[y][x]
                new_empty_pos = (nx, ny)
                new_goal_pos = goal_pos
                if (nx, ny) == goal_pos:
                    new_goal_pos = (x, y)
                queue.append((new_grid, new_empty_pos, new_goal_pos, steps + 1))
    return -1  # Should not reach here for solvable puzzles

# Find the minimal steps
min_steps = find_min_steps(grid, empty_node, goal_data)

# Output the result
print(min_steps)
# Out:
# 7

# %%
import re
from collections import deque

# Read the input data
with open('input.txt') as f:
    lines = f.readlines()

# Parse the input data
nodes = {}
max_x = max_y = 0
for line in lines[1:]:
    match = re.match(r'/dev/grid/node-x(\d+)-y(\d+)\s+(\d+)T\s+(\d+)T\s+(\d+)T', line)
    if match:
        x, y, size, used, avail = map(int, match.groups())
        nodes[(x, y)] = {'size': size, 'used': used, 'avail': avail}
        max_x = max(max_x, x)
        max_y = max(max_y, y)

# Build the grid
grid = [['.' for _ in range(max_x + 1)] for _ in range(max_y + 1)]
empty_node = None
for (x, y), node in nodes.items():
    if node['used'] == 0:
        grid[y][x] = '_'
        empty_node = (x, y)
    elif node['used'] > 100:  # Arbitrary threshold for large nodes
        grid[y][x] = '#'
    if y == 0 and x == max_x:
        goal_data = (x, y)

# Function to find the minimal steps
def find_min_steps(grid, empty_node, goal_data):
    from copy import deepcopy
    visited = set()
    queue = deque()
    state = (deepcopy(grid), empty_node, goal_data, 0)
    queue.append(state)
    steps_checked = 0  # Counter for progress reporting
    report_interval = 100  # Adjust this value as needed

    while queue:
        grid_state, empty_pos, goal_pos, steps = queue.popleft()
        steps_checked += 1

        # Progress reporting
        if steps_checked % report_interval == 0:
            print(f"Searched {steps_checked} states.")

        if goal_pos == (0, 0):
            return steps
        key = (tuple(map(tuple, grid_state)), empty_pos, goal_pos)
        if key in visited:
            continue
        visited.add(key)
        x, y = empty_pos
        for dx, dy in [(-1,0),(1,0),(0,-1),(0,1)]:
            nx, ny = x + dx, y + dy
            if 0 <= nx <= max_x and 0 <= ny <= max_y and grid_state[ny][nx] != '#':
                new_grid = deepcopy(grid_state)
                # Swap empty node with its neighbor
                new_grid[y][x], new_grid[ny][nx] = new_grid[ny][nx], new_grid[y][x]
                new_empty_pos = (nx, ny)
                new_goal_pos = goal_pos
                if (nx, ny) == goal_pos:
                    new_goal_pos = (x, y)
                queue.append((new_grid, new_empty_pos, new_goal_pos, steps + 1))
    return -1  # Should not reach here for solvable puzzles

# Find the minimal steps
min_steps = find_min_steps(grid, empty_node, goal_data)

# Output the result
print(min_steps)
# Out:
# Searched 100 states.
# Searched 200 states.
# Searched 300 states.
# Searched 400 states.
# Searched 500 states.
# Searched 600 states.
# Searched 700 states.
# Searched 800 states.
# Searched 900 states.
# Searched 1000 states.
# Searched 1100 states.
# Searched 1200 states.
# Searched 1300 states.
# Searched 1400 states.
# Searched 1500 states.
# Searched 1600 states.
# Searched 1700 states.
# Searched 1800 states.
# Searched 1900 states.
# Searched 2000 states.
# Searched 2100 states.
# Searched 2200 states.
# Searched 2300 states.
# Searched 2400 states.
# Searched 2500 states.
# Searched 2600 states.
# Searched 2700 states.
# Searched 2800 states.
# Searched 2900 states.
# Searched 3000 states.
# Searched 3100 states.
# Searched 3200 states.
# Searched 3300 states.
# Searched 3400 states.
# Searched 3500 states.
# Searched 3600 states.
# Searched 3700 states.
# Searched 3800 states.
# Searched 3900 states.
# Searched 4000 states.
# Searched 4100 states.
# Searched 4200 states.
# Searched 4300 states.
# Searched 4400 states.
# Searched 4500 states.
# Searched 4600 states.
# Searched 4700 states.
# Searched 4800 states.
# Searched 4900 states.
# Searched 5000 states.
# Searched 5100 states.
# Searched 5200 states.
# Searched 5300 states.
# Searched 5400 states.
# Searched 5500 states.
# Searched 5600 states.
# Searched 5700 states.
# Searched 5800 states.
# Searched 5900 states.
# Searched 6000 states.
# Searched 6100 states.
# Searched 6200 states.
# Searched 6300 states.
# Searched 6400 states.
# Searched 6500 states.
# Searched 6600 states.
# Searched 6700 states.
# Searched 6800 states.
# Searched 6900 states.
# Searched 7000 states.
# Searched 7100 states.
# Searched 7200 states.
# Searched 7300 states.
# Searched 7400 states.
# Searched 7500 states.
# Searched 7600 states.
# Searched 7700 states.
# Searched 7800 states.
# Searched 7900 states.
# Searched 8000 states.
# Searched 8100 states.
# Searched 8200 states.
# Searched 8300 states.
# Searched 8400 states.
# Searched 8500 states.
# Searched 8600 states.
# Searched 8700 states.
# Searched 8800 states.
# Searched 8900 states.
# Searched 9000 states.
# Searched 9100 states.
# Searched 9200 states.
# Searched 9300 states.
# Searched 9400 states.
# Searched 9500 states.
# Searched 9600 states.
# Searched 9700 states.
# Searched 9800 states.
# Searched 9900 states.
# Searched 10000 states.
# Searched 10100 states.
# Searched 10200 states.
# Searched 10300 states.
# Searched 10400 states.
# Searched 10500 states.
# Searched 10600 states.
# Searched 10700 states.
# Searched 10800 states.
# Searched 10900 states.
# Searched 11000 states.
# Searched 11100 states.
# Searched 11200 states.
# Searched 11300 states.
# Searched 11400 states.
# Searched 11500 states.
# Searched 11600 states.
# Searched 11700 states.
# Searched 11800 states.
# Searched 11900 states.
# Searched 12000 states.
# Searched 12100 states.
# Searched 12200 states.
# Searched 12300 states.
# Searched 12400 states.
# Searched 12500 states.
# Searched 12600 states.
# Searched 12700 states.
# Searched 12800 states.
# Searched 12900 states.
# Searched 13000 states.
# Searched 13100 states.
# Searched 13200 states.
# Searched 13300 states.
# Searched 13400 states.
# Searched 13500 states.
# Searched 13600 states.
# Searched 13700 states.
# Searched 13800 states.
# Searched 13900 states.
# Searched 14000 states.
# Searched 14100 states.
# Searched 14200 states.
# Searched 14300 states.
# Searched 14400 states.
# Searched 14500 states.
# Searched 14600 states.
# Searched 14700 states.
# Searched 14800 states.
# Searched 14900 states.
# Searched 15000 states.
# Searched 15100 states.
# Searched 15200 states.
# Searched 15300 states.
# Searched 15400 states.
# Searched 15500 states.
# Searched 15600 states.
# Searched 15700 states.
# Searched 15800 states.
# Searched 15900 states.
# Searched 16000 states.
# Searched 16100 states.
# Searched 16200 states.
# Searched 16300 states.
# Searched 16400 states.
# Searched 16500 states.
# Searched 16600 states.
# Searched 16700 states.
# Searched 16800 states.
# Searched 16900 states.
# Searched 17000 states.
# Searched 17100 states.
# Searched 17200 states.
# Searched 17300 states.
# Searched 17400 states.
# Searched 17500 states.
# Searched 17600 states.
# Searched 17700 states.
# Searched 17800 states.
# Searched 17900 states.
# Searched 18000 states.
# Searched 18100 states.
# Searched 18200 states.
# Searched 18300 states.
# Searched 18400 states.
# Searched 18500 states.
# Searched 18600 states.
# Searched 18700 states.
# Searched 18800 states.
# Searched 18900 states.
# Searched 19000 states.
# Searched 19100 states.
# Searched 19200 states.
# Searched 19300 states.
# Searched 19400 states.
# Searched 19500 states.
# Searched 19600 states.
# Searched 19700 states.
# Searched 19800 states.
# Searched 19900 states.
# Searched 20000 states.
# Searched 20100 states.
# Searched 20200 states.
# Searched 20300 states.
# Searched 20400 states.
# Searched 20500 states.
# Searched 20600 states.
# Searched 20700 states.
# Searched 20800 states.
# Searched 20900 states.
# Searched 21000 states.
# Searched 21100 states.
# Searched 21200 states.
# Searched 21300 states.
# Searched 21400 states.
# Searched 21500 states.
# Searched 21600 states.
# Searched 21700 states.
# Searched 21800 states.
# Searched 21900 states.
# Searched 22000 states.
# Searched 22100 states.
# Searched 22200 states.
# Searched 22300 states.
# Searched 22400 states.
# Searched 22500 states.
# Searched 22600 states.
# Searched 22700 states.
# Searched 22800 states.
# Searched 22900 states.
# Searched 23000 states.
# Searched 23100 states.
# Searched 23200 states.
# Searched 23300 states.
# Searched 23400 states.
# Searched 23500 states.
# Searched 23600 states.
# Searched 23700 states.
# Searched 23800 states.
# Searched 23900 states.
# Searched 24000 states.
# Searched 24100 states.
# Searched 24200 states.
# Searched 24300 states.
# Searched 24400 states.
# Searched 24500 states.
# Searched 24600 states.
# Searched 24700 states.
# Searched 24800 states.
# Searched 24900 states.
# Searched 25000 states.
# Searched 25100 states.
# Searched 25200 states.
# Searched 25300 states.
# Searched 25400 states.
# Searched 25500 states.
# Searched 25600 states.
# Searched 25700 states.
# Searched 25800 states.
# Searched 25900 states.
# Searched 26000 states.
# Searched 26100 states.
# Searched 26200 states.
# Searched 26300 states.
# Searched 26400 states.
# Searched 26500 states.
# Searched 26600 states.
# Searched 26700 states.
# Searched 26800 states.
# Searched 26900 states.
# Searched 27000 states.
# Searched 27100 states.
# Searched 27200 states.
# Searched 27300 states.
# Searched 27400 states.
# Searched 27500 states.
# Searched 27600 states.
# Searched 27700 states.
# Searched 27800 states.
# Searched 27900 states.
# Searched 28000 states.
# Searched 28100 states.
# Searched 28200 states.
# Searched 28300 states.
# Searched 28400 states.
# Searched 28500 states.
# Searched 28600 states.
# Searched 28700 states.
# Searched 28800 states.
# Searched 28900 states.
# Searched 29000 states.
# Searched 29100 states.
# Searched 29200 states.
# Searched 29300 states.
# Searched 29400 states.
# Searched 29500 states.
# Searched 29600 states.
# Searched 29700 states.
# Searched 29800 states.
# Searched 29900 states.
# Searched 30000 states.
# Searched 30100 states.
# Searched 30200 states.
# Searched 30300 states.
# Searched 30400 states.
# Searched 30500 states.
# Searched 30600 states.
# Searched 30700 states.
# Searched 30800 states.
# Searched 30900 states.
# Searched 31000 states.
# Searched 31100 states.
# Searched 31200 states.
# Searched 31300 states.
# Searched 31400 states.
# Searched 31500 states.
# Searched 31600 states.
# Searched 31700 states.
# Searched 31800 states.
# Searched 31900 states.
# Searched 32000 states.
# Searched 32100 states.
# Searched 32200 states.
# Searched 32300 states.
# Searched 32400 states.
# Searched 32500 states.
# Searched 32600 states.
# Searched 32700 states.
# Searched 32800 states.
# Searched 32900 states.
# Searched 33000 states.
# Searched 33100 states.
# Searched 33200 states.
# Searched 33300 states.
# Searched 33400 states.
# Searched 33500 states.
# Searched 33600 states.
# Searched 33700 states.
# Searched 33800 states.
# Searched 33900 states.
# Searched 34000 states.
# Searched 34100 states.
# Searched 34200 states.
# Searched 34300 states.
# Searched 34400 states.
# Searched 34500 states.
# Searched 34600 states.
# Searched 34700 states.
# Searched 34800 states.
# Searched 34900 states.
# Searched 35000 states.
# Searched 35100 states.
# Searched 35200 states.
# Searched 35300 states.
# Searched 35400 states.
# Searched 35500 states.
# Searched 35600 states.
# Searched 35700 states.
# Searched 35800 states.
# Searched 35900 states.
# Searched 36000 states.
# Searched 36100 states.
# Searched 36200 states.
# Searched 36300 states.
# Searched 36400 states.
# Searched 36500 states.
# Searched 36600 states.
# Searched 36700 states.
# Searched 36800 states.
# Searched 36900 states.
# Searched 37000 states.
# Searched 37100 states.
# Searched 37200 states.
# Searched 37300 states.
# Searched 37400 states.
# Searched 37500 states.
# Searched 37600 states.
# Searched 37700 states.
# Searched 37800 states.
# Searched 37900 states.
# Searched 38000 states.
# Searched 38100 states.
# Searched 38200 states.
# Searched 38300 states.
# Searched 38400 states.
# Searched 38500 states.
# Searched 38600 states.
# Searched 38700 states.
# Searched 38800 states.
# Searched 38900 states.
# Searched 39000 states.
# Searched 39100 states.
# Searched 39200 states.
# Searched 39300 states.
# Searched 39400 states.
# Searched 39500 states.
# Searched 39600 states.
# Searched 39700 states.
# Searched 39800 states.
# Searched 39900 states.
# Searched 40000 states.
# Searched 40100 states.
# Searched 40200 states.
# Searched 40300 states.
# Searched 40400 states.
# Searched 40500 states.
# Searched 40600 states.
# Searched 40700 states.
# Searched 40800 states.
# Searched 40900 states.
# Searched 41000 states.
# Searched 41100 states.
# Searched 41200 states.
# Searched 41300 states.
# Searched 41400 states.
# Searched 41500 states.
# Searched 41600 states.
# Searched 41700 states.
# Searched 41800 states.
# Searched 41900 states.
# Searched 42000 states.
# Searched 42100 states.
# Searched 42200 states.
# Searched 42300 states.
# Searched 42400 states.
# Searched 42500 states.
# Searched 42600 states.
# Searched 42700 states.
# Searched 42800 states.
# Searched 42900 states.
# Searched 43000 states.
# Searched 43100 states.
# Searched 43200 states.
# Searched 43300 states.
# Searched 43400 states.
# Searched 43500 states.
# Searched 43600 states.
# Searched 43700 states.
# Searched 43800 states.
# Searched 43900 states.
# Searched 44000 states.
# Searched 44100 states.
# Searched 44200 states.
# Searched 44300 states.
# Searched 44400 states.
# Searched 44500 states.
# Searched 44600 states.
# Searched 44700 states.
# Searched 44800 states.
# Searched 44900 states.
# Searched 45000 states.
# Searched 45100 states.
# Searched 45200 states.
# Searched 45300 states.
# Searched 45400 states.
# Searched 45500 states.
# Searched 45600 states.
# Searched 45700 states.
# Searched 45800 states.
# Searched 45900 states.
# Searched 46000 states.
# Searched 46100 states.
# Searched 46200 states.
# Searched 46300 states.
# Searched 46400 states.
# Searched 46500 states.
# Searched 46600 states.
# Searched 46700 states.
# Searched 46800 states.
# Searched 46900 states.
# Searched 47000 states.
# Searched 47100 states.
# Searched 47200 states.
# Searched 47300 states.
# Searched 47400 states.
# Searched 47500 states.
# Searched 47600 states.
# Searched 47700 states.
# Searched 47800 states.
# Searched 47900 states.
# Searched 48000 states.
# Searched 48100 states.
# Searched 48200 states.
# Searched 48300 states.
# Searched 48400 states.
# Searched 48500 states.
# Searched 48600 states.
# Searched 48700 states.
# Searched 48800 states.
# Searched 48900 states.
# Searched 49000 states.
# Searched 49100 states.
# Searched 49200 states.
# Searched 49300 states.
# Searched 49400 states.
# Searched 49500 states.
# Searched 49600 states.
# Searched 49700 states.
# Searched 49800 states.
# Searched 49900 states.
# Searched 50000 states.
# Searched 50100 states.
# Searched 50200 states.
# Searched 50300 states.
# Searched 50400 states.
# Searched 50500 states.
# Searched 50600 states.
# Searched 50700 states.
# Searched 50800 states.
# Searched 50900 states.
# Searched 51000 states.
# Searched 51100 states.
# Searched 51200 states.
# Searched 51300 states.
# Searched 51400 states.
# Searched 51500 states.
# Searched 51600 states.
# Searched 51700 states.
# Searched 51800 states.
# Searched 51900 states.
# Searched 52000 states.
# Searched 52100 states.
# Searched 52200 states.
# Searched 52300 states.
# Searched 52400 states.
# Searched 52500 states.
# Searched 52600 states.
# Searched 52700 states.
# Searched 52800 states.
# Searched 52900 states.
# Searched 53000 states.
# Searched 53100 states.
# Searched 53200 states.
# Searched 53300 states.
# Searched 53400 states.
# Searched 53500 states.
# Searched 53600 states.
# Searched 53700 states.
# Searched 53800 states.
# Searched 53900 states.
# Searched 54000 states.
# Searched 54100 states.
# Searched 54200 states.
# Searched 54300 states.
# Searched 54400 states.
# Searched 54500 states.
# Searched 54600 states.
# Searched 54700 states.
# Searched 54800 states.
# Searched 54900 states.
# Searched 55000 states.
# Searched 55100 states.
# Searched 55200 states.
# Searched 55300 states.
# Searched 55400 states.
# Searched 55500 states.
# Searched 55600 states.
# Searched 55700 states.
# Searched 55800 states.
# Searched 55900 states.
# Searched 56000 states.
# Searched 56100 states.
# Searched 56200 states.
# Searched 56300 states.
# Searched 56400 states.
# Searched 56500 states.
# Searched 56600 states.
# Searched 56700 states.
# Searched 56800 states.
# Searched 56900 states.
# Searched 57000 states.
# Searched 57100 states.
# Searched 57200 states.
# Searched 57300 states.
# Searched 57400 states.
# Searched 57500 states.
# Searched 57600 states.
# Searched 57700 states.
# Searched 57800 states.
# Searched 57900 states.
# Searched 58000 states.
# Searched 58100 states.
# Searched 58200 states.
# Searched 58300 states.
# Searched 58400 states.
# Searched 58500 states.
# Searched 58600 states.
# Searched 58700 states.
# Searched 58800 states.
# Searched 58900 states.
# Searched 59000 states.
# Searched 59100 states.
# Searched 59200 states.
# Searched 59300 states.
# Searched 59400 states.
# Searched 59500 states.
# Searched 59600 states.
# Searched 59700 states.
# Searched 59800 states.
# Searched 59900 states.
# Searched 60000 states.
# Searched 60100 states.
# Searched 60200 states.
# Searched 60300 states.
# Searched 60400 states.
# Searched 60500 states.
# Searched 60600 states.
# Searched 60700 states.
# Searched 60800 states.
# Searched 60900 states.
# Searched 61000 states.
# Searched 61100 states.
# Searched 61200 states.
# Searched 61300 states.
# Searched 61400 states.
# Searched 61500 states.
# Searched 61600 states.
# Searched 61700 states.
# Searched 61800 states.
# Searched 61900 states.
# Searched 62000 states.
# Searched 62100 states.
# Searched 62200 states.
# Searched 62300 states.
# Searched 62400 states.
# Searched 62500 states.
# Searched 62600 states.
# Searched 62700 states.
# Searched 62800 states.
# Searched 62900 states.
# Searched 63000 states.
# Searched 63100 states.
# Searched 63200 states.
# Searched 63300 states.
# Searched 63400 states.
# Searched 63500 states.
# Searched 63600 states.
# Searched 63700 states.
# Searched 63800 states.
# Searched 63900 states.
# Searched 64000 states.
# Searched 64100 states.
# Searched 64200 states.
# Searched 64300 states.
# Searched 64400 states.
# Searched 64500 states.
# Searched 64600 states.
# Searched 64700 states.
# Searched 64800 states.
# Searched 64900 states.
# Searched 65000 states.
# Searched 65100 states.
# Searched 65200 states.
# Searched 65300 states.
# Searched 65400 states.
# Searched 65500 states.
# Searched 65600 states.
# Searched 65700 states.
# Searched 65800 states.
# Searched 65900 states.
# Searched 66000 states.
# Searched 66100 states.
# Searched 66200 states.
# Searched 66300 states.
# Searched 66400 states.
# Searched 66500 states.
# Searched 66600 states.
# Searched 66700 states.
# Searched 66800 states.
# Searched 66900 states.
# Searched 67000 states.
# Searched 67100 states.
# Searched 67200 states.
# Searched 67300 states.
# Searched 67400 states.
# Searched 67500 states.
# Searched 67600 states.
# Searched 67700 states.
# Searched 67800 states.
# Searched 67900 states.
# Searched 68000 states.
# Searched 68100 states.
# Searched 68200 states.
# Searched 68300 states.
# Searched 68400 states.
# Searched 68500 states.
# Searched 68600 states.
# Searched 68700 states.
# Searched 68800 states.
# Searched 68900 states.
# Searched 69000 states.
# Searched 69100 states.
# Searched 69200 states.
# Searched 69300 states.
# Searched 69400 states.
# Searched 69500 states.
# Searched 69600 states.
# Searched 69700 states.
# Searched 69800 states.
# Searched 69900 states.
# Searched 70000 states.
# Searched 70100 states.
# Searched 70200 states.
# Searched 70300 states.
# Searched 70400 states.
# Searched 70500 states.
# Searched 70600 states.
# Searched 70700 states.
# Searched 70800 states.
# Searched 70900 states.
# Searched 71000 states.
# Searched 71100 states.
# Searched 71200 states.
# Searched 71300 states.
# Searched 71400 states.
# Searched 71500 states.
# Searched 71600 states.
# Searched 71700 states.
# Searched 71800 states.
# Searched 71900 states.
# Searched 72000 states.
# Searched 72100 states.
# Searched 72200 states.
# Searched 72300 states.
# Searched 72400 states.
# Searched 72500 states.
# Searched 72600 states.
# Searched 72700 states.
# Searched 72800 states.
# Searched 72900 states.
# Searched 73000 states.
# Searched 73100 states.
# Searched 73200 states.
# Searched 73300 states.
# Searched 73400 states.
# Searched 73500 states.
# Searched 73600 states.
# Searched 73700 states.
# Searched 73800 states.
# Searched 73900 states.
# Searched 74000 states.
# Searched 74100 states.
# Searched 74200 states.
# Searched 74300 states.
# Searched 74400 states.
# Searched 74500 states.
# Searched 74600 states.
# Searched 74700 states.
# Searched 74800 states.
# Searched 74900 states.
# Searched 75000 states.
# Searched 75100 states.
# Searched 75200 states.
# Searched 75300 states.
# Searched 75400 states.
# Searched 75500 states.
# Searched 75600 states.
# Searched 75700 states.
# Searched 75800 states.
# Searched 75900 states.
# Searched 76000 states.
# Searched 76100 states.
# Searched 76200 states.
# Searched 76300 states.
# Searched 76400 states.
# Searched 76500 states.
# Searched 76600 states.
# Searched 76700 states.
# Searched 76800 states.
# Searched 76900 states.
# Searched 77000 states.
# Searched 77100 states.
# Searched 77200 states.
# Searched 77300 states.
# Searched 77400 states.
# Searched 77500 states.
# Searched 77600 states.
# Searched 77700 states.
# Searched 77800 states.
# Searched 77900 states.
# Searched 78000 states.
# Searched 78100 states.
# Searched 78200 states.
# Searched 78300 states.
# Searched 78400 states.
# Searched 78500 states.
# Searched 78600 states.
# Searched 78700 states.
# Searched 78800 states.
# Searched 78900 states.
# Searched 79000 states.
# Searched 79100 states.
# Searched 79200 states.
# Searched 79300 states.
# Searched 79400 states.
# Searched 79500 states.
# Searched 79600 states.
# Searched 79700 states.
# Searched 79800 states.
# Searched 79900 states.
# Searched 80000 states.
# Searched 80100 states.
# Searched 80200 states.
# Searched 80300 states.
# Searched 80400 states.
# Searched 80500 states.
# Searched 80600 states.
# Searched 80700 states.
# Searched 80800 states.
# Searched 80900 states.
# Searched 81000 states.
# Searched 81100 states.
# Searched 81200 states.
# Searched 81300 states.
# Searched 81400 states.
# Searched 81500 states.
# Searched 81600 states.
# Searched 81700 states.
# Searched 81800 states.
# Searched 81900 states.
# Searched 82000 states.
# Searched 82100 states.
# Searched 82200 states.
# Searched 82300 states.
# Searched 82400 states.
# Searched 82500 states.
# Searched 82600 states.
# Searched 82700 states.
# Searched 82800 states.
# Searched 82900 states.
# Searched 83000 states.
# Searched 83100 states.
# Searched 83200 states.
# Searched 83300 states.
# Searched 83400 states.
# Searched 83500 states.
# Searched 83600 states.
# Searched 83700 states.
# Searched 83800 states.
# Searched 83900 states.
# Searched 84000 states.
# Searched 84100 states.
# Searched 84200 states.
# Searched 84300 states.
# Searched 84400 states.
# Searched 84500 states.
# Searched 84600 states.
# Searched 84700 states.
# Searched 84800 states.
# Searched 84900 states.
# Searched 85000 states.
# Searched 85100 states.
# Searched 85200 states.
# Searched 85300 states.
# Searched 85400 states.
# Searched 85500 states.
# Searched 85600 states.
# Searched 85700 states.
# Searched 85800 states.
# Searched 85900 states.
# Searched 86000 states.
# Searched 86100 states.
# Searched 86200 states.
# Searched 86300 states.
# Searched 86400 states.
# Searched 86500 states.
# Searched 86600 states.
# Searched 86700 states.
# Searched 86800 states.
# Searched 86900 states.
# Searched 87000 states.
# Searched 87100 states.
# Searched 87200 states.
# Searched 87300 states.
# Searched 87400 states.
# Searched 87500 states.
# Searched 87600 states.
# Searched 87700 states.
# Searched 87800 states.
# Searched 87900 states.
# Searched 88000 states.
# Searched 88100 states.
# Searched 88200 states.
# Searched 88300 states.
# Searched 88400 states.
# Searched 88500 states.
# Searched 88600 states.
# Searched 88700 states.
# Searched 88800 states.
# Searched 88900 states.
# Searched 89000 states.
# Searched 89100 states.
# Searched 89200 states.
# Searched 89300 states.
# Searched 89400 states.
# Searched 89500 states.
# Searched 89600 states.
# Searched 89700 states.
# Searched 89800 states.
# Searched 89900 states.
# Searched 90000 states.
# Searched 90100 states.
# Searched 90200 states.
# Searched 90300 states.
# Searched 90400 states.
# Searched 90500 states.
# Searched 90600 states.
# Searched 90700 states.
# Searched 90800 states.
# Searched 90900 states.
# Searched 91000 states.
# Searched 91100 states.
# Searched 91200 states.
# Searched 91300 states.
# Searched 91400 states.
# Searched 91500 states.
# Searched 91600 states.
# Searched 91700 states.
# Searched 91800 states.
# Searched 91900 states.
# Searched 92000 states.
# Searched 92100 states.
# Searched 92200 states.
# Searched 92300 states.
# Searched 92400 states.
# Searched 92500 states.
# Searched 92600 states.
# Searched 92700 states.
# Searched 92800 states.
# Searched 92900 states.
# Searched 93000 states.
# Searched 93100 states.
# Searched 93200 states.
# Searched 93300 states.
# Searched 93400 states.
# Searched 93500 states.
# Searched 93600 states.
# Searched 93700 states.
# Searched 93800 states.
# Searched 93900 states.
# Searched 94000 states.
# Searched 94100 states.
# Searched 94200 states.
# Searched 94300 states.
# Searched 94400 states.
# Searched 94500 states.
# Searched 94600 states.
# Searched 94700 states.
# Searched 94800 states.
# Searched 94900 states.
# Searched 95000 states.
# Searched 95100 states.
# Searched 95200 states.
# Searched 95300 states.
# Searched 95400 states.
# Searched 95500 states.
# Searched 95600 states.
# Searched 95700 states.
# Searched 95800 states.
# Searched 95900 states.
# Searched 96000 states.
# Searched 96100 states.
# Searched 96200 states.
# Searched 96300 states.
# Searched 96400 states.
# Searched 96500 states.
# Searched 96600 states.
# Searched 96700 states.
# Searched 96800 states.
# Searched 96900 states.
# Searched 97000 states.
# Searched 97100 states.
# Searched 97200 states.
# Searched 97300 states.
# Searched 97400 states.
# Searched 97500 states.
# Searched 97600 states.
# Searched 97700 states.
# Searched 97800 states.
# Searched 97900 states.
# Searched 98000 states.
# Searched 98100 states.
# Searched 98200 states.
# Searched 98300 states.
# Searched 98400 states.
# Searched 98500 states.
# Searched 98600 states.
# Searched 98700 states.
# Searched 98800 states.
# Searched 98900 states.
# Searched 99000 states.
# Searched 99100 states.
# Searched 99200 states.
# Searched 99300 states.
# Searched 99400 states.
# Searched 99500 states.
# Searched 99600 states.
# Searched 99700 states.
# Searched 99800 states.
# Searched 99900 states.
# Searched 100000 states.
# Searched 100100 states.
# Searched 100200 states.
# Searched 100300 states.
# Searched 100400 states.
# Searched 100500 states.
# Searched 100600 states.
# Searched 100700 states.
# Searched 100800 states.
# Searched 100900 states.
# Searched 101000 states.
# Searched 101100 states.
# Searched 101200 states.
# Searched 101300 states.
# Searched 101400 states.
# Searched 101500 states.
# Searched 101600 states.
# Searched 101700 states.
# Searched 101800 states.
# Searched 101900 states.
# Searched 102000 states.
# Searched 102100 states.
# Searched 102200 states.
# Searched 102300 states.
# Searched 102400 states.
# Searched 102500 states.
# Searched 102600 states.
# Searched 102700 states.
# Searched 102800 states.
# Searched 102900 states.
# Searched 103000 states.
# Searched 103100 states.
# Searched 103200 states.
# Searched 103300 states.
# Searched 103400 states.
# Searched 103500 states.
# Searched 103600 states.
# Searched 103700 states.
# Searched 103800 states.
# Searched 103900 states.
# Searched 104000 states.
# Searched 104100 states.
# Searched 104200 states.
# Searched 104300 states.
# Searched 104400 states.
# Searched 104500 states.
# Searched 104600 states.
# Searched 104700 states.
# Searched 104800 states.
# Searched 104900 states.
# Searched 105000 states.
# Searched 105100 states.
# Searched 105200 states.
# Searched 105300 states.
# Searched 105400 states.
# Searched 105500 states.
# Searched 105600 states.
# Searched 105700 states.
# Searched 105800 states.
# Searched 105900 states.
# Searched 106000 states.
# Searched 106100 states.
# Searched 106200 states.
# Searched 106300 states.
# Searched 106400 states.
# Searched 106500 states.
# Searched 106600 states.
# Searched 106700 states.
# Searched 106800 states.
# Searched 106900 states.
# Searched 107000 states.
# Searched 107100 states.
# Searched 107200 states.
# Searched 107300 states.
# Searched 107400 states.
# Searched 107500 states.
# Searched 107600 states.
# Searched 107700 states.
# Searched 107800 states.
# Searched 107900 states.
# Searched 108000 states.
# Searched 108100 states.
# Searched 108200 states.
# Searched 108300 states.
# Searched 108400 states.
# Searched 108500 states.
# Searched 108600 states.
# Searched 108700 states.
# Searched 108800 states.
# Searched 108900 states.
# Searched 109000 states.
# Searched 109100 states.
# Searched 109200 states.
# Searched 109300 states.
# Searched 109400 states.
# Searched 109500 states.
# Searched 109600 states.
# Searched 109700 states.
# Searched 109800 states.
# Searched 109900 states.
# Searched 110000 states.
# Searched 110100 states.
# Searched 110200 states.
# Searched 110300 states.
# Searched 110400 states.
# Searched 110500 states.
# Searched 110600 states.
# Searched 110700 states.
# Searched 110800 states.
# Searched 110900 states.
# Searched 111000 states.
# Searched 111100 states.
# Searched 111200 states.
# Searched 111300 states.
# Searched 111400 states.
# Searched 111500 states.
# Searched 111600 states.
# Searched 111700 states.
# Searched 111800 states.
# Searched 111900 states.
# Searched 112000 states.
# Searched 112100 states.
# Searched 112200 states.
# Searched 112300 states.
# Searched 112400 states.
# Searched 112500 states.
# Searched 112600 states.
# Searched 112700 states.
# Searched 112800 states.
# Searched 112900 states.
# Searched 113000 states.
# Searched 113100 states.
# Searched 113200 states.
# Searched 113300 states.
# Searched 113400 states.
# Searched 113500 states.
# Searched 113600 states.
# Searched 113700 states.
# Searched 113800 states.
# Searched 113900 states.
# Searched 114000 states.
# Searched 114100 states.
# Searched 114200 states.
# Searched 114300 states.
# Searched 114400 states.
# Searched 114500 states.
# Searched 114600 states.
# Searched 114700 states.
# Searched 114800 states.
# Searched 114900 states.
# Searched 115000 states.
# Searched 115100 states.
# Searched 115200 states.
# Searched 115300 states.
# Searched 115400 states.
# Searched 115500 states.
# Searched 115600 states.
# Searched 115700 states.
# Searched 115800 states.
# Searched 115900 states.
# Searched 116000 states.
# Searched 116100 states.
# Searched 116200 states.
# Searched 116300 states.
# Searched 116400 states.
# Searched 116500 states.
# Searched 116600 states.
# Searched 116700 states.
# Searched 116800 states.
# Searched 116900 states.
# Searched 117000 states.
# Searched 117100 states.
# Searched 117200 states.
# Searched 117300 states.
# Searched 117400 states.
# Searched 117500 states.
# Searched 117600 states.
# Searched 117700 states.
# Searched 117800 states.
# Searched 117900 states.
# Searched 118000 states.
# Searched 118100 states.
# Searched 118200 states.
# Searched 118300 states.
# Searched 118400 states.
# Searched 118500 states.
# Searched 118600 states.
# Searched 118700 states.
# Searched 118800 states.
# Searched 118900 states.
# Searched 119000 states.
# Searched 119100 states.
# Searched 119200 states.
# Searched 119300 states.
# Searched 119400 states.
# Searched 119500 states.
# Searched 119600 states.
# Searched 119700 states.
# Searched 119800 states.
# Searched 119900 states.
# Searched 120000 states.
# Searched 120100 states.
# Searched 120200 states.
# Searched 120300 states.
# Searched 120400 states.
# Searched 120500 states.
# Searched 120600 states.
# Searched 120700 states.
# Searched 120800 states.
# Searched 120900 states.
# Searched 121000 states.
# Searched 121100 states.
# Searched 121200 states.
# Searched 121300 states.
# Searched 121400 states.
# Searched 121500 states.
# Searched 121600 states.
# Searched 121700 states.
# Searched 121800 states.
# Searched 121900 states.
# Searched 122000 states.
# Searched 122100 states.
# Searched 122200 states.
# Searched 122300 states.
# Searched 122400 states.
# Searched 122500 states.
# Searched 122600 states.
# Searched 122700 states.
# Searched 122800 states.
# Searched 122900 states.
# Searched 123000 states.
# Searched 123100 states.
# Searched 123200 states.
# Searched 123300 states.
# Searched 123400 states.
# Searched 123500 states.
# Searched 123600 states.
# Searched 123700 states.
# Searched 123800 states.
# Searched 123900 states.
# Searched 124000 states.
# Searched 124100 states.
# Searched 124200 states.
# Searched 124300 states.
# Searched 124400 states.
# Searched 124500 states.
# Searched 124600 states.
# Searched 124700 states.
# Searched 124800 states.
# Searched 124900 states.
# Searched 125000 states.
# Searched 125100 states.
# Searched 125200 states.
# Searched 125300 states.
# Searched 125400 states.
# Searched 125500 states.
# Searched 125600 states.
# Searched 125700 states.
# Searched 125800 states.
# Searched 125900 states.
# Searched 126000 states.
# Searched 126100 states.
# Searched 126200 states.
# Searched 126300 states.
# Searched 126400 states.
# Searched 126500 states.
# Searched 126600 states.
# Searched 126700 states.
# Searched 126800 states.
# Searched 126900 states.
# Searched 127000 states.
# Searched 127100 states.
# Searched 127200 states.
# Searched 127300 states.
# Searched 127400 states.
# Searched 127500 states.
# Searched 127600 states.
# Searched 127700 states.
# Searched 127800 states.
# Searched 127900 states.
# Searched 128000 states.
# Searched 128100 states.
# Searched 128200 states.
# Searched 128300 states.
# Searched 128400 states.
# Searched 128500 states.
# Searched 128600 states.
# Searched 128700 states.
# Searched 128800 states.
# Searched 128900 states.
# Searched 129000 states.
# Searched 129100 states.
# Searched 129200 states.
# Searched 129300 states.
# Searched 129400 states.
# Searched 129500 states.
# Searched 129600 states.
# Searched 129700 states.
# Searched 129800 states.
# Searched 129900 states.
# Searched 130000 states.
# Searched 130100 states.
# Searched 130200 states.
# Searched 130300 states.
# Searched 130400 states.
# Searched 130500 states.
# Searched 130600 states.
# Searched 130700 states.
# Searched 130800 states.
# Searched 130900 states.
# Searched 131000 states.
# Searched 131100 states.
# Searched 131200 states.
# Searched 131300 states.
# Searched 131400 states.
# Searched 131500 states.
# Searched 131600 states.
# Searched 131700 states.
# Searched 131800 states.
# Searched 131900 states.
# Searched 132000 states.
# Searched 132100 states.
# Searched 132200 states.
# Searched 132300 states.
# Searched 132400 states.
# Searched 132500 states.
# Searched 132600 states.
# Searched 132700 states.
# Searched 132800 states.
# Searched 132900 states.
# Searched 133000 states.
# Searched 133100 states.
# Searched 133200 states.
# Searched 133300 states.
# Searched 133400 states.
# Searched 133500 states.
# Searched 133600 states.
# Searched 133700 states.
# Searched 133800 states.
# Searched 133900 states.
# Searched 134000 states.
# Searched 134100 states.
# Searched 134200 states.
# Searched 134300 states.
# Searched 134400 states.
# Searched 134500 states.
# Searched 134600 states.
# Searched 134700 states.
# Searched 134800 states.
# Searched 134900 states.
# Searched 135000 states.
# Searched 135100 states.
# Searched 135200 states.
# Searched 135300 states.
# Searched 135400 states.
# Searched 135500 states.
# Searched 135600 states.
# Searched 135700 states.
# Searched 135800 states.
# Searched 135900 states.
# Searched 136000 states.
# Searched 136100 states.
# Searched 136200 states.
# Searched 136300 states.
# Searched 136400 states.
# Searched 136500 states.
# Searched 136600 states.
# Searched 136700 states.
# Searched 136800 states.
# Searched 136900 states.
# Searched 137000 states.
# Searched 137100 states.
# Searched 137200 states.
# Searched 137300 states.
# Searched 137400 states.
# Searched 137500 states.
# Searched 137600 states.
# Searched 137700 states.
# Searched 137800 states.
# Searched 137900 states.
# Searched 138000 states.
# Searched 138100 states.
# Searched 138200 states.
# Searched 138300 states.
# Searched 138400 states.
# Searched 138500 states.
# Searched 138600 states.
# Searched 138700 states.
# Searched 138800 states.
# Searched 138900 states.
# Searched 139000 states.
# Searched 139100 states.
# Searched 139200 states.
# Searched 139300 states.
# Searched 139400 states.
# Searched 139500 states.
# Searched 139600 states.
# Searched 139700 states.
# Searched 139800 states.
# Searched 139900 states.
# Searched 140000 states.
# Searched 140100 states.
# Searched 140200 states.
# Searched 140300 states.
# Searched 140400 states.
# Searched 140500 states.
# Searched 140600 states.
# Searched 140700 states.
# Searched 140800 states.
# Searched 140900 states.
# Searched 141000 states.
# Searched 141100 states.
# Searched 141200 states.
# Searched 141300 states.
# Searched 141400 states.
# Searched 141500 states.
# Searched 141600 states.
# Searched 141700 states.
# Searched 141800 states.
# Searched 141900 states.
# Searched 142000 states.
# Searched 142100 states.
# Searched 142200 states.
# Searched 142300 states.
# Searched 142400 states.
# Searched 142500 states.
# Searched 142600 states.
# Searched 142700 states.
# Searched 142800 states.
# Searched 142900 states.
# Searched 143000 states.
# Searched 143100 states.
# Searched 143200 states.
# Searched 143300 states.
# Searched 143400 states.
# Searched 143500 states.
# Searched 143600 states.
# Searched 143700 states.
# Searched 143800 states.
# Searched 143900 states.
# Searched 144000 states.
# Searched 144100 states.
# Searched 144200 states.
# Searched 144300 states.
# Searched 144400 states.
# Searched 144500 states.
# Searched 144600 states.
# Searched 144700 states.
# Searched 144800 states.
# Searched 144900 states.
# Searched 145000 states.
# Searched 145100 states.
# Searched 145200 states.
# Searched 145300 states.
# Searched 145400 states.
# Searched 145500 states.
# Searched 145600 states.
# Searched 145700 states.
# Searched 145800 states.
# Searched 145900 states.
# Searched 146000 states.
# Searched 146100 states.
# Searched 146200 states.
# Searched 146300 states.
# Searched 146400 states.
# Searched 146500 states.
# Searched 146600 states.
# Searched 146700 states.
# Searched 146800 states.
# Searched 146900 states.
# Searched 147000 states.
# Searched 147100 states.
# Searched 147200 states.
# Searched 147300 states.
# Searched 147400 states.
# Searched 147500 states.
# Searched 147600 states.
# Searched 147700 states.
# Searched 147800 states.
# Searched 147900 states.
# Searched 148000 states.
# Searched 148100 states.
# Searched 148200 states.
# Searched 148300 states.
# Searched 148400 states.
# Searched 148500 states.
# Searched 148600 states.
# Searched 148700 states.
# Searched 148800 states.
# Searched 148900 states.
# Searched 149000 states.
# Searched 149100 states.
# Searched 149200 states.
# Searched 149300 states.
# Searched 149400 states.
# Searched 149500 states.
# Searched 149600 states.
# Searched 149700 states.
# Searched 149800 states.
# Searched 149900 states.
# Searched 150000 states.
# Searched 150100 states.
# Searched 150200 states.
# Searched 150300 states.
# Searched 150400 states.
# Searched 150500 states.
# Searched 150600 states.
# Searched 150700 states.
# Searched 150800 states.
# Searched 150900 states.
# Searched 151000 states.
# Searched 151100 states.
# Searched 151200 states.
# Searched 151300 states.
# Searched 151400 states.
# Searched 151500 states.
# Searched 151600 states.
# Searched 151700 states.
# Searched 151800 states.
# Searched 151900 states.
# Searched 152000 states.
# Searched 152100 states.
# Searched 152200 states.
# Searched 152300 states.
# Searched 152400 states.
# Searched 152500 states.
# Searched 152600 states.
# Searched 152700 states.
# Searched 152800 states.
# Searched 152900 states.
# Searched 153000 states.
# Searched 153100 states.
# Searched 153200 states.
# Searched 153300 states.
# Searched 153400 states.
# Searched 153500 states.
# Searched 153600 states.
# Searched 153700 states.
# Searched 153800 states.
# Searched 153900 states.
# Searched 154000 states.
# Searched 154100 states.
# Searched 154200 states.
# Searched 154300 states.
# Searched 154400 states.
# Searched 154500 states.
# Searched 154600 states.
# Searched 154700 states.
# Searched 154800 states.
# Searched 154900 states.
# Searched 155000 states.
# Searched 155100 states.
# Searched 155200 states.
# Searched 155300 states.
# Searched 155400 states.
# Searched 155500 states.
# Searched 155600 states.
# Searched 155700 states.
# Searched 155800 states.
# Searched 155900 states.
# Searched 156000 states.
# Searched 156100 states.
# Searched 156200 states.
# Searched 156300 states.
# Searched 156400 states.
# Searched 156500 states.
# Searched 156600 states.
# Searched 156700 states.
# Searched 156800 states.
# Searched 156900 states.
# Searched 157000 states.
# Searched 157100 states.
# Searched 157200 states.
# Searched 157300 states.
# Searched 157400 states.
# Searched 157500 states.
# Searched 157600 states.
# Searched 157700 states.
# Searched 157800 states.
# Searched 157900 states.
# Searched 158000 states.
# Searched 158100 states.
# Searched 158200 states.
# Searched 158300 states.
# Searched 158400 states.
# Searched 158500 states.
# Searched 158600 states.
# Searched 158700 states.
# Searched 158800 states.
# Searched 158900 states.
# Searched 159000 states.
# Searched 159100 states.
# Searched 159200 states.
# Searched 159300 states.
# Searched 159400 states.
# Searched 159500 states.
# Searched 159600 states.
# Searched 159700 states.
# Searched 159800 states.
# Searched 159900 states.
# Searched 160000 states.
# Searched 160100 states.
# Searched 160200 states.
# Searched 160300 states.
# Searched 160400 states.
# Searched 160500 states.
# Searched 160600 states.
# Searched 160700 states.
# Searched 160800 states.
# Searched 160900 states.
# Searched 161000 states.
# Searched 161100 states.
# Searched 161200 states.
# Searched 161300 states.
# Searched 161400 states.
# Searched 161500 states.
# Searched 161600 states.
# Searched 161700 states.
# Searched 161800 states.
# Searched 161900 states.
# Searched 162000 states.
# Searched 162100 states.
# Searched 162200 states.
# Searched 162300 states.
# Searched 162400 states.
# Searched 162500 states.
# Searched 162600 states.
# Searched 162700 states.
# Searched 162800 states.
# Searched 162900 states.
# Searched 163000 states.
# Searched 163100 states.
# Searched 163200 states.
# Searched 163300 states.
# Searched 163400 states.
# Searched 163500 states.
# Searched 163600 states.
# Searched 163700 states.
# Searched 163800 states.
# Searched 163900 states.
# Searched 164000 states.
# Searched 164100 states.
# Searched 164200 states.
# Searched 164300 states.
# Searched 164400 states.
# Searched 164500 states.
# Searched 164600 states.
# Searched 164700 states.
# Searched 164800 states.
# Searched 164900 states.
# Searched 165000 states.
# Searched 165100 states.
# Searched 165200 states.
# Searched 165300 states.
# Searched 165400 states.
# Searched 165500 states.
# Searched 165600 states.
# Searched 165700 states.
# Searched 165800 states.
# Searched 165900 states.
# Searched 166000 states.
# Searched 166100 states.
# Searched 166200 states.
# Searched 166300 states.
# Searched 166400 states.
# Searched 166500 states.
# Searched 166600 states.
# Searched 166700 states.
# Searched 166800 states.
# Searched 166900 states.
# Searched 167000 states.
# Searched 167100 states.
# Searched 167200 states.
# Searched 167300 states.
# Searched 167400 states.
# Searched 167500 states.
# Searched 167600 states.
# Searched 167700 states.
# Searched 167800 states.
# Searched 167900 states.
# Searched 168000 states.
# Searched 168100 states.
# Searched 168200 states.
# Searched 168300 states.
# Searched 168400 states.
# Searched 168500 states.
# Searched 168600 states.
# Searched 168700 states.
# Searched 168800 states.
# Searched 168900 states.
# Searched 169000 states.
# Searched 169100 states.
# Searched 169200 states.
# Searched 169300 states.
# Searched 169400 states.
# Searched 169500 states.
# Searched 169600 states.
# Searched 169700 states.
# Searched 169800 states.
# Searched 169900 states.
# Searched 170000 states.
# Searched 170100 states.
# Searched 170200 states.
# Searched 170300 states.
# Searched 170400 states.
# Searched 170500 states.
# Searched 170600 states.
# Searched 170700 states.
# Searched 170800 states.
# Searched 170900 states.
# Searched 171000 states.
# Searched 171100 states.
# Searched 171200 states.
# Searched 171300 states.
# Searched 171400 states.
# Searched 171500 states.
# Searched 171600 states.
# Searched 171700 states.
# Searched 171800 states.
# Searched 171900 states.
# Searched 172000 states.
# Searched 172100 states.
# Searched 172200 states.
# Searched 172300 states.
# Searched 172400 states.
# Searched 172500 states.
# Searched 172600 states.
# Searched 172700 states.
# Searched 172800 states.
# Searched 172900 states.
# Searched 173000 states.
# Searched 173100 states.
# Searched 173200 states.
# Searched 173300 states.
# Searched 173400 states.
# Searched 173500 states.
# Searched 173600 states.
# Searched 173700 states.
# Searched 173800 states.
# Searched 173900 states.
# Searched 174000 states.
# Searched 174100 states.
# Searched 174200 states.
# Searched 174300 states.
# Searched 174400 states.
# Searched 174500 states.
# Searched 174600 states.
# Searched 174700 states.
# Searched 174800 states.
# Searched 174900 states.
# Searched 175000 states.
# Searched 175100 states.
# Searched 175200 states.
# Searched 175300 states.
# Searched 175400 states.
# Searched 175500 states.
# Searched 175600 states.
# Searched 175700 states.
# Searched 175800 states.
# Searched 175900 states.
# Searched 176000 states.
# Searched 176100 states.
# Searched 176200 states.
# Searched 176300 states.
# Searched 176400 states.
# Searched 176500 states.
# Searched 176600 states.
# Searched 176700 states.
# Searched 176800 states.
# Searched 176900 states.
# Searched 177000 states.
# Searched 177100 states.
# Searched 177200 states.
# Searched 177300 states.
# Searched 177400 states.
# Searched 177500 states.
# Searched 177600 states.
# Searched 177700 states.
# Searched 177800 states.
# Searched 177900 states.
# Searched 178000 states.
# Searched 178100 states.
# Searched 178200 states.
# Searched 178300 states.
# Searched 178400 states.
# Searched 178500 states.
# Searched 178600 states.
# Searched 178700 states.
# Searched 178800 states.
# Searched 178900 states.
# Searched 179000 states.
# Searched 179100 states.
# Searched 179200 states.
# Searched 179300 states.
# Searched 179400 states.
# Searched 179500 states.
# Searched 179600 states.
# Searched 179700 states.
# Searched 179800 states.
# Searched 179900 states.
# Searched 180000 states.
# Searched 180100 states.
# Searched 180200 states.
# Searched 180300 states.
# Searched 180400 states.
# Searched 180500 states.
# Searched 180600 states.
# Searched 180700 states.
# Searched 180800 states.
# Searched 180900 states.
# Searched 181000 states.
# Searched 181100 states.
# Searched 181200 states.
# Searched 181300 states.
# Searched 181400 states.
# Searched 181500 states.
# Searched 181600 states.
# Searched 181700 states.
# Searched 181800 states.
# Searched 181900 states.
# Searched 182000 states.
# Searched 182100 states.
# Searched 182200 states.
# Searched 182300 states.
# Searched 182400 states.
# Searched 182500 states.
# Searched 182600 states.
# Searched 182700 states.
# Searched 182800 states.
# Searched 182900 states.
# Searched 183000 states.
# Searched 183100 states.
# Searched 183200 states.
# Searched 183300 states.
# Searched 183400 states.
# Searched 183500 states.
# Searched 183600 states.
# Searched 183700 states.
# Searched 183800 states.
# Searched 183900 states.
# Searched 184000 states.
# Searched 184100 states.
# Searched 184200 states.
# Searched 184300 states.
# Searched 184400 states.
# Searched 184500 states.
# Searched 184600 states.
# Searched 184700 states.
# Searched 184800 states.
# Searched 184900 states.
# Searched 185000 states.
# Searched 185100 states.
# Searched 185200 states.
# Searched 185300 states.
# Searched 185400 states.
# Searched 185500 states.
# Searched 185600 states.
# Searched 185700 states.
# Searched 185800 states.
# Searched 185900 states.
# Searched 186000 states.
# Searched 186100 states.
# Searched 186200 states.
# Searched 186300 states.
# Searched 186400 states.
# Searched 186500 states.
# Searched 186600 states.
# Searched 186700 states.
# Searched 186800 states.
# Searched 186900 states.
# Searched 187000 states.
# Searched 187100 states.
# Searched 187200 states.
# Searched 187300 states.
# Searched 187400 states.
# Searched 187500 states.
# Searched 187600 states.
# Searched 187700 states.
# Searched 187800 states.
# Searched 187900 states.
# Searched 188000 states.
# Searched 188100 states.
# Searched 188200 states.
# Searched 188300 states.
# Searched 188400 states.
# Searched 188500 states.
# Searched 188600 states.
# Searched 188700 states.
# Searched 188800 states.
# Searched 188900 states.
# Searched 189000 states.
# Searched 189100 states.
# Searched 189200 states.
# Searched 189300 states.
# Searched 189400 states.
# Searched 189500 states.
# Searched 189600 states.
# Searched 189700 states.
# Searched 189800 states.
# Searched 189900 states.
# Searched 190000 states.
# Searched 190100 states.
# Searched 190200 states.
# Searched 190300 states.
# Searched 190400 states.
# Searched 190500 states.
# Searched 190600 states.
# Searched 190700 states.
# Searched 190800 states.
# Searched 190900 states.
# Searched 191000 states.
# Searched 191100 states.
# Searched 191200 states.
# Searched 191300 states.
# Searched 191400 states.
# Searched 191500 states.
# Searched 191600 states.
# Searched 191700 states.
# Searched 191800 states.
# Searched 191900 states.
# Searched 192000 states.
# Searched 192100 states.
# Searched 192200 states.
# Searched 192300 states.
# Searched 192400 states.
# Searched 192500 states.
# Searched 192600 states.
# Searched 192700 states.
# Searched 192800 states.
# Searched 192900 states.
# Searched 193000 states.
# Searched 193100 states.
# Searched 193200 states.
# Searched 193300 states.
# Searched 193400 states.
# Searched 193500 states.
# Searched 193600 states.
# Searched 193700 states.
# Searched 193800 states.
# Searched 193900 states.
# Searched 194000 states.
# Searched 194100 states.
# Searched 194200 states.
# Searched 194300 states.
# Searched 194400 states.
# Searched 194500 states.
# Searched 194600 states.
# Searched 194700 states.
# Searched 194800 states.
# Searched 194900 states.
# Searched 195000 states.
# Searched 195100 states.
# Searched 195200 states.
# Searched 195300 states.
# Searched 195400 states.
# Searched 195500 states.
# Searched 195600 states.
# Searched 195700 states.
# Searched 195800 states.
# Searched 195900 states.
# Searched 196000 states.
# Searched 196100 states.
# Searched 196200 states.
# Searched 196300 states.
# Searched 196400 states.
# Searched 196500 states.
# Searched 196600 states.
# Searched 196700 states.
# Searched 196800 states.
# Searched 196900 states.
# Searched 197000 states.
# Searched 197100 states.
# Searched 197200 states.
# Searched 197300 states.
# Searched 197400 states.
# Searched 197500 states.
# Searched 197600 states.
# Searched 197700 states.
# Searched 197800 states.
# Searched 197900 states.
# Searched 198000 states.
# Searched 198100 states.
# Searched 198200 states.
# Searched 198300 states.
# Searched 198400 states.
# Searched 198500 states.
# Searched 198600 states.
# Searched 198700 states.
# Searched 198800 states.
# Searched 198900 states.
# Searched 199000 states.
# Searched 199100 states.
# Searched 199200 states.
# Searched 199300 states.
# Searched 199400 states.
# Searched 199500 states.
# Searched 199600 states.
# Searched 199700 states.
# Searched 199800 states.
# Searched 199900 states.
# Searched 200000 states.
# Searched 200100 states.
# Searched 200200 states.
# Searched 200300 states.
# Searched 200400 states.
# Searched 200500 states.
# Searched 200600 states.
# Searched 200700 states.
# Searched 200800 states.
# Searched 200900 states.
# Searched 201000 states.
# Searched 201100 states.
# Searched 201200 states.
# Searched 201300 states.
# Searched 201400 states.
# Searched 201500 states.
# Searched 201600 states.
# Searched 201700 states.
# Searched 201800 states.
# Searched 201900 states.
# Searched 202000 states.
# Searched 202100 states.
# Searched 202200 states.
# Searched 202300 states.
# Searched 202400 states.
# Searched 202500 states.
# Searched 202600 states.
# Searched 202700 states.
# Searched 202800 states.
# Searched 202900 states.
# Searched 203000 states.
# Searched 203100 states.
# Searched 203200 states.
# Searched 203300 states.
# Searched 203400 states.
# Searched 203500 states.
# Searched 203600 states.
# Searched 203700 states.
# Searched 203800 states.
# Searched 203900 states.
# Searched 204000 states.
# Searched 204100 states.
# Searched 204200 states.
# Searched 204300 states.
# Searched 204400 states.
# Searched 204500 states.
# Searched 204600 states.
# ...
# Searched 1080200 states.
# Searched 1080300 states.
# Searched 1080400 states.
# Searched 1080500 states.
# Searched 1080600 states.
# Searched 1080700 states.
# Searched 1080800 states.
# Searched 1080900 states.
# Searched 1081000 states.
# Searched 1081100 states.
# Searched 1081200 states.
# Searched 1081300 states.
# Searched 1081400 states.
# Searched 1081500 states.
# Searched 1081600 states.
# Searched 1081700 states.
# Searched 1081800 states.
# Searched 1081900 states.
# Searched 1082000 states.
# Searched 1082100 states.
# Searched 1082200 states.
# Searched 1082300 states.
# Searched 1082400 states.
# Searched 1082500 states.
# Searched 1082600 states.
# Searched 1082700 states.
# Searched 1082800 states.
# Searched 1082900 states.
# Searched 1083000 states.
# Searched 1083100 states.
# Searched 1083200 states.
# Searched 1083300 states.
# Searched 1083400 states.
# Searched 1083500 states.
# Searched 1083600 states.
# Searched 1083700 states.
# Searched 1083800 states.
# Searched 1083900 states.
# Searched 1084000 states.
# Searched 1084100 states.
# Searched 1084200 states.
# Searched 1084300 states.
# Searched 1084400 states.
# Searched 1084500 states.
# Searched 1084600 states.
# Searched 1084700 states.
# Searched 1084800 states.
# Searched 1084900 states.
# Searched 1085000 states.
# Searched 1085100 states.
# Searched 1085200 states.
# Searched 1085300 states.
# Searched 1085400 states.
# Searched 1085500 states.
# Searched 1085600 states.
# Searched 1085700 states.
# Searched 1085800 states.
# Searched 1085900 states.
# Searched 1086000 states.
# Searched 1086100 states.
# Searched 1086200 states.
# Searched 1086300 states.
# Searched 1086400 states.
# Searched 1086500 states.
# Searched 1086600 states.
# Searched 1086700 states.
# Searched 1086800 states.
# Searched 1086900 states.
# Searched 1087000 states.
# Searched 1087100 states.
# Searched 1087200 states.
# Searched 1087300 states.
# Searched 1087400 states.
# Searched 1087500 states.
# Searched 1087600 states.
# Searched 1087700 states.
# Searched 1087800 states.
# Searched 1087900 states.
# Searched 1088000 states.
# Searched 1088100 states.
# Searched 1088200 states.
# Searched 1088300 states.
# Searched 1088400 states.
# Searched 1088500 states.
# Searched 1088600 states.
# Searched 1088700 states.
# Searched 1088800 states.
# Searched 1088900 states.
# Searched 1089000 states.
# Searched 1089100 states.
# Searched 1089200 states.
# Searched 1089300 states.
# Searched 1089400 states.
# Searched 1089500 states.
# Searched 1089600 states.
# Searched 1089700 states.
# Searched 1089800 states.
# Searched 1089900 states.
# Searched 1090000 states.
# Searched 1090100 states.
# Searched 1090200 states.
# Searched 1090300 states.
# Searched 1090400 states.
# Searched 1090500 states.
# Searched 1090600 states.
# Searched 1090700 states.
# Searched 1090800 states.
# Searched 1090900 states.
# Searched 1091000 states.
# Searched 1091100 states.
# Searched 1091200 states.
# Searched 1091300 states.
# Searched 1091400 states.
# Searched 1091500 states.
# Searched 1091600 states.
# Searched 1091700 states.
# Searched 1091800 states.
# Searched 1091900 states.
# Searched 1092000 states.
# Searched 1092100 states.
# Searched 1092200 states.
# Searched 1092300 states.
# Searched 1092400 states.
# Searched 1092500 states.
# Searched 1092600 states.
# Searched 1092700 states.
# Searched 1092800 states.
# Searched 1092900 states.
# Searched 1093000 states.
# Searched 1093100 states.
# Searched 1093200 states.
# Searched 1093300 states.
# Searched 1093400 states.
# Searched 1093500 states.
# Searched 1093600 states.
# Searched 1093700 states.
# Searched 1093800 states.
# Searched 1093900 states.
# Searched 1094000 states.
# Searched 1094100 states.
# Searched 1094200 states.
# Searched 1094300 states.
# Searched 1094400 states.
# Searched 1094500 states.
# Searched 1094600 states.
# Searched 1094700 states.
# Searched 1094800 states.
# Searched 1094900 states.
# Searched 1095000 states.
# Searched 1095100 states.
# Searched 1095200 states.
# Searched 1095300 states.
# Searched 1095400 states.
# Searched 1095500 states.
# Searched 1095600 states.
# Searched 1095700 states.
# Searched 1095800 states.
# Searched 1095900 states.
# Searched 1096000 states.
# Searched 1096100 states.
# Searched 1096200 states.
# Searched 1096300 states.
# Searched 1096400 states.
# Searched 1096500 states.
# Searched 1096600 states.
# Searched 1096700 states.
# Searched 1096800 states.
# Searched 1096900 states.
# Searched 1097000 states.
# Searched 1097100 states.
# Searched 1097200 states.
# Searched 1097300 states.
# Searched 1097400 states.
# Searched 1097500 states.
# Searched 1097600 states.
# Searched 1097700 states.
# Searched 1097800 states.
# Searched 1097900 states.
# Searched 1098000 states.
# Searched 1098100 states.
# Searched 1098200 states.
# Searched 1098300 states.
# Searched 1098400 states.
# Searched 1098500 states.
# Searched 1098600 states.
# Searched 1098700 states.
# Searched 1098800 states.
# Searched 1098900 states.
# Searched 1099000 states.
# Searched 1099100 states.
# Searched 1099200 states.
# Searched 1099300 states.
# Searched 1099400 states.
# Searched 1099500 states.
# Searched 1099600 states.
# Searched 1099700 states.
# Searched 1099800 states.
# Searched 1099900 states.
# Searched 1100000 states.
# Searched 1100100 states.
# Searched 1100200 states.
# Searched 1100300 states.
# Searched 1100400 states.
# Searched 1100500 states.
# Searched 1100600 states.
# Searched 1100700 states.
# Searched 1100800 states.
# Searched 1100900 states.
# Searched 1101000 states.
# Searched 1101100 states.
# Searched 1101200 states.
# Searched 1101300 states.
# Searched 1101400 states.
# Searched 1101500 states.
# Searched 1101600 states.
# Searched 1101700 states.
# Searched 1101800 states.
# Searched 1101900 states.
# Searched 1102000 states.
# Searched 1102100 states.
# Searched 1102200 states.
# Searched 1102300 states.
# Searched 1102400 states.
# Searched 1102500 states.
# Searched 1102600 states.
# Searched 1102700 states.
# Searched 1102800 states.
# Searched 1102900 states.
# Searched 1103000 states.
# Searched 1103100 states.
# Searched 1103200 states.
# Searched 1103300 states.
# Searched 1103400 states.
# Searched 1103500 states.
# Searched 1103600 states.
# Searched 1103700 states.
# Searched 1103800 states.
# Searched 1103900 states.
# Searched 1104000 states.
# Searched 1104100 states.
# Searched 1104200 states.
# Searched 1104300 states.
# Searched 1104400 states.
# Searched 1104500 states.
# Searched 1104600 states.
# Searched 1104700 states.
# Searched 1104800 states.
# Searched 1104900 states.
# Searched 1105000 states.
# Searched 1105100 states.
# Searched 1105200 states.
# Searched 1105300 states.
# Searched 1105400 states.
# Searched 1105500 states.
# Searched 1105600 states.
# Searched 1105700 states.
# Searched 1105800 states.
# Searched 1105900 states.
# Searched 1106000 states.
# Searched 1106100 states.
# Searched 1106200 states.
# Searched 1106300 states.
# Searched 1106400 states.
# Searched 1106500 states.
# Searched 1106600 states.
# Searched 1106700 states.
# Searched 1106800 states.
# Searched 1106900 states.
# Searched 1107000 states.
# Searched 1107100 states.
# Searched 1107200 states.
# Searched 1107300 states.
# Searched 1107400 states.
# Searched 1107500 states.
# Searched 1107600 states.
# Searched 1107700 states.
# Searched 1107800 states.
# Searched 1107900 states.
# Searched 1108000 states.
# Searched 1108100 states.
# Searched 1108200 states.
# Searched 1108300 states.
# Searched 1108400 states.
# Searched 1108500 states.
# Searched 1108600 states.
# Searched 1108700 states.
# Searched 1108800 states.
# Searched 1108900 states.
# Searched 1109000 states.
# Searched 1109100 states.
# Searched 1109200 states.
# Searched 1109300 states.
# Searched 1109400 states.
# Searched 1109500 states.
# Searched 1109600 states.
# Searched 1109700 states.
# Searched 1109800 states.
# Searched 1109900 states.
# Searched 1110000 states.
# Searched 1110100 states.
# Searched 1110200 states.
# Searched 1110300 states.
# Searched 1110400 states.
# Searched 1110500 states.
# Searched 1110600 states.
# Searched 1110700 states.
# Searched 1110800 states.
# Searched 1110900 states.
# Searched 1111000 states.
# Searched 1111100 states.
# Searched 1111200 states.
# Searched 1111300 states.
# Searched 1111400 states.
# Searched 1111500 states.
# Searched 1111600 states.
# Searched 1111700 states.
# Searched 1111800 states.
# Searched 1111900 states.
# Searched 1112000 states.
# Searched 1112100 states.
# Searched 1112200 states.
# Searched 1112300 states.
# Searched 1112400 states.
# Searched 1112500 states.
# Searched 1112600 states.
# Searched 1112700 states.
# Searched 1112800 states.
# Searched 1112900 states.
# Searched 1113000 states.
# Searched 1113100 states.
# Searched 1113200 states.
# Searched 1113300 states.
# Searched 1113400 states.
# Searched 1113500 states.
# Searched 1113600 states.
# Searched 1113700 states.
# Searched 1113800 states.
# Searched 1113900 states.
# Searched 1114000 states.
# Searched 1114100 states.
# Searched 1114200 states.
# Searched 1114300 states.
# Searched 1114400 states.
# Searched 1114500 states.
# Searched 1114600 states.
# Searched 1114700 states.
# Searched 1114800 states.
# Searched 1114900 states.
# Searched 1115000 states.
# Searched 1115100 states.
# Searched 1115200 states.
# Searched 1115300 states.
# Searched 1115400 states.
# Searched 1115500 states.
# Searched 1115600 states.
# Searched 1115700 states.
# Searched 1115800 states.
# Searched 1115900 states.
# Searched 1116000 states.
# Searched 1116100 states.
# Searched 1116200 states.
# Searched 1116300 states.
# Searched 1116400 states.
# Searched 1116500 states.
# Searched 1116600 states.
# Searched 1116700 states.
# Searched 1116800 states.
# Searched 1116900 states.
# Searched 1117000 states.
# Searched 1117100 states.
# Searched 1117200 states.
# Searched 1117300 states.
# Searched 1117400 states.
# Searched 1117500 states.
# Searched 1117600 states.
# Searched 1117700 states.
# Searched 1117800 states.
# Searched 1117900 states.
# Searched 1118000 states.
# Searched 1118100 states.
# Searched 1118200 states.
# Searched 1118300 states.
# Searched 1118400 states.
# Searched 1118500 states.
# Searched 1118600 states.
# Searched 1118700 states.
# Searched 1118800 states.
# Searched 1118900 states.
# Searched 1119000 states.
# Searched 1119100 states.
# Searched 1119200 states.
# Searched 1119300 states.
# Searched 1119400 states.
# Searched 1119500 states.
# Searched 1119600 states.
# Searched 1119700 states.
# Searched 1119800 states.
# Searched 1119900 states.
# Searched 1120000 states.
# Searched 1120100 states.
# Searched 1120200 states.
# Searched 1120300 states.
# Searched 1120400 states.
# Searched 1120500 states.
# Searched 1120600 states.
# Searched 1120700 states.
# Searched 1120800 states.
# Searched 1120900 states.
# Searched 1121000 states.
# Searched 1121100 states.
# Searched 1121200 states.
# Searched 1121300 states.
# Searched 1121400 states.
# Searched 1121500 states.
# Searched 1121600 states.
# Searched 1121700 states.
# Searched 1121800 states.
# Searched 1121900 states.
# Searched 1122000 states.
# Searched 1122100 states.
# Searched 1122200 states.
# Searched 1122300 states.
# Searched 1122400 states.
# Searched 1122500 states.
# Searched 1122600 states.
# Searched 1122700 states.
# Searched 1122800 states.
# Searched 1122900 states.
# Searched 1123000 states.
# Searched 1123100 states.
# Searched 1123200 states.
# Searched 1123300 states.
# Searched 1123400 states.
# Searched 1123500 states.
# Searched 1123600 states.
# Searched 1123700 states.
# Searched 1123800 states.
# Searched 1123900 states.
# Searched 1124000 states.
# Searched 1124100 states.
# Searched 1124200 states.
# Searched 1124300 states.
# Searched 1124400 states.
# Searched 1124500 states.
# Searched 1124600 states.
# Searched 1124700 states.
# Searched 1124800 states.
# Searched 1124900 states.
# Searched 1125000 states.
# Searched 1125100 states.
# Searched 1125200 states.
# Searched 1125300 states.
# Searched 1125400 states.
# Searched 1125500 states.
# Searched 1125600 states.
# Searched 1125700 states.
# Searched 1125800 states.
# Searched 1125900 states.
# Searched 1126000 states.
# Searched 1126100 states.
# Searched 1126200 states.
# Searched 1126300 states.
# Searched 1126400 states.
# Searched 1126500 states.
# Searched 1126600 states.
# Searched 1126700 states.
# Searched 1126800 states.
# Searched 1126900 states.
# Searched 1127000 states.
# Searched 1127100 states.
# Searched 1127200 states.
# Searched 1127300 states.
# Searched 1127400 states.
# Searched 1127500 states.
# Searched 1127600 states.
# Searched 1127700 states.
# Searched 1127800 states.
# Searched 1127900 states.
# Searched 1128000 states.
# Searched 1128100 states.
# Searched 1128200 states.
# Searched 1128300 states.
# Searched 1128400 states.
# Searched 1128500 states.
# Searched 1128600 states.
# Searched 1128700 states.
# Searched 1128800 states.
# Searched 1128900 states.
# Searched 1129000 states.
# Searched 1129100 states.
# Searched 1129200 states.
# Searched 1129300 states.
# Searched 1129400 states.
# Searched 1129500 states.
# Searched 1129600 states.
# Searched 1129700 states.
# Searched 1129800 states.
# Searched 1129900 states.
# Searched 1130000 states.
# Searched 1130100 states.
# Searched 1130200 states.
# Searched 1130300 states.
# Searched 1130400 states.
# Searched 1130500 states.
# Searched 1130600 states.
# Searched 1130700 states.
# Searched 1130800 states.
# Searched 1130900 states.
# Searched 1131000 states.
# Searched 1131100 states.
# Searched 1131200 states.
# Searched 1131300 states.
# Searched 1131400 states.
# Searched 1131500 states.
# Searched 1131600 states.
# Searched 1131700 states.
# Searched 1131800 states.
# Searched 1131900 states.
# Searched 1132000 states.
# Searched 1132100 states.
# Searched 1132200 states.
# Searched 1132300 states.
# Searched 1132400 states.
# Searched 1132500 states.
# Searched 1132600 states.
# Searched 1132700 states.
# Searched 1132800 states.
# Searched 1132900 states.
# Searched 1133000 states.
# Searched 1133100 states.
# Searched 1133200 states.
# Searched 1133300 states.
# Searched 1133400 states.
# Searched 1133500 states.
# Searched 1133600 states.
# Searched 1133700 states.
# Searched 1133800 states.
# Searched 1133900 states.
# Searched 1134000 states.
# Searched 1134100 states.
# Searched 1134200 states.
# Searched 1134300 states.
# Searched 1134400 states.
# Searched 1134500 states.
# Searched 1134600 states.
# Searched 1134700 states.
# Searched 1134800 states.
# Searched 1134900 states.
# Searched 1135000 states.
# Searched 1135100 states.
# Searched 1135200 states.
# Searched 1135300 states.
# Searched 1135400 states.
# Searched 1135500 states.
# Searched 1135600 states.
# Searched 1135700 states.
# Searched 1135800 states.
# Searched 1135900 states.
# Searched 1136000 states.
# Searched 1136100 states.
# Searched 1136200 states.
# Searched 1136300 states.
# Searched 1136400 states.
# Searched 1136500 states.
# Searched 1136600 states.
# Searched 1136700 states.
# Searched 1136800 states.
# Searched 1136900 states.
# Searched 1137000 states.
# Searched 1137100 states.
# Searched 1137200 states.
# Searched 1137300 states.
# Searched 1137400 states.
# Searched 1137500 states.
# Searched 1137600 states.
# Searched 1137700 states.
# Searched 1137800 states.
# Searched 1137900 states.
# Searched 1138000 states.
# Searched 1138100 states.
# Searched 1138200 states.
# Searched 1138300 states.
# Searched 1138400 states.
# Searched 1138500 states.
# Searched 1138600 states.
# Searched 1138700 states.
# Searched 1138800 states.
# Searched 1138900 states.
# Searched 1139000 states.
# Searched 1139100 states.
# Searched 1139200 states.
# Searched 1139300 states.
# Searched 1139400 states.
# Searched 1139500 states.
# Searched 1139600 states.
# Searched 1139700 states.
# Searched 1139800 states.
# Searched 1139900 states.
# Searched 1140000 states.
# Searched 1140100 states.
# Searched 1140200 states.
# Searched 1140300 states.
# Searched 1140400 states.
# Searched 1140500 states.
# Searched 1140600 states.
# Searched 1140700 states.
# Searched 1140800 states.
# Searched 1140900 states.
# Searched 1141000 states.
# Searched 1141100 states.
# Searched 1141200 states.
# Searched 1141300 states.
# Searched 1141400 states.
# Searched 1141500 states.
# Searched 1141600 states.
# Searched 1141700 states.
# Searched 1141800 states.
# Searched 1141900 states.
# Searched 1142000 states.
# Searched 1142100 states.
# Searched 1142200 states.
# Searched 1142300 states.
# Searched 1142400 states.
# Searched 1142500 states.
# Searched 1142600 states.
# Searched 1142700 states.
# Searched 1142800 states.
# Searched 1142900 states.
# Searched 1143000 states.
# Searched 1143100 states.
# Searched 1143200 states.
# Searched 1143300 states.
# Searched 1143400 states.
# Searched 1143500 states.
# Searched 1143600 states.
# Searched 1143700 states.
# Searched 1143800 states.
# Searched 1143900 states.
# Searched 1144000 states.
# 213

# %%
import re
from collections import deque
import time  # Import time module for time measurements

# Read the input data
with open('input.txt') as f:
    lines = f.readlines()

# Parse the input data
nodes = {}
max_x = max_y = 0
for line in lines[1:]:
    match = re.match(r'/dev/grid/node-x(\d+)-y(\d+)\s+(\d+)T\s+(\d+)T\s+(\d+)T', line)
    if match:
        x, y, size, used, avail = map(int, match.groups())
        nodes[(x, y)] = {'size': size, 'used': used, 'avail': avail}
        max_x = max(max_x, x)
        max_y = max(max_y, y)

# Build the grid
grid = [['.' for _ in range(max_x + 1)] for _ in range(max_y + 1)]
empty_node = None
for (x, y), node in nodes.items():
    if node['used'] == 0:
        grid[y][x] = '_'
        empty_node = (x, y)
    elif node['used'] > 100:  # Arbitrary threshold for large nodes
        grid[y][x] = '#'
    if y == 0 and x == max_x:
        goal_data = (x, y)

# Function to find the minimal steps
def find_min_steps(grid, empty_node, goal_data):
    from copy import deepcopy
    visited = set()
    queue = deque()
    state = (deepcopy(grid), empty_node, goal_data, 0)
    queue.append(state)
    steps_checked = 0  # Counter for progress reporting
    report_interval = 10000  # Adjust this value as needed

    start_time = time.time()  # Record the start time
    last_report_time = start_time  # Time of the last report

    while queue:
        grid_state, empty_pos, goal_pos, steps = queue.popleft()
        steps_checked += 1

        # Progress reporting
        if steps_checked % report_interval == 0:
            current_time = time.time()
            time_since_last_report = current_time - last_report_time
            total_elapsed_time = current_time - start_time
            print(f"Searched {steps_checked} states. "
                  f"Time since last report: {time_since_last_report:.2f}s, "
                  f"Total elapsed time: {total_elapsed_time:.2f}s.")
            last_report_time = current_time

        if goal_pos == (0, 0):
            return steps
        key = (tuple(map(tuple, grid_state)), empty_pos, goal_pos)
        if key in visited:
            continue
        visited.add(key)
        x, y = empty_pos
        for dx, dy in [(-1,0),(1,0),(0,-1),(0,1)]:
            nx, ny = x + dx, y + dy
            if 0 <= nx <= max_x and 0 <= ny <= max_y and grid_state[ny][nx] != '#':
                new_grid = deepcopy(grid_state)
                # Swap empty node with its neighbor
                new_grid[y][x], new_grid[ny][nx] = new_grid[ny][nx], new_grid[y][x]
                new_empty_pos = (nx, ny)
                new_goal_pos = goal_pos
                if (nx, ny) == goal_pos:
                    new_goal_pos = (x, y)
                queue.append((new_grid, new_empty_pos, new_goal_pos, steps + 1))
    return -1  # Should not reach here for solvable puzzles

# Find the minimal steps
min_steps = find_min_steps(grid, empty_node, goal_data)

# Output the result
print(f"Minimal steps required: {min_steps}")
# Out:
# Searched 10000 states. Time since last report: 4.20s, Total elapsed time: 4.20s.
# Searched 20000 states. Time since last report: 4.29s, Total elapsed time: 8.50s.
# Searched 30000 states. Time since last report: 4.56s, Total elapsed time: 13.06s.
# Searched 40000 states. Time since last report: 4.28s, Total elapsed time: 17.33s.
# Searched 50000 states. Time since last report: 4.38s, Total elapsed time: 21.72s.
# Searched 60000 states. Time since last report: 4.35s, Total elapsed time: 26.07s.
# Searched 70000 states. Time since last report: 5.05s, Total elapsed time: 31.12s.
# Searched 80000 states. Time since last report: 4.21s, Total elapsed time: 35.33s.
# Searched 90000 states. Time since last report: 3.92s, Total elapsed time: 39.25s.
# Searched 100000 states. Time since last report: 3.77s, Total elapsed time: 43.02s.
# Searched 110000 states. Time since last report: 4.11s, Total elapsed time: 47.13s.
# Searched 120000 states. Time since last report: 4.11s, Total elapsed time: 51.24s.
# Searched 130000 states. Time since last report: 3.97s, Total elapsed time: 55.21s.
# Searched 140000 states. Time since last report: 4.17s, Total elapsed time: 59.37s.
# Searched 150000 states. Time since last report: 4.11s, Total elapsed time: 63.48s.
# Searched 160000 states. Time since last report: 4.12s, Total elapsed time: 67.60s.
# Searched 170000 states. Time since last report: 4.19s, Total elapsed time: 71.79s.
# Searched 180000 states. Time since last report: 5.35s, Total elapsed time: 77.14s.
# Searched 190000 states. Time since last report: 4.16s, Total elapsed time: 81.30s.
# Searched 200000 states. Time since last report: 4.39s, Total elapsed time: 85.69s.
# Searched 210000 states. Time since last report: 4.89s, Total elapsed time: 90.57s.
# Searched 220000 states. Time since last report: 4.59s, Total elapsed time: 95.16s.
# Searched 230000 states. Time since last report: 6.40s, Total elapsed time: 101.56s.
# Searched 240000 states. Time since last report: 4.04s, Total elapsed time: 105.60s.
# Searched 250000 states. Time since last report: 4.01s, Total elapsed time: 109.61s.
# Searched 260000 states. Time since last report: 4.57s, Total elapsed time: 114.18s.
# Searched 270000 states. Time since last report: 4.24s, Total elapsed time: 118.42s.
# Searched 280000 states. Time since last report: 4.34s, Total elapsed time: 122.76s.
# Searched 290000 states. Time since last report: 4.41s, Total elapsed time: 127.17s.
# Searched 300000 states. Time since last report: 4.12s, Total elapsed time: 131.30s.
# Searched 310000 states. Time since last report: 5.13s, Total elapsed time: 136.42s.
# Searched 320000 states. Time since last report: 5.27s, Total elapsed time: 141.69s.
# Searched 330000 states. Time since last report: 4.37s, Total elapsed time: 146.06s.
# Searched 340000 states. Time since last report: 5.03s, Total elapsed time: 151.09s.
# Searched 350000 states. Time since last report: 4.28s, Total elapsed time: 155.37s.
# Searched 360000 states. Time since last report: 4.10s, Total elapsed time: 159.47s.
# Searched 370000 states. Time since last report: 4.38s, Total elapsed time: 163.85s.
# Searched 380000 states. Time since last report: 4.41s, Total elapsed time: 168.27s.
# Searched 390000 states. Time since last report: 4.55s, Total elapsed time: 172.82s.
# Searched 400000 states. Time since last report: 5.95s, Total elapsed time: 178.77s.
# Searched 410000 states. Time since last report: 4.06s, Total elapsed time: 182.83s.
# Searched 420000 states. Time since last report: 4.11s, Total elapsed time: 186.95s.
# Searched 430000 states. Time since last report: 4.22s, Total elapsed time: 191.16s.
# Searched 440000 states. Time since last report: 4.18s, Total elapsed time: 195.34s.
# Searched 450000 states. Time since last report: 4.28s, Total elapsed time: 199.62s.
# Searched 460000 states. Time since last report: 4.01s, Total elapsed time: 203.63s.
# Searched 470000 states. Time since last report: 4.17s, Total elapsed time: 207.80s.
# Searched 480000 states. Time since last report: 5.03s, Total elapsed time: 212.83s.
# Searched 490000 states. Time since last report: 5.42s, Total elapsed time: 218.25s.
# Searched 500000 states. Time since last report: 4.28s, Total elapsed time: 222.53s.
# Searched 510000 states. Time since last report: 4.58s, Total elapsed time: 227.10s.
# Searched 520000 states. Time since last report: 4.51s, Total elapsed time: 231.61s.
# Searched 530000 states. Time since last report: 4.23s, Total elapsed time: 235.84s.
# Searched 540000 states. Time since last report: 4.00s, Total elapsed time: 239.84s.
# Searched 550000 states. Time since last report: 4.16s, Total elapsed time: 244.00s.
# Searched 560000 states. Time since last report: 4.14s, Total elapsed time: 248.14s.
# Searched 570000 states. Time since last report: 4.11s, Total elapsed time: 252.26s.
# Searched 580000 states. Time since last report: 4.03s, Total elapsed time: 256.29s.
# Searched 590000 states. Time since last report: 4.10s, Total elapsed time: 260.39s.
# Searched 600000 states. Time since last report: 3.98s, Total elapsed time: 264.36s.
# Searched 610000 states. Time since last report: 3.86s, Total elapsed time: 268.22s.
# Searched 620000 states. Time since last report: 4.12s, Total elapsed time: 272.34s.
# Searched 630000 states. Time since last report: 4.13s, Total elapsed time: 276.47s.
# Searched 640000 states. Time since last report: 4.04s, Total elapsed time: 280.51s.
# Searched 650000 states. Time since last report: 4.10s, Total elapsed time: 284.61s.
# Searched 660000 states. Time since last report: 3.99s, Total elapsed time: 288.60s.
# Searched 670000 states. Time since last report: 4.40s, Total elapsed time: 293.00s.
# Searched 680000 states. Time since last report: 4.34s, Total elapsed time: 297.34s.
# Searched 690000 states. Time since last report: 4.66s, Total elapsed time: 302.00s.
# Searched 700000 states. Time since last report: 4.35s, Total elapsed time: 306.35s.
# Searched 710000 states. Time since last report: 4.00s, Total elapsed time: 310.35s.
# Searched 720000 states. Time since last report: 3.90s, Total elapsed time: 314.25s.
# Searched 730000 states. Time since last report: 4.23s, Total elapsed time: 318.48s.
# Searched 740000 states. Time since last report: 4.43s, Total elapsed time: 322.91s.
# Searched 750000 states. Time since last report: 4.58s, Total elapsed time: 327.49s.
# Searched 760000 states. Time since last report: 4.29s, Total elapsed time: 331.77s.
# Searched 770000 states. Time since last report: 5.39s, Total elapsed time: 337.17s.
# Searched 780000 states. Time since last report: 3.95s, Total elapsed time: 341.11s.
# Searched 790000 states. Time since last report: 3.97s, Total elapsed time: 345.09s.
# Searched 800000 states. Time since last report: 4.17s, Total elapsed time: 349.26s.
# Searched 810000 states. Time since last report: 4.27s, Total elapsed time: 353.53s.
# Searched 820000 states. Time since last report: 4.49s, Total elapsed time: 358.02s.
# Searched 830000 states. Time since last report: 4.33s, Total elapsed time: 362.35s.
# Searched 840000 states. Time since last report: 4.03s, Total elapsed time: 366.38s.
# Searched 850000 states. Time since last report: 3.84s, Total elapsed time: 370.22s.
# Searched 860000 states. Time since last report: 3.84s, Total elapsed time: 374.06s.
# Searched 870000 states. Time since last report: 4.00s, Total elapsed time: 378.06s.
# Searched 880000 states. Time since last report: 4.10s, Total elapsed time: 382.15s.
# Searched 890000 states. Time since last report: 3.86s, Total elapsed time: 386.01s.
# Searched 900000 states. Time since last report: 3.93s, Total elapsed time: 389.94s.
# Searched 910000 states. Time since last report: 5.68s, Total elapsed time: 395.62s.
# Searched 920000 states. Time since last report: 4.17s, Total elapsed time: 399.79s.
# Searched 930000 states. Time since last report: 4.08s, Total elapsed time: 403.88s.
# Searched 940000 states. Time since last report: 3.97s, Total elapsed time: 407.84s.
# Searched 950000 states. Time since last report: 3.98s, Total elapsed time: 411.82s.
# Searched 960000 states. Time since last report: 3.93s, Total elapsed time: 415.75s.
# Searched 970000 states. Time since last report: 3.89s, Total elapsed time: 419.64s.
# Searched 980000 states. Time since last report: 3.93s, Total elapsed time: 423.57s.
# Searched 990000 states. Time since last report: 4.14s, Total elapsed time: 427.71s.
# Searched 1000000 states. Time since last report: 4.09s, Total elapsed time: 431.79s.
# Searched 1010000 states. Time since last report: 4.04s, Total elapsed time: 435.84s.
# Searched 1020000 states. Time since last report: 3.84s, Total elapsed time: 439.67s.
# Searched 1030000 states. Time since last report: 4.01s, Total elapsed time: 443.68s.
# Searched 1040000 states. Time since last report: 4.06s, Total elapsed time: 447.75s.
# Searched 1050000 states. Time since last report: 4.09s, Total elapsed time: 451.84s.
# Searched 1060000 states. Time since last report: 5.63s, Total elapsed time: 457.47s.
# Searched 1070000 states. Time since last report: 4.34s, Total elapsed time: 461.81s.
# Searched 1080000 states. Time since last report: 4.32s, Total elapsed time: 466.13s.
# Searched 1090000 states. Time since last report: 4.82s, Total elapsed time: 470.95s.
# Searched 1100000 states. Time since last report: 4.48s, Total elapsed time: 475.43s.
# Searched 1110000 states. Time since last report: 4.46s, Total elapsed time: 479.88s.
# Searched 1120000 states. Time since last report: 4.54s, Total elapsed time: 484.42s.
# Searched 1130000 states. Time since last report: 4.52s, Total elapsed time: 488.94s.
# Searched 1140000 states. Time since last report: 4.48s, Total elapsed time: 493.42s.
# Minimal steps required: 213

# %%
print(1)
# Out:
# 1

# %%
import re
from collections import deque
import time
import heapq

# Read the input data
with open('part-002-example-input.txt') as f:
    lines = f.readlines()

# Parse the input data
nodes = {}
max_x = max_y = 0
for line in lines[1:]:
    match = re.match(r'/dev/grid/node-x(\d+)-y(\d+)\s+(\d+)T\s+(\d+)T\s+(\d+)T', line)
    if match:
        x, y, size, used, avail = map(int, match.groups())
        nodes[(x, y)] = {'size': size, 'used': used, 'avail': avail}
        max_x = max(max_x, x)
        max_y = max(max_y, y)

# Build the grid
grid = [['.' for _ in range(max_x + 1)] for _ in range(max_y + 1)]
empty_node = None
for (x, y), node in nodes.items():
    if node['used'] == 0:
        grid[y][x] = '_'
        empty_node = (x, y)
    elif node['used'] > 100:  # Adjust threshold based on data
        grid[y][x] = '#'
    if y == 0 and x == max_x:
        goal_data = (x, y)

# Function to calculate heuristic
def heuristic(goal_pos):
    # Estimate the minimal number of steps required to bring the goal data to (0,0)
    # Each move of the goal data requires moving the empty space next to it and swapping
    x, y = goal_pos
    return abs(x - 0) + abs(y - 0)

# Function to find the minimal steps using A* search
def find_min_steps(grid, empty_node, goal_data):
    import time
    from copy import deepcopy

    start_time = time.time()
    last_report_time = start_time

    visited = set()
    # Priority queue for A* search
    heap = []
    steps_checked = 0  # Counter for progress reporting
    report_interval = 10000  # Adjust as needed

    # Initial state
    state = (heuristic(goal_data), 0, grid, empty_node, goal_data)
    heapq.heappush(heap, state)

    while heap:
        f_score, steps, grid_state, empty_pos, goal_pos = heapq.heappop(heap)
        steps_checked += 1

        # Progress reporting
        if steps_checked % report_interval == 0:
            current_time = time.time()
            time_since_last_report = current_time - last_report_time
            total_elapsed_time = current_time - start_time
            print(f"Searched {steps_checked} states. "
                  f"Time since last report: {time_since_last_report:.2f}s, "
                  f"Total elapsed time: {total_elapsed_time:.2f}s.")
            last_report_time = current_time

        if goal_pos == (0, 0):
            return steps

        key = (tuple(map(tuple, grid_state)), empty_pos, goal_pos)
        if key in visited:
            continue
        visited.add(key)

        x_empty, y_empty = empty_pos
        for dx, dy in [(-1,0),(1,0),(0,-1),(0,1)]:
            nx_empty, ny_empty = x_empty + dx, y_empty + dy
            if 0 <= nx_empty <= max_x and 0 <= ny_empty <= max_y and grid_state[ny_empty][nx_empty] != '#':
                # Create a new grid state
                new_grid = [row[:] for row in grid_state]
                # Swap empty node with its neighbor
                new_grid[y_empty][x_empty], new_grid[ny_empty][nx_empty] = new_grid[ny_empty][nx_empty], new_grid[y_empty][x_empty]
                new_empty_pos = (nx_empty, ny_empty)
                new_goal_pos = goal_pos
                # If we moved the empty space into the goal data's position, we effectively moved the goal data
                if (nx_empty, ny_empty) == goal_pos:
                    new_goal_pos = (x_empty, y_empty)
                # Calculate new heuristic
                h = heuristic(new_goal_pos)
                # Total cost = steps taken + heuristic
                f = steps + 1 + h
                # Add new state to the priority queue
                heapq.heappush(heap, (f, steps + 1, new_grid, new_empty_pos, new_goal_pos))

    return -1  # If the goal is unreachable

# Find the minimal steps
min_steps = find_min_steps(grid, empty_node, goal_data)

# Output the result
print(f"Minimal steps required: {min_steps}")
# Out:
# Minimal steps required: 7

# %%
import re
from collections import deque
import time
import heapq

# Read the input data
with open('input.txt') as f:
    lines = f.readlines()

# Parse the input data
nodes = {}
max_x = max_y = 0
for line in lines[1:]:
    match = re.match(r'/dev/grid/node-x(\d+)-y(\d+)\s+(\d+)T\s+(\d+)T\s+(\d+)T', line)
    if match:
        x, y, size, used, avail = map(int, match.groups())
        nodes[(x, y)] = {'size': size, 'used': used, 'avail': avail}
        max_x = max(max_x, x)
        max_y = max(max_y, y)

# Build the grid
grid = [['.' for _ in range(max_x + 1)] for _ in range(max_y + 1)]
empty_node = None
for (x, y), node in nodes.items():
    if node['used'] == 0:
        grid[y][x] = '_'
        empty_node = (x, y)
    elif node['used'] > 100:  # Adjust threshold based on data
        grid[y][x] = '#'
    if y == 0 and x == max_x:
        goal_data = (x, y)

# Function to calculate heuristic
def heuristic(goal_pos):
    # Estimate the minimal number of steps required to bring the goal data to (0,0)
    # Each move of the goal data requires moving the empty space next to it and swapping
    x, y = goal_pos
    return abs(x - 0) + abs(y - 0)

# Function to find the minimal steps using A* search
def find_min_steps(grid, empty_node, goal_data):
    import time
    from copy import deepcopy

    start_time = time.time()
    last_report_time = start_time

    visited = set()
    # Priority queue for A* search
    heap = []
    steps_checked = 0  # Counter for progress reporting
    report_interval = 1000  # Adjust as needed

    # Initial state
    state = (heuristic(goal_data), 0, grid, empty_node, goal_data)
    heapq.heappush(heap, state)

    while heap:
        f_score, steps, grid_state, empty_pos, goal_pos = heapq.heappop(heap)
        steps_checked += 1

        # Progress reporting
        if steps_checked % report_interval == 0:
            current_time = time.time()
            time_since_last_report = current_time - last_report_time
            total_elapsed_time = current_time - start_time
            print(f"Searched {steps_checked} states. "
                  f"Time since last report: {time_since_last_report:.2f}s, "
                  f"Total elapsed time: {total_elapsed_time:.2f}s.")
            last_report_time = current_time

        if goal_pos == (0, 0):
            return steps

        key = (tuple(map(tuple, grid_state)), empty_pos, goal_pos)
        if key in visited:
            continue
        visited.add(key)

        x_empty, y_empty = empty_pos
        for dx, dy in [(-1,0),(1,0),(0,-1),(0,1)]:
            nx_empty, ny_empty = x_empty + dx, y_empty + dy
            if 0 <= nx_empty <= max_x and 0 <= ny_empty <= max_y and grid_state[ny_empty][nx_empty] != '#':
                # Create a new grid state
                new_grid = [row[:] for row in grid_state]
                # Swap empty node with its neighbor
                new_grid[y_empty][x_empty], new_grid[ny_empty][nx_empty] = new_grid[ny_empty][nx_empty], new_grid[y_empty][x_empty]
                new_empty_pos = (nx_empty, ny_empty)
                new_goal_pos = goal_pos
                # If we moved the empty space into the goal data's position, we effectively moved the goal data
                if (nx_empty, ny_empty) == goal_pos:
                    new_goal_pos = (x_empty, y_empty)
                # Calculate new heuristic
                h = heuristic(new_goal_pos)
                # Total cost = steps taken + heuristic
                f = steps + 1 + h
                # Add new state to the priority queue
                heapq.heappush(heap, (f, steps + 1, new_grid, new_empty_pos, new_goal_pos))

    return -1  # If the goal is unreachable

# Find the minimal steps
min_steps = find_min_steps(grid, empty_node, goal_data)

# Output the result
print(f"Minimal steps required: {min_steps}")
# Out:
# Searched 1000 states. Time since last report: 0.05s, Total elapsed time: 0.05s.
# Searched 2000 states. Time since last report: 0.04s, Total elapsed time: 0.09s.
# Searched 3000 states. Time since last report: 0.02s, Total elapsed time: 0.10s.
# Searched 4000 states. Time since last report: 0.03s, Total elapsed time: 0.13s.
# Searched 5000 states. Time since last report: 0.05s, Total elapsed time: 0.18s.
# Searched 6000 states. Time since last report: 0.03s, Total elapsed time: 0.22s.
# Searched 7000 states. Time since last report: 0.03s, Total elapsed time: 0.25s.
# Searched 8000 states. Time since last report: 0.03s, Total elapsed time: 0.28s.
# Searched 9000 states. Time since last report: 0.03s, Total elapsed time: 0.31s.
# Searched 10000 states. Time since last report: 0.04s, Total elapsed time: 0.35s.
# Searched 11000 states. Time since last report: 0.04s, Total elapsed time: 0.39s.
# Searched 12000 states. Time since last report: 0.07s, Total elapsed time: 0.45s.
# Searched 13000 states. Time since last report: 0.04s, Total elapsed time: 0.49s.
# Searched 14000 states. Time since last report: 0.02s, Total elapsed time: 0.51s.
# Searched 15000 states. Time since last report: 0.05s, Total elapsed time: 0.56s.
# Searched 16000 states. Time since last report: 0.03s, Total elapsed time: 0.59s.
# Searched 17000 states. Time since last report: 0.03s, Total elapsed time: 0.62s.
# Searched 18000 states. Time since last report: 0.04s, Total elapsed time: 0.66s.
# Searched 19000 states. Time since last report: 0.07s, Total elapsed time: 0.73s.
# Searched 20000 states. Time since last report: 0.04s, Total elapsed time: 0.76s.
# Searched 21000 states. Time since last report: 0.04s, Total elapsed time: 0.81s.
# Searched 22000 states. Time since last report: 0.03s, Total elapsed time: 0.83s.
# Searched 23000 states. Time since last report: 0.04s, Total elapsed time: 0.88s.
# Searched 24000 states. Time since last report: 0.04s, Total elapsed time: 0.92s.
# Searched 25000 states. Time since last report: 0.11s, Total elapsed time: 1.03s.
# Searched 26000 states. Time since last report: 0.02s, Total elapsed time: 1.05s.
# Searched 27000 states. Time since last report: 0.09s, Total elapsed time: 1.14s.
# Searched 28000 states. Time since last report: 0.04s, Total elapsed time: 1.18s.
# Searched 29000 states. Time since last report: 0.03s, Total elapsed time: 1.21s.
# Searched 30000 states. Time since last report: 0.04s, Total elapsed time: 1.25s.
# Searched 31000 states. Time since last report: 0.04s, Total elapsed time: 1.28s.
# Searched 32000 states. Time since last report: 0.04s, Total elapsed time: 1.32s.
# Searched 33000 states. Time since last report: 0.05s, Total elapsed time: 1.38s.
# Searched 34000 states. Time since last report: 0.04s, Total elapsed time: 1.42s.
# Searched 35000 states. Time since last report: 0.09s, Total elapsed time: 1.51s.
# Searched 36000 states. Time since last report: 0.05s, Total elapsed time: 1.56s.
# Searched 37000 states. Time since last report: 0.05s, Total elapsed time: 1.61s.
# Searched 38000 states. Time since last report: 0.04s, Total elapsed time: 1.65s.
# Searched 39000 states. Time since last report: 0.03s, Total elapsed time: 1.68s.
# Searched 40000 states. Time since last report: 0.03s, Total elapsed time: 1.71s.
# Searched 41000 states. Time since last report: 0.03s, Total elapsed time: 1.74s.
# Searched 42000 states. Time since last report: 0.05s, Total elapsed time: 1.79s.
# Searched 43000 states. Time since last report: 0.11s, Total elapsed time: 1.90s.
# Searched 44000 states. Time since last report: 0.03s, Total elapsed time: 1.93s.
# Searched 45000 states. Time since last report: 0.04s, Total elapsed time: 1.96s.
# Searched 46000 states. Time since last report: 0.05s, Total elapsed time: 2.02s.
# Searched 47000 states. Time since last report: 0.04s, Total elapsed time: 2.05s.
# Searched 48000 states. Time since last report: 0.05s, Total elapsed time: 2.10s.
# Searched 49000 states. Time since last report: 0.04s, Total elapsed time: 2.14s.
# Searched 50000 states. Time since last report: 0.03s, Total elapsed time: 2.17s.
# Searched 51000 states. Time since last report: 0.03s, Total elapsed time: 2.21s.
# Searched 52000 states. Time since last report: 0.11s, Total elapsed time: 2.32s.
# Searched 53000 states. Time since last report: 0.04s, Total elapsed time: 2.36s.
# Searched 54000 states. Time since last report: 0.05s, Total elapsed time: 2.41s.
# Searched 55000 states. Time since last report: 0.04s, Total elapsed time: 2.45s.
# Searched 56000 states. Time since last report: 0.05s, Total elapsed time: 2.50s.
# Searched 57000 states. Time since last report: 0.03s, Total elapsed time: 2.53s.
# Searched 58000 states. Time since last report: 0.04s, Total elapsed time: 2.57s.
# Searched 59000 states. Time since last report: 0.05s, Total elapsed time: 2.62s.
# Searched 60000 states. Time since last report: 0.15s, Total elapsed time: 2.77s.
# Searched 61000 states. Time since last report: 0.04s, Total elapsed time: 2.81s.
# Searched 62000 states. Time since last report: 0.04s, Total elapsed time: 2.85s.
# Searched 63000 states. Time since last report: 0.04s, Total elapsed time: 2.89s.
# Searched 64000 states. Time since last report: 0.03s, Total elapsed time: 2.92s.
# Searched 65000 states. Time since last report: 0.04s, Total elapsed time: 2.96s.
# Searched 66000 states. Time since last report: 0.05s, Total elapsed time: 3.01s.
# Searched 67000 states. Time since last report: 0.04s, Total elapsed time: 3.05s.
# Searched 68000 states. Time since last report: 0.04s, Total elapsed time: 3.09s.
# Searched 69000 states. Time since last report: 0.10s, Total elapsed time: 3.19s.
# Searched 70000 states. Time since last report: 0.05s, Total elapsed time: 3.24s.
# Searched 71000 states. Time since last report: 0.04s, Total elapsed time: 3.29s.
# Searched 72000 states. Time since last report: 0.04s, Total elapsed time: 3.33s.
# Searched 73000 states. Time since last report: 0.03s, Total elapsed time: 3.36s.
# Searched 74000 states. Time since last report: 0.06s, Total elapsed time: 3.42s.
# Searched 75000 states. Time since last report: 0.04s, Total elapsed time: 3.46s.
# Searched 76000 states. Time since last report: 0.05s, Total elapsed time: 3.51s.
# Searched 77000 states. Time since last report: 0.04s, Total elapsed time: 3.55s.
# Searched 78000 states. Time since last report: 0.12s, Total elapsed time: 3.67s.
# Searched 79000 states. Time since last report: 0.04s, Total elapsed time: 3.71s.
# Searched 80000 states. Time since last report: 0.05s, Total elapsed time: 3.76s.
# Searched 81000 states. Time since last report: 0.05s, Total elapsed time: 3.81s.
# Searched 82000 states. Time since last report: 0.04s, Total elapsed time: 3.85s.
# Searched 83000 states. Time since last report: 0.04s, Total elapsed time: 3.89s.
# Searched 84000 states. Time since last report: 0.05s, Total elapsed time: 3.93s.
# Searched 85000 states. Time since last report: 0.04s, Total elapsed time: 3.97s.
# Searched 86000 states. Time since last report: 0.04s, Total elapsed time: 4.01s.
# Searched 87000 states. Time since last report: 0.11s, Total elapsed time: 4.12s.
# Searched 88000 states. Time since last report: 0.04s, Total elapsed time: 4.17s.
# Searched 89000 states. Time since last report: 0.05s, Total elapsed time: 4.21s.
# Searched 90000 states. Time since last report: 0.05s, Total elapsed time: 4.26s.
# Searched 91000 states. Time since last report: 0.04s, Total elapsed time: 4.30s.
# Searched 92000 states. Time since last report: 0.05s, Total elapsed time: 4.34s.
# Searched 93000 states. Time since last report: 0.04s, Total elapsed time: 4.38s.
# Searched 94000 states. Time since last report: 0.05s, Total elapsed time: 4.43s.
# Searched 95000 states. Time since last report: 0.05s, Total elapsed time: 4.48s.
# Searched 96000 states. Time since last report: 0.14s, Total elapsed time: 4.62s.
# Searched 97000 states. Time since last report: 0.03s, Total elapsed time: 4.65s.
# Searched 98000 states. Time since last report: 0.05s, Total elapsed time: 4.70s.
# Searched 99000 states. Time since last report: 0.03s, Total elapsed time: 4.73s.
# Searched 100000 states. Time since last report: 0.05s, Total elapsed time: 4.78s.
# Searched 101000 states. Time since last report: 0.06s, Total elapsed time: 4.83s.
# Searched 102000 states. Time since last report: 0.03s, Total elapsed time: 4.87s.
# Searched 103000 states. Time since last report: 0.04s, Total elapsed time: 4.91s.
# Searched 104000 states. Time since last report: 0.04s, Total elapsed time: 4.95s.
# Searched 105000 states. Time since last report: 0.19s, Total elapsed time: 5.13s.
# Searched 106000 states. Time since last report: 0.07s, Total elapsed time: 5.20s.
# Searched 107000 states. Time since last report: 0.03s, Total elapsed time: 5.23s.
# Searched 108000 states. Time since last report: 0.04s, Total elapsed time: 5.27s.
# Searched 109000 states. Time since last report: 0.03s, Total elapsed time: 5.31s.
# Searched 110000 states. Time since last report: 0.05s, Total elapsed time: 5.36s.
# Searched 111000 states. Time since last report: 0.05s, Total elapsed time: 5.41s.
# Searched 112000 states. Time since last report: 0.04s, Total elapsed time: 5.44s.
# Searched 113000 states. Time since last report: 0.05s, Total elapsed time: 5.49s.
# Searched 114000 states. Time since last report: 0.13s, Total elapsed time: 5.62s.
# Searched 115000 states. Time since last report: 0.06s, Total elapsed time: 5.68s.
# Searched 116000 states. Time since last report: 0.04s, Total elapsed time: 5.73s.
# Searched 117000 states. Time since last report: 0.05s, Total elapsed time: 5.77s.
# Searched 118000 states. Time since last report: 0.06s, Total elapsed time: 5.83s.
# Searched 119000 states. Time since last report: 0.02s, Total elapsed time: 5.85s.
# Searched 120000 states. Time since last report: 0.04s, Total elapsed time: 5.89s.
# Searched 121000 states. Time since last report: 0.05s, Total elapsed time: 5.95s.
# Searched 122000 states. Time since last report: 0.04s, Total elapsed time: 5.98s.
# Searched 123000 states. Time since last report: 0.17s, Total elapsed time: 6.15s.
# Searched 124000 states. Time since last report: 0.03s, Total elapsed time: 6.18s.
# Searched 125000 states. Time since last report: 0.04s, Total elapsed time: 6.23s.
# Searched 126000 states. Time since last report: 0.05s, Total elapsed time: 6.28s.
# Searched 127000 states. Time since last report: 0.05s, Total elapsed time: 6.32s.
# Searched 128000 states. Time since last report: 0.06s, Total elapsed time: 6.39s.
# Searched 129000 states. Time since last report: 0.04s, Total elapsed time: 6.43s.
# Searched 130000 states. Time since last report: 0.04s, Total elapsed time: 6.47s.
# Searched 131000 states. Time since last report: 0.04s, Total elapsed time: 6.51s.
# Searched 132000 states. Time since last report: 0.19s, Total elapsed time: 6.70s.
# Searched 133000 states. Time since last report: 0.08s, Total elapsed time: 6.78s.
# Searched 134000 states. Time since last report: 0.05s, Total elapsed time: 6.82s.
# Searched 135000 states. Time since last report: 0.05s, Total elapsed time: 6.87s.
# Searched 136000 states. Time since last report: 0.05s, Total elapsed time: 6.92s.
# Searched 137000 states. Time since last report: 0.04s, Total elapsed time: 6.96s.
# Searched 138000 states. Time since last report: 0.04s, Total elapsed time: 6.99s.
# Searched 139000 states. Time since last report: 0.05s, Total elapsed time: 7.05s.
# Searched 140000 states. Time since last report: 0.04s, Total elapsed time: 7.09s.
# Searched 141000 states. Time since last report: 0.17s, Total elapsed time: 7.26s.
# Searched 142000 states. Time since last report: 0.05s, Total elapsed time: 7.30s.
# Searched 143000 states. Time since last report: 0.04s, Total elapsed time: 7.34s.
# Searched 144000 states. Time since last report: 0.04s, Total elapsed time: 7.38s.
# Searched 145000 states. Time since last report: 0.04s, Total elapsed time: 7.42s.
# Searched 146000 states. Time since last report: 0.05s, Total elapsed time: 7.47s.
# Searched 147000 states. Time since last report: 0.05s, Total elapsed time: 7.53s.
# Searched 148000 states. Time since last report: 0.04s, Total elapsed time: 7.56s.
# Searched 149000 states. Time since last report: 0.05s, Total elapsed time: 7.61s.
# Searched 150000 states. Time since last report: 0.16s, Total elapsed time: 7.77s.
# Searched 151000 states. Time since last report: 0.03s, Total elapsed time: 7.79s.
# Searched 152000 states. Time since last report: 0.08s, Total elapsed time: 7.87s.
# Searched 153000 states. Time since last report: 0.04s, Total elapsed time: 7.92s.
# Searched 154000 states. Time since last report: 0.04s, Total elapsed time: 7.95s.
# Searched 155000 states. Time since last report: 0.03s, Total elapsed time: 7.99s.
# Searched 156000 states. Time since last report: 0.05s, Total elapsed time: 8.04s.
# Searched 157000 states. Time since last report: 0.04s, Total elapsed time: 8.08s.
# Searched 158000 states. Time since last report: 0.06s, Total elapsed time: 8.14s.
# Searched 159000 states. Time since last report: 0.18s, Total elapsed time: 8.32s.
# Searched 160000 states. Time since last report: 0.04s, Total elapsed time: 8.36s.
# Searched 161000 states. Time since last report: 0.06s, Total elapsed time: 8.42s.
# Searched 162000 states. Time since last report: 0.04s, Total elapsed time: 8.47s.
# Searched 163000 states. Time since last report: 0.04s, Total elapsed time: 8.51s.
# Searched 164000 states. Time since last report: 0.04s, Total elapsed time: 8.55s.
# Searched 165000 states. Time since last report: 0.05s, Total elapsed time: 8.60s.
# Searched 166000 states. Time since last report: 0.04s, Total elapsed time: 8.64s.
# Searched 167000 states. Time since last report: 0.06s, Total elapsed time: 8.70s.
# Searched 168000 states. Time since last report: 0.04s, Total elapsed time: 8.74s.
# Searched 169000 states. Time since last report: 0.19s, Total elapsed time: 8.92s.
# Searched 170000 states. Time since last report: 0.05s, Total elapsed time: 8.97s.
# Searched 171000 states. Time since last report: 0.04s, Total elapsed time: 9.01s.
# Searched 172000 states. Time since last report: 0.05s, Total elapsed time: 9.06s.
# Searched 173000 states. Time since last report: 0.06s, Total elapsed time: 9.12s.
# Searched 174000 states. Time since last report: 0.05s, Total elapsed time: 9.17s.
# Searched 175000 states. Time since last report: 0.05s, Total elapsed time: 9.21s.
# Searched 176000 states. Time since last report: 0.04s, Total elapsed time: 9.25s.
# Searched 177000 states. Time since last report: 0.04s, Total elapsed time: 9.29s.
# Searched 178000 states. Time since last report: 0.18s, Total elapsed time: 9.46s.
# Searched 179000 states. Time since last report: 0.05s, Total elapsed time: 9.51s.
# Searched 180000 states. Time since last report: 0.05s, Total elapsed time: 9.57s.
# Searched 181000 states. Time since last report: 0.06s, Total elapsed time: 9.63s.
# Searched 182000 states. Time since last report: 0.03s, Total elapsed time: 9.66s.
# Searched 183000 states. Time since last report: 0.05s, Total elapsed time: 9.71s.
# Searched 184000 states. Time since last report: 0.04s, Total elapsed time: 9.75s.
# Searched 185000 states. Time since last report: 0.04s, Total elapsed time: 9.79s.
# Searched 186000 states. Time since last report: 0.19s, Total elapsed time: 9.97s.
# Searched 187000 states. Time since last report: 0.06s, Total elapsed time: 10.04s.
# Searched 188000 states. Time since last report: 0.05s, Total elapsed time: 10.09s.
# Searched 189000 states. Time since last report: 0.06s, Total elapsed time: 10.15s.
# Searched 190000 states. Time since last report: 0.04s, Total elapsed time: 10.19s.
# Searched 191000 states. Time since last report: 0.04s, Total elapsed time: 10.23s.
# Searched 192000 states. Time since last report: 0.05s, Total elapsed time: 10.27s.
# Searched 193000 states. Time since last report: 0.04s, Total elapsed time: 10.31s.
# Searched 194000 states. Time since last report: 0.04s, Total elapsed time: 10.35s.
# Searched 195000 states. Time since last report: 0.22s, Total elapsed time: 10.57s.
# Searched 196000 states. Time since last report: 0.05s, Total elapsed time: 10.62s.
# Searched 197000 states. Time since last report: 0.09s, Total elapsed time: 10.71s.
# Searched 198000 states. Time since last report: 0.06s, Total elapsed time: 10.77s.
# Searched 199000 states. Time since last report: 0.04s, Total elapsed time: 10.81s.
# Searched 200000 states. Time since last report: 0.02s, Total elapsed time: 10.83s.
# Searched 201000 states. Time since last report: 0.05s, Total elapsed time: 10.87s.
# Searched 202000 states. Time since last report: 0.04s, Total elapsed time: 10.92s.
# Searched 203000 states. Time since last report: 0.05s, Total elapsed time: 10.96s.
# Searched 204000 states. Time since last report: 0.08s, Total elapsed time: 11.04s.
# Searched 205000 states. Time since last report: 0.22s, Total elapsed time: 11.26s.
# Searched 206000 states. Time since last report: 0.05s, Total elapsed time: 11.31s.
# Searched 207000 states. Time since last report: 0.04s, Total elapsed time: 11.35s.
# Searched 208000 states. Time since last report: 0.04s, Total elapsed time: 11.40s.
# Searched 209000 states. Time since last report: 0.03s, Total elapsed time: 11.43s.
# Searched 210000 states. Time since last report: 0.04s, Total elapsed time: 11.47s.
# Searched 211000 states. Time since last report: 0.05s, Total elapsed time: 11.52s.
# Searched 212000 states. Time since last report: 0.04s, Total elapsed time: 11.56s.
# Searched 213000 states. Time since last report: 0.07s, Total elapsed time: 11.63s.
# Searched 214000 states. Time since last report: 0.22s, Total elapsed time: 11.85s.
# Searched 215000 states. Time since last report: 0.06s, Total elapsed time: 11.90s.
# Searched 216000 states. Time since last report: 0.03s, Total elapsed time: 11.94s.
# Searched 217000 states. Time since last report: 0.04s, Total elapsed time: 11.98s.
# Searched 218000 states. Time since last report: 0.04s, Total elapsed time: 12.02s.
# Searched 219000 states. Time since last report: 0.06s, Total elapsed time: 12.08s.
# Searched 220000 states. Time since last report: 0.04s, Total elapsed time: 12.12s.
# Searched 221000 states. Time since last report: 0.06s, Total elapsed time: 12.18s.
# Searched 222000 states. Time since last report: 0.05s, Total elapsed time: 12.24s.
# Searched 223000 states. Time since last report: 0.26s, Total elapsed time: 12.49s.
# Searched 224000 states. Time since last report: 0.07s, Total elapsed time: 12.56s.
# Searched 225000 states. Time since last report: 0.04s, Total elapsed time: 12.60s.
# Searched 226000 states. Time since last report: 0.04s, Total elapsed time: 12.64s.
# Searched 227000 states. Time since last report: 0.04s, Total elapsed time: 12.68s.
# Searched 228000 states. Time since last report: 0.05s, Total elapsed time: 12.72s.
# Searched 229000 states. Time since last report: 0.06s, Total elapsed time: 12.79s.
# Searched 230000 states. Time since last report: 0.05s, Total elapsed time: 12.84s.
# Searched 231000 states. Time since last report: 0.24s, Total elapsed time: 13.08s.
# Searched 232000 states. Time since last report: 0.06s, Total elapsed time: 13.14s.
# Searched 233000 states. Time since last report: 0.03s, Total elapsed time: 13.17s.
# Searched 234000 states. Time since last report: 0.04s, Total elapsed time: 13.21s.
# Searched 235000 states. Time since last report: 0.05s, Total elapsed time: 13.26s.
# Searched 236000 states. Time since last report: 0.04s, Total elapsed time: 13.30s.
# Searched 237000 states. Time since last report: 0.06s, Total elapsed time: 13.37s.
# Searched 238000 states. Time since last report: 0.06s, Total elapsed time: 13.43s.
# Searched 239000 states. Time since last report: 0.06s, Total elapsed time: 13.49s.
# Searched 240000 states. Time since last report: 0.23s, Total elapsed time: 13.72s.
# Searched 241000 states. Time since last report: 0.06s, Total elapsed time: 13.77s.
# Searched 242000 states. Time since last report: 0.03s, Total elapsed time: 13.80s.
# Searched 243000 states. Time since last report: 0.05s, Total elapsed time: 13.84s.
# Searched 244000 states. Time since last report: 0.05s, Total elapsed time: 13.89s.
# Searched 245000 states. Time since last report: 0.03s, Total elapsed time: 13.93s.
# Searched 246000 states. Time since last report: 0.05s, Total elapsed time: 13.97s.
# Searched 247000 states. Time since last report: 0.06s, Total elapsed time: 14.03s.
# Searched 248000 states. Time since last report: 0.04s, Total elapsed time: 14.08s.
# Searched 249000 states. Time since last report: 0.26s, Total elapsed time: 14.34s.
# Searched 250000 states. Time since last report: 0.05s, Total elapsed time: 14.39s.
# Searched 251000 states. Time since last report: 0.05s, Total elapsed time: 14.44s.
# Searched 252000 states. Time since last report: 0.04s, Total elapsed time: 14.47s.
# Searched 253000 states. Time since last report: 0.04s, Total elapsed time: 14.52s.
# Searched 254000 states. Time since last report: 0.03s, Total elapsed time: 14.55s.
# Searched 255000 states. Time since last report: 0.07s, Total elapsed time: 14.62s.
# Searched 256000 states. Time since last report: 0.07s, Total elapsed time: 14.69s.
# Searched 257000 states. Time since last report: 0.08s, Total elapsed time: 14.77s.
# Searched 258000 states. Time since last report: 0.07s, Total elapsed time: 14.84s.
# Searched 259000 states. Time since last report: 0.26s, Total elapsed time: 15.10s.
# Searched 260000 states. Time since last report: 0.06s, Total elapsed time: 15.15s.
# Searched 261000 states. Time since last report: 0.04s, Total elapsed time: 15.20s.
# Searched 262000 states. Time since last report: 0.04s, Total elapsed time: 15.24s.
# Searched 263000 states. Time since last report: 0.03s, Total elapsed time: 15.27s.
# Searched 264000 states. Time since last report: 0.06s, Total elapsed time: 15.32s.
# Searched 265000 states. Time since last report: 0.07s, Total elapsed time: 15.39s.
# Searched 266000 states. Time since last report: 0.06s, Total elapsed time: 15.45s.
# Searched 267000 states. Time since last report: 0.05s, Total elapsed time: 15.50s.
# Searched 268000 states. Time since last report: 0.26s, Total elapsed time: 15.75s.
# Searched 269000 states. Time since last report: 0.06s, Total elapsed time: 15.81s.
# Searched 270000 states. Time since last report: 0.07s, Total elapsed time: 15.88s.
# Searched 271000 states. Time since last report: 0.05s, Total elapsed time: 15.92s.
# Searched 272000 states. Time since last report: 0.05s, Total elapsed time: 15.97s.
# Searched 273000 states. Time since last report: 0.04s, Total elapsed time: 16.01s.
# Searched 274000 states. Time since last report: 0.03s, Total elapsed time: 16.04s.
# Searched 275000 states. Time since last report: 0.06s, Total elapsed time: 16.11s.
# Searched 276000 states. Time since last report: 0.05s, Total elapsed time: 16.15s.
# Searched 277000 states. Time since last report: 0.26s, Total elapsed time: 16.42s.
# Searched 278000 states. Time since last report: 0.06s, Total elapsed time: 16.47s.
# Searched 279000 states. Time since last report: 0.02s, Total elapsed time: 16.50s.
# Searched 280000 states. Time since last report: 0.07s, Total elapsed time: 16.57s.
# Searched 281000 states. Time since last report: 0.05s, Total elapsed time: 16.62s.
# Searched 282000 states. Time since last report: 0.05s, Total elapsed time: 16.67s.
# Searched 283000 states. Time since last report: 0.04s, Total elapsed time: 16.71s.
# Searched 284000 states. Time since last report: 0.03s, Total elapsed time: 16.74s.
# Searched 285000 states. Time since last report: 0.06s, Total elapsed time: 16.81s.
# Searched 286000 states. Time since last report: 0.07s, Total elapsed time: 16.88s.
# Searched 287000 states. Time since last report: 0.29s, Total elapsed time: 17.17s.
# Searched 288000 states. Time since last report: 0.07s, Total elapsed time: 17.24s.
# Searched 289000 states. Time since last report: 0.07s, Total elapsed time: 17.31s.
# Searched 290000 states. Time since last report: 0.06s, Total elapsed time: 17.36s.
# Searched 291000 states. Time since last report: 0.05s, Total elapsed time: 17.41s.
# Searched 292000 states. Time since last report: 0.06s, Total elapsed time: 17.47s.
# Searched 293000 states. Time since last report: 0.06s, Total elapsed time: 17.53s.
# Searched 294000 states. Time since last report: 0.04s, Total elapsed time: 17.57s.
# Searched 295000 states. Time since last report: 0.06s, Total elapsed time: 17.63s.
# Searched 296000 states. Time since last report: 0.27s, Total elapsed time: 17.90s.
# Searched 297000 states. Time since last report: 0.17s, Total elapsed time: 18.06s.
# Searched 298000 states. Time since last report: 0.07s, Total elapsed time: 18.13s.
# Searched 299000 states. Time since last report: 0.09s, Total elapsed time: 18.22s.
# Searched 300000 states. Time since last report: 0.17s, Total elapsed time: 18.40s.
# Searched 301000 states. Time since last report: 0.12s, Total elapsed time: 18.51s.
# Searched 302000 states. Time since last report: 0.06s, Total elapsed time: 18.58s.
# Searched 303000 states. Time since last report: 0.06s, Total elapsed time: 18.64s.
# Searched 304000 states. Time since last report: 0.06s, Total elapsed time: 18.70s.
# Searched 305000 states. Time since last report: 0.29s, Total elapsed time: 18.99s.
# Searched 306000 states. Time since last report: 0.08s, Total elapsed time: 19.08s.
# Searched 307000 states. Time since last report: 0.09s, Total elapsed time: 19.17s.
# Searched 308000 states. Time since last report: 0.06s, Total elapsed time: 19.23s.
# Searched 309000 states. Time since last report: 0.06s, Total elapsed time: 19.29s.
# Searched 310000 states. Time since last report: 0.08s, Total elapsed time: 19.37s.
# Searched 311000 states. Time since last report: 0.07s, Total elapsed time: 19.44s.
# Searched 312000 states. Time since last report: 0.05s, Total elapsed time: 19.49s.
# Searched 313000 states. Time since last report: 0.04s, Total elapsed time: 19.53s.
# Searched 314000 states. Time since last report: 0.04s, Total elapsed time: 19.57s.
# Searched 315000 states. Time since last report: 0.26s, Total elapsed time: 19.84s.
# Searched 316000 states. Time since last report: 0.06s, Total elapsed time: 19.90s.
# Searched 317000 states. Time since last report: 0.06s, Total elapsed time: 19.96s.
# Searched 318000 states. Time since last report: 0.08s, Total elapsed time: 20.04s.
# Searched 319000 states. Time since last report: 0.08s, Total elapsed time: 20.12s.
# Searched 320000 states. Time since last report: 0.07s, Total elapsed time: 20.18s.
# Searched 321000 states. Time since last report: 0.07s, Total elapsed time: 20.26s.
# Searched 322000 states. Time since last report: 0.07s, Total elapsed time: 20.32s.
# Searched 323000 states. Time since last report: 0.06s, Total elapsed time: 20.38s.
# Searched 324000 states. Time since last report: 0.26s, Total elapsed time: 20.64s.
# Searched 325000 states. Time since last report: 0.04s, Total elapsed time: 20.68s.
# Searched 326000 states. Time since last report: 0.05s, Total elapsed time: 20.73s.
# Searched 327000 states. Time since last report: 0.03s, Total elapsed time: 20.76s.
# Searched 328000 states. Time since last report: 0.05s, Total elapsed time: 20.81s.
# Searched 329000 states. Time since last report: 0.06s, Total elapsed time: 20.87s.
# Searched 330000 states. Time since last report: 0.06s, Total elapsed time: 20.93s.
# Searched 331000 states. Time since last report: 0.08s, Total elapsed time: 21.01s.
# Searched 332000 states. Time since last report: 0.06s, Total elapsed time: 21.07s.
# Searched 333000 states. Time since last report: 0.06s, Total elapsed time: 21.13s.
# Searched 334000 states. Time since last report: 0.28s, Total elapsed time: 21.41s.
# Searched 335000 states. Time since last report: 0.05s, Total elapsed time: 21.46s.
# Searched 336000 states. Time since last report: 0.04s, Total elapsed time: 21.50s.
# Searched 337000 states. Time since last report: 0.05s, Total elapsed time: 21.55s.
# Searched 338000 states. Time since last report: 0.05s, Total elapsed time: 21.60s.
# Searched 339000 states. Time since last report: 0.07s, Total elapsed time: 21.66s.
# Searched 340000 states. Time since last report: 0.07s, Total elapsed time: 21.73s.
# Searched 341000 states. Time since last report: 0.07s, Total elapsed time: 21.80s.
# Searched 342000 states. Time since last report: 0.10s, Total elapsed time: 21.91s.
# Searched 343000 states. Time since last report: 0.09s, Total elapsed time: 22.00s.
# Searched 344000 states. Time since last report: 0.28s, Total elapsed time: 22.28s.
# Searched 345000 states. Time since last report: 0.06s, Total elapsed time: 22.33s.
# Searched 346000 states. Time since last report: 0.05s, Total elapsed time: 22.39s.
# Searched 347000 states. Time since last report: 0.05s, Total elapsed time: 22.44s.
# Searched 348000 states. Time since last report: 0.04s, Total elapsed time: 22.47s.
# Searched 349000 states. Time since last report: 0.04s, Total elapsed time: 22.51s.
# Searched 350000 states. Time since last report: 0.05s, Total elapsed time: 22.56s.
# Searched 351000 states. Time since last report: 0.07s, Total elapsed time: 22.63s.
# Searched 352000 states. Time since last report: 0.07s, Total elapsed time: 22.70s.
# Searched 353000 states. Time since last report: 0.30s, Total elapsed time: 23.01s.
# Searched 354000 states. Time since last report: 0.10s, Total elapsed time: 23.10s.
# Searched 355000 states. Time since last report: 0.11s, Total elapsed time: 23.21s.
# Searched 356000 states. Time since last report: 0.14s, Total elapsed time: 23.35s.
# Searched 357000 states. Time since last report: 0.09s, Total elapsed time: 23.44s.
# Searched 358000 states. Time since last report: 0.09s, Total elapsed time: 23.52s.
# Searched 359000 states. Time since last report: 0.06s, Total elapsed time: 23.59s.
# Searched 360000 states. Time since last report: 0.06s, Total elapsed time: 23.65s.
# Searched 361000 states. Time since last report: 0.05s, Total elapsed time: 23.70s.
# Searched 362000 states. Time since last report: 0.07s, Total elapsed time: 23.77s.
# Searched 363000 states. Time since last report: 0.48s, Total elapsed time: 24.25s.
# Searched 364000 states. Time since last report: 0.07s, Total elapsed time: 24.32s.
# Searched 365000 states. Time since last report: 0.07s, Total elapsed time: 24.39s.
# Searched 366000 states. Time since last report: 0.06s, Total elapsed time: 24.45s.
# Searched 367000 states. Time since last report: 0.07s, Total elapsed time: 24.51s.
# Searched 368000 states. Time since last report: 0.07s, Total elapsed time: 24.58s.
# Searched 369000 states. Time since last report: 0.05s, Total elapsed time: 24.63s.
# Searched 370000 states. Time since last report: 0.06s, Total elapsed time: 24.69s.
# Searched 371000 states. Time since last report: 0.06s, Total elapsed time: 24.75s.
# Searched 372000 states. Time since last report: 0.25s, Total elapsed time: 25.00s.
# Searched 373000 states. Time since last report: 0.03s, Total elapsed time: 25.04s.
# Searched 374000 states. Time since last report: 0.06s, Total elapsed time: 25.09s.
# Searched 375000 states. Time since last report: 0.08s, Total elapsed time: 25.17s.
# Searched 376000 states. Time since last report: 0.06s, Total elapsed time: 25.23s.
# Searched 377000 states. Time since last report: 0.06s, Total elapsed time: 25.29s.
# Searched 378000 states. Time since last report: 0.06s, Total elapsed time: 25.35s.
# Searched 379000 states. Time since last report: 0.05s, Total elapsed time: 25.40s.
# Searched 380000 states. Time since last report: 0.04s, Total elapsed time: 25.44s.
# Searched 381000 states. Time since last report: 0.06s, Total elapsed time: 25.50s.
# Searched 382000 states. Time since last report: 0.28s, Total elapsed time: 25.79s.
# Searched 383000 states. Time since last report: 0.05s, Total elapsed time: 25.84s.
# Searched 384000 states. Time since last report: 0.03s, Total elapsed time: 25.87s.
# Searched 385000 states. Time since last report: 0.05s, Total elapsed time: 25.92s.
# Searched 386000 states. Time since last report: 0.06s, Total elapsed time: 25.98s.
# Searched 387000 states. Time since last report: 0.07s, Total elapsed time: 26.05s.
# Searched 388000 states. Time since last report: 0.08s, Total elapsed time: 26.13s.
# Searched 389000 states. Time since last report: 0.08s, Total elapsed time: 26.21s.
# Searched 390000 states. Time since last report: 0.07s, Total elapsed time: 26.28s.
# Searched 391000 states. Time since last report: 0.30s, Total elapsed time: 26.58s.
# Searched 392000 states. Time since last report: 0.06s, Total elapsed time: 26.64s.
# Searched 393000 states. Time since last report: 0.04s, Total elapsed time: 26.68s.
# Searched 394000 states. Time since last report: 0.04s, Total elapsed time: 26.73s.
# Searched 395000 states. Time since last report: 0.04s, Total elapsed time: 26.77s.
# Searched 396000 states. Time since last report: 0.05s, Total elapsed time: 26.82s.
# Searched 397000 states. Time since last report: 0.04s, Total elapsed time: 26.85s.
# Searched 398000 states. Time since last report: 0.05s, Total elapsed time: 26.91s.
# Searched 399000 states. Time since last report: 0.07s, Total elapsed time: 26.97s.
# Searched 400000 states. Time since last report: 0.07s, Total elapsed time: 27.05s.
# Searched 401000 states. Time since last report: 0.28s, Total elapsed time: 27.33s.
# Searched 402000 states. Time since last report: 0.09s, Total elapsed time: 27.42s.
# Searched 403000 states. Time since last report: 0.07s, Total elapsed time: 27.48s.
# Searched 404000 states. Time since last report: 0.09s, Total elapsed time: 27.57s.
# Searched 405000 states. Time since last report: 0.11s, Total elapsed time: 27.69s.
# Searched 406000 states. Time since last report: 0.06s, Total elapsed time: 27.75s.
# Searched 407000 states. Time since last report: 0.05s, Total elapsed time: 27.80s.
# Searched 408000 states. Time since last report: 0.04s, Total elapsed time: 27.84s.
# Searched 409000 states. Time since last report: 0.03s, Total elapsed time: 27.87s.
# Searched 410000 states. Time since last report: 0.31s, Total elapsed time: 28.18s.
# Searched 411000 states. Time since last report: 0.07s, Total elapsed time: 28.26s.
# Searched 412000 states. Time since last report: 0.06s, Total elapsed time: 28.32s.
# Searched 413000 states. Time since last report: 0.10s, Total elapsed time: 28.42s.
# Searched 414000 states. Time since last report: 0.06s, Total elapsed time: 28.48s.
# Searched 415000 states. Time since last report: 0.06s, Total elapsed time: 28.54s.
# Searched 416000 states. Time since last report: 0.05s, Total elapsed time: 28.59s.
# Searched 417000 states. Time since last report: 0.06s, Total elapsed time: 28.65s.
# Searched 418000 states. Time since last report: 0.05s, Total elapsed time: 28.70s.
# Searched 419000 states. Time since last report: 0.04s, Total elapsed time: 28.74s.
# Searched 420000 states. Time since last report: 0.29s, Total elapsed time: 29.04s.
# Searched 421000 states. Time since last report: 0.04s, Total elapsed time: 29.07s.
# Searched 422000 states. Time since last report: 0.05s, Total elapsed time: 29.13s.
# Searched 423000 states. Time since last report: 0.06s, Total elapsed time: 29.19s.
# Searched 424000 states. Time since last report: 0.06s, Total elapsed time: 29.25s.
# Searched 425000 states. Time since last report: 0.06s, Total elapsed time: 29.30s.
# Searched 426000 states. Time since last report: 0.07s, Total elapsed time: 29.37s.
# Searched 427000 states. Time since last report: 0.09s, Total elapsed time: 29.46s.
# Searched 428000 states. Time since last report: 0.06s, Total elapsed time: 29.52s.
# Searched 429000 states. Time since last report: 0.05s, Total elapsed time: 29.57s.
# Searched 430000 states. Time since last report: 0.35s, Total elapsed time: 29.92s.
# Searched 431000 states. Time since last report: 0.05s, Total elapsed time: 29.97s.
# Searched 432000 states. Time since last report: 0.06s, Total elapsed time: 30.03s.
# Searched 433000 states. Time since last report: 0.05s, Total elapsed time: 30.08s.
# Searched 434000 states. Time since last report: 0.05s, Total elapsed time: 30.13s.
# Searched 435000 states. Time since last report: 0.06s, Total elapsed time: 30.19s.
# Searched 436000 states. Time since last report: 0.07s, Total elapsed time: 30.26s.
# Searched 437000 states. Time since last report: 0.06s, Total elapsed time: 30.32s.
# Searched 438000 states. Time since last report: 0.08s, Total elapsed time: 30.39s.
# Searched 439000 states. Time since last report: 0.05s, Total elapsed time: 30.44s.
# Searched 440000 states. Time since last report: 0.34s, Total elapsed time: 30.79s.
# Searched 441000 states. Time since last report: 0.05s, Total elapsed time: 30.84s.
# Searched 442000 states. Time since last report: 0.06s, Total elapsed time: 30.90s.
# Searched 443000 states. Time since last report: 0.05s, Total elapsed time: 30.94s.
# Searched 444000 states. Time since last report: 0.05s, Total elapsed time: 30.99s.
# Searched 445000 states. Time since last report: 0.05s, Total elapsed time: 31.05s.
# Searched 446000 states. Time since last report: 0.10s, Total elapsed time: 31.14s.
# Searched 447000 states. Time since last report: 0.05s, Total elapsed time: 31.20s.
# Searched 448000 states. Time since last report: 0.06s, Total elapsed time: 31.26s.
# Searched 449000 states. Time since last report: 0.36s, Total elapsed time: 31.61s.
# Searched 450000 states. Time since last report: 0.11s, Total elapsed time: 31.72s.
# Searched 451000 states. Time since last report: 0.10s, Total elapsed time: 31.82s.
# Searched 452000 states. Time since last report: 0.08s, Total elapsed time: 31.90s.
# Searched 453000 states. Time since last report: 0.09s, Total elapsed time: 31.99s.
# Searched 454000 states. Time since last report: 0.06s, Total elapsed time: 32.05s.
# Searched 455000 states. Time since last report: 0.06s, Total elapsed time: 32.12s.
# Searched 456000 states. Time since last report: 0.07s, Total elapsed time: 32.19s.
# Searched 457000 states. Time since last report: 0.06s, Total elapsed time: 32.25s.
# Searched 458000 states. Time since last report: 0.08s, Total elapsed time: 32.32s.
# Searched 459000 states. Time since last report: 0.31s, Total elapsed time: 32.64s.
# Searched 460000 states. Time since last report: 0.07s, Total elapsed time: 32.71s.
# Searched 461000 states. Time since last report: 0.06s, Total elapsed time: 32.77s.
# Searched 462000 states. Time since last report: 0.07s, Total elapsed time: 32.84s.
# Searched 463000 states. Time since last report: 0.08s, Total elapsed time: 32.91s.
# Searched 464000 states. Time since last report: 0.07s, Total elapsed time: 32.98s.
# Searched 465000 states. Time since last report: 0.07s, Total elapsed time: 33.05s.
# Searched 466000 states. Time since last report: 0.05s, Total elapsed time: 33.11s.
# Searched 467000 states. Time since last report: 0.06s, Total elapsed time: 33.17s.
# Searched 468000 states. Time since last report: 0.07s, Total elapsed time: 33.23s.
# Searched 469000 states. Time since last report: 0.32s, Total elapsed time: 33.55s.
# Searched 470000 states. Time since last report: 0.04s, Total elapsed time: 33.59s.
# Searched 471000 states. Time since last report: 0.04s, Total elapsed time: 33.64s.
# Searched 472000 states. Time since last report: 0.03s, Total elapsed time: 33.67s.
# Searched 473000 states. Time since last report: 0.06s, Total elapsed time: 33.72s.
# Searched 474000 states. Time since last report: 0.06s, Total elapsed time: 33.78s.
# Searched 475000 states. Time since last report: 0.06s, Total elapsed time: 33.84s.
# Searched 476000 states. Time since last report: 0.07s, Total elapsed time: 33.91s.
# Searched 477000 states. Time since last report: 0.08s, Total elapsed time: 33.99s.
# Searched 478000 states. Time since last report: 0.14s, Total elapsed time: 34.13s.
# Searched 479000 states. Time since last report: 0.34s, Total elapsed time: 34.47s.
# Searched 480000 states. Time since last report: 0.06s, Total elapsed time: 34.53s.
# Searched 481000 states. Time since last report: 0.05s, Total elapsed time: 34.58s.
# Searched 482000 states. Time since last report: 0.04s, Total elapsed time: 34.62s.
# Searched 483000 states. Time since last report: 0.06s, Total elapsed time: 34.68s.
# Searched 484000 states. Time since last report: 0.05s, Total elapsed time: 34.73s.
# Searched 485000 states. Time since last report: 0.04s, Total elapsed time: 34.77s.
# Searched 486000 states. Time since last report: 0.05s, Total elapsed time: 34.82s.
# Searched 487000 states. Time since last report: 0.06s, Total elapsed time: 34.88s.
# Searched 488000 states. Time since last report: 0.33s, Total elapsed time: 35.22s.
# Searched 489000 states. Time since last report: 0.11s, Total elapsed time: 35.32s.
# Searched 490000 states. Time since last report: 0.09s, Total elapsed time: 35.42s.
# Searched 491000 states. Time since last report: 0.09s, Total elapsed time: 35.51s.
# Searched 492000 states. Time since last report: 0.05s, Total elapsed time: 35.56s.
# Searched 493000 states. Time since last report: 0.08s, Total elapsed time: 35.64s.
# Searched 494000 states. Time since last report: 0.06s, Total elapsed time: 35.70s.
# Searched 495000 states. Time since last report: 0.05s, Total elapsed time: 35.75s.
# Searched 496000 states. Time since last report: 0.06s, Total elapsed time: 35.81s.
# Searched 497000 states. Time since last report: 0.10s, Total elapsed time: 35.91s.
# Searched 498000 states. Time since last report: 0.34s, Total elapsed time: 36.25s.
# Searched 499000 states. Time since last report: 0.05s, Total elapsed time: 36.30s.
# Searched 500000 states. Time since last report: 0.07s, Total elapsed time: 36.37s.
# Searched 501000 states. Time since last report: 0.06s, Total elapsed time: 36.42s.
# Searched 502000 states. Time since last report: 0.07s, Total elapsed time: 36.50s.
# Searched 503000 states. Time since last report: 0.07s, Total elapsed time: 36.57s.
# Searched 504000 states. Time since last report: 0.07s, Total elapsed time: 36.64s.
# Searched 505000 states. Time since last report: 0.06s, Total elapsed time: 36.70s.
# Searched 506000 states. Time since last report: 0.07s, Total elapsed time: 36.77s.
# Searched 507000 states. Time since last report: 0.06s, Total elapsed time: 36.82s.
# Searched 508000 states. Time since last report: 0.37s, Total elapsed time: 37.19s.
# Searched 509000 states. Time since last report: 0.06s, Total elapsed time: 37.26s.
# Searched 510000 states. Time since last report: 0.04s, Total elapsed time: 37.29s.
# Searched 511000 states. Time since last report: 0.04s, Total elapsed time: 37.34s.
# Searched 512000 states. Time since last report: 0.04s, Total elapsed time: 37.38s.
# Searched 513000 states. Time since last report: 0.06s, Total elapsed time: 37.43s.
# Searched 514000 states. Time since last report: 0.07s, Total elapsed time: 37.50s.
# Searched 515000 states. Time since last report: 0.09s, Total elapsed time: 37.59s.
# Searched 516000 states. Time since last report: 0.10s, Total elapsed time: 37.69s.
# Searched 517000 states. Time since last report: 0.38s, Total elapsed time: 38.07s.
# Searched 518000 states. Time since last report: 0.07s, Total elapsed time: 38.14s.
# Searched 519000 states. Time since last report: 0.07s, Total elapsed time: 38.21s.
# Searched 520000 states. Time since last report: 0.05s, Total elapsed time: 38.26s.
# Searched 521000 states. Time since last report: 0.06s, Total elapsed time: 38.32s.
# Searched 522000 states. Time since last report: 0.05s, Total elapsed time: 38.37s.
# Searched 523000 states. Time since last report: 0.06s, Total elapsed time: 38.43s.
# Searched 524000 states. Time since last report: 0.04s, Total elapsed time: 38.47s.
# Searched 525000 states. Time since last report: 0.03s, Total elapsed time: 38.51s.
# Searched 526000 states. Time since last report: 0.04s, Total elapsed time: 38.55s.
# Searched 527000 states. Time since last report: 0.33s, Total elapsed time: 38.87s.
# Searched 528000 states. Time since last report: 0.06s, Total elapsed time: 38.94s.
# Searched 529000 states. Time since last report: 0.06s, Total elapsed time: 39.00s.
# Searched 530000 states. Time since last report: 0.09s, Total elapsed time: 39.09s.
# Searched 531000 states. Time since last report: 0.08s, Total elapsed time: 39.18s.
# Searched 532000 states. Time since last report: 0.07s, Total elapsed time: 39.25s.
# Searched 533000 states. Time since last report: 0.08s, Total elapsed time: 39.32s.
# Searched 534000 states. Time since last report: 0.06s, Total elapsed time: 39.39s.
# Searched 535000 states. Time since last report: 0.06s, Total elapsed time: 39.45s.
# Searched 536000 states. Time since last report: 0.05s, Total elapsed time: 39.50s.
# Searched 537000 states. Time since last report: 0.36s, Total elapsed time: 39.86s.
# Searched 538000 states. Time since last report: 0.06s, Total elapsed time: 39.92s.
# Searched 539000 states. Time since last report: 0.09s, Total elapsed time: 40.01s.
# Searched 540000 states. Time since last report: 0.05s, Total elapsed time: 40.06s.
# Searched 541000 states. Time since last report: 0.07s, Total elapsed time: 40.13s.
# Searched 542000 states. Time since last report: 0.08s, Total elapsed time: 40.21s.
# Searched 543000 states. Time since last report: 0.07s, Total elapsed time: 40.28s.
# Searched 544000 states. Time since last report: 0.08s, Total elapsed time: 40.36s.
# Searched 545000 states. Time since last report: 0.07s, Total elapsed time: 40.43s.
# Searched 546000 states. Time since last report: 0.07s, Total elapsed time: 40.50s.
# Searched 547000 states. Time since last report: 0.37s, Total elapsed time: 40.87s.
# Searched 548000 states. Time since last report: 0.06s, Total elapsed time: 40.93s.
# Searched 549000 states. Time since last report: 0.07s, Total elapsed time: 41.00s.
# Searched 550000 states. Time since last report: 0.05s, Total elapsed time: 41.05s.
# Searched 551000 states. Time since last report: 0.04s, Total elapsed time: 41.10s.
# Searched 552000 states. Time since last report: 0.04s, Total elapsed time: 41.14s.
# Searched 553000 states. Time since last report: 0.06s, Total elapsed time: 41.20s.
# Searched 554000 states. Time since last report: 0.05s, Total elapsed time: 41.25s.
# Searched 555000 states. Time since last report: 0.06s, Total elapsed time: 41.31s.
# Searched 556000 states. Time since last report: 0.37s, Total elapsed time: 41.68s.
# Searched 557000 states. Time since last report: 0.11s, Total elapsed time: 41.79s.
# Searched 558000 states. Time since last report: 0.11s, Total elapsed time: 41.90s.
# Searched 559000 states. Time since last report: 0.07s, Total elapsed time: 41.97s.
# Searched 560000 states. Time since last report: 0.09s, Total elapsed time: 42.06s.
# Searched 561000 states. Time since last report: 0.07s, Total elapsed time: 42.13s.
# Searched 562000 states. Time since last report: 0.05s, Total elapsed time: 42.18s.
# Searched 563000 states. Time since last report: 0.09s, Total elapsed time: 42.28s.
# Searched 564000 states. Time since last report: 0.06s, Total elapsed time: 42.33s.
# Searched 565000 states. Time since last report: 0.04s, Total elapsed time: 42.37s.
# Searched 566000 states. Time since last report: 0.38s, Total elapsed time: 42.75s.
# Searched 567000 states. Time since last report: 0.04s, Total elapsed time: 42.79s.
# Searched 568000 states. Time since last report: 0.04s, Total elapsed time: 42.84s.
# Searched 569000 states. Time since last report: 0.06s, Total elapsed time: 42.90s.
# Searched 570000 states. Time since last report: 0.08s, Total elapsed time: 42.97s.
# Searched 571000 states. Time since last report: 0.13s, Total elapsed time: 43.10s.
# Searched 572000 states. Time since last report: 0.17s, Total elapsed time: 43.27s.
# Searched 573000 states. Time since last report: 0.09s, Total elapsed time: 43.36s.
# Searched 574000 states. Time since last report: 0.06s, Total elapsed time: 43.43s.
# Searched 575000 states. Time since last report: 0.07s, Total elapsed time: 43.50s.
# Searched 576000 states. Time since last report: 0.37s, Total elapsed time: 43.87s.
# Searched 577000 states. Time since last report: 0.06s, Total elapsed time: 43.93s.
# Searched 578000 states. Time since last report: 0.06s, Total elapsed time: 43.99s.
# Searched 579000 states. Time since last report: 0.05s, Total elapsed time: 44.04s.
# Searched 580000 states. Time since last report: 0.06s, Total elapsed time: 44.09s.
# Searched 581000 states. Time since last report: 0.07s, Total elapsed time: 44.16s.
# ...
# Searched 768000 states. Time since last report: 0.11s, Total elapsed time: 67.51s.
# Searched 769000 states. Time since last report: 0.09s, Total elapsed time: 67.60s.
# Searched 770000 states. Time since last report: 0.07s, Total elapsed time: 67.68s.
# Searched 771000 states. Time since last report: 0.06s, Total elapsed time: 67.73s.
# Searched 772000 states. Time since last report: 0.03s, Total elapsed time: 67.77s.
# Searched 773000 states. Time since last report: 0.09s, Total elapsed time: 67.86s.
# Searched 774000 states. Time since last report: 0.05s, Total elapsed time: 67.90s.
# Searched 775000 states. Time since last report: 0.05s, Total elapsed time: 67.96s.
# Searched 776000 states. Time since last report: 0.47s, Total elapsed time: 68.43s.
# Searched 777000 states. Time since last report: 0.06s, Total elapsed time: 68.49s.
# Searched 778000 states. Time since last report: 0.09s, Total elapsed time: 68.57s.
# Searched 779000 states. Time since last report: 0.08s, Total elapsed time: 68.66s.
# Searched 780000 states. Time since last report: 0.11s, Total elapsed time: 68.77s.
# Searched 781000 states. Time since last report: 0.09s, Total elapsed time: 68.85s.
# Searched 782000 states. Time since last report: 0.09s, Total elapsed time: 68.94s.
# Searched 783000 states. Time since last report: 0.05s, Total elapsed time: 68.99s.
# Searched 784000 states. Time since last report: 0.07s, Total elapsed time: 69.06s.
# Searched 785000 states. Time since last report: 0.11s, Total elapsed time: 69.18s.
# Searched 786000 states. Time since last report: 0.42s, Total elapsed time: 69.60s.
# Searched 787000 states. Time since last report: 0.07s, Total elapsed time: 69.67s.
# Searched 788000 states. Time since last report: 0.06s, Total elapsed time: 69.73s.
# Searched 789000 states. Time since last report: 0.06s, Total elapsed time: 69.79s.
# Searched 790000 states. Time since last report: 0.07s, Total elapsed time: 69.86s.
# Searched 791000 states. Time since last report: 0.06s, Total elapsed time: 69.92s.
# Searched 792000 states. Time since last report: 0.04s, Total elapsed time: 69.96s.
# Searched 793000 states. Time since last report: 0.05s, Total elapsed time: 70.01s.
# Searched 794000 states. Time since last report: 0.08s, Total elapsed time: 70.09s.
# Searched 795000 states. Time since last report: 0.10s, Total elapsed time: 70.18s.
# Searched 796000 states. Time since last report: 0.53s, Total elapsed time: 70.71s.
# Searched 797000 states. Time since last report: 0.09s, Total elapsed time: 70.80s.
# Searched 798000 states. Time since last report: 0.08s, Total elapsed time: 70.89s.
# Searched 799000 states. Time since last report: 0.06s, Total elapsed time: 70.95s.
# Searched 800000 states. Time since last report: 0.08s, Total elapsed time: 71.03s.
# Searched 801000 states. Time since last report: 0.08s, Total elapsed time: 71.10s.
# Searched 802000 states. Time since last report: 0.06s, Total elapsed time: 71.17s.
# Searched 803000 states. Time since last report: 0.06s, Total elapsed time: 71.23s.
# Searched 804000 states. Time since last report: 0.05s, Total elapsed time: 71.28s.
# Searched 805000 states. Time since last report: 0.05s, Total elapsed time: 71.34s.
# Searched 806000 states. Time since last report: 0.07s, Total elapsed time: 71.40s.
# Searched 807000 states. Time since last report: 0.49s, Total elapsed time: 71.89s.
# Searched 808000 states. Time since last report: 0.06s, Total elapsed time: 71.95s.
# Searched 809000 states. Time since last report: 0.07s, Total elapsed time: 72.02s.
# Searched 810000 states. Time since last report: 0.08s, Total elapsed time: 72.10s.
# Searched 811000 states. Time since last report: 0.10s, Total elapsed time: 72.20s.
# Searched 812000 states. Time since last report: 0.08s, Total elapsed time: 72.28s.
# Searched 813000 states. Time since last report: 0.10s, Total elapsed time: 72.38s.
# Searched 814000 states. Time since last report: 0.07s, Total elapsed time: 72.45s.
# Searched 815000 states. Time since last report: 0.09s, Total elapsed time: 72.54s.
# Searched 816000 states. Time since last report: 0.06s, Total elapsed time: 72.60s.
# Searched 817000 states. Time since last report: 0.49s, Total elapsed time: 73.09s.
# Searched 818000 states. Time since last report: 0.08s, Total elapsed time: 73.16s.
# Searched 819000 states. Time since last report: 0.10s, Total elapsed time: 73.27s.
# Searched 820000 states. Time since last report: 0.09s, Total elapsed time: 73.35s.
# Searched 821000 states. Time since last report: 0.07s, Total elapsed time: 73.42s.
# Searched 822000 states. Time since last report: 0.08s, Total elapsed time: 73.50s.
# Searched 823000 states. Time since last report: 0.06s, Total elapsed time: 73.56s.
# Searched 824000 states. Time since last report: 0.10s, Total elapsed time: 73.66s.
# Searched 825000 states. Time since last report: 0.07s, Total elapsed time: 73.73s.
# Searched 826000 states. Time since last report: 0.08s, Total elapsed time: 73.81s.
# Searched 827000 states. Time since last report: 0.09s, Total elapsed time: 73.90s.
# Searched 828000 states. Time since last report: 0.46s, Total elapsed time: 74.35s.
# Searched 829000 states. Time since last report: 0.08s, Total elapsed time: 74.43s.
# Searched 830000 states. Time since last report: 0.09s, Total elapsed time: 74.52s.
# Searched 831000 states. Time since last report: 0.08s, Total elapsed time: 74.60s.
# Searched 832000 states. Time since last report: 0.08s, Total elapsed time: 74.68s.
# Searched 833000 states. Time since last report: 0.17s, Total elapsed time: 74.85s.
# Searched 834000 states. Time since last report: 0.09s, Total elapsed time: 74.94s.
# Searched 835000 states. Time since last report: 0.06s, Total elapsed time: 75.00s.
# Searched 836000 states. Time since last report: 0.05s, Total elapsed time: 75.05s.
# Searched 837000 states. Time since last report: 0.05s, Total elapsed time: 75.10s.
# Searched 838000 states. Time since last report: 0.44s, Total elapsed time: 75.54s.
# Searched 839000 states. Time since last report: 0.10s, Total elapsed time: 75.64s.
# Searched 840000 states. Time since last report: 0.11s, Total elapsed time: 75.75s.
# Searched 841000 states. Time since last report: 0.13s, Total elapsed time: 75.87s.
# Searched 842000 states. Time since last report: 0.10s, Total elapsed time: 75.97s.
# Searched 843000 states. Time since last report: 0.11s, Total elapsed time: 76.08s.
# Searched 844000 states. Time since last report: 0.09s, Total elapsed time: 76.17s.
# Searched 845000 states. Time since last report: 0.09s, Total elapsed time: 76.26s.
# Searched 846000 states. Time since last report: 0.08s, Total elapsed time: 76.33s.
# Searched 847000 states. Time since last report: 0.06s, Total elapsed time: 76.39s.
# Searched 848000 states. Time since last report: 0.08s, Total elapsed time: 76.47s.
# Searched 849000 states. Time since last report: 0.46s, Total elapsed time: 76.93s.
# Searched 850000 states. Time since last report: 0.07s, Total elapsed time: 77.00s.
# Searched 851000 states. Time since last report: 0.07s, Total elapsed time: 77.07s.
# Searched 852000 states. Time since last report: 0.07s, Total elapsed time: 77.14s.
# Searched 853000 states. Time since last report: 0.05s, Total elapsed time: 77.19s.
# Searched 854000 states. Time since last report: 0.06s, Total elapsed time: 77.25s.
# Searched 855000 states. Time since last report: 0.08s, Total elapsed time: 77.33s.
# Searched 856000 states. Time since last report: 0.07s, Total elapsed time: 77.40s.
# Searched 857000 states. Time since last report: 0.10s, Total elapsed time: 77.50s.
# Searched 858000 states. Time since last report: 0.11s, Total elapsed time: 77.61s.
# Searched 859000 states. Time since last report: 0.87s, Total elapsed time: 78.48s.
# Searched 860000 states. Time since last report: 0.11s, Total elapsed time: 78.60s.
# Searched 861000 states. Time since last report: 0.13s, Total elapsed time: 78.73s.
# Searched 862000 states. Time since last report: 0.12s, Total elapsed time: 78.85s.
# Searched 863000 states. Time since last report: 0.10s, Total elapsed time: 78.95s.
# Searched 864000 states. Time since last report: 0.10s, Total elapsed time: 79.05s.
# Searched 865000 states. Time since last report: 0.08s, Total elapsed time: 79.13s.
# Searched 866000 states. Time since last report: 0.09s, Total elapsed time: 79.21s.
# Searched 867000 states. Time since last report: 0.06s, Total elapsed time: 79.27s.
# Searched 868000 states. Time since last report: 0.06s, Total elapsed time: 79.33s.
# Searched 869000 states. Time since last report: 0.45s, Total elapsed time: 79.78s.
# Searched 870000 states. Time since last report: 0.10s, Total elapsed time: 79.88s.
# Searched 871000 states. Time since last report: 0.09s, Total elapsed time: 79.97s.
# Searched 872000 states. Time since last report: 0.10s, Total elapsed time: 80.06s.
# Searched 873000 states. Time since last report: 0.14s, Total elapsed time: 80.21s.
# Searched 874000 states. Time since last report: 0.09s, Total elapsed time: 80.30s.
# Searched 875000 states. Time since last report: 0.10s, Total elapsed time: 80.40s.
# Searched 876000 states. Time since last report: 0.09s, Total elapsed time: 80.49s.
# Searched 877000 states. Time since last report: 0.09s, Total elapsed time: 80.58s.
# Searched 878000 states. Time since last report: 0.08s, Total elapsed time: 80.65s.
# Searched 879000 states. Time since last report: 0.07s, Total elapsed time: 80.72s.
# Searched 880000 states. Time since last report: 0.48s, Total elapsed time: 81.20s.
# Searched 881000 states. Time since last report: 0.07s, Total elapsed time: 81.27s.
# Searched 882000 states. Time since last report: 0.06s, Total elapsed time: 81.33s.
# Searched 883000 states. Time since last report: 0.09s, Total elapsed time: 81.42s.
# Searched 884000 states. Time since last report: 0.04s, Total elapsed time: 81.46s.
# Searched 885000 states. Time since last report: 0.05s, Total elapsed time: 81.51s.
# Searched 886000 states. Time since last report: 0.09s, Total elapsed time: 81.60s.
# Searched 887000 states. Time since last report: 0.10s, Total elapsed time: 81.70s.
# Searched 888000 states. Time since last report: 0.11s, Total elapsed time: 81.81s.
# Searched 889000 states. Time since last report: 0.11s, Total elapsed time: 81.91s.
# Searched 890000 states. Time since last report: 0.07s, Total elapsed time: 81.98s.
# Searched 891000 states. Time since last report: 0.55s, Total elapsed time: 82.53s.
# Searched 892000 states. Time since last report: 0.15s, Total elapsed time: 82.68s.
# Searched 893000 states. Time since last report: 0.12s, Total elapsed time: 82.80s.
# Searched 894000 states. Time since last report: 0.14s, Total elapsed time: 82.93s.
# Searched 895000 states. Time since last report: 0.11s, Total elapsed time: 83.04s.
# Searched 896000 states. Time since last report: 0.08s, Total elapsed time: 83.12s.
# Searched 897000 states. Time since last report: 0.07s, Total elapsed time: 83.19s.
# Searched 898000 states. Time since last report: 0.08s, Total elapsed time: 83.27s.
# Searched 899000 states. Time since last report: 0.09s, Total elapsed time: 83.35s.
# Searched 900000 states. Time since last report: 0.56s, Total elapsed time: 83.92s.
# Searched 901000 states. Time since last report: 0.18s, Total elapsed time: 84.10s.
# Searched 902000 states. Time since last report: 0.22s, Total elapsed time: 84.31s.
# Searched 903000 states. Time since last report: 0.15s, Total elapsed time: 84.46s.
# Searched 904000 states. Time since last report: 0.09s, Total elapsed time: 84.54s.
# Searched 905000 states. Time since last report: 0.10s, Total elapsed time: 84.64s.
# Searched 906000 states. Time since last report: 0.09s, Total elapsed time: 84.74s.
# Searched 907000 states. Time since last report: 0.08s, Total elapsed time: 84.82s.
# Searched 908000 states. Time since last report: 0.17s, Total elapsed time: 84.99s.
# Searched 909000 states. Time since last report: 0.09s, Total elapsed time: 85.08s.
# Searched 910000 states. Time since last report: 0.11s, Total elapsed time: 85.18s.
# Searched 911000 states. Time since last report: 0.44s, Total elapsed time: 85.63s.
# Searched 912000 states. Time since last report: 0.08s, Total elapsed time: 85.70s.
# Searched 913000 states. Time since last report: 0.05s, Total elapsed time: 85.75s.
# Searched 914000 states. Time since last report: 0.05s, Total elapsed time: 85.80s.
# Searched 915000 states. Time since last report: 0.05s, Total elapsed time: 85.84s.
# Searched 916000 states. Time since last report: 0.06s, Total elapsed time: 85.90s.
# Searched 917000 states. Time since last report: 0.08s, Total elapsed time: 85.98s.
# Searched 918000 states. Time since last report: 0.11s, Total elapsed time: 86.09s.
# Searched 919000 states. Time since last report: 0.10s, Total elapsed time: 86.19s.
# Searched 920000 states. Time since last report: 0.08s, Total elapsed time: 86.27s.
# Searched 921000 states. Time since last report: 0.10s, Total elapsed time: 86.37s.
# Searched 922000 states. Time since last report: 0.45s, Total elapsed time: 86.82s.
# Searched 923000 states. Time since last report: 0.08s, Total elapsed time: 86.90s.
# Searched 924000 states. Time since last report: 0.07s, Total elapsed time: 86.97s.
# Searched 925000 states. Time since last report: 0.06s, Total elapsed time: 87.03s.
# Searched 926000 states. Time since last report: 0.07s, Total elapsed time: 87.09s.
# Searched 927000 states. Time since last report: 0.07s, Total elapsed time: 87.16s.
# Searched 928000 states. Time since last report: 0.05s, Total elapsed time: 87.22s.
# Searched 929000 states. Time since last report: 0.05s, Total elapsed time: 87.26s.
# Searched 930000 states. Time since last report: 0.03s, Total elapsed time: 87.30s.
# Searched 931000 states. Time since last report: 0.07s, Total elapsed time: 87.36s.
# Searched 932000 states. Time since last report: 0.47s, Total elapsed time: 87.84s.
# Searched 933000 states. Time since last report: 0.10s, Total elapsed time: 87.94s.
# Searched 934000 states. Time since last report: 0.13s, Total elapsed time: 88.07s.
# Searched 935000 states. Time since last report: 0.11s, Total elapsed time: 88.18s.
# Searched 936000 states. Time since last report: 0.07s, Total elapsed time: 88.25s.
# Searched 937000 states. Time since last report: 0.08s, Total elapsed time: 88.34s.
# Searched 938000 states. Time since last report: 0.09s, Total elapsed time: 88.42s.
# Searched 939000 states. Time since last report: 0.08s, Total elapsed time: 88.51s.
# Searched 940000 states. Time since last report: 0.08s, Total elapsed time: 88.59s.
# Searched 941000 states. Time since last report: 0.06s, Total elapsed time: 88.65s.
# Searched 942000 states. Time since last report: 0.07s, Total elapsed time: 88.72s.
# Searched 943000 states. Time since last report: 0.54s, Total elapsed time: 89.26s.
# Searched 944000 states. Time since last report: 0.06s, Total elapsed time: 89.32s.
# Searched 945000 states. Time since last report: 0.05s, Total elapsed time: 89.37s.
# Searched 946000 states. Time since last report: 0.07s, Total elapsed time: 89.44s.
# Searched 947000 states. Time since last report: 0.15s, Total elapsed time: 89.59s.
# Searched 948000 states. Time since last report: 0.16s, Total elapsed time: 89.75s.
# Searched 949000 states. Time since last report: 0.08s, Total elapsed time: 89.83s.
# Searched 950000 states. Time since last report: 0.11s, Total elapsed time: 89.94s.
# Searched 951000 states. Time since last report: 0.09s, Total elapsed time: 90.03s.
# Searched 952000 states. Time since last report: 0.09s, Total elapsed time: 90.12s.
# Searched 953000 states. Time since last report: 0.10s, Total elapsed time: 90.22s.
# Searched 954000 states. Time since last report: 0.58s, Total elapsed time: 90.80s.
# Searched 955000 states. Time since last report: 0.07s, Total elapsed time: 90.87s.
# Searched 956000 states. Time since last report: 0.07s, Total elapsed time: 90.94s.
# Searched 957000 states. Time since last report: 0.06s, Total elapsed time: 91.00s.
# Searched 958000 states. Time since last report: 0.05s, Total elapsed time: 91.04s.
# Searched 959000 states. Time since last report: 0.06s, Total elapsed time: 91.11s.
# Minimal steps required: 213
